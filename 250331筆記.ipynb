# %% [markdown]
# ### 📢【[K線捕手](https://www.facebook.com/kevinyang20180801/posts/pfbid0zffCukc6vAxF6HzNUr6giFU4uryvZZGW5ME28GE1j5cizg1E3LhfMPoewYp98y5Kl)盤前快訊】周五夜盤暴跌，恐有補跌壓力！⚠️
# 📉 受到歐美股市上週五晚間重挫影響，台指期夜盤也大跌458點！許多投資朋友紛紛敲碗，為了讓大家提早掌握趨勢，我們提前進行解盤教學。
# 🚨 早在先前我們多次強調，極度量縮盤整後，一旦趨勢明朗，行情將快速發展。不論上攻或下跌，變化都會加速，然而根據綜合條件分析，往下修正的機率較高。
# 🔎 上週四台股走弱，下跌308點；經歷13天低量盤整後，週五再跌348點，並跌破關鍵支撐位。依照週五夜盤表現，明日開盤恐將出現超過400點以上的補跌壓力。
# 📊 雖然空方壓力仍在，但透過前低支撐、頭部跌幅滿足、黃金分割率等指標來觀察，連續急跌之後，上半周有機會出現止穩跡象。
# ✅ 投資建議：
# 👉 空手或持股比重低的投資人：不必急著搶短線，耐心等待止跌訊號出現。
# 👉 做空的投資人：若行情來到複合式支撐區，切勿過度追空，應適時回補，落袋為安。
# 📈 本週「K線追擊周報」數位訂閱將深入解析國際股市、匯率、加權指數、櫃買指數，並結合技術面與籌碼面，規劃關鍵支撐位置與反彈條件。
# 🔥 重點關注：
# 🔹 第一階段跌幅滿足與支撐區到位後，該如何精準選股？
# 🔹 第一波下跌後，多方轉強的關鍵信號是什麼？
# 🔹有沒有可能出現第二波跌勢？
# 📢 完整深度解析，請見「K線追擊周報」數位訂閱！
# 📢 歡迎分享，請註明出處：K線捕手 楊忠憲粉絲團 🔥

# %% [markdown]
# 完整內容請看K線追擊週報數位訂閱~
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3107&fbclid=IwY2xjawJV6-VleHRuA2FlbQIxMAABHVhQPNzfmjh8ow0knysXU0zIJuD3Y94PVZbLCYDq-Z3skvhSEHOiNUm1Fg_aem_6gKpHjsUrVwAeWaiBE7BQg

# %% [markdown]
# ### [K線捕手](https://www.facebook.com/kevinyang20180801/)

# %% [markdown]
# [對等關稅本周揭曉 台股能守21K或20K？專家點出反彈5條件](https://www.ctee.com.tw/news/20250331700032-430201?fbclid=IwY2xjawJW079leHRuA2FlbQIxMAABHXUr6zPnPQXcu2RC0o-fCjzxit4TKoqU9NUF81iVdDWTs69uxxM07J2uPg_aem_zFry_os8wpn_r_nXCGC_Pw)
# 全球關注的4月2日對等關稅課徵將於本周揭曉，關稅政策外，美國還面臨PCE通膨升溫、富人稅可能提高等影響，美股已先行於上周五重挫，台指期夜盤大跌458點或2.12％收21,141點，台積電ADR也創半年新低價。法人表示，台股本周清明節連假僅三個交易日，31日將面臨21,000點保衛戰。
#
# [外資雙策略 台股續觀望 對等關稅公布後震盪區間落在這](https://www.ctee.com.tw/news/20250331700035-430201?fbclid=IwY2xjawJW0-5leHRuA2FlbQIxMAABHba_0GOdRoXF6qGMitVKj8s2n1BxfWKr5fG7b_5V3VUtMcKomB-ogIo6cw_aem_J9x4-RlXyZzXHdrIjBc7Dg)
# 台股本周逢清明連假僅三個交易日，加上美國總統川普預計4月2日拋出對等關稅，外資定調「一動不如一靜」、「一進不如一出」雙重策略。外資分析師說，若無突發情況，本周三個交易日成交量可能持續低迷，外資研究機構過去一周來很少出研究報告的「清淡」狀態，也將延續。
#
# [聯強等15檔4月漲率高 法人周買超前三名金融股全包](https://www.ctee.com.tw/news/20250331700186-430201?fbclid=IwY2xjawJW1CJleHRuA2FlbQIxMAABHdbPYlNuxWsL8fnuSWpNYdDQWzr_fIB0wvwdzmP1yKNIglexOtvt1zQpKw_aem_l8vtWv1vOQC1iCegNeDNag)
# 「川普2.0」嚇壞市場，4月2日對等關稅政策投資人屏息以待，專家指出，台股28日恐慌性下殺、短線賣壓已大致宣洩完畢，惟美國啟動貿易戰後，匯率戰、科技戰考驗仍在，各國祭出的報復措施亦不容忽視，台股短線反彈後仍有回檔風險，中信金（2891）、彰銀（2801）、聯強（2347）等15檔4月漲率高、本益比低於大盤、法人單周加碼股，有望逆勢突圍。
#
# [川普加稅喊玩更大一點 希望讓美國經濟「脫胎換骨」](https://money.udn.com/money/story/5599/8642642?fbclid=IwY2xjawJW1ExleHRuA2FlbQIxMAABHXUr6zPnPQXcu2RC0o-fCjzxit4TKoqU9NUF81iVdDWTs69uxxM07J2uPg_aem_zFry_os8wpn_r_nXCGC_Pw)
# 美國本周關稅措施將多箭齊發，包括將公布對等關稅細節，開徵加墨商品進口關稅和對委內瑞拉石油買家課徵「二級關稅」、以及加徵汽車關稅，但美國總統川普似乎覺得還不夠，傳敦促高階顧問「玩更大一點」，認為開徵關稅是讓美國經濟轉型的難得機會。
#
# [北美線海運長約價 年度談判進入最後關頭 看漲兩成](https://www.facebook.com/kevinyang20180801/posts/pfbid0gzisHiREAhNASDthgjRk72dYDJhMrdpSrsbJRzdivssMc8i4Kef9oukrRsBg18Mel)
# 全球貨櫃海運北美線的年度合約談判進入最後階段，近日傳出美國大型零售商正在簽署2025-2026年度北美線服務合約，價格比去年高出上看20%；4月開始進入第二輪的中型進口商及物流業的價格談判，年增幅則從兩成起跳。

# %% [markdown]
# 日本續創波段新低，有第二層頭部雛形：
# ![messageImage_1743380938011.jpg](attachment:97716d36-9b12-4d47-bc2c-2001f52333e9.jpg)
#
# 這個試撮盤，有點誇張：
# ![messageImage_1743381160092.jpg](attachment:ef12ea37-aea7-418f-9191-79ed059b9e12.jpg)
#
# 期貨開低下跌不意外，只是這個跌點還是比預期大上許多：
# ![messageImage_1743381923842.jpg](attachment:ab9920c3-49f8-4f17-b118-8b4ae04dd00d.jpg)
# 直接測試前低支撐。
#
# 加權指數一樣開低大跌，測試前低支撐：
# ![messageImage_1743382896105.jpg](attachment:565e8d7c-38bc-4f2f-85a5-00c7dd6b5087.jpg)
#
# 負乖離來到5.31%：
# ![messageImage_1743383168422.jpg](attachment:6010102b-1146-4bd9-8d84-f7360c3c6c58.jpg)
#
# 櫃買指數負乖離6.16%，有長天期頭部雛形：
# ![messageImage_1743383244791.jpg](attachment:92cee89d-b364-4ee5-8e54-7cdb71886574.jpg)
#
# 怕晚上說來不及，先簡單說，做多的不要急著搶，但有做空的投資人可以部份回補獲利了結。
#
# 如果你是做多一路凹單到現在，都沒減碼，就先不要動了，等一下反彈，但也不要再加碼。

# %% [markdown]
# 台幣貶破中期支撐、鴻海做頭續跌、金融保險類股指數跌破上升楔形：
# ![messageImage_1743383934431.jpg](attachment:1dc77d2e-2f00-40c6-8668-2a95dbeeda81.jpg)
# ![messageImage_1743383960904.jpg](attachment:c9360fd1-bd9d-4ae5-96d2-d6deed1d5b89.jpg)
# ![messageImage_1743384018912.jpg](attachment:0696183f-882e-45f6-a73b-0cbcea737c32.jpg)

# %% [markdown]
# 元大台灣50反1(00632R)
# ![messageImage_1743383976182.jpg](attachment:cb765800-fe52-47ce-8b21-79cedd47a4fa.jpg)
#
# 期元大S&P黃金正2(00708L)
# ![messageImage_1743384010327.jpg](attachment:745be3e6-3208-45e2-83e9-a60fa7f4d9f7.jpg)
#
# 國泰美國道瓊反1(00669R)
# ![messageImage_1743384118357.jpg](attachment:dec66c99-1ff1-4ee7-9438-dfdc14f00e8a.jpg)

# %% [markdown]
# 📈 本週「K線追擊周報」數位訂閱將深入解析國際股市、匯率、加權指數、櫃買指數，並結合技術面與籌碼面，規劃關鍵支撐位置與反彈條件。
#
# 🔥 重點關注：
# 🔹 第一階段跌幅滿足與支撐區到位後，該如何精準選股？
# 🔹 第一波下跌後，多方轉強的關鍵信號是什麼？
# 🔹有沒有可能出現第二波跌勢？
# https://www.facebook.com/kevinyang20180801/posts/pfbid0zffCukc6vAxF6HzNUr6giFU4uryvZZGW5ME28GE1j5cizg1E3LhfMPoewYp98y5Kl

# %% [markdown]
# 其實盤勢會不會續跌，多頭跟空頭的邏輯是相通的，多頭要續漲，就要看有沒有可用之兵，比如盤整但籌碼好的，或是剛剛打底完成的多方潛力股…，這樣整體續航力才會增加。
# 反過來空頭就要看有沒有空方的伏兵，即將起跌或是頭部已經很明確的，這樣就會很清楚未來續跌機率高不高？今天負乖離過大，究竟是終點站還是中繼站？
# 今晚數位訂閱會針對這部份深入檢視~

# %% [markdown]
# [當海面風平浪靜時](https://www.facebook.com/kevinyang20180801/posts/pfbid0oViWAZQLjjukKKjxQwCqXLajfZn8db6WX5WTrhijiknq9KjU6JgXJyR3KvFdjMEQl)，沒有人會特別關注氣象預報，因為即使不加理會，依然能夠順利出海、滿載而歸。然而，當暴風雨突如其來，才會驚覺天氣預測的重要性。
# 投資亦然——在多頭市場時，技術分析似乎可有可無，但當空頭來襲，投資人才會急於尋找解方。然而，如果平時沒有累積足夠的知識，缺乏對技術分析、投資心法與策略的理解，那麼等到市場風暴席捲而來，往往已經來不及應對。
# 但別擔心，這次你或許還沒跟上沒關係，因為股市每天都在運行。只要掌握正確的方法，調整觀念並持續學習，你將永遠擁有機會，在市場中穩健前行。

# %% [markdown]
# ![717411.jpg](attachment:c8e50515-6bdb-4d4f-9988-71569409ad5f.jpg)
# ![717480.jpg](attachment:eb13ac1e-1785-4965-84e0-5a7f4141a0f7.jpg)

# %% [markdown]
# **今日影音已上架💫**
# 台股狂瀉906點！空頭中繼站還是終點？多空投資人怎麼應對？
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3111

# %% [markdown]
# ### 本日進度
# * 這邊的「[股票投資筆記](https://github.com/yilintung/StockInvestmentNotebook)」主要是記載[股票老師](https://www.facebook.com/kevinyang20180801/)的資訊為主，之後開發的「量化技術分析」將會運用於在新的筆記系統中。
#   - 系統開發過渡時期仍會維持此處的「股票投資筆記」內容更新。
#   - 記錄「[K線追擊週報](https://smart.businessweekly.com.tw/e-subscription/channel?c=GROUP00014146)」影片連結於此筆記中。
#   - 因應[Windows 10於2025年10月14日停止支援](https://www.sogi.com.tw/articles/how-to-windows/6264412)，新的筆記系統將只運作於Windows 11上。
# * 量化技術分析系統
#   - 下個月（2025年4月）開始將進行「量化技術分析系統」的重新規劃。
#   - 之前開發的StockChartPatterns類別，近期會用其來進行系統規劃之參照。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
##### 使用2024年7月31日到今日(2025年3月31日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250331.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
neckline_start_date  = '2024-09-13'
neckline_end_date    = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_x           = [date_to_index(df_k_line,'2024-09-20'),date_to_index(df_k_line,'2024-11-28'),date_to_index(df_k_line,'2025-03-10')]
neckline_y           = [df_k_line.loc['2024-09-20']['Close'],df_k_line.loc['2024-11-28']['Close'],df_k_line.loc['2025-03-10']['Close']]
slope,intercept      = np.polyfit(neckline_x,neckline_y,1)
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_price   = slope * date_to_index(df_k_line,neckline_end_date) + intercept

# 設定狹幅盤整區間
line1_start_date = '2025-03-11'
line1_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
line1_price      = df_k_line.loc['2025-03-13']['Open']
line2_start_date = line1_start_date
line2_end_date   = line1_end_date
line2_price      = df_k_line.loc['2025-03-19']['Close']

seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(line1_start_date,line1_price),(line1_end_date,line1_price)],
    [(line2_start_date,line2_price),(line2_end_date,line2_price)]
]

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.5,1.0,1.0), colors=('xkcd:red','xkcd:bright blue','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 3         2024-08-05  19830.88   LO
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# 112       2025-01-13  22488.33   LO
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 3         2024-08-05  19830.88   LO
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# 112       2025-01-13  22488.33   LO
# 134       2025-02-21  23730.25   HI

# %%
# 進行型態識別(GPT版)
result = chart_pattern.RecognitionUsingGPT()
print(result)
# Out:
# 在這張K線圖中，可以觀察到以下價格型態：
#
# 1. **上升趨勢**：從2024年7月底到2024年10月初，價格呈現上升趨勢。
#
# 2. **頭肩頂**：在2024年10月到2025年1月期間，價格形成一個頭肩頂型態，顯示可能的趨勢反轉。
#
# 3. **下降趨勢**：從2025年1月開始，價格開始下跌，並在2025年3月加速下跌。
#
# 近期型態的狀況：
#
# - **急速下跌**：在2025年3月，價格出現急速下跌，形成一個明顯的下降趨勢，顯示出強烈的賣壓。這可能是由於市場情緒的轉變或外部因素的影響。投資者應該謹慎觀察，尋找可能的支撐位或反彈信號。

# %%
import os
import io
import base64

from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
api_key = os.environ.get('OPENAI_API_KEY_TOKEN')
client = OpenAI(api_key = api_key)

# %%
from PIL import Image

def get_first_last(mask, axis: int):
    """ Find the first and last index of non-zero values along an axis in `mask` """
    mask_axis = np.argmax(mask, axis=axis) > 0
    a = np.argmax(mask_axis)
    b = len(mask_axis) - np.argmax(mask_axis[::-1])
    return int(a), int(b)

def crop_borders(img, crop_color):
    np_img = np.array(img)
    mask = (np_img != crop_color)[..., 0]  # compute a mask
    x0, x1 = get_first_last(mask, 0)       # find boundaries along x axis
    y0, y1 = get_first_last(mask, 1)       # find boundaries along y axis
    return img.crop((x0, y0, x1, y1))

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 繪製K線圖
img = io.BytesIO()
kwargs = dict(type='candle', style=s, figratio=(16,9), volume=True, savefig=dict(fname=img,format='png'))
mpf.plot(df_k_line,**kwargs)

# 刪除空白
image    = Image.open(img).convert("RGB")
image    = crop_borders(image, crop_color=(255, 255, 255))
crop_img = io.BytesIO()
image.save(crop_img,format='PNG')
display(image)

# 將影像檔(PNG)編碼為Base64
base64_image = base64.b64encode(crop_img.getvalue()).decode()
# Out:
# <PIL.Image.Image image mode=RGB size=808x487>

# %%
# 嘗試讓GPT-4o識別結果量化
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "您是一位股票技術分析師，可以從K線圖識別出價格型態"},
        {"role": "user", "content": [
                {"type": "text", "text": "請識別以下K線圖中有哪些價格型態，並使用JSON格式輸出型態的類型與起訖區間。"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#     {
#         "type": "Head and Shoulders",
#         "start": "2024-Sep-26",
#         "end": "2025-Mar-04"
#     },
#     {
#         "type": "Double Top",
#         "start": "2024-Oct-29",
#         "end": "2025-Feb-03"
#     }
# ]
# ```

# %%
import json

# 將GPT-4o的JSON輸出轉換為Python類型
json_start      = False
json_start_char = ''
resp_json_str   = '' 
for char in response.choices[0].message.content :
    if json_start is False :
        if char == '[' or char == '{' :
            json_start_char = char
            json_start      = True
            resp_json_str  += char
    else :
        resp_json_str += char
        if json_start_char == '[' and char == ']' :
            json_start = False
        if json_start_char == '{' and char == '}' :
            json_start = False
response_patterns = json.loads(resp_json_str)
print(response_patterns)
# Out:
# [{'type': 'Head and Shoulders', 'start': '2024-Sep-26', 'end': '2025-Mar-04'}, {'type': 'Double Top', 'start': '2024-Oct-29', 'end': '2025-Feb-03'}]

# %%
from datetime import datetime

for pattern in response_patterns :
    print('型態類型 ＝ {}'.format(pattern['type']))
    # 利用自動趨勢線繪製頸線
    pattern_start_index  = date_to_index(df_k_line,datetime.strptime(pattern['start'],'%Y-%b-%d'))
    pattern_end_index    = date_to_index(df_k_line,datetime.strptime(pattern['start'],'%Y-%b-%d'))
    range_price          = df_k_line[datetime.strptime(pattern['start'],'%Y-%b-%d'):datetime.strptime(pattern['end'],'%Y-%b-%d')]
    chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
    params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
    seq_of_seq_of_points = lines[0]
    # 設定K線格式
    mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
    s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
    # 繪製K線圖
    kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
    mpf.plot(df_k_line,**kwargs)
# Out:
# 型態類型 ＝ Head and Shoulders
# 型態類型 ＝ Double Top
