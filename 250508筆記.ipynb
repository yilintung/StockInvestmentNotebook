# 「你最近有這種感覺嗎？打開看盤軟體沒興趣，聽到財經新聞想轉台，連平常最愛追的個股也懶得看了⋯⋯你可能正在經歷投資倦怠。」
# 🧠 認知一：你是因為無聊，還是因為焦慮？
# 無聊常發生在盤整盤、沒劇情時。焦慮則可能來自前幾波虧損未恢復，或期待過高。寫下你最近幾次下單前的心情，是出於興趣還是壓力？
# 🧠 認知二：你是在操作市場，還是被市場牽著走？
# 若發現自己「只是因為別人都在買才進場」、「怕錯過」才硬看盤，代表已經失去主動權。回顧近三次交易，你有明確進出場依據嗎？
# 🧠 認知三：投資是否正在吞噬你的生活平衡？
# 當投資變成壓力源，可能已不再是幫你創造自由的工具。這一週你花在看盤的時間，是否遠超過其他生活面向（如工作、家庭、興趣）？
# 🧠 認知四：你多久沒「學習新東西」了？
# 倦怠常來自停滯，學習是打破單調與懷疑的最好方式。挑一個跟選股或交易有關，但不同面向的主題，如個人財富管理、資產配置、風險管理、商品組合。
# 🧠 認知五：你還記得為什麼一開始要投資嗎？
# 初衷能幫助你重新定位與定調。你是為了財富自由、生活品質、還是單純興趣？現階段的策略與當初目標一致嗎？
# 🎁 盤整盤，是重新整頓心態與技術的好時機。
# 若有倦怠，不一定是壞事，可能代表你需要調整策略、換個節奏，甚至暫時離開也無妨。有多久沒檢視你的投資初衷，你的投資初衷是甚麼？

# %% [markdown]
# ![768865.jpg](attachment:c49ec2d4-e724-40ed-9dc7-3448c4567a9e.jpg)
# ![768866.jpg](attachment:50f579fd-7e20-4c92-a70f-f2116686e3a1.jpg)

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統：規劃與開發
#   - 建立技術分析資料庫
#     * 預先下載股票資訊與2019年12月30日至2025年5月6日之日Ｋ、周Ｋ與月Ｋ資料。
#     * 更新這兩日的價格資料到資料庫中。

# %%
import os
import sys
import pandas as pd
import datetime
import sqlite3
import requests
import time

from dotenv import load_dotenv, find_dotenv
from FinMind.data import DataLoader

# %%
### 測試：讀取SQLite資料庫 ###

# 開啟資料庫
conn = sqlite3.connect('data/stock.db')

# %%
# 確認指定日期是否存在於資料庫中？ #

cursor = conn.cursor()

# 若回傳為None，則代表該日期並不存在於資料庫中
cursor.execute("SELECT * FROM DailyPrice WHERE Date='2025-05-04'")
db_result=cursor.fetchone()
print(db_result is None)
# Out:
# True

# %%
# 確認指定日期是否存在於資料庫中？ #

#若回傳不是None，則代表該日期並存在於資料庫中
cursor.execute("SELECT * FROM DailyPrice WHERE Date='2025-05-06'")
db_result=cursor.fetchone()
print(db_result is None)
# Out:
# False

# %%
# 依"日期"讀取資料 #

# Pandas讀取資料庫，若該日期資料不存在於資料庫時則回傳「空」的DataFrame
price_db_df = pd.read_sql_query("SELECT * FROM DailyPrice WHERE Date='2025-05-04'", conn)
print('是否為空的DataFrame？ {}'.format('是' if price_db_df.empty is True else '否'))
# Out:
# 是否為空的DataFrame？ 是

# %%
# 依"日期"讀取資料 #

# Pandas讀取資料庫，若該日期資料存在於資料庫時則回傳DataFrame
price_db_df = pd.read_sql_query("SELECT * FROM DailyPrice WHERE Date='2025-05-06'", conn)
display(price_db_df)

# 從該日期的資料中找出對應股票代號(在此是加權指數)的資料
display(price_db_df[price_db_df['StockID'] == 'TAIEX'])
# Out:
#       SerialNo                StockID        Date      Open      High  \
# 0      3038695                   0050  2025-05-06    169.95    172.10
# 1      3038696                   0051  2025-05-06     69.45     70.20
# 2      3038697                   0052  2025-05-06    162.55    164.65
# 3      3038698                   0053  2025-05-06     89.65     90.80
# 4      3038699                   0055  2025-05-06     26.40     26.88
# ...        ...                    ...         ...       ...       ...
# 2623   3041318                  TAIEX  2025-05-06  20353.88  20623.85
# 2624   3041319                   TPEx  2025-05-06    219.25    221.81
# 2625   3041320               Textiles  2025-05-06    542.02    544.07
# 2626   3041321                Tourism  2025-05-06    116.27    118.44
# 2627   3041322  TradingConsumersGoods  2025-05-06    262.04    264.75
#
#            Low     Close      Volume         Value
# 0       169.35    171.00    29982445    5126154837
# ...

# %%
# 依"股票代碼"(在此是台積電)讀取區間日期資料 #

price_db_df = pd.read_sql("SELECT * FROM DailyPrice WHERE StockID='2330' AND (Date BETWEEN '2025-01-02' AND '2025-05-06')", conn)
display(price_db_df)
# Out:
#     SerialNo StockID        Date    Open    High     Low   Close    Volume  \
# 0    2837890    2330  2025-01-02  1070.0  1075.0  1055.0  1065.0  45045125
# 1    2840487    2330  2025-01-03  1080.0  1085.0  1075.0  1075.0  31244211
# 2    2843085    2330  2025-01-06  1100.0  1125.0  1095.0  1125.0  77874801
# 3    2845685    2330  2025-01-07  1150.0  1160.0  1130.0  1130.0  54691485
# 4    2848285    2330  2025-01-08  1110.0  1130.0  1105.0  1105.0  49181518
# ..       ...     ...         ...     ...     ...     ...     ...       ...
# 73   3028846    2330  2025-04-29   897.0   902.0   893.0   902.0  31146996
# 74   3031471    2330  2025-04-30   901.0   908.0   899.0   908.0  39204833
# 75   3034097    2330  2025-05-02   938.0   950.0   932.0   950.0  48129292
# 76   3036724    2330  2025-05-05   956.0   957.0   923.0   938.0  56516129
# 77   3039352    2330  2025-05-06   916.0   930.0   916.0   920.0  43358708
#
#           Value
# 0   47883206644
# 1   33728652860
# ...

# %%
# 關閉資料庫
conn.close()

# %%
### 更新：近期資料 ###

# API 使用次數
def api_usage() :
    url = "https://api.web.finmindtrade.com/v2/user_info"
    payload = {
        "token": token,
    }
    resp = requests.get(url, params=payload)
    return resp.json()["user_count"],resp.json()["api_request_limit"]

# python 取得時間範圍內日期列表
# 來源：https://www.cnblogs.com/xiao-xue-di/p/11900649.html
def date_range(beginDate, endDate):
    dates = []
    dt = datetime.datetime.strptime(beginDate, "%Y-%m-%d")
    date = beginDate[:]
    while date <= endDate:
        dates.append(date)
        dt = dt + datetime.timedelta(1)
        date = dt.strftime("%Y-%m-%d")
    return dates

# 取得範圍日期列表(2025年5月7日至2025年5月8日)
price_date_list = date_range('2025-05-07', '2025-05-08')

# %%
# 設定FinMind API
load_dotenv(find_dotenv())
token = os.environ.get('FINMIND_TOKEN')
api = DataLoader()
api.login_by_token(api_token=token)

# %%
# 連線資料庫
conn = sqlite3.connect('data/stock.db')
cursor = conn.cursor()

# %%
# 確認外鍵支持
conn.execute('PRAGMA foreign_keys = ON;')

res = conn.execute('PRAGMA foreign_keys;')
res.fetchone()
# Out:
# (1,)

# %%
# 從資料庫中載入「台股總覽 TaiwanStockInfo」
df_stock_info = pd.read_sql("SELECT * FROM StockInfo", conn)
display(df_stock_info)
# Out:
#                     StockID StockName IndustryCategory  Type
# 0                      0050    元大台灣50              ETF  twse
# 1                      0051   元大中型100              ETF  twse
# 2                      0052      富邦科技              ETF  twse
# 3                      0053      元大電子              ETF  twse
# 4                      0054    元大台商50              ETF  twse
# ...                     ...       ...              ...   ...
# 2934                  TAIEX      加權指數               大盤  twse
# 2935               Textiles   紡織纖維類指數            Index  twse
# 2936                Tourism   觀光事業類指數            Index  twse
# 2937                   TPEx      櫃買指數               大盤  tpex
# 2938  TradingConsumersGoods   貿易百貨類指數            Index  twse
#
# [2939 rows x 4 columns]

# %%
# 更新資料庫
sql_cmd     = "SELECT * FROM DailyPrice WHERE (Date BETWEEN '{}' AND '{}')".format(price_date_list[0],price_date_list[-1])
price_db_df = pd.read_sql(sql_cmd, conn)
if price_db_df.empty is True :
    for price_date in price_date_list :
        # API 使用次數 #
        user_count,api_request_limit = api_usage()
        if user_count > (api_request_limit - 100) :
            print('抓取資料速度過快（user_count＝ {} ，api_request_limit ＝ {}），等三十分鐘後再行抓取'.format(user_count,api_request_limit))
            time.sleep(30*60)
        
        # 股價日成交資訊 TaiwanStockPrice：一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
        while True :
            try :
                df = api.taiwan_stock_daily(start_date=price_date,)
            except Exception as e:
                print('日K：日期{}發生錯誤{}，重試'.format(price_date,e))
                continue
            break
        if df.empty is not True :
            print('日K：{}'.format(price_date))
            df_daily_price = df.drop(columns=['spread','Trading_turnover'])
            df_daily_price = df_daily_price.rename(columns={'date':'Date','stock_id':'StockID','Trading_Volume':'Volume','Trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_daily_price = df_daily_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_daily_price = df_daily_price[df_daily_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_daily_price.to_sql('DailyPrice', conn, if_exists='append', index=False)
        else :
            time.sleep(1)
        
        # 台股週 K 資料表 TaiwanStockWeekPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
        url = "https://api.finmindtrade.com/api/v4/data"
        parameter = {
            "dataset": "TaiwanStockWeekPrice",
            "start_date": price_date,
            "token": token,
        }
        while True :
            resp = requests.get(url, params=parameter)
            if resp.status_code == 200 :
                break
            else :
                print('周K：日期{}發生錯誤，回應狀態碼 ＝ {}'.format(price_date,resp.status_code))
                if resp.status_code == 402 :
                    print('周K：API 用量超出上限，等十分鐘後重試')
                    time.sleep(10*60)
        data = resp.json()
        df_weekly_price = pd.DataFrame(data["data"])
        if df_weekly_price.empty is not True :
            print('周K：{}'.format(price_date))
            df_weekly_price = df_weekly_price.drop(columns=['yweek','spread','trading_turnover'])
            df_weekly_price = df_weekly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_weekly_price = df_weekly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_weekly_price = df_weekly_price[df_weekly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_weekly_price.to_sql('WeeklyPrice', conn, if_exists='append', index=False)
        else :    
            time.sleep(1)
    
        # 台股月 K 資料表 TaiwanStockMonthPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
        url = "https://api.finmindtrade.com/api/v4/data"
        parameter = {
            "dataset": "TaiwanStockMonthPrice",
            "start_date": price_date,
            "token": token, 
        }
        while True :
            resp = requests.get(url, params=parameter)
            if resp.status_code == 200 :
                break
            else :
                print('月K：日期{}發生錯誤，回應狀態碼 ＝ {}'.format(price_date,resp.status_code))
                if resp.status_code == 402 :
                    print('月K：API 用量超出上限，等十分鐘後重試')
                    time.sleep(10*60)
        data = resp.json()
        df_monthly_price = pd.DataFrame(data["data"])
        if df_monthly_price.empty is not True :
            print('月K：{}'.format(price_date))
            df_monthly_price = df_monthly_price.drop(columns=['ymonth','spread','trading_turnover'])
            df_monthly_price = df_monthly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_monthly_price = df_monthly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_monthly_price = df_monthly_price[df_monthly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_monthly_price.to_sql('MonthlyPrice', conn, if_exists='append', index=False)
        else :    
            time.sleep(1)
# Out:
# 2025-05-08 20:00:49.307 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 日K：2025-05-07
# 2025-05-08 20:00:56.103 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 日K：2025-05-08

# %%
# 檢查資料庫是否更新
price_db_df = pd.read_sql(sql_cmd, conn)
display(price_db_df)
# Out:
#       SerialNo                StockID        Date      Open      High  \
# 0      3041323                   0050  2025-05-07    171.80    172.50
# 1      3041324                   0051  2025-05-07     70.00     70.00
# 2      3041325                   0052  2025-05-07    163.00    164.95
# 3      3041326                   0053  2025-05-07     90.20     90.20
# 4      3041327                   0055  2025-05-07     26.74     26.93
# ...        ...                    ...         ...       ...       ...
# 5250   3046573                  TAIEX  2025-05-08  20559.65  20747.28
# 5251   3046574                   TPEx  2025-05-08    219.82    223.03
# 5252   3046575               Textiles  2025-05-08    544.65    548.45
# 5253   3046576                Tourism  2025-05-08    116.02    117.72
# 5254   3046577  TradingConsumersGoods  2025-05-08    261.78    263.63
#
#            Low     Close      Volume         Value
# 0       169.95    170.35    13869395    2371470073
# ...

# %%
# 修改並關閉資料庫
conn.commit()
conn.close()
