# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 試作基於[AI Agent](https://en.wikipedia.org/wiki/AI_agent)技術之全AI解盤程序，規劃過程可參考與[ChatGPT之對話紀錄](https://chatgpt.com/share/69bb97e8-eee4-800c-9546-754d854ad424)。實作程式碼在筆記最後一項「技術開發」中，這部份仍是初期試作僅用於概念驗證。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-03-19 21:57:39.150 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-03-19 21:57:39.200 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-03-19 21:57:39.213 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1471：股票名稱 ＝ 首利，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1710：股票名稱 ＝ 東聯，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1711：股票名稱 ＝ 永光，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1720：股票名稱 ＝ 生達，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1731：股票名稱 ＝ 美吾華，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1752：股票名稱 ＝ 南光，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1760：股票名稱 ＝ 寶齡富錦，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1783：股票名稱 ＝ 和康生，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1786：股票名稱 ＝ 科妍，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2303：股票名稱 ＝ 聯電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2321：股票名稱 ＝ 東訊，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2331：股票名稱 ＝ 精英，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2344：股票名稱 ＝ 華邦電，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2345：股票名稱 ＝ 智邦，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2347：股票名稱 ＝ 聯強，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2353：股票名稱 ＝ 宏碁，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2354：股票名稱 ＝ 鴻準，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2355：股票名稱 ＝ 敬鵬，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2364：股票名稱 ＝ 倫飛，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2373：股票名稱 ＝ 震旦行，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2374：股票名稱 ＝ 佳能，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2381：股票名稱 ＝ 華宇，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2383：股票名稱 ＝ 台光電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2385：股票名稱 ＝ 群光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2393：股票名稱 ＝ 億光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2395：股票名稱 ＝ 研華，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2397：股票名稱 ＝ 友通，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2406：股票名稱 ＝ 國碩，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2408：股票名稱 ＝ 南亞科，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2417：股票名稱 ＝ 圓剛，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2426：股票名稱 ＝ 鼎元，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2427：股票名稱 ＝ 三商電，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2428：股票名稱 ＝ 興勤，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2433：股票名稱 ＝ 互盛電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2434：股票名稱 ＝ 統懋，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2441：股票名稱 ＝ 超豐，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2442：股票名稱 ＝ 新美齊，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2446：股票名稱 ＝ 全懋，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2447：股票名稱 ＝ 鼎新，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2452：股票名稱 ＝ 乾坤，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2455：股票名稱 ＝ 全新，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2463：股票名稱 ＝ 研揚，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2465：股票名稱 ＝ 麗臺，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2466：股票名稱 ＝ 冠西電，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2472：股票名稱 ＝ 立隆電，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2473：股票名稱 ＝ 思源，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2474：股票名稱 ＝ 可成，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2476：股票名稱 ＝ 鉅祥，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2477：股票名稱 ＝ 美隆電，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2494：股票名稱 ＝ 廣業科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3011：股票名稱 ＝ 今皓，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3013：股票名稱 ＝ 晟銘電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3014：股票名稱 ＝ 聯陽，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3018：股票名稱 ＝ 隆銘綠能，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3019：股票名稱 ＝ 亞光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3026：股票名稱 ＝ 禾伸堂，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3027：股票名稱 ＝ 盛達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3032：股票名稱 ＝ 偉訓，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3034：股票名稱 ＝ 聯詠，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3037：股票名稱 ＝ 欣興，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3041：股票名稱 ＝ 揚智，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3042：股票名稱 ＝ 晶技，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3043：股票名稱 ＝ 科風，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3045：股票名稱 ＝ 台灣大，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3046：股票名稱 ＝ 建碁，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3047：股票名稱 ＝ 訊舟，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3048：股票名稱 ＝ 益登，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3050：股票名稱 ＝ 鈺德，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3053：股票名稱 ＝ 鼎營，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3054：股票名稱 ＝ 立萬利，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3061：股票名稱 ＝ 璨圓，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3062：股票名稱 ＝ 建漢，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3063：股票名稱 ＝ 飛信，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3092：股票名稱 ＝ 鴻碩，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3149：股票名稱 ＝ 正達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3271：股票名稱 ＝ 其樂達，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3311：股票名稱 ＝ 閎暉，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3312：股票名稱 ＝ 弘憶股，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3338：股票名稱 ＝ 泰碩，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3376：股票名稱 ＝ 新日興，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3380：股票名稱 ＝ 明泰，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3416：股票名稱 ＝ 融程電，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3419：股票名稱 ＝ 譁裕，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3432：股票名稱 ＝ 台端，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3447：股票名稱 ＝ 展達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3515：股票名稱 ＝ 華擎，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3528：股票名稱 ＝ 安馳，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3534：股票名稱 ＝ 雷凌，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3545：股票名稱 ＝ 敦泰，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3563：股票名稱 ＝ 牧德，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3573：股票名稱 ＝ 穎台，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3591：股票名稱 ＝ 艾笛森，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3592：股票名稱 ＝ 瑞鼎，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3593：股票名稱 ＝ 力銘，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3605：股票名稱 ＝ 宏致，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3638：股票名稱 ＝ F-IML，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3686：股票名稱 ＝ 達能，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3694：股票名稱 ＝ 海華，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3697：股票名稱 ＝ F-晨星，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3701：股票名稱 ＝ 大眾控，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3702：股票名稱 ＝ 大聯大，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3711：股票名稱 ＝ 日月光投控，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3714：股票名稱 ＝ 富采，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4137：股票名稱 ＝ 麗豐-KY，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4148：股票名稱 ＝ 全宇生技-KY，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4746：股票名稱 ＝ 台耀，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4763：股票名稱 ＝ 材料*-KY，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4764：股票名稱 ＝ 雙鍵，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4770：股票名稱 ＝ 上品，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4906：股票名稱 ＝ 正文，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4915：股票名稱 ＝ 致伸，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4927：股票名稱 ＝ 泰鼎-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4935：股票名稱 ＝ 茂林-KY，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4938：股票名稱 ＝ 和碩，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4943：股票名稱 ＝ 康控-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4949：股票名稱 ＝ 有成精密，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4952：股票名稱 ＝ 凌通，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4956：股票名稱 ＝ 光鋐，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4958：股票名稱 ＝ 臻鼎-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4967：股票名稱 ＝ 十銓，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4976：股票名稱 ＝ 佳凌，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4989：股票名稱 ＝ 榮科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5203：股票名稱 ＝ 訊連，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5222：股票名稱 ＝ 全訊，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5225：股票名稱 ＝ 東科-KY，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5234：股票名稱 ＝ 達興材料，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5243：股票名稱 ＝ 乙盛-KY，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5244：股票名稱 ＝ 弘凱，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5269：股票名稱 ＝ 祥碩，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5280：股票名稱 ＝ F-敦泰，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5434：股票名稱 ＝ 崇越，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5471：股票名稱 ＝ 松翰，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5484：股票名稱 ＝ 慧友，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6112：股票名稱 ＝ 邁達特，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6116：股票名稱 ＝ 彩晶，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6117：股票名稱 ＝ 迎廣，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6119：股票名稱 ＝ 大傳，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6128：股票名稱 ＝ 上福，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6133：股票名稱 ＝ 金橋，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6136：股票名稱 ＝ 富爾特，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6141：股票名稱 ＝ 柏承，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6164：股票名稱 ＝ 華興，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6168：股票名稱 ＝ 宏齊，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6191：股票名稱 ＝ 精成科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6206：股票名稱 ＝ 飛捷，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6225：股票名稱 ＝ 天瀚，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6226：股票名稱 ＝ 光鼎，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6243：股票名稱 ＝ 迅杰，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6255：股票名稱 ＝ 奈普，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6257：股票名稱 ＝ 矽格，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6269：股票名稱 ＝ 台郡，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6282：股票名稱 ＝ 康舒，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6286：股票名稱 ＝ 立錡，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6412：股票名稱 ＝ 群電，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6416：股票名稱 ＝ 瑞祺電通，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6442：股票名稱 ＝ 光聖，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6449：股票名稱 ＝ 鈺邦，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6451：股票名稱 ＝ 訊芯-KY，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6472：股票名稱 ＝ 保瑞，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6491：股票名稱 ＝ 晶碩，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6515：股票名稱 ＝ 穎崴，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6531：股票名稱 ＝ 愛普*，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6533：股票名稱 ＝ 晶心科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6550：股票名稱 ＝ 北極星藥業-KY，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6552：股票名稱 ＝ 易華電，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6573：股票名稱 ＝ 虹揚-KY，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6598：股票名稱 ＝ ABC-KY，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6672：股票名稱 ＝ 騰輝電子-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6674：股票名稱 ＝ 鋐寶科技，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6715：股票名稱 ＝ 嘉基，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6742：股票名稱 ＝ 澤米，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6756：股票名稱 ＝ 威鋒電子，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6799：股票名稱 ＝ 來頡，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6805：股票名稱 ＝ 富世達，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6834：股票名稱 ＝ 天二科技，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6861：股票名稱 ＝ 睿生光電，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6862：股票名稱 ＝ 三集瑞-KY，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6916：股票名稱 ＝ 華凌，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6918：股票名稱 ＝ 愛派司，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6919：股票名稱 ＝ 康霈*，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6931：股票名稱 ＝ 青松健康，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6933：股票名稱 ＝ AMAX-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6934：股票名稱 ＝ 心誠鎂，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6955：股票名稱 ＝ 邦睿生技-創，產業類別 ＝ 創新板股票，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6962：股票名稱 ＝ 奕力-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 7631：股票名稱 ＝ 聚賢研發-創，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 7823：股票名稱 ＝ 奧義賽博-KY創，產業類別 ＝ 創新板股票，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8008：股票名稱 ＝ 建興電，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8011：股票名稱 ＝ 台通，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8045：股票名稱 ＝ 達運光電，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8046：股票名稱 ＝ 南電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8070：股票名稱 ＝ 長華*，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8072：股票名稱 ＝ 陞泰，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8110：股票名稱 ＝ 華東，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8112A：股票名稱 ＝ 至上甲特，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8114：股票名稱 ＝ 振樺電，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8199：股票名稱 ＝ 廣鎵，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 9912：股票名稱 ＝ 偉聯，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# ##### 更新技術分析資料 #####
# 2026-03-19 21:57:39.896 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-09
# 【略過】週Ｋ：2026-03-09
# 2026-03-19 21:57:46.047 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-10
# 2026-03-19 21:57:51.549 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-11
# 2026-03-19 21:57:57.066 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-12
# 2026-03-19 21:58:02.537 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-13
# 2026-03-19 21:58:08.233 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 2026-03-19 21:58:12.049 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 2026-03-19 21:58:15.627 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-16
# 2026-03-19 21:58:21.089 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-17
# 2026-03-19 21:58:26.868 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-03-18
# 2026-03-19 21:58:32.396 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockPrice, data_id:
# 【新建】日Ｋ：2026-03-19

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-13</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 8939.19億元 ，十日均量 ＝ 7901.75億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2026-01-06開始到2026-03-19結束，估算目標價為27535.55點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02當週死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體仍屬上漲後的高檔盤整偏強：價格維持在60日線之上，但近端在20日線附近反覆拉鋸，顯示短線進入震盪消化。近期出現一根較明顯回檔黑K，代表上檔賣壓仍在，短線以區間整理看待。<br />
# <br />
#  價量關係<br />
# 上攻至高檔時成交量放大，隨後回檔時量能仍維持在相對高位，屬於高檔換手而非明顯量縮無力。短線若要再走強，需見到上漲時量增、回檔時量縮，否則容易在區間內來回震盪。<br />
# <br />
#  支撐與壓力<br />
# - 支撐：先看33,700點附近（短期均線與近期收盤密集區），跌破則看33,000點附近（近期低點帶）。<br />
# - 壓力：上檔先看34,350點附近（近期高點區），若能帶量突破，下一道壓力看34,400點附近（前高帶）。<br />
# <br />
#  KD 指標解讀<br />
# KD 目前位於超買區（&gt;80），且K線仍在D線之上，短線偏多但已進入容易震盪的區域。由於超買不宜單獨視為反轉，需搭配價格是否守住支撐與MACD動能是否續強來確認。<br />
# <br />
#  MACD 指標解讀<br />
# DIF 仍在 MACD 線之下，柱狀體維持負值，代表中短期動能尚未翻多，但先前負柱明顯收斂後近期略有擴大，顯示反彈動能有轉弱跡象。整體屬於「價格偏強、動能仍在修復」的結構，短線追價需更謹慎。<br />
# <br />
#  綜合評價<br />
# 目前為多頭架構未破、但高檔震盪整理：只要守住33,700點與33,000點支撐帶，仍偏向以回檔後再上攻的路徑看待。若後續無法突破34,350～34,400點且MACD負柱再度擴大，則盤整時間可能拉長，操作上宜以區間應對並嚴守停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-19<br />
# 十字線 : 2026-03-19<br />
# 鎚子線／吊人線 : 2026-03-13<br />
# 吞噬 : 2026-03-13</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 2095.87億元 ，十日均量 ＝ 1600.16億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2025-12-16開始到2026-03-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-11黃金交叉。並且2026-03-19於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-02-23當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前為上漲趨勢，近期連續收高並推升至約330點附近，短線維持強勢。均線呈現短期均線在上、中期均線在下的多頭排列，且均線同步上彎，趨勢延續性佳。<br />
# <br />
#  價量關係<br />
# 上漲過程中成交量同步放大至約2,096億元，屬於價漲量增，多方動能有跟上。惟高檔量能偏熱，若後續出現價平量縮或價跌量增，將是短線轉弱的警訊。<br />
# <br />
#  支撐與壓力<br />
# 上方壓力先看前高區約333點附近，若帶量突破，將有機會延伸上攻空間；若無法突破，容易在高檔震盪。下方支撐依序看329點附近（短線守勢）、322點附近（短期均線帶），再下來是312點附近（較關鍵的短中期支撐帶）。<br />
# <br />
#  KD指標解讀<br />
# KD位於超買區（&gt;80），且K值略有鈍化跡象，代表短線追價動能偏亢奮、震盪風險上升。惟在價格仍走多、且動能指標未轉弱前，KD超買不宜單獨視為反轉訊號。<br />
# <br />
#  MACD指標解讀<br />
# DIF位於MACD之上且持續上行，柱狀體同步擴大，顯示多方動能增強、趨勢偏多。就目前圖表狀態，未見明顯與價格相反的背離訊號，多方仍占優勢。<br />
# <br />
#  綜合評價<br />
# 整體屬於多頭趨勢延續，均線多頭排列配合MACD動能走強，偏向續攻格局。短線因KD高檔鈍化，較可能以高檔震盪/小幅回檔方式消化漲幅；操作上以守住322點附近支撐作為多方續強的關鍵觀察，並留意333點壓力帶的突破量能表現。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 2340 ， 股票名稱 ＝ 台亞
# 股票代碼 ＝ 2495 ， 股票名稱 ＝ 普安
# 股票代碼 ＝ 8176 ， 股票名稱 ＝ 智捷
# 股票代碼 ＝ 6170 ， 股票名稱 ＝ 統振
# 股票代碼 ＝ 8088 ， 股票名稱 ＝ 品安
# 股票代碼 ＝ 4741 ， 股票名稱 ＝ 泓瀚
# 股票代碼 ＝ 6265 ， 股票名稱 ＝ 方土昶
# 股票代碼 ＝ 6168 ， 股票名稱 ＝ 宏齊
# 股票代碼 ＝ 9933 ， 股票名稱 ＝ 中鼎
# 股票代碼 ＝ 8105 ， 股票名稱 ＝ 凌巨
# 股票代碼 ＝ 1449 ， 股票名稱 ＝ 佳和
# 股票代碼 ＝ 6112 ， 股票名稱 ＝ 邁達特
# 股票代碼 ＝ 4906 ， 股票名稱 ＝ 正文
# 股票代碼 ＝ 2465 ， 股票名稱 ＝ 麗臺
# 股票代碼 ＝ 3338 ， 股票名稱 ＝ 泰碩

# %% [markdown]
# * 篩選結果
#   - 新興(2605)：穩健續漲
#     ![260319_2.png](attachment:41546db5-cb20-4403-9483-4404300de32d.png)
#   - 新唐(4919)：穩健續漲／強勢多頭
#     ![260319_3.png](attachment:f242ba3f-169f-482e-9948-e63e4f38c6b3.png)
#   - 誠美材(4960)：多頭回檔
#     ![260319_4.png](attachment:86a2b17d-ba70-4523-8125-9366bd603f3f.png)
#   - 榮創(3437)：強勢多頭
#     ![260319_5.png](attachment:6296955d-5d82-43e6-b5bc-1fd1f5ceffe2.png)
#   - 映泰(2399)：穩健續漲／強勢多頭
#     ![260319_6.png](attachment:9e764f2d-5613-4db9-8a21-c48a4846aae3.png)
#   - 正文(4906)：穩健續漲
#     ![260319_7.png](attachment:250b9564-427a-4ed1-808a-8128ba6da479.png)
#   - 億光(2393)：穩健續漲
#     ![260319_8.png](attachment:c72b3229-a028-49b0-8423-2198d5e9bc2b.png)
#   - 東聯(1710)：技術突破
#     ![260319_10.png](attachment:0dd410c6-6451-4d66-9c09-89beb1fda1ef.png)

# %% [markdown]
# * 觀察股列表
#   ![260319_1.png](attachment:c66d79fc-d339-4fd9-84b0-abe64a0672a0.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：有中期底形雛形，仍在打底中。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-13<br />
# 十字線 : 2026-03-13<br />
# 吞噬 : 2026-03-18<br />
# 孕育線／懷抱線 : 2026-03-13</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 2641張 ，十日均量 ＝ 2487張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-08-15開始到2026-03-19結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線走平、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-19死亡交叉。並且2026-03-19於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體屬上漲格局，近期自低檔轉強後連續推升並站回多條均線之上。惟3月19日收黑回檔，短線呈現高檔震盪，需觀察回檔是否守住短期均線帶。<br />
# <br />
#  價量關係<br />
# 上攻段量能有放大，顯示追價動能曾明顯增溫；但3月19日回檔時量能仍在相對高位，代表高檔出現獲利了結與換手。若後續回檔量縮、上攻量增，較有利延續多方趨勢。<br />
# <br />
#  支撐與壓力<br />
# 支撐先看52.8元（近期回檔低點區），再看51.8～52.6元（中短期均線匯聚帶）。壓力先看54.5元（近期高點），若放量突破，下一道壓力為55.8元（較長期均線附近）。<br />
# <br />
#  KD指標解讀<br />
# KD位於高檔區，近期K線自高檔回落並出現K線下彎，顯示短線動能降溫。由於仍在偏高位置，KD不宜單獨視為反轉訊號，需搭配價格是否跌破支撐與MACD動能是否續弱確認。<br />
# <br />
#  MACD指標解讀<br />
# DIF維持在MACD線之上且同步走揚，整體仍偏多；但柱狀體由高檔縮短，代表上攻動能開始鈍化。若後續柱狀體續縮甚至翻負，短線回檔壓力將加大。<br />
# <br />
#  綜合評價<br />
# 目前以多頭趨勢中的高檔回檔整理看待：均線偏多排列支撐趨勢，但動能指標顯示短線漲勢降溫。操作上重點觀察52.8元與51.8～52.6元支撐帶是否守穩；守穩則仍有機會再測54.5元，跌破則回檔可能擴大。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-10-09','2026-03-19',line_drawing_callback)
display(image)
# Out:
# 估算目標價為57.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-205)：外資大買(+804)、投信大賣(-1058)、自營小買(+19)。
# 主力小賣(-23)。
# 分公司買賣家數差分散(-78)。
# 融資減(-67)、融券減(-4)。

# %% [markdown]
# * 宏碁(2353)
#   看法：突破後拉回，頸線支撐有守。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2353')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=837x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-17<br />
# 十字線 : 2026-03-17<br />
# 孕育線／懷抱線 : 2026-03-19<br />
# 高檔夜星 : 2026-03-13</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 45838張 ，十日均量 ＝ 36346張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-11-18開始到2026-03-19結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-18黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-02-23當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體為上漲格局，近期出現帶量長紅推升後，隔日以黑K回檔但仍守在相對高檔，屬強勢整理。均線呈現短期均線在上、並同步上彎，價格維持在短中期均線之上，趨勢偏多不變。<br />
# <br />
#  價量關係<br />
# 上攻當日成交量明顯放大至113,226張，屬於量能有效擴增的推升型態。隔日回檔量縮至45,838張，呈現「價回檔、量縮」的健康整理，賣壓相對可控。<br />
# <br />
#  支撐與壓力<br />
# 支撐先看短期均線附近約27.84元，再看前一波放量長紅的低點區約27.70元；若跌破，下一道支撐落在中期均線附近約27.16元。壓力先看近期高點區約29.15～29.45元，屬短線多方續攻需消化的套牢/獲利了結帶。<br />
# <br />
#  KD 指標解讀<br />
# K值位於中高檔並上行，且K線高於D線，顯示短線動能偏多延續。惟尚未進入明確超買區，較偏向「強勢區震盪」而非反轉訊號，仍需搭配價格是否守住支撐帶觀察。<br />
# <br />
#  MACD 指標解讀<br />
# DIF線維持在MACD線之上且雙線同步上行，柱狀體擴大，代表多方動能正在增強。就目前圖形未見明顯背離，動能結構仍支持價格維持偏多走勢。<br />
# <br />
#  綜合評價<br />
# 目前屬多頭趨勢中的回檔整理，量價結構偏正向，短線只要守住27.70～27.84元支撐帶，多方仍有機會再挑戰29.15～29.45元壓力區。若後續回檔跌破27.70元且量能放大，則需提防轉為較深的整理並回測27.16元附近支撐。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-11-17'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-12-04']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-01-30'
    bottom_price = range_prices.loc['2026-01-30']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2353','2025-10-14','2026-03-19',line_drawing_callback)
display(image)
# Out:
# 估算目標價為30.80元
# <PIL.Image.Image image mode=RGB size=866x481>

# %% [markdown]
# 籌碼面：
# 法人大賣(-16757)：外資大賣(-16172)、投信小賣(-171)、自營小賣(-414)。
# 主力大賣(-12535)。
# 分公司買賣家數差分散(-38)。
# 融資大增(+1808)、融券減(-14)。

# %% [markdown]
# ### 技術開發

# %%
# 解盤物件清除
analysis = None

# %% [markdown]
# 股票解盤AI Agent

# %%
import os
import pandas as pd
import numpy as np
import datetime
import sqlite3
import io
import base64
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import markdown

import json

from talib.abstract import *
from dotenv import load_dotenv, find_dotenv
from PIL import Image
from IPython.core.display import HTML

from typing import Any, Dict, List, Optional, Tuple
from openai import OpenAI

# %%
##### 【公用函式】 來源 ： https://www.cnblogs.com/Rosaany/p/15561918.html #####
def get_monday_to_sunday(today, weekly=0):
    last = weekly * 7
    today = datetime.datetime.strptime(str(today), "%Y-%m-%d")
    monday = datetime.datetime.strftime(today - datetime.timedelta(today.weekday() - last), "%Y-%m-%d")
    monday_ = datetime.datetime.strptime(monday, "%Y-%m-%d")
    sunday = datetime.datetime.strftime(monday_ + datetime.timedelta(monday_.weekday() + 6), "%Y-%m-%d")
    return monday, sunday

###### 【內部函式】 當日Ｋ價格資料為零時之修正函式 ######
def correcting_zero_price_issue( daily_price_df, debug = False) :
    # 開啟寫時複製(Copy-on-Write)
    copy_on_write = pd.options.mode.copy_on_write
    pd.options.mode.copy_on_write = True
    
    # 找出開盤價、最高價、收盤價與最低價皆為0的價格資料
    zero_prices_df =  daily_price_df[(daily_price_df['Open'] == 0.0) & (daily_price_df['High'] == 0.0) & (daily_price_df['Low'] == 0.0) & (daily_price_df['Close'] == 0.0)]
    if zero_prices_df.empty is False :
        zero_prices_idx = zero_prices_df.index
        df_first_idx    = daily_price_df.iloc[0].name
        for idx in zero_prices_idx :
            if (idx - 1) >= df_first_idx :
                # 當開盤價、最高價、收盤價與最低價皆為0時，會用前一個交易日的收盤價來做修正
                prev_close_price = daily_price_df.loc[idx-1]['Close']
                prev_stock_id    = daily_price_df.loc[idx-1]['StockID']
                curr_stock_id    = daily_price_df.loc[idx]['StockID']
                if debug is True :
                    print('ＤＥＢＵＧ ： 〈代碼：{}，日期：{}〉  修改前：開 ＝ {} 高 ＝ {} 低 ＝ {} 收 ＝ {}'.format(curr_stock_id,daily_price_df.loc[idx]['Date'],daily_price_df.loc[idx,'Open'],daily_price_df.loc[idx,'High'],daily_price_df.loc[idx,'Low'],daily_price_df.loc[idx,'Close']), end='')
                daily_price_df.loc[idx,'Open']  = prev_close_price
                daily_price_df.loc[idx,'High']  = prev_close_price
                daily_price_df.loc[idx,'Low']   = prev_close_price
                daily_price_df.loc[idx,'Close'] = prev_close_price
                if debug is True :
                    print(' ， 修改後：開 ＝ {} 高 ＝ {} 低 ＝ {} 收 ＝ {}'.format(daily_price_df.loc[idx,'Open'],daily_price_df.loc[idx,'High'],daily_price_df.loc[idx,'Low'],daily_price_df.loc[idx,'Close']))
            else :
                pass
    
    # 還原初始狀態
    pd.options.mode.copy_on_write = copy_on_write

###### 【公用函式】 來源 ： https://stackoverflow.com/questions/73604477/i-am-trying-to-crop-an-image-to-remove-extra-space-in-python #####
def get_first_last(mask, axis: int):
    """ Find the first and last index of non-zero values along an axis in `mask` """
    mask_axis = np.argmax(mask, axis=axis) > 0
    a = np.argmax(mask_axis)
    b = len(mask_axis) - np.argmax(mask_axis[::-1])
    return int(a), int(b)

def crop_borders(img, crop_color):
    np_img = np.array(img)
    mask = (np_img != crop_color)[..., 0]   # compute a mask
    x0, x1 = get_first_last(mask, 0)        # find boundaries along x axis
    y0, y1 = get_first_last(mask, 1)        # find boundaries along y axis
    return img.crop((x0, y0, x1, y1)) 

def result_to_dataframe(result: dict) -> pd.DataFrame:
    df = pd.DataFrame(
        {
            "解盤內容": result
        }
    )
    df.index.name = "技術分析工具"
    return df
def display_result( result) :
    result_df = result_to_dataframe( result)
    result_md   = result_df.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %%
import json
from typing import Any, Dict, Optional, Tuple
from openai import OpenAI


# =========================
# PROMPT BUILDERS
# =========================

def build_system_prompt(instrument: dict) -> str:
    return f"""
你是一位技術分析師，使用「看圖優先」。

【核心原則】
- 由長到短（長→中→短）
- 最終必須整合成單一結論
- 不可暴露技術欄位名稱
- 型態可以不存在，不可硬湊

【MACD輸出規範】
只允許：DIF線、MACD線、OSC柱體
禁止：macd / macdsignal / 訊號線

【標的】
{json.dumps(instrument, ensure_ascii=False)}
"""


def build_phase1_prompt(stock_id: str) -> str:
    return f"""
你會收到三張圖：
1. 長週期（240）
2. 中週期（120）
3. 短週期（60）

請由長→中→短分析。

--------------------------------------------------

【型態規則】

- 無明確型態 → structure_type = none
- 可用 price_state 描述（narrow_range / high_level_consolidation...）
- 不可硬判型態

--------------------------------------------------

【支撐壓力規則（重要）】

- 支撐與壓力必須來自：
  - 明確高低點（swing high / low）
  - 均線
  - 區間上下緣

- 若不清楚，不可猜測

--------------------------------------------------

【KD判讀與資料需求規則（重要）】

- KD子圖上有兩條綠線，代表超買區與超賣區的區隔

請依以下原則判斷：

1. 若能從圖上清楚判斷：
   - KD已進入超買區（高於上方綠線）
   - 或KD已進入超賣區（低於下方綠線）
   → 可直接判讀，不需要額外資料

2. 若無法明確判斷（例如接近邊界、圖形模糊）：
   → 不可主觀判定
   → 必須設定：
     "need_price_data": "YES"

3. 若KD位置會影響判斷（例如：
   - 是否過熱
   - 是否超跌
   - 是否接近轉折）
   但圖上不夠清楚：
   → 必須設定 need_price_data = YES

--------------------------------------------------

【need_price_data 判斷總規則】

只有在以下情況才設為 YES：

- 支撐 / 壓力無法確認
- KD是否進入超買/超賣無法確認
- 指標位置會影響結論但圖上不清楚

否則應為 NO

--------------------------------------------------

【輸出 JSON】

{{
  "stock_id": "{stock_id}",
  "long_view": {{
    "trend": "...",
    "structure_type": "...",
    "price_state": "...",
    "structure_bias": "...",
    "structure_strength": "...",
    "support": {{"value": number, "source": "...", "strength": "..."}},
    "resistance": {{"value": number, "source": "...", "strength": "..."}},
    "note": ""
  }},
  "mid_view": {{ ... }},
  "short_view": {{ ... }},
  "need_price_data": "YES | NO",
  "need_price_data_reason": ""
}}
"""


def build_phase2_prompt(stock_id: str, structure: dict, price_data=None) -> str:
    prompt = f"""
請分析 {stock_id}。

【結構】
{json.dumps(structure, ensure_ascii=False)}

--------------------------------------------------

【用語在地化與語氣控制（強制）】

你必須使用台灣技術分析常用語，並依盤面狀態選擇最合適的描述層級。

【禁止用詞（不可出現任何變形）】
- 箱體
- 箱體整理
- 箱體震盪
- 箱型
- 箱型整理
- trading range

【用詞選擇邏輯（必須遵守）】
請依據盤面狀態選擇最貼切的用語：

1. 若波動幅度很小、價格壓縮：
→ 使用「狹幅整理」

2. 若價格在小區間內來回但未明確上下界：
→ 使用「整理」或「盤整」

3. 若存在明確支撐與壓力區間：
→ 使用「區間整理」或「區間震盪」

4. 若位置在相對高位：
→ 使用「高檔整理」或「高檔震盪」

5. 若位置在相對低位：
→ 使用「低檔整理」或「低檔震盪」

【型態轉換規則（重要）】
若 structure_type = box：
- 必須轉換語言，不可出現「箱」字
- 依情境選擇：
  - 區間整理
  - 區間震盪
  - 高檔整理
  - 狹幅整理

--------------------------------------------------

【技術指標用語白名單（強制遵守）】

所有技術指標必須使用對應的標準用語，不可混用、不可自創。

【KD指標（隨機指標）】
允許用語：
- 超買區（80以上）
- 超賣區（20以下）
- 高檔 / 低檔
- 鈍化
- 黃金交叉 / 死亡交叉
- 回升 / 回落

禁止用語：
- 偏強區
- 偏弱區
- 強勢區 / 弱勢區
- 動能區

【KD超買超賣確認規則（重要）】
- 圖上 KD 子圖有兩條綠線，作為超買區與超賣區的區隔
- 若可從圖上清楚判斷 KD 已進入超買區或超賣區，才能直接使用「超買區 / 超賣區」
- 若無法從圖上明確確認是否進入超買區或超賣區，則不得自行猜測
- 若本次有補充數據，應以數據確認後再描述
- 若沒有補充數據，則改用較保守的語言，例如：
  - 接近高檔
  - 接近低檔
  - 位於高檔區附近
  - 位於低檔區附近

【MACD指標】
允許用語：
- DIF線
- MACD線
- OSC柱體
- 零軸
- 多方 / 空方
- 動能增強 / 動能減弱
- 柱體擴大 / 柱體縮小
- 背離（頂背離 / 底背離）

禁止用語：
- 訊號線
- macd / macdsignal / macdhist
- 強勢區 / 弱勢區

【移動平均線（均線）】
允許用語：
- 短期均線（5日、10日）
- 中期均線（20日、60日）
- 上揚 / 下彎 / 走平
- 多頭排列 / 空頭排列
- 均線糾結
- 支撐 / 壓力
- 均線翻揚 / 均線轉弱

禁止用語：
- 動能
- 強弱區

【成交量】
允許用語：
- 價漲量增
- 價跌量縮
- 量縮整理
- 量能放大 / 量能縮小
- 爆量
- 換手
- 價量背離

禁止用語：
- 動能區
- 強弱區

【成交量描述規則（重要）】
- 成交量分析應優先使用：
  - 價漲量增
  - 價跌量縮
  - 量縮整理
- 若無法明確對應上述三者，再輔助使用：
  - 量能放大 / 量能縮小
  - 換手
  - 價量背離
- 不要把成交量描述得過度抽象，盡量落在價量關係上

【通用限制】
- 不可混用不同指標語言
- 若不確定，請使用最基本描述：
  → 高檔 / 低檔 / 回升 / 回落
- 不可創造新術語

--------------------------------------------------

【跨週期整合（重要）】

- 長決定方向
- 中決定結構
- 短決定節奏

最終輸出必須整合為「單一觀點」

❌ 禁止：
長週期... 中週期... 短週期...

✅ 必須：
融合為自然語句

--------------------------------------------------

【K棒規則】

K棒只代表短期（3~5天）
不可拆成長中短三段

--------------------------------------------------

【內部結論（不可輸出）】

你可以在內部先形成：
- 核心結論
- 決策結構（方向 / 位置 / 行為）

但不可輸出

--------------------------------------------------

【輸出 JSON】

{{
  "K棒": "...",
  "K線圖": "...",
  "成交量": "...",
  "型態": "...",
  "移動平均線": "...",
  "MACD指標": "...",
  "KD指標": "...",
  "整體評價": "..."
}}
"""

    if price_data:
        prompt += "\n\n補充數據：\n" + json.dumps(price_data, ensure_ascii=False)

    return prompt


# =========================
# AGENT
# =========================

class StockAnalysisAgent:

    def __init__(self, model: str = "gpt-5.2", sqlite_db_path = 'data/stock.db', debug = False):
        # API Key不明寫，從環境變數中取得
        load_dotenv(find_dotenv())
        api_key = os.environ.get('OPENAI_API_KEY_TOKEN')
        self.client = OpenAI(api_key=api_key)
        self.model = model
        # 我的內部屬性
        ### 設定除錯旗標 ###
        self._debug = debug
        ### 設定股票代號 ###
        self._stock_id = None
        # 我的初始化程序
        ### 連線資料庫 ###
        if os.path.isfile(sqlite_db_path):
            self._conn = sqlite3.connect( sqlite_db_path)
        else :
            raise ValueError('The database file does not exist.')
        ### 從資料庫中載入「台股總覽 TaiwanStockInfo」 ###
        try :
            self._df_stock_info = pd.read_sql("SELECT * FROM StockInfo", self._conn)
        except Exception as e:
            raise ValueError('An error occurred while loading TaiwanStockInfo.')

        self.lookbacks = {
            "long": 240,
            "mid": 120,
            "short": 60,
        }

    # 我的內部方法
    ### 列印除錯訊息之內部方法 ###
    def _debug_print( self, msg) :
        if self._debug is True :
            print("ＤＥＢＵＧ ： {}".format(msg))
    ### 重置內部屬性之內部方法 ###
    def _reset_internal_attribute( self) :
        self._daily_price_df        = None
        self._sma_df                = None
        self._kd_df                 = None
        self._macd_df               = None
        self._instrument_type       = None
        self._price_unit            = None
        self._volume_unit           = None
        ### 從資料庫中載入日Ｋ資料之內部方法 ###
    def _loading_price_data( self, stock_id) :
        # 將載入的「台股總覽 TaiwanStockInfo」進行格式轉換
        df_stock_info = self._df_stock_info.set_index(self._df_stock_info['StockID'],inplace=False)
        df_stock_info = df_stock_info.drop(columns=['StockID'])
        
        # 判斷股票代碼(stock_id)是否存在於「台股總覽 TaiwanStockInfo」中
        if stock_id in df_stock_info.index:
            
            # 取得該股票代碼的產業分類
            individual_stock_info = df_stock_info.loc[stock_id]
            industry_category     = individual_stock_info['IndustryCategory']
            
            # 設定開始日期與結束日期
            current_date       = datetime.datetime.today()
            daily_end_date     = current_date.strftime('%Y-%m-%d')
            daily_start_date,_ = get_monday_to_sunday((current_date - datetime.timedelta(days=730)).strftime('%Y-%m-%d'))
            
            # 讀取日Ｋ價格資料
            sql_cmd = "SELECT * FROM DailyPrice WHERE StockID='{}' AND (Date BETWEEN '{}' AND '{}') ORDER BY Date".format(stock_id,daily_start_date,daily_end_date)
            try :
                daily_price_df = pd.read_sql( sql_cmd, self._conn)
            except Exception as e:
                self._debug_print('讀取日Ｋ資料錯誤，錯誤訊息＝ {}'.format(str(e)))
                return False
            # 調整停牌或未交易之日Ｋ價格資料
            correcting_zero_price_issue( daily_price_df, debug = self._debug)
            # 格式轉換：日期格式、成交量(成交值)
            daily_price_df           = daily_price_df.drop(columns=['SerialNo','StockID'])
            daily_price_df['Date']   = daily_price_df['Date'].astype('datetime64[ns]')
            daily_price_df.set_index(daily_price_df['Date'],inplace=True)
            daily_price_df           = daily_price_df.drop(columns=['Date'])
            if industry_category == 'Index' or industry_category == '大盤' :
                daily_price_df           = daily_price_df.drop(columns=['Volume'])
                daily_price_df           = daily_price_df.rename(columns={'Value':'Volume'})
                daily_price_df['Volume'] = daily_price_df['Volume'].div(100000000.00)
                daily_price_df['Volume'] = daily_price_df['Volume'].round(2)
            else :
                daily_price_df           = daily_price_df.drop(columns=['Value'])
                daily_price_df['Volume'] = daily_price_df['Volume'].div(1000)
                daily_price_df['Volume'] = daily_price_df['Volume'].round()
                daily_price_df['Volume'] = daily_price_df['Volume'].astype('int64')
            self._daily_price_df         = daily_price_df
                
            if industry_category == 'Index' or industry_category == '大盤' :
                self._instrument_type       = 'index'
                self._price_unit            = '點'
                self._volume_unit           = '億元'
            else :
                self._instrument_type       = 'stock'
                self._price_unit            = '元'
                self._volume_unit           = '張'
                
            return True
        return False
    ### 使用talib程式庫計算技術指標之內部方法 ###
    def _technical_indicators( self) :
        # 日Ｋ價格資料轉換為talib格式
        daily_price_df_talib          = self._daily_price_df.copy()
        daily_price_df_talib.columns  = [ i.lower() for i in daily_price_df_talib.columns]
        
        # 計算移動平均線
        talib_sma5        = SMA( daily_price_df_talib, timeperiod=5)
        talib_sma10       = SMA( daily_price_df_talib, timeperiod=10)
        talib_sma20       = SMA( daily_price_df_talib, timeperiod=20)
        talib_sma60       = SMA( daily_price_df_talib, timeperiod=60)
        talib_sma120      = SMA( daily_price_df_talib, timeperiod=120)
        talib_sma240      = SMA( daily_price_df_talib, timeperiod=240)
        # 設定名稱
        talib_sma5.name   = 'SMA5'
        talib_sma10.name  = 'SMA10'
        talib_sma20.name  = 'SMA20'
        talib_sma60.name  = 'SMA60'
        talib_sma120.name = 'SMA120'
        talib_sma240.name = 'SMA240'
        # 合併各條均線
        talib_sma_df      = pd.concat([talib_sma5, talib_sma10, talib_sma20, talib_sma60, talib_sma120, talib_sma240], axis=1)
        # 取小數點後兩位
        self._sma_df      = talib_sma_df.round(2)
        
        # 計算ＫＤ指標
        talib_daily_kd = STOCH( daily_price_df_talib, fastk_period=9, slowk_period=3, slowd_period=3)
        # 取小數點後兩位
        self._kd_df    = talib_daily_kd.round(2)
        
        # 計算ＭＡＣＤ指標
        talib_daily_macd = MACD( daily_price_df_talib, fastperiod=12, slowperiod=26, signalperiod=9)
        # 取小數點後兩位
        self._macd_df    = talib_daily_macd.round(2)
    ### 載入價量資料並計算技術指標 ###
    def _loading_price_data_and_technical_indicators( self, stock_id) :
        if self._stock_id is None or self._stock_id != stock_id :
            self._debug_print('設置或重置內部屬性')
            self._reset_internal_attribute()
            self._debug_print('載入價量資料,股票代碼 ＝ {}'.format(stock_id))
            if self._loading_price_data( stock_id) is True :
                self._debug_print('計算技術指標')
                self._technical_indicators()
                self._stock_id = stock_id
            else :
                raise ValueError("讀取價量資料錯誤！")


    # ===== TODO =====

    def classify_instrument(self, stock_id: str) -> Dict[str, str]:
        
        self._loading_price_data_and_technical_indicators( stock_id)
        
        return {"instrument_type":self._instrument_type , "price_unit":self._price_unit , "volume_unit": self._volume_unit}

    def get_analysis_dates(self, prev_days: int) -> Tuple[str, str]:

        if  self._daily_price_df is not None :
            end_date   = self._daily_price_df.iloc[-1].name.strftime('%Y-%m-%d')
            start_date = self._daily_price_df.iloc[-1-prev_days].name.strftime('%Y-%m-%d')
            self._debug_print('開始日期 ＝ {} （輸入參數 ＝ {} ）， 結束日期 ＝ {} '.format(start_date,prev_days,end_date))
        else :
            raise ValueError("沒有價量資料！")
        
        return (start_date,end_date)


    def get_chart(self, stock_id: str, start_date: str, end_date: str) -> str:
        
        self._loading_price_data_and_technical_indicators( stock_id)
        
        range_prices = self._daily_price_df[start_date:end_date]
        range_sma    = self._sma_df[start_date:end_date]
        range_kd     = self._kd_df[start_date:end_date]
        range_macd   = self._macd_df[start_date:end_date]
        
        # 設定K線格式
        mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
        s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
        
        # ＫＤ指標：超買線
        kd_overbought_line = [80] * range_prices.shape[0]
        # ＫＤ指標：賣超線
        kd_oversold_line   = [20] * range_prices.shape[0]

        # 設定技術指標
        added_plots = [
            mpf.make_addplot(range_sma['SMA5'],width=0.8,color='xkcd:red brown'),
            mpf.make_addplot(range_sma['SMA10'],width=0.8,color='xkcd:dark sky blue'),
            mpf.make_addplot(range_sma['SMA20'],width=0.8,color='xkcd:violet'),
            mpf.make_addplot(range_sma['SMA60'],width=0.8,color='xkcd:orange'),
            mpf.make_addplot(range_kd['slowk'],width=0.8,panel=2,secondary_y=False,color='xkcd:red',ylabel='KD'),
            mpf.make_addplot(range_kd['slowd'],width=0.8,panel=2,secondary_y=False,color='xkcd:blue'),
            mpf.make_addplot(kd_overbought_line,width=0.8,panel=2,secondary_y=False,linestyle='--',color='xkcd:green'),
            mpf.make_addplot(kd_oversold_line,width=0.8,panel=2,secondary_y=False,linestyle='--',color='xkcd:green'),
            mpf.make_addplot(range_macd['macdhist'],type='bar',panel=3,secondary_y=False,color='xkcd:grey',ylabel='MACD'),
            mpf.make_addplot(range_macd['macd'],width=0.8,panel=3,secondary_y=False,color='xkcd:red'),
            mpf.make_addplot(range_macd['macdsignal'],width=0.8,panel=3,secondary_y=False,color='xkcd:blue')
        ]

        # 設定Ｋ線圖X軸座標值
        ticks        = []
        tlabs        = []
        label_count  = 0
        total_k_line = range_prices.shape[0]
        for idx in range(total_k_line) :
            timestamp = range_prices.iloc[idx].name
            if idx == 0 :
                ticks.append(idx)
                tlabs.append(timestamp.strftime('%Y-%m-%d'))
                label_count = 0
            elif (idx+1) == total_k_line:
                if label_count < 5 :
                    # 移除上一筆資料
                    ticks.pop()
                    tlabs.pop()
                ticks.append(idx)
                tlabs.append(timestamp.strftime('%Y-%m-%d'))
            elif label_count > 10 :
                ticks.append(idx)
                tlabs.append(timestamp.strftime('%Y-%m-%d'))
                label_count = 0
            label_count += 1
        
        # 繪製Ｋ線圖
        tmp = io.BytesIO()
        kwargs = dict(type='candle', style=s, figratio=(16,9), volume=True, addplot=added_plots, main_panel=0, volume_panel=1, panel_ratios=(5, 1, 2, 2), num_panels=4, datetime_format='%Y-%m-%d', returnfig=True, savefig=dict(fname=tmp))
        fig, axlist = mpf.plot(range_prices,**kwargs)
        axlist[-2].set_xticks(ticks,labels=tlabs,ha='right')
        tmp = None
        
        # 保存Ｋ線圖
        img = io.BytesIO()
        fig.savefig(img,format='png')

        # 刪除空白
        image    = Image.open(img).convert("RGB")
        image    = crop_borders(image, crop_color=(255, 255, 255))
        crop_img = io.BytesIO()
        image.save(crop_img,format='PNG')
        
        # 將影像檔(PNG)編碼為Base64
        base64_image = base64.b64encode(crop_img.getvalue()).decode()
        
        return base64_image

    def get_price_data(self, stock_id: str, start_date: str, end_date: str) -> Dict[str, Any]:
        
        self._loading_price_data_and_technical_indicators( stock_id)
        
        range_prices     = self._daily_price_df[start_date:end_date]
        range_sma        = self._sma_df[start_date:end_date]
        range_kd         = self._kd_df[start_date:end_date]
        range_macd       = self._macd_df[start_date:end_date]
        
        ret_records_list = []
        
        for idx in range(len(range_prices)) :
            record = {
                "date": range_prices.iloc[idx].name.strftime('%Y-%m-%d'),
                "open": range_prices.iloc[idx]['Open'],
                "high": range_prices.iloc[idx]['High'],
                "low": range_prices.iloc[idx]['Low'],
                "close": range_prices.iloc[idx]['Close'],
                "volume": range_prices.iloc[idx]['Volume'],
                "sma5": range_sma.iloc[idx]['SMA5'],
                "sma10": range_sma.iloc[idx]['SMA10'],
                "sma20": range_sma.iloc[idx]['SMA20'],
                "sma60": range_sma.iloc[idx]['SMA60'],
                "macd": range_macd.iloc[idx]['macd'],
                "macdsignal": range_macd.iloc[idx]['macdsignal'],
                "macdhist": range_macd.iloc[idx]['macdhist'],
                "slowk": range_kd.iloc[idx]['slowk'],
                "slowd": range_kd.iloc[idx]['slowd'] 
            }
            ret_records_list.append(record)

        summary = {'latest_close' : range_prices.iloc[-1]['Close']}
            
        return {"records":ret_records_list,"summary":summary}


    # ===== internal =====

    def _image_url(self, b64: str):
        return f"data:image/png;base64,{b64}"

    def _safe_json(self, text: str):
        text = text.strip().replace("```json", "").replace("```", "")
        return json.loads(text)

    def _call(self, system, user, images):
        content = [{"type": "input_text", "text": user}]
        for k in ["long", "mid", "short"]:
            content.append({"type": "input_image", "image_url": images[k]})

        r = self.client.responses.create(
            model=self.model,
            input=[
                {"role": "system", "content": system},
                {"role": "user", "content": content}
            ]
        )
        return r.output_text

    def _get_charts(self, stock_id):
        result = {}
        for k, days in self.lookbacks.items():
            s, e = self.get_analysis_dates(days)
            b64 = self.get_chart(stock_id, s, e)
            result[k] = self._image_url(b64)
        return result

    # ===== Phase 1 =====

    def extract_structure(self, stock_id: str):
        instrument = self.classify_instrument(stock_id)
        charts = self._get_charts(stock_id)

        raw = self._call(
            build_system_prompt(instrument),
            build_phase1_prompt(stock_id),
            charts
        )

        return self._safe_json(raw)

    # ===== Phase 2 =====

    def generate_analysis(self, stock_id, structure):
        instrument = self.classify_instrument(stock_id)
        charts = self._get_charts(stock_id)

        price_data = None
        if structure.get("need_price_data") == "YES":
            s, e = self.get_analysis_dates(120)
            price_data = self.get_price_data(stock_id, s, e)

        raw = self._call(
            build_system_prompt(instrument),
            build_phase2_prompt(stock_id, structure, price_data),
            charts
        )

        return self._safe_json(raw)

    # ===== API =====

    def run(self, stock_id: str, debug=False):

        structure = self.extract_structure(stock_id)
        analysis = self.generate_analysis(stock_id, structure)

        if debug:
            return {
                "結構": structure,
                "分析": analysis
            }

        # 👉 正式輸出（乾淨版）
        return analysis

# %%
agent = StockAnalysisAgent(debug=True)

# %%
# 測試：加權指數
result = agent.run('TAIEX')
display_result(result)
# Out:
# ＤＥＢＵＧ ： 設置或重置內部屬性
# ＤＥＢＵＧ ： 載入價量資料,股票代碼 ＝ TAIEX
# ＤＥＢＵＧ ： 計算技術指標
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-03-24 （輸入參數 ＝ 240 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-09-12 （輸入參數 ＝ 120 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-12-11 （輸入參數 ＝ 60 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-03-24 （輸入參數 ＝ 240 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-09-12 （輸入參數 ＝ 120 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-12-11 （輸入參數 ＝ 60 ）， 結束日期 ＝ 2026-03-19
# ＤＥＢＵＧ ： 開始日期 ＝ 2025-09-12 （輸入參數 ＝ 120 ）， 結束日期 ＝ 2026-03-19
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>K棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>近3~5個交易日先強彈到34348點後，隨即拉回收在33689點，形成「反彈後遇壓回落」的短線節奏；高點未能續創高，顯示上檔追價意願不足，短線以震盪偏整理看待。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>K線圖</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>目前仍在高檔區間震盪，近期波動加大但尚未脫離整理架構；就你提供的區間關鍵位來看，短線以33500點附近為主要支撐觀察區，上檔則先看34500點附近的壓力帶，往上才有機會再挑戰35000點一帶的波段壓力。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>近期成交量維持在相對高檔（約8,000~12,000億元區間）但走勢呈現「高檔震盪、量能起伏」；屬於震盪換手的型態，尚未看到突破壓力時應有的連續放量結構，因此上檔仍偏容易遇壓。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>以高檔區間整理為主，短線一度急跌後反彈，但目前仍回到整理帶內，屬「區間內的拉回—反彈—再整理」的延伸。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>均線仍是多頭排列格局，且中期均線（20日、60日）維持上揚，長線方向沒有被破壞；但短期均線（5日、10日）在近期急跌後轉為走平到略帶壓力，代表短線要再攻，需要先站穩5日與10日均線並讓乖離收斂。以數值看，收盤33689點略低於5日均線33723點、仍高於10日均線33479點，短線屬「回測後撐住、但尚未轉強」的狀態。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>MACD指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>DIF線仍在零軸上方但明顯回落，MACD線同步走弱，OSC柱體落在零軸下方且未見有效縮小，代表多方趨勢仍在、但這一段上攻力道已轉鈍，短線反彈比較像修復，續攻需要時間或再度放量配合。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>KD指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>以補充數據可明確確認：KD已在超買區（K=84.91、D=77.51；K值高於80）。目前K值高於D值，屬於高檔回升後維持在超買區附近，但因位置已高，接下來若在壓力帶出現K下彎或死亡交叉，容易轉成高檔鈍化後的回落；反之若能放量站回34500點附近，才有機會延伸高檔鈍化並再攻。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>長線多頭架構未破，但目前屬高檔區間整理、上攻動能轉鈍：操作節奏宜以「守支撐、等表態」為主，33500點附近不破偏向續抱/偏多看待；若能帶量站上34500點並續強，才偏向重新轉回攻勢、上看35000點；反之若跌破33500點，整理時間恐拉長並回測更下方的支撐帶（中期以33000點附近為關鍵）。</p>
# </td>
# </tr>
# </tbody>
# </table>
