# %% [markdown]
# ### 工作進度
# * 【置頂】**新的筆記內容架構**與**量化技術分析系統**相關資訊請參閱[250801筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250801%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 本日「K線追擊週報」LINE群組資訊：[楊忠憲K線追擊週報_251020日報.docx]()。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-10-20 20:53:10.353 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 新增股票代碼。代碼 ＝ 009813：股票名稱 ＝ 貝萊德標普卓越50，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2059：股票名稱 ＝ 川湖，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2303：股票名稱 ＝ 聯電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2314：股票名稱 ＝ 台揚，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2336：股票名稱 ＝ 致伸，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2352：股票名稱 ＝ 佳世達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2353：股票名稱 ＝ 宏碁，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2359：股票名稱 ＝ 所羅門，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2361：股票名稱 ＝ 鴻友，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2369：股票名稱 ＝ 菱生，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2380：股票名稱 ＝ 虹光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2381：股票名稱 ＝ 華宇，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2387：股票名稱 ＝ 精元，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2388：股票名稱 ＝ 威盛，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2392：股票名稱 ＝ 正崴，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2396：股票名稱 ＝ 精碟，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2403：股票名稱 ＝ 友尚，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2421：股票名稱 ＝ 建準，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2430：股票名稱 ＝ 燦坤，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2431：股票名稱 ＝ 聯昌，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2436：股票名稱 ＝ 偉詮電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2438：股票名稱 ＝ 翔耀，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2439：股票名稱 ＝ 美律，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2442：股票名稱 ＝ 新美齊，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2450：股票名稱 ＝ 神腦，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2452：股票名稱 ＝ 乾坤，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2466：股票名稱 ＝ 冠西電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2468：股票名稱 ＝ 華經，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2471：股票名稱 ＝ 資通，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2473：股票名稱 ＝ 思源，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2494：股票名稱 ＝ 廣業科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2498：股票名稱 ＝ 宏達電，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3002：股票名稱 ＝ 歐格，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3008：股票名稱 ＝ 大立光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3013：股票名稱 ＝ 晟銘電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3017：股票名稱 ＝ 奇鋐，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3018：股票名稱 ＝ 隆銘綠能，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3020：股票名稱 ＝ 奇普仕，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3026：股票名稱 ＝ 禾伸堂，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3027：股票名稱 ＝ 盛達，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3033：股票名稱 ＝ 威健，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 
產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6213：股票名稱 ＝ 聯茂，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6214：股票名稱 ＝ 精誠，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6215：股票名稱 ＝ 和椿，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6235：股票名稱 ＝ 華孚，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6239：股票名稱 ＝ 力成，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6255：股票名稱 ＝ 奈普，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6277：股票名稱 ＝ 宏正，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6278：股票名稱 ＝ 台表科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6281：股票名稱 ＝ 全國電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6282：股票名稱 ＝ 康舒，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6283：股票名稱 ＝ 淳安，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6286：股票名稱 ＝ 立錡，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6405：股票名稱 ＝ 悅城，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6412：股票名稱 ＝ 群電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6414：股票名稱 ＝ 樺漢，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6446：股票名稱 ＝ 藥華藥，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6449：股票名稱 ＝ 鈺邦，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6456：股票名稱 ＝ GIS-KY，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6472：股票名稱 ＝ 保瑞，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6477：股票名稱 ＝ 安集，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6491：股票名稱 ＝ 晶碩，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6525：股票名稱 ＝ 捷敏-KY，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6526：股票名稱 ＝ 達發，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6541：股票名稱 ＝ 泰福-KY，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6668：股票名稱 ＝ 中揚光，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6689：股票名稱 ＝ 伊雲谷，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6742：股票名稱 ＝ 澤米，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 7836：股票名稱 ＝ 智生活，產業類別 ＝ 其他，類型 ＝ emerging
# 修改股票資訊。代碼 ＝ 8078：股票名稱 ＝ 華寶，產業類別 ＝ 電子工業，類型 ＝ twse
# ##### 更新技術分析資料 #####
# 2025-10-20 20:53:12.457 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:53:18.010 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:53:46.713 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:53:51.684 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:53:56.855 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:20.278 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:25.546 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:30.716 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:49.803 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:54.558 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:54:59.311 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 周K：2025-10-13
# 2025-10-20 20:55:45.774 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:55:51.033 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-10-20 20:55:56.472 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 日K：2025-10-20

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x481>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 4989.61億元 ，十日均量 ＝ 5569.69億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.24點。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-16黃金交叉。並且2025-10-20於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-06當周黃金交叉。並且2025-10-13該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>技術分析<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，K線多為紅K，顯示多頭力量較強。短期移動平均線（5日、10日）均在中長期移動平均線（20日、60日）之上，且呈現多頭排列，顯示上漲趨勢明顯。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有逐步減少的趨勢，顯示出量價背離的現象，需留意可能的回檔風險。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：短期支撐可參考10日移動平均線附近。<br />
# - 壓力位：近期高點附近可能形成壓力。<br />
# <br />
#  KD指標解讀<br />
# KD指標中的K線與D線均位於超買區，且K線高於D線，顯示短期內可能有回檔壓力，但整體仍維持多頭格局。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線高於MACD線，且柱狀體為正值，顯示多頭趨勢持續，但需注意柱狀體有縮短的跡象，可能預示動能減弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於多頭趨勢，但需注意成交量減少及技術指標顯示的短期回檔風險。建議投資者在持有多單的同時，設置適當的停損點位，以防止回檔風險。若價格突破近期高點，則可考慮加碼進場。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x481>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>孕育線／懷抱線 : 2025-10-17</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1074.07億元 ，十日均量 ＝ 1240.6億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-17黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-22當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>技術分析<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現盤整狀態，K線在短期移動平均線附近波動，顯示市場缺乏明確方向。長期移動平均線（如60日線）仍然向上，表明中長期趨勢仍偏多。<br />
# <br />
#  價量關係<br />
# 成交量在最近幾個交易日有所減少，顯示市場交投清淡，投資者觀望情緒較重。價格上漲時成交量未見明顯放大，顯示多頭動能不足。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：260點附近，該位置為近期多次測試的低點。<br />
# - 壓力位：265點附近，為近期高點，突破此位置需成交量配合。<br />
# <br />
#  KD指標<br />
# KD指標目前在50附近，K線上穿D線，顯示短期有反彈動能，但尚未進入超買區，需觀察後續動能是否持續。<br />
# <br />
#  MACD指標<br />
# MACD指標的DIF線與MACD線接近，且柱狀體逐漸縮短，顯示空頭動能減弱，市場可能進入盤整或反彈階段。<br />
# <br />
#  綜合評價<br />
# 目前市場處於盤整階段，短期內可能會在260至265點之間波動。若成交量能有效放大並突破265點，則有望進一步上行。投資者可考慮在支撐位附近布局，並在壓力位附近適時停利。若跌破260點，需謹慎觀望，考慮停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股解盤
# * 觀察股列表：
#   ![251020_1.png](attachment:589f26a5-5d76-4d1e-95b2-79d868df113f.png)

# %% [markdown]
# * 飛宏(2457)
#   看法：突破後回測，支撐有守。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2457')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 10357張 ，十日均量 ＝ 11428張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-05-28開始到2025-07-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-20死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-13當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析，以下是對當前市場狀況的技術分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，尤其在10月中旬出現明顯的上升走勢。K線圖顯示價格在高點後有些許回檔，但整體仍維持在較高水準。<br />
# <br />
#  價量關係<br />
# 成交量在價格上漲時顯著增加，顯示出多頭動能強勁。然而，隨著價格回檔，成交量也有所減少，這可能表示短期內多頭動能減弱。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：短期支撐位可觀察在27元附近，該位置接近近期回檔低點。<br />
# - 壓力位：上方壓力位在29元左右，接近近期高點。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線已從超買區回落，D線仍在高位，顯示出短期內可能有進一步回檔的風險，但整體仍維持在強勢區域。<br />
# <br />
#  MACD指標<br />
# MACD指標顯示多頭趨勢明顯，DIF線高於MACD線，且柱狀體維持正值，顯示出市場仍有上漲動能。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於多頭趨勢中，但短期內可能會有回檔調整。建議投資者在支撐位附近尋找買入機會，並在接近壓力位時考慮停利。若價格跌破支撐位，需謹慎觀察是否有進一步下跌的風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-26'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-09']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-07-09'
    bottom_price = range_prices.loc['2025-07-09']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-10-15'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2457','2025-02-21','2025-10-20',line_drawing_callback)
display(image)
# Out:
# 估算目標價為33.00元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-455)：外資小賣(-556)、投信中立(0)、自營小買(+101)。
# 主力小賣(-1205)。
# 分公司買賣家數差分散(-83)。
# 融資增(+293)、融券中立(-5)。
