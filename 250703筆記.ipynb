# %% [markdown]
# ### 工作進度
# * 新的筆記架構仍待定。
# * 調整GPT-4o模型的提示詞(Prompt)。

# %% [markdown]
# #### 引入模組與定義公用函式

# %%
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %% [markdown]
# #### 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 指數解盤

# %% [markdown]
# * 加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=811x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-03<br />
# 十字線 : 2025-07-03</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 3838.25億元 ，十日均量 ＝ 3831.85億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-03黃金交叉。並且2025-07-03於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-06-23該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# - 趨勢狀況：目前價格呈現上漲趨勢。K線多數為紅K，顯示多頭力量較強。<br />
# - 移動平均線：5日、10日、20日均線均向上，且價格位於均線之上，顯示短中期趨勢向好。<br />
# <br />
#  價量關係<br />
# - 成交量：近期成交量穩定，並未出現明顯放量或縮量，顯示市場情緒較為穩定。<br />
# - 價量配合：價格上漲時成交量並未大幅增加，顯示上漲動能可能有限。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：短期支撐在5日均線附近，約在22500點。<br />
# - 壓力位置：上方壓力在23000點附近，若能有效突破，將有進一步上漲空間。<br />
# <br />
#  KD指標<br />
# - 指標狀態：K線與D線在高位，接近超買區，但尚未出現明顯的死亡交叉，顯示短期仍有上漲空間，但需警惕回檔風險。<br />
# <br />
#  MACD指標<br />
# - 指標狀態：DIF線在MACD線之上，且灰色柱體為正，顯示多頭趨勢仍在延續。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於上漲趨勢中，短期內可能會面臨壓力位的挑戰。建議投資者在23000點附近謹慎操作，若突破可考慮加碼，否則需注意回檔風險。停損可設在22500點附近，以控制風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=798x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2025-06-30<br />
# 孕育線／懷抱線 : 2025-07-01</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 932.16億元 ，十日均量 ＝ 925.17億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-03黃金交叉。並且2025-07-03於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-02當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# - 趨勢狀況：近期價格呈現盤整趨勢。K線在240點附近波動，短期移動平均線（5日、10日）與中期移動平均線（20日、60日）糾結在一起，顯示出市場缺乏明顯的方向性。<br />
# <br />
#  價量關係<br />
# - 成交量：成交量整體平穩，未見明顯放量或縮量現象，顯示市場觀望情緒較重，買賣雙方力量相對均衡。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：短期支撐位在230點附近，該位置為多次回檔的低點。<br />
# - 壓力位置：上方壓力位在240點，為近期多次未能突破的高點。<br />
# <br />
#  KD指標<br />
# - 解讀：KD指標目前在高檔區域（接近80），但未進入超買區，K線與D線糾結，顯示短期內可能會有震盪整理。<br />
# <br />
#  MACD指標<br />
# - 解讀：MACD線與信號線接近零軸，且柱狀體顯示出動能較弱，市場缺乏明顯的上漲或下跌動能。<br />
# <br />
#  綜合評價<br />
# 目前市場處於盤整階段，價格在支撐與壓力之間波動，成交量平穩，顯示市場觀望情緒濃厚。KD與MACD指標均顯示出市場缺乏明顯的方向性。建議投資者在此階段保持觀望，等待市場出現明確的突破信號後再行操作。若價格突破240點壓力位，則可考慮進行短期多頭操作；若跌破230點支撐位，則需謹慎觀察是否進一步下跌。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 老師資訊

# %% [markdown]
# 📢【K線捕手｜7/3 盤前快訊】高檔整理 × 觀望氛圍 × 避險思維升溫
# 台股近期波動不大，但指數仍守穩 5 日線支撐，且中期轉折指標20 日線持續上揚，顯示中期趨勢尚未翻空。不過市場觀望情緒濃厚，成交量縮至 3041 億，靜待 7/9 美國關稅結果出爐。
# 📊 外資動向觀察：
# 買超前10名：日月光投控、彰銀、中信金、兆豐金、啟碁、中工、南亞、00940、00637L、台新金，賣超最大：元大台灣50（賣出近 4.9 萬張）。值得注意的是，外資近兩月持續加碼「元大台灣50反1」，而期貨空單逼近 5.5 萬口，創歷史新高，顯示即便現貨買超，避險思維也同步升溫。
# 🧭 操作策略與技術指標提醒：
# 20日線為多空轉折觀察重心，長期下降壓力線與盤整壓力區仍存在，盤中若出現量縮震盪，不宜追高。保守控制3～5成資金，聚焦2成具技術優勢的個股進行順勢操作，嚴避技術面轉弱個股，控制追價風險。
# 📬 每週一三五出刊 👉《K線追擊周報》
# 🌟 學習 × 操作 × 盤感同步提升
# 🔁 歡迎轉發分享，請註明出處：K線捕手｜楊忠憲粉絲團
# ![515863599_1324379403029317_1299134608149253778_n.jpg](attachment:9a7f959d-bc2a-4626-808c-bc97d3ba3c7b.jpg)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import datetime
import sqlite3

from talib.abstract import *

# %%
def get_monday_to_sunday(today, weekly=0):
    last = weekly * 7
    today = datetime.datetime.strptime(str(today), "%Y-%m-%d")
    monday = datetime.datetime.strftime(today - datetime.timedelta(today.weekday() - last), "%Y-%m-%d")
    monday_ = datetime.datetime.strptime(monday, "%Y-%m-%d")
    sunday = datetime.datetime.strftime(monday_ + datetime.timedelta(monday_.weekday() + 6), "%Y-%m-%d")
    return monday, sunday

# %%
stock_id           = 'TAIEX'
current_date       = datetime.datetime.today()
daily_end_date     = current_date.strftime('%Y-%m-%d')
daily_start_date,_ = get_monday_to_sunday((current_date - datetime.timedelta(days=730)).strftime('%Y-%m-%d'))

# %%
# 連線資料庫
conn = sqlite3.connect('data/stock.db')

# %%
# 從資料庫中載入「台股總覽 TaiwanStockInfo」
df_stock_info = pd.read_sql("SELECT * FROM StockInfo", conn)

# 將載入的「台股總覽 TaiwanStockInfo」進行格式轉換
df_stock_info.set_index(df_stock_info['StockID'],inplace=True)
df_stock_info = df_stock_info.drop(columns=['StockID'])

# %%
# 取得該股票代碼的產業分類
industry_category = df_stock_info.loc[stock_id]['IndustryCategory']

# %%
# 讀取日Ｋ價格資料
sql_cmd = "SELECT * FROM DailyPrice WHERE StockID='{}' AND (Date BETWEEN '{}' AND '{}')".format(stock_id,daily_start_date,daily_end_date)
daily_price_df = pd.read_sql( sql_cmd, conn)

# %%
# 格式轉換：日期格式、成交量(成交值)
daily_price_df           = daily_price_df.drop(columns=['SerialNo','StockID'])
daily_price_df['Date']   = daily_price_df['Date'].astype('datetime64[ns]')
daily_price_df.set_index(daily_price_df['Date'],inplace=True)
daily_price_df.drop(columns=['Date'],inplace=True)
if industry_category == 'Index' or industry_category == '大盤' :
    daily_price_df           = daily_price_df.drop(columns=['Volume'])
    daily_price_df           = daily_price_df.rename(columns={'Value':'Volume'})
    daily_price_df['Volume'] = daily_price_df['Volume'].div(100000000.00)
    daily_price_df['Volume'] = daily_price_df['Volume'].round(2)
else :
    daily_price_df           = daily_price_df.drop(columns=['Value'])
    daily_price_df['Volume'] = daily_price_df['Volume'].div(1000)
    daily_price_df['Volume'] = daily_price_df['Volume'].round()
    daily_price_df['Volume'] = daily_price_df['Volume'].astype('int64')

# %%
# 日Ｋ價格資料轉換為talib格式
daily_price_df_talib          = daily_price_df.copy()
daily_price_df_talib.columns  = [ i.lower() for i in daily_price_df_talib.columns]
        
# 計算移動平均線
talib_sma5        = SMA( daily_price_df_talib, timeperiod=5)
talib_sma10       = SMA( daily_price_df_talib, timeperiod=10)
talib_sma20       = SMA( daily_price_df_talib, timeperiod=20)
talib_sma60       = SMA( daily_price_df_talib, timeperiod=60)
talib_sma120      = SMA( daily_price_df_talib, timeperiod=120)
talib_sma240      = SMA( daily_price_df_talib, timeperiod=240)
# 設定名稱
talib_sma5.name   = 'SMA5'
talib_sma10.name  = 'SMA10'
talib_sma20.name  = 'SMA20'
talib_sma60.name  = 'SMA60'
talib_sma120.name = 'SMA120'
talib_sma240.name = 'SMA240'
# 合併各條均線
talib_sma_df      = pd.concat([talib_sma5, talib_sma10, talib_sma20, talib_sma60, talib_sma120, talib_sma240], axis=1)
# 取小數點後兩位
sma_df            = talib_sma_df.round(2)

# %%
# 設定價格範圍
range_prices = daily_price_df['2024-07-01':]
# 設定均線範圍
range_sma    = sma_df['2024-07-01':]

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定下降壓力線
resistance_line_start_date  = '2024-07-05'
resistance_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
resistance_line_x           = [date_to_index(range_prices,'2024-07-11'),date_to_index(range_prices,'2025-02-18')]
resistance_line_y           = [range_prices.loc['2024-07-11']['Low'],range_prices.loc['2025-02-18']['High']]
slope,intercept             = np.polyfit(resistance_line_x,resistance_line_y,1)
resistance_line_start_price = slope * date_to_index(range_prices,resistance_line_start_date) + intercept
resistance_line_end_price   = slope * date_to_index(range_prices,resistance_line_end_date) + intercept

# 設定盤整區間
line1_start_date = '2024-09-24'
line1_end_date   = '2025-03-06'
line1_price      = range_prices.loc['2025-01-07']['High']
line2_start_date = line1_start_date
line2_end_date   = line1_end_date
line2_price      = range_prices.loc['2024-12-02']['Open']

seq_of_seq_of_points=[
    [(resistance_line_start_date,resistance_line_start_price),(resistance_line_end_date,resistance_line_end_price)],
    [(line1_start_date,line1_price),(line1_end_date,line1_price)],
    [(line2_start_date,line2_price),(line2_end_date,line2_price)]
]

# 設定均線
added_plots = [
    mpf.make_addplot(range_sma['SMA5'],width=0.8,color='xkcd:red brown'),
    mpf.make_addplot(range_sma['SMA10'],width=0.8,color='xkcd:dark sky blue'),
    mpf.make_addplot(range_sma['SMA20'],width=1.0,color='xkcd:violet'),
    mpf.make_addplot(range_sma['SMA60'],width=0.8,color='xkcd:orange')
]

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=added_plots, alines=dict(alines=seq_of_seq_of_points, linewidths=(1.5,1.0,1.0), colors=('xkcd:red','xkcd:bright blue','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(range_prices,**kwargs)
