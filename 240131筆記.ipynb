# %% [markdown]
# #### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】再過4日，封關過年
# 昨天加權指數開高來到18138，曾提到可能會回測支撐，隨即開高走低，下跌85點，成交量稍微放大到2963億。櫃買指數相對穩定，小幅突破箱型區間，維持平盤之上，小漲0.22%。
# 雖然加權指數跌點不大，但卻是近9個交易日以來，首度出現明顯的黑K棒，今天不排除持續測試5日線，不過昨天提到「目前短中長期趨勢都偏多，最強的走勢只要5日線沒有跌破且下彎，短多就沒有結束，即使有拉回測試支撐，只要箱型區間沒有跌破，中期多方結構也不用過度擔心。」
# 指數中性偏多看待，但考驗投資人的選股功力，畢竟偏多族群一樣只有有半導體、電子、電子通路、綠能環保，弱是個股雖然上周以來，也跟著指數上漲，但格局上還是屬於反彈跟盤整，而且不少都到大壓力區了，上攻力道會趨緩，未來如果只靠隨機式和感覺式的選股，很能風險會比較高。
# 短線操作以及長期操作不需要考慮是否抱股過年，但波段操作的投資人就要好好思考，倘若仍想抱股過年，該個股封關前能守穩5日線或10日線基本上是相對安全，但如果20日線已經跌破且下彎，應優先積極減碼。溫馨提醒：連同今天計算，封關倒數剩下4個交易日。 (出處：K線捕手楊忠憲粉絲團)
# ![424799539_896208509179744_8457074447261981754_n.jpg](attachment:a7dfc03d-4d0f-4e71-beec-6168fc76bdff.jpg)

# %% [markdown]
# [財報空窗期 小飆股活跳跳](https://www.ctee.com.tw/news/20240131700220-430201?fbclid=IwAR1BaKaf3ObnYoguqfv_dO_w6f47PMHcjasbw5NW7KSZc3GST6tkXDjDJEk)
# 台積電在內的主要權值股熄火，使得台股加權指數30日微跌0.47％，收在18,034點，仍力守萬八關卡。與此同時，股價百元內（每張市值低於10萬元）的小型股活蹦亂跳，如蔚華科（3055）、尚立（3360）、亞矽（6113）、麗臺（2465）等。專家建議，在農曆年前的財報空窗期，可以依據熱門族群來挑小飆股，但需留意龍頭指標股的走勢。
#
# [美財報周鬧封關 13勇士抱股過年](https://www.ctee.com.tw/news/20240131700040-430201?fbclid=IwAR2S2qq-PZGpaf8V9UmnSYFIKaMCnhQF4oDmpe0gJR_A2NKry9RlLXwFe4s)
# 決戰美股超級財報周，1月31日開始連續三天，有多家美國AI科技巨頭公布財報，其中五大巨擘谷歌、超微、微軟、高通、蘋果，與台鏈關係最為密切，概念股將跟著台股封關收紅做最後的衝刺，法人並建議可依各機構做出的評等與目標價布局，抱股過年。
# 綜合內外資券商看法，篩選與這五家巨擘財報相關的概念股，計有技嘉、全新等13檔，「買進」評等有廣達、台積電、技嘉、緯穎、大立光、華通共六檔。「持有」評等則有勤誠與鴻海，「中立」評等為全新與穩懋；「逢低買進」評等有英業達、南電、欣興。
#
# [航運股Q1續揚帆？農曆年後航運價法人這樣看](https://www.ctee.com.tw/news/20240130700708-430201?fbclid=IwAR15EhYCjfFVIw3HgSFg6yKUktzO83XO4sF8f755GE-qgcpnnHYRvw2qyW0)
# 隨時序接近農曆春節，貨量增長幅度將逐漸趨緩，農曆年後進入需求空窗期，船舶陸續返回亞洲港口後，航商調度將相對具有餘裕，預期運價將高檔回落，運價止跌時機將視2024/3中旬需求恢復狀況而定。此外，2024年貨櫃市場運力增速逾9%，隨年後新船陸續下水，亦將逐漸緩解紅海危機事件導致的供給吃緊狀態。
#
# [金管會主委黃天牧：台股強韌穩健前行 向財部建議延長當沖降稅](https://money.udn.com/money/story/5613/7744258?fbclid=IwAR3fO9N0PBJVjPbqTbHMHgGnbYw_rGue-ImPTWhuGJkvofy7V-8dhJOe0ec)
# 金管會主委黃天牧昨（30）日指出，今年台股表現將是「展現韌性、穩健前行」。去年台股飆漲27%是近五年最佳戰績，但在金龍年，台股有地緣政治、氣候變遷、及全球選舉年，尤其是美國11月大選更是重中之重，今年在多重風險環境下，仍需臨淵履薄、步步為營，但台股深具韌性，具有「雲開月明的特質」。針對當沖降稅時間是否延長，證期局長張振山表示，證交所已在1月底提出稅式支出報告，正向財政部建議，延長當沖降稅的減稅期。
#
# [IMF 上修全球 GDP 成長到3.1% 地緣衝突威脅全球供應鏈仍是風險](https://money.udn.com/money/story/5599/7744264?fbclid=IwAR27LiVs1IJnlUZwZRcAYA4M1nqPZCj86Q8YpLZSXRsxHzbSC2RrGGChSSA)
# IMF提及的風險包含，地緣政治震撼和全球供應中斷，例如葉門胡塞叛軍在紅海發動的攻擊，或中東衝突擴大，導致大宗商品價格再次竄升，或頑強的通膨迫使各國央行在更長的時間維持高利率。
# IMF正關注中東衝突升高的可能性，「就目前而言，在供應中斷方面，以及對整體通膨的可能影響，仍相當有限」。
# IMF也再次告誡，認為全球可能發生貿易碎片化（fragmentation），並預測今年全球貿易成長3.3%，明年則成長3.6%，都低於歷史平均值4.9%。

# %% [markdown]
# 日本持續測試中期支撐：
# ![messageImage_1706659510709.jpg](attachment:90537504-a15b-483a-acec-08e0c87416fa.jpg)
#
# 期貨開低，下跌112點：
# ![messageImage_1706661951876.jpg](attachment:0dff449b-a9de-493e-b9a2-3802d64d8fb0.jpg)
#
# 加權指數開低小破5日線，測試中期支撐：
# ![messageImage_1706662839345.jpg](attachment:280ad4cf-2e34-4ecd-82bb-c326e7fb2cc9.jpg)
#
# 櫃買指數也是開低，不過守穩短中期支撐：
# ![messageImage_1706662919200.jpg](attachment:f6f8557a-2db4-40ae-93fd-022a5c86f9e5.jpg)
#
# 往滿足區前進：
# ![messageImage_1706663017513.jpg](attachment:8a8f8125-5b62-4238-a7ad-68f13b34e94d.jpg)
# 離滿足區空間有限：
# ![messageImage_1706663637265.jpg](attachment:536e6788-3305-4187-a92a-02f080ecfd98.jpg)

# %% [markdown]
# 加權指數休息，櫃買指數續攻：
# ![292293.jpg](attachment:e88aa5bf-d4b5-45c2-9e70-2b82f2f7f0c7.jpg)
# ![292294.jpg](attachment:d8024319-ea1e-4256-a6e1-25d2002c001f.jpg)
#
# 今天可能就要測試10日線了：
# ![73733.jpg](attachment:e40a9e53-a309-49ef-91df-0f6ade4066bc.jpg)
# ![73734.jpg](attachment:ed114cf5-b6ec-40c8-82fe-d8d0e26220fe.jpg)

# %% [markdown]
# ![292594.jpg](attachment:d2068c33-9bb0-43a8-a9a1-11ce8b5b944d.jpg)
# ![292595.jpg](attachment:a7c68f2b-19d7-486c-b2bf-4f527a078e74.jpg)

# %% [markdown]
# ### 本日進度
# * 本日投資觀點：市場靜待FOMC結果，美股四大指數漲跌互見
#   美國12月職位空缺數意外上升，表明勞動市場需求依然強勁，但就業者的心態轉趨謹慎，消費者信心繼續改善，市場持續消化企業財報，道瓊(+0.3%)續創歷史新高收報38467點，科技類股由蘋果(-3.69%)領跌，終場美股四大指數漲跌互見。盤後財報，Alphabet因上季廣告收入不如預期，盤後大跌逾5%，微軟受益於雲端業績成長，財報優於預期，盤後下跌約1%，AMD因財報展望保守，盤後重挫逾6%。市場靜待FOMC結果出爐，料按兵不動，關注縮表計畫及降息線索，目前利率期貨市場顯示Fed3月降息預期仍維持50%上下。
#   ![240131_1.png](attachment:97879391-6f26-48fc-8100-2af986959e3b.png)
# * **暫時空手**，觀察後續盤勢發展。
# * 將**整合**[PatternPy](https://github.com/keithorange/PatternPy)專案與[Algorithmic Chart Pattern Detection](https://analyzingalpha.com/algorithmic-chart-pattern-detection)文章之程式碼。
# * 【課程試聽，開始募集】
#   新一季的平日夜間班課程即將開始，每周五晚上7-9點，共計12周(堂)。沒有複習影片，會提供講義電子檔，全程線上課程，所以請務必評估時間是否能配合。2月16日第一堂課開放試聽，如果同學想試聽請到加入群組：https://line.me/R/ti/g/WwVaOvgX_C。
# * TradingView - [All Chart Patterns](https://www.tradingview.com/support/solutions/43000706927-all-chart-patterns/)
#   - Bullish Flag
#   - Bearish Flag
#   - Bullish Pennant
#   - Bearish Pennant
#   - Double Top (雙重頂)
#   - Double Bottom (雙重底)
#   - Triple Top (三重頂)
#   - Triple Bottom (三重底)
#   - Head And Shoulders (頭肩頂)
#   - Inverse Head And Shoulders (頭肩底)
#   - Rising Wedge
#   - Falling Wedge
#   - Triangle
#   - Rectangle (矩形)
# * 追蹤：宏致(3605)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2022年2月25日到今日收盤(2024年1月31日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_3605_240131.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_x_date = ['2023-03-09','2023-12-20']
neckline_x = [date_to_index(df_k_line,neckline_x_date[0]),date_to_index(df_k_line,neckline_x_date[1])]
neckline_y = [df_k_line.loc[neckline_x_date[0]]['Open'],df_k_line.loc[neckline_x_date[1]]['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_date = '2022-07-12'
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
breakout_date = '2024-01-24'
breakout_price = slope * date_to_index(df_k_line,breakout_date) + intercept
print('頸線開始價格 ＝ {:.2f} ， 頸線結束價格 ＝ {:.2f} ， 頸線突破價格 ＝ {:.2f}元'.format(neckline_start_price,neckline_end_price,breakout_price))

# 估算目標價
bottom_price_date = '2023-08-22'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
target_price = (on_neckline_price - bottom_price) + breakout_price
print('目標價 ＝ {:.2f}元'.format(target_price))
# Out:
# 頸線開始價格 ＝ 36.73 ， 頸線結束價格 ＝ 33.18 ， 頸線突破價格 ＝ 33.23元
# 目標價 ＝ 40.60元

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakout_date,breakout_price),(breakout_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
    
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1000)
mpf.plot(df_k_line,**kwargs)

# %% [markdown]
# * 追蹤：上曜(1316)

# %%
##### 使用2022年1月17日到今日收盤(2024年1月31日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1316_240131.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定頸線
neckline_start_date = '2022-09-07'
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_price = df_k_line.loc['2023-05-08']['Open']
breakout_date = '2024-01-30'

# 估算目標價
bottom_price_date = '2023-09-11'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('頸線價格 ＝ {:.2f}元 ， 底部最低價格 ＝ {:.2f}元 ； 估算目標價 ＝ {:.2f}元'.format(neckline_price,bottom_price,target_price))
# Out:
# 頸線價格 ＝ 13.85元 ， 底部最低價格 ＝ 10.15元 ； 估算目標價 ＝ 17.55元

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(breakout_date,neckline_price),(breakout_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
    
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1000)
mpf.plot(df_k_line,**kwargs)
