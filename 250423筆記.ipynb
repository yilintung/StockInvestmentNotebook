# ![messageImage_1745369434452.jpg](attachment:61934da4-c436-4e26-9b3d-21cfe44cee2b.jpg)
#
# 加權和櫃買上漲，中期持續箱型整理：
# ![750615.jpg](attachment:707d6a7f-19ff-48ec-8bdd-42063def464b.jpg)
# ![750616.jpg](attachment:6fdf7c09-ae23-4730-baf5-f4c1ada9e14e.jpg)
#
# 早上盤前說的，只要沒有被突破或跌破，指數就仍處於「中期箱型震盪」。
# 📈 上漲不需過度樂觀，📉 下跌也無須恐慌，保持中性視角最穩妥！

# %% [markdown]
# ![750692.jpg](attachment:a5d0f702-de3c-4b3a-b0ce-ba2f772ea2c4.jpg)
# ![750694.jpg](attachment:92ea6555-7b06-4142-bead-5342d0a5ad51.jpg)

# %% [markdown]
# 今天整體量能相較前幾日有放大，但還是偏低。
#
# 樂觀一點，你可以說盤整量縮，保守點一樣是反彈的價量關係。

# %% [markdown]
# 金耘國際(4950)
# ![messageImage_1745370308419.jpg](attachment:2e8448c9-fe41-4c7f-be18-8919667d776b.jpg)

# %% [markdown]
# 【[股市投資](https://www.facebook.com/kevinyang20180801/posts/pfbid02wPD6Kh8sdvcUpxajSEAvaNBR6d5e7VJke3dbpFENAeaEjtaHF1HcY5p2csgwmyg5l)，先學會輸】
# ❝你不喜歡輸？那你在股市會很痛苦。❞
# 在實際教學中，我不只一次聽到學生說：「我不喜歡輸的感覺。」這句話背後，藏著許多投資人「不會停損、不敢面對虧損」的根本原因。
# 或許你過去的人生順風順水，學業出色、事業成功，一路走來幾乎沒有碰過什麼挫折。尤其是那些學歷高、職位高的投資人，從小就是別人口中的「人生勝利組」，根本沒練習過如何面對失敗。
# 但股市不是你能用成績單解鎖的關卡，它是 「人生的總檢討」。
# 🎯 為什麼在股市中「不習慣輸」會變成致命傷？
# 因為在股市，你無法逃避失敗。現實人生中，有時候失敗可以選擇不面對、不承認、不處理；但在股市中，只要你還抱著那檔虧損的股票，它就每天提醒你——你錯了。
# 這裡沒有老師、沒有主管，也沒有標準答案，只有 你面對自己的決策與情緒的能力。
# 💡 其實，我算是幸運的
# 說實話，我不是最優秀的學生，也不是最成功的創業者，一路上總是平平的中段班。但也因為這樣，我學會了怎麼在失敗中站起來。每一次跌倒都變成了一次心理肌力的訓練。
# 所以當我踏進股市，雖然一樣會痛，但我知道怎麼調適、怎麼停損，怎麼從失敗中找經驗值。
# ✅ 投資不是比聰明，是比誰更能面對輸
# 如果你還討厭輸，那你要學會喜歡「學習輸」——
# ✔ 接受虧損是必經過程
# ✔ 練習果斷停損
# ✔ 練心理比練技術還重要
# 股市不只是打怪升級，是照妖鏡。它照出你的性格、你的盲點、你的執著，甚至你的人生價值觀。
#
# 📉📈【[看新聞，千萬別只看標題！](https://www.facebook.com/kevinyang20180801/posts/pfbid0qErj8qyXe2vmZiUBrpYotuyPvzqMgryqd13EhRcUgKeHwj8HPxtPfHXtfTLt9SJRl)】
# 昨天道瓊大漲，不少媒體就急著喊「美股井噴！」但冷靜想想——兩週前那根長紅K，那又該叫什麼？🌋🚀
# 其實真正的投資人都知道：
# 👉 大漲 ≠ 多頭起飛
# 👉 看盤 ≠ 看熱鬧
# 👉 分析重點在於驗證，而不是跟風！
# 昨天這波，其實就是短線跌深反彈罷了。
# 中期來看，道瓊還是在箱型整理區間打轉，結構沒變，方向未定。
# 別被頭條牽著鼻子走，你要的是判斷力，不是驚嘆號！🧠📊

# %% [markdown]
# ![751182.jpg](attachment:129c32df-4d8b-474a-b08b-e0fd4bbf69d9.jpg)
# ![751183.jpg](attachment:1845dcd1-71a3-49fb-a3f9-4bf7fbd9bc24.jpg)

# %% [markdown]
# 🎯今日影音已上架
# 美債瀕臨破底！黃金、日圓拉回還能追？操作策略一次看
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3140

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統：規劃與開發
#   - 確認與敲定資料庫架構。
#     ![250423_1.png](attachment:53c399f0-8571-4fe5-b468-94fe472fb715.png)
#     * 加入「[交易額](https://www.twse.com.tw/en/trading/statistics/index02.html)」欄位。
#   - 確認與敲定技術型態之[主觀性質的客觀化](https://www.ipci.com.tw/books_in.php?book_id=294)：StockChartPatterns類別。
#     * 先確定一個版本來做驗證並用於系統中，待系統上線上後再依實際情況進行調整。
# * 驗證：StockChartPatterns類別
#   - 「底部型態識別方法」修改與驗證。
#   - 調整「型態識別（使用ＧＰＴ－４ｏ多模態模型）方法」之提問文字描述。

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization( prices, patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            # 驗證：型態最後一個轉折點離價格資料距離
            print('◆ 型態最後一個轉折點離價格資料距離 ＝ {} '.format( date_to_index(prices,prices.iloc[-1].name) - date_to_index(prices,pattern_window.iloc[-1]['Date']) ))
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
                
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
                
                # 後處理：無效三角形判斷 — 交叉
                if line2_end_price > line1_end_price :
                    print("  Ⅹ 無效的三角形型態")
                    continue
                else :
                    # 設定趨勢線
                    seq_of_seq_of_points=[
                        [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                        [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                    ]
            elif pattern_name == '上升旗形' or pattern_name == '下降旗形' or pattern_name == '看跌三角旗形' or pattern_name == '看漲三角旗形'  : 
                line1_start_date = pattern_window.iloc[1]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line1_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line2_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization( prices, patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if '頂' in pattern['type'] :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 15.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            elif '底' in pattern['type'] :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line2_angle)
                if neckline_angle > 15.0 :
                    highest_point = sys.float_info.min
                    for index,price in range_price.iterrows() :
                        if price['Open'] > highest_point :
                            highest_point = price['Open']
                        if price['Close'] > lowest_point :
                            highest_point = price['Close']
                    seq_of_seq_of_points = [(lines[1][0][0],highest_point),(lines[1][1][0],highest_point)]
                else :
                    seq_of_seq_of_points = lines[1]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
# 型態視覺化：型態後處理程序之雛形
def bottom_pattern_visualization( prices, bottom_pattern) :
    bottom_pattern_breakout = False
    if 'bottom_pattern_breakout_date' in bottom_pattern :
        bottom_pattern_breakout_date  = bottom_pattern['bottom_pattern_breakout_date']
        bottom_pattern_breakout_price = bottom_pattern['bottom_pattern_breakout_price']
        pattern_breakout = True
    neckline_start_date  = bottom_pattern['neckline_start_date']
    neckline_start_price = bottom_pattern['neckline_start_price']
    neckline_end_date    = bottom_pattern['neckline_end_date']
    neckline_end_price   = bottom_pattern['neckline_end_price']
    bottom_price_date    = bottom_pattern['bottom_price_date']
    bottom_price         = bottom_pattern['bottom_price']
    on_neckline_price    = bottom_pattern['on_neckline_price']
    target_price         = bottom_pattern['target_price']
    
    # 設定K線格式
    mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
    s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

    # 設定頸線
    if bottom_pattern_breakout is True :
        seq_of_seq_of_points=[
            [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
            [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
            [(bottom_pattern_breakout_date,bottom_pattern_breakout_price),(bottom_pattern_breakout_date,target_price)]
                             ]
    else :
        seq_of_seq_of_points=[
            [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
            [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
            [(neckline_end_date,neckline_end_price),(neckline_end_date,target_price)]
                             ]
    
    # 繪製K線圖
    kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=(1.2,10,10), colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
    mpf.plot(prices,**kwargs)

# %% [markdown]
# > 底部型態案例一

# %%
##### 使用2024年1月2日到2025年1月9日收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_3543_250109.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
patterns = chart_pattern.RecognitionBottom()
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 15）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 45 （日期 ＝ 2024-03-15 ） ， 底部型態結束索引 ＝ 240 （日期 ＝ 2024-12-30 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 0.00°
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 240 ～ 248
# ＤＥＢＵＧ ： 底部最低價格 ＝ 19.85元 ； 估算目標價 ＝ 29.15元
# {'neckline_start_date': '2024-02-29', 'neckline_start_price': 24.500101742987276, 'neckline_end_date': '2025-01-09', 'neckline_end_price': 24.499948046134154, 'bottom_price_date': '2024-08-07', 'bottom_price': 19.85, 'on_neckline_price': 24.50002381218851, 'target_price': 29.14997185832266}

# %% [markdown]
# > 底部型態案例二

# %%
##### 使用2023年6月5日到2024年11月7日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2332_241107.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
patterns = chart_pattern.RecognitionBottom()
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 22）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 76 （日期 ＝ 2023-09-22 ） ， 底部型態結束索引 ＝ 346 （日期 ＝ 2024-11-06 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 6.14°
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 346 ～ 348
# ＤＥＢＵＧ ： 確認底部型態突破，收盤價超過頸線３％。價格索引 ＝ 347 ， 日期 ＝ 2024-11-07 ， 突破時頸線價格 ＝ 20.02元
# ＤＥＢＵＧ ： 底部最低價格 ＝ 16.15元 ； 估算目標價 ＝ 24.04元
# {'neckline_start_date': '2023-09-19', 'neckline_start_price': 20.66885896103906, 'neckline_end_date': '2024-11-07', 'neckline_end_price': 20.024116165127644, 'bottom_pattern_breakout_date': '2024-11-07', 'bottom_pattern_breakout_price': 20.024116165127644, 'bottom_price_date': '2024-08-07', 'bottom_price': 16.15, 'on_neckline_price': 20.167653794874344, 'target_price': 24.04176996000199}

# %% [markdown]
# > 底部型態案例三

# %%
##### 使用2022年2月25日到2023年3月11日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_6274_230311.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
patterns = chart_pattern.RecognitionBottom()
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 10）
# ＤＥＢＵＧ ： 此轉折高點與底部型態之前高點間不足１５％空間，結束底部型態確認。此轉折點 ＝
# Date     2023-03-09 00:00:00
# Price                   69.6
# Type                      HI
# Name: 251, dtype: object
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 89 （日期 ＝ 2022-07-07 ） ， 底部型態結束索引 ＝ 217 （日期 ＝ 2023-01-06 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 0.46°
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 217 ～ 237
# ＤＥＢＵＧ ： 確認底部型態突破，收盤價超過頸線３％。價格索引 ＝ 218 ， 日期 ＝ 2023-01-09 ， 突破時頸線價格 ＝ 58.36元
# ＤＥＢＵＧ ： 底部最低價格 ＝ 39.40元 ； 估算目標價 ＝ 77.42元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 10 ，結束索引 ＝ 10）
# {'neckline_start_date': '2022-06-27', 'neckline_start_price': 58.58210741838101, 'neckline_end_date': '2023-01-09', 'neckline_end_price': 58.35935102268281, 'bottom_pattern_breakout_date': '2023-01-09', 'bottom_pattern_breakout_price': 58.35935102268281, 'bottom_price_date': '2022-10-13', 'bottom_price': 39.4, 'on_neckline_price': 58.45853452733675, 'target_price': 77.41788555001956}

# %% [markdown]
# > 底部型態案例四

# %%
##### 使用2024年1月16日到2025年1月16日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_6140_250116.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 案例：目標價過前高
patterns = chart_pattern.RecognitionBottom()
print(patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 16）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 24 （日期 ＝ 2024-02-29 ） ， 底部型態結束索引 ＝ 238 （日期 ＝ 2025-01-10 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 37.51°
# ＤＥＢＵＧ ： 頸線角度-37.51°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 40.50）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 238 ～ 243
# ＤＥＢＵＧ ： 底部最低價格 ＝ 21.75元 ； 估算目標價 ＝ 59.25元
# ＤＥＢＵＧ ： 目標價過前高，非有效底部型態 ： {'neckline_start_date': '2024-02-02', 'neckline_start_price': 40.5, 'neckline_end_date': '2025-01-16', 'neckline_end_price': 40.5, 'bottom_price_date': '2024-11-29', 'bottom_price': 21.75, 'on_neckline_price': 40.5, 'target_price': 59.25}
# []

# %%
patterns = chart_pattern.RecognitionBottom(valid_pattern_check=False)
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 16）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 24 （日期 ＝ 2024-02-29 ） ， 底部型態結束索引 ＝ 238 （日期 ＝ 2025-01-10 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 37.51°
# ＤＥＢＵＧ ： 頸線角度-37.51°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 40.50）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 238 ～ 243
# ＤＥＢＵＧ ： 底部最低價格 ＝ 21.75元 ； 估算目標價 ＝ 59.25元
# {'neckline_start_date': '2024-02-02', 'neckline_start_price': 40.5, 'neckline_end_date': '2025-01-16', 'neckline_end_price': 40.5, 'bottom_price_date': '2024-11-29', 'bottom_price': 21.75, 'on_neckline_price': 40.5, 'target_price': 59.25}

# %%
patterns = chart_pattern.RecognitionBottom(turning_point_args={'mode':'close', 'order':10, 'smoothing':2})
print(patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'close', 'order': 10, 'smoothing': 2}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 16）
# ＤＥＢＵＧ ： 此轉折高點超過先前轉折高點１５％，結束底部型態確認。此轉折點 ＝
# Date     2024-05-31 00:00:00
# Price                  37.65
# Type                      HI
# Name: 87, dtype: object
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 44 （日期 ＝ 2024-03-28 ） ， 底部型態結束索引 ＝ 83 （日期 ＝ 2024-05-27 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 25.63°
# ＤＥＢＵＧ ： 頸線角度-25.63°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 30.80）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 83 ～ 103
# ＤＥＢＵＧ ： 確認底部型態突破，收盤價超過頸線３％。價格索引 ＝ 84 ， 日期 ＝ 2024-05-28 ， 突破時頸線價格 ＝ 30.80元
# ＤＥＢＵＧ ： 底部最低價格 ＝ 26.55元 ； 估算目標價 ＝ 35.05元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 7 ，結束索引 ＝ 16）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 131 （日期 ＝ 2024-08-06 ） ， 底部型態結束索引 ＝ 238 （日期 ＝ 2025-01-10 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 4.17°
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 238 ～ 243
# ＤＥＢＵＧ ： 底部最低價格 ＝ 22.30元 ； 估算目標價 ＝ 35.59元
# [{'argument': {'mode': 'close', 'order': 10, 'smoothing': 2}, 'bottom_pattern': {'neckline_start_date': '2024-03-14', 'neckline_start_price': 30.8, 'neckline_end_date': '2024-05-28', 'neckline_end_price': 30.8, 'bottom_pattern_breakout_date': '2024-05-28', 'bottom_pattern_breakout_price': 30.8, 'bottom_price_date': '2024-04-23', 'bottom_price': 26.55, 'on_neckline_price': 30.8, 'target_price': 35.05}}, {'argument': {'mode': 'close', 'order': 10, 'smoothing': 2}, 'bottom_pattern': {'neckline_start_date': '2024-07-26', 'neckline_start_price': 29.961654617120743, 'neckline_end_date': '2025-01-16', 'neckline_end_price': 28.728228042987617, 'bottom_price_date': '2024-11-19', 'bottom_price': 22.3, 'on_neckline_price': 29.15679151366099, 'target_price': 35.585019556648604}}]

# %%
# 繪製第一個型態
pattern = patterns[0]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# {'neckline_start_date': '2024-03-14', 'neckline_start_price': 30.8, 'neckline_end_date': '2024-05-28', 'neckline_end_price': 30.8, 'bottom_pattern_breakout_date': '2024-05-28', 'bottom_pattern_breakout_price': 30.8, 'bottom_price_date': '2024-04-23', 'bottom_price': 26.55, 'on_neckline_price': 30.8, 'target_price': 35.05}

# %%
# 繪製第二個型態
pattern = patterns[1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# {'neckline_start_date': '2024-07-26', 'neckline_start_price': 29.961654617120743, 'neckline_end_date': '2025-01-16', 'neckline_end_price': 28.728228042987617, 'bottom_price_date': '2024-11-19', 'bottom_price': 22.3, 'on_neckline_price': 29.15679151366099, 'target_price': 35.585019556648604}

# %% [markdown]
# > 底部型態案例五

# %%
##### 使用2023年12月13日到2025年1月22日收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_8093_250128.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 案例：有太過突出的高點
patterns = chart_pattern.RecognitionBottom()
print(patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 10）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 181 （日期 ＝ 2024-09-12 ） ， 底部型態結束索引 ＝ 262 （日期 ＝ 2025-01-13 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 21.40°
# ＤＥＢＵＧ ： 頸線角度-21.40°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 22.70）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 262 ～ 270
# ＤＥＢＵＧ ： 底部最低價格 ＝ 19.50元 ； 估算目標價 ＝ 25.90元
# ＤＥＢＵＧ ： 底部型態中有突出５％的高點，非有效底部型態 ： {'neckline_start_date': '2024-07-29', 'neckline_start_price': 22.7, 'neckline_end_date': '2025-01-22', 'neckline_end_price': 22.7, 'bottom_price_date': '2024-09-12', 'bottom_price': 19.5, 'on_neckline_price': 22.7, 'target_price': 25.9}
# []

# %%
patterns = chart_pattern.RecognitionBottom(valid_pattern_check=False)
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 10）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 181 （日期 ＝ 2024-09-12 ） ， 底部型態結束索引 ＝ 262 （日期 ＝ 2025-01-13 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 21.40°
# ＤＥＢＵＧ ： 頸線角度-21.40°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 22.70）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 262 ～ 270
# ＤＥＢＵＧ ： 底部最低價格 ＝ 19.50元 ； 估算目標價 ＝ 25.90元
# {'neckline_start_date': '2024-07-29', 'neckline_start_price': 22.7, 'neckline_end_date': '2025-01-22', 'neckline_end_price': 22.7, 'bottom_price_date': '2024-09-12', 'bottom_price': 19.5, 'on_neckline_price': 22.7, 'target_price': 25.9}

# %%
patterns = chart_pattern.RecognitionBottom({'mode':'close', 'order':5})
pattern = patterns[-1]['bottom_pattern']
print(pattern)
bottom_pattern_visualization(df_k_line,pattern)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'close', 'order': 5}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 23）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 154 （日期 ＝ 2024-08-06 ） ， 底部型態結束索引 ＝ 255 （日期 ＝ 2025-01-02 ）
# ＤＥＢＵＧ ： 頸線角度（絕對值） ＝ 30.17°
# ＤＥＢＵＧ ： 頸線角度-30.17°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 24.60）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 255 ～ 270
# ＤＥＢＵＧ ： 底部最低價格 ＝ 19.95元 ； 估算目標價 ＝ 29.25元
# {'neckline_start_date': '2024-07-15', 'neckline_start_price': 24.6, 'neckline_end_date': '2025-01-22', 'neckline_end_price': 24.6, 'bottom_price_date': '2024-09-11', 'bottom_price': 19.95, 'on_neckline_price': 24.6, 'target_price': 29.250000000000004}

# %% [markdown]
# > GPT-4o版型態識別：今天大盤

# %%
##### 使用2023年8月16日到今日(2025年4月23日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250423.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定區間價格
range_prices = df_k_line['2025-02-18':]
range_sma    = df_sma['2025-02-18':]

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
support_line_start_date    = '2025-04-07'
support_line_end_date      = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
support_line_price         = range_prices.loc['2025-04-07']['Open']
resistance_line_start_date = support_line_start_date
resistance_line_end_date   = support_line_end_date
resistance_line_price      = range_prices.loc['2025-04-10']['Open']

seq_of_seq_of_points=[
    [(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)],
    [(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)],
]

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(range_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(range_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(range_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(range_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(range_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(range_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.2, colors='xkcd:red', alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(range_prices,**kwargs)

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o(single_pattern = True)
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-04-18 ， 型態結束日期 ＝ 2024-09-30

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 上升趨勢 ， 型態開始日期 ＝ 2023-08-17 ， 型態結束日期 ＝ 2024-06-30
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-06-30 ， 型態結束日期 ＝ 2024-11-04
# 型態類型 ＝ 下降趨勢 ， 型態開始日期 ＝ 2025-01-13 ， 型態結束日期 ＝ 2025-04-23

# %% [markdown]
# > GPT-4o版型態識別：底部型態

# %%
##### 使用2022年2月25日到2023年3月11日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_6274_230311.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o(single_pattern = True)
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩底 ， 型態開始日期 ＝ 2022-06-30 ， 型態結束日期 ＝ 2023-02-07
