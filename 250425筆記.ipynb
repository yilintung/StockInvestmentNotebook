# ![753513.jpg](attachment:6eed492f-1cf0-4dc9-b40a-288abc641429.jpg)

# %% [markdown]
# 陞泰(8072)
# ![messageImage_1745543013954.jpg](attachment:91430705-a902-4495-b8a3-0813b56052ae.jpg)
# ![messageImage_1745543025264.jpg](attachment:e33ef0a7-84be-49cd-8a2d-1ff5915ece45.jpg)
#
# 台積電(2330)
# ![messageImage_1745543093784.jpg](attachment:dddb4eda-da13-4bc6-b9f5-403b834230ca.jpg)

# %% [markdown]
# [最近看到同學回傳讀書心得分享內容](https://www.facebook.com/kevinyang20180801/posts/pfbid02m8LrVU1nKvwzhi1P8XSWevjFXAYP7WYxYvVZzXJmtFTZPkSDduiVPTWXMrHjszvDl)，真的是非常感動，以下僅做適度潤飾與排版，盡可能保留原始內容：
# 近期將《專買黑馬股》系列1、2、3再次讀過，看著看著心中有些想法，特別紀錄當下感悟。個人認為「選股、買點、目標價」是這套交易系統與操作方法的源頭、基石。甚至對這三件事多作說明，觀點不一定適當，全文如下：
# \[1/3\]
# 黑馬股系列書籍是作者針對投資標的價格，提出系統化、模組化的評價模式與相應買賣方法。此交易系統有其理論基礎，且能在股市實際運用，歷經金融市場數次多空循環，驗證時間長達十年以上，並解決坊間常見的兩大投資痛點：
# 投資理論架構雖完善、論述清楚，但面對金融市場時，缺乏有效的實務買賣方法。交易方式缺乏完整嚴謹的論證，大多為自行研究或口耳相傳，有時可行、有時不可行。
# 作者亦指出，透過技術分析建構的交易系統有其侷限。當行情處於多頭時，底型等距離目標滿足法與旗型的成功率分別為 85% 與 75%，換言之，仍有 15%～25% 的失敗率。
# 為此，需透過盤中漲跌、K 棒、價量關係、均線、乖離率、KD、MACD 與型態等技術分析工具，適時進行停利與停損動作，以確保獲利入袋並減少大幅損失本金的風險，也藉此補強原先交易系統的不足之處。
# \[2/3\]
# 價格評價始於三件事：選股、買點、目標價。買進投資標的前，需先進行分析與評價。個股選定後，在盤中觀察是否出現買進訊號，接著規劃行情走勢並擬定交易對策。三者之間的關係如下：
# a) 有了 3（目標價），必然已存在 2（買點）與 1（選股）。
# b) 2 不會憑空出現，必然先有 1，未必有 3。
# c) 一切需從 1 開始，但未必會有 2 與 3。
# 透過 a、b、c 三種關係，凸顯出選股、買點與目標價背後的邏輯思維——有效的買點不會憑空出現。
# 價格評價首重趨勢、位階、型態、支撐、壓力與轉折六大元素，接著透過技術指標工具、圖形工具、價量關係與籌碼等進行綜合分析與細部拆解，給予合理評分。分數若高於評價門檻，方能納入選股名單並執行買進動作。
# 也就是說，投資人將從 K 線圖上的宏觀趨勢為起點，經由一連串資訊梳理與判讀，找出微觀轉折 K 棒的漲幅、量能、時間與籌碼等有效買進訊號。
# \[3/3\]
# 買進投資標的後，並非放著不管、期待股價自然上漲至目標價後賣出賺取價差。在股價行進過程中，經常會因國內外環境、市場消息或公司重大政策的發布影響股價走向。
# 此時，若投資人心中尚未有因應對策，面對股價異常波動或下跌時，往往會不知所措，任由原先帳上獲利變為打平、小賠、中賠，最後大賠出場。
# 因此，買進後應依據持有成本與當下行情，擬定數個交易對策，再從中挑選最可能發生的情境進行應對，方能因應突發狀況。
# 最後，投資人除了需具備專業與經驗外，若能搭配書中提及的資產配置、風險控管、部位調節與健康投資心態，將是成為長期股市贏家的關鍵因子。
# 若非刻意追求技術分析在歷史上的定位或研發新式指標工具與方法，建議投資朋友多加閱讀《專買黑馬股》系列1、2、3，讀熟、讀懂、讀通。如此，股市淘金，便能游刃有餘。

# %% [markdown]
# ![753722.jpg](attachment:fc57f8b2-cb47-4e21-88a7-745b753373a2.jpg)
# ![753723.jpg](attachment:3ffdc608-0733-4d2a-ace4-060d46abca76.jpg)

# %% [markdown]
# 🎯今日影音已上架
# 轉強還是假象？台股該進場還是觀望？
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3144

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統：規劃與開發
#   - 型態識別（StockChartPatterns類別）後處理程序研究

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if pattern['type'] == '頭肩頂' or pattern['type'] == '雙頂' or pattern['type'] == '圓弧頂' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 15.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2023年8月21日到今日(2025年4月25日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250425.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o(major_pattern=False)
print(patterns)
# Out:
# [{'type': '上升趨勢', 'start': '2023-08-21', 'end': '2024-02-01'}, {'type': '頭肩頂', 'start': '2024-02-01', 'end': '2024-10-04'}, {'type': '下降趨勢', 'start': '2024-10-04', 'end': '2025-03-17'}]

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-04-01 ， 型態結束日期 ＝ 2025-01-06

# %%
gpt4o_major_pattern           = patterns[0]
gpt4o_major_pattern_start_idx = date_to_index(df_k_line,gpt4o_major_pattern['start'])
gpt4o_major_pattern_end_idx   = date_to_index(df_k_line,gpt4o_major_pattern['end'])

# %%
# 進行型態識別
turning_point_args = []
turning_point_args.append({'mode':'open_close', 'order':5})
turning_point_args.append({'mode':'open_close', 'order':10})
turning_point_args.append({'mode':'open_close', 'order':15})
turning_point_args.append({'mode':'open_close', 'order':20})
turning_point_args.append({'mode':'open_close', 'order':25})
turning_point_args.append({'mode':'open_close', 'order':30})
patterns = chart_pattern.Recognition(max_bars=360, turning_point_args=turning_point_args)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'open_close', 'order': 15}, {'mode': 'open_close', 'order': 20}, {'mode': 'open_close', 'order': 25}, {'mode': 'open_close', 'order': 30}]

# %%
# 後處理程序實驗：頭部
pattern_suitable_distance = sys.maxsize
candidate_pattern         = None
for pattern_name in patterns:
    if '頂' in pattern_name :
        for pattern in patterns[pattern_name] :
            window            = pattern['window']
            pattern_start_idx = window.iloc[1].name
            pattern_end_idx   = window.iloc[-1].name
            pattern_distance  = abs(gpt4o_major_pattern_start_idx - pattern_start_idx) + abs(gpt4o_major_pattern_end_idx - pattern_end_idx)
            if pattern_distance < pattern_suitable_distance :
                print('pattern_name = {} , gpt4o_major_pattern_start_idx = {} , gpt4o_major_pattern_end_idx = {} , pattern_start_idx = {} , pattern_end_idx = {} '.format(pattern_name,gpt4o_major_pattern_start_idx,gpt4o_major_pattern_end_idx,pattern_start_idx,pattern_end_idx))
                pattern_suitable_distance = pattern_distance
                candidate_pattern         = [pattern_name,pattern['argument'],pattern['window']]

if candidate_pattern is not None :                        
    pattern_name   = candidate_pattern[0]
    pattern_window = candidate_pattern[2]
    seq_of_seq_of_points = []
    if pattern_name == '雙重頂' or pattern_name == '雙重底':
        pattern_first_date_idx  = pattern_window.iloc[0].name
        pattern_start_date_idx  = pattern_window.iloc[1].name
        neckline_start_date_idx = gpt4o_major_pattern_start_idx
        neckline_end_date_idx   = gpt4o_major_pattern_end_idx
        neckline_start_date     = df_k_line.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
        neckline_end_date       = df_k_line.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
        neckline_start_price    = pattern_window.iloc[2]['Price']
        neckline_end_price      = pattern_window.iloc[2]['Price']
        # 設定頸線
        seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
    elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
        pattern_first_date_idx  = pattern_window.iloc[0].name
        pattern_start_date_idx  = pattern_window.iloc[1].name
        neckline_start_date_idx = gpt4o_major_pattern_start_idx
        neckline_end_date_idx   = gpt4o_major_pattern_end_idx
        neckline_start_date     = df_k_line.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
        neckline_end_date       = df_k_line.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
        neckline_x              = [date_to_index(df_k_line,pattern_window.iloc[2]['Date']),date_to_index(df_k_line,pattern_window.iloc[4]['Date'])]
        neckline_y              = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
        neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
        neckline_start_price    = neckline_slope * date_to_index(df_k_line,neckline_start_date) + neckline_intercept
        neckline_end_price     = neckline_slope * date_to_index(df_k_line,neckline_end_date) + neckline_intercept
        # 設定頸線
        seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
    # 設定K線格式
    mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
    s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)        
    # 設定轉折點
    turning_points_len = len(np.array(df_k_line['Close']))
    turning_points = np.array([np.nan]*turning_points_len)
    for point in pattern_window.iterrows() :
        turning_points[point[0]] = point[1]['Price']
    apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]        
    # 繪製K線圖
    kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
    mpf.plot(df_k_line,**kwargs)
# Out:
# pattern_name = 雙重頂 , gpt4o_major_pattern_start_idx = 148 , gpt4o_major_pattern_end_idx = 336 , pattern_start_idx = 152 , pattern_end_idx = 186
# pattern_name = 雙重頂 , gpt4o_major_pattern_start_idx = 148 , gpt4o_major_pattern_end_idx = 336 , pattern_start_idx = 217 , pattern_end_idx = 282
# pattern_name = 頭肩頂 , gpt4o_major_pattern_start_idx = 148 , gpt4o_major_pattern_end_idx = 336 , pattern_start_idx = 152 , pattern_end_idx = 243
