# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-04-23 21:30:57.622 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-23 21:30:57.672 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-23 21:30:57.692 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 新增股票代碼。代碼 ＝ 009819：股票名稱 ＝ 中信數據及電力，產業類別 ＝ ETF，類型 ＝ twse
# 新增股票代碼。代碼 ＝ 009820：股票名稱 ＝ 元大納斯達克精選，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1704：股票名稱 ＝ 榮化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1708：股票名稱 ＝ 東鹼，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1709：股票名稱 ＝ 和益，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1723：股票名稱 ＝ 中碳，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1726：股票名稱 ＝ 永記，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1727：股票名稱 ＝ 中華化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1762：股票名稱 ＝ 中化生，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1773：股票名稱 ＝ 勝一，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 14601.03億元 ，十日均量 ＝ 10056.18億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重底，型態範圍由2026-03-03開始到2026-04-08結束，估算目標價為37317.96點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2026-04-23<br />
# 高檔夜星 : 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 4148.54億元 ，十日均量 ＝ 2965.38億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2025-11-20開始到2026-03-24結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 6129 ， 股票名稱 ＝ 普誠
# 股票代碼 ＝ 6104 ， 股票名稱 ＝ 創惟
# 股票代碼 ＝ 6243 ， 股票名稱 ＝ 迅杰
# 股票代碼 ＝ 6695 ， 股票名稱 ＝ 芯鼎
# 股票代碼 ＝ 6558 ， 股票名稱 ＝ 興能高
# 股票代碼 ＝ 6962 ， 股票名稱 ＝ 奕力-KY
# 股票代碼 ＝ 5471 ， 股票名稱 ＝ 松翰

# %% [markdown]
# * 篩選結果
#   - 九暘(8040)：多頭回檔
#     ![260423_2.png](attachment:a125302c-db72-4a94-8cc8-1dd43466bffc.png)
#   - 威盛(2388)：多頭回檔
#     ![260423_3.png](attachment:3771bfad-dcd2-420e-89c6-597ab75228a6.png)
#   - 通嘉(3588)：穩健續漲／已到壓力區
#     ![260423_4.png](attachment:f4baaaa3-bce7-41ff-a9f6-1e698fe291af.png)
#   - 九齊(6494)：多頭回檔
#     ![260423_5.png](attachment:5a95e2bb-2bfa-4d62-9b62-48ad81e5ec8c.png)
#   - 公準(3178)：多頭回檔
#     ![260423_6.png](attachment:e9749d75-bab5-452c-8cf3-d906714f3c5c.png)
#   - 和碩(4938)：多頭回檔
#     ![260423_7.png](attachment:9ea1b98b-cb44-4002-b279-46646b4d8c37.png)

# %% [markdown]
# * 觀察股列表
#   ![260422_1.png](attachment:d3dbb977-7ada-4bb1-be56-78450079ceaf.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：跌破頸線支撐，因此這檔追蹤至今日。
#   新聞：[「二哥」、 緯創強勢入列！00900成分股大換血　「護國神山」竟被踢出](https://www.ftnn.com.tw/news/539491)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2026-04-22<br />
# 鎚子線／吊人線 : 2026-04-22<br />
# 吞噬 : 2026-04-20 , 2026-04-21 , 2026-04-23<br />
# 孕育線／懷抱線 : 2026-04-22</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 3511張 ，十日均量 ＝ 2666張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-08-11開始到2026-04-23結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-10-09','2026-04-23',line_drawing_callback)
display(image)
# Out:
# 估算目標價為57.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-703)：外資小買(+374)、投信大賣(-1043)、自營小賣(-34)。
# 主力大賣(-691)。
# 分公司買賣家數差分散(-216)。
# 融資中立(-1)、融券增(+6)。

# %% [markdown]
# * 盟立(2464)
#   看法：遇到前高壓力後急速拉回，因此這檔追蹤至今日。
#   ![260423_8.png](attachment:b82b1c31-d9d0-4a23-945f-dc9aed436f1d.png)
#   新聞：[SpaceX替太空AI踩煞車！示警商業化未必可行　太空概念股昇達科、華通、盟立跌停](https://www.ftnn.com.tw/news/540168)

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。

# %%
stock_analysis(analysis,'2464')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-21<br />
# 吞噬 : 2026-04-17 , 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 20567張 ，十日均量 ＝ 13556張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2026-01-05開始到2026-03-09結束，估算目標價為52.10元。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# 籌碼面：
# 法人大賣(-2444)：外資大賣(-1867)、投信中立(0)、自營大賣(-577)。
# 主力大賣(-3389)。
# 分公司買賣家數差分散(-39)。
# 融資減(-533)、融券減(-95)。
