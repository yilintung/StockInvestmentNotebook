# 下面這樣說可能會不小心酸到很多人，如果那些總經、個經、產業、基本面、財報…，真的對投資和交易有用，那全世界最有錢的人應該都是商學院出身，但真相是否如此，我想不用我說，你也知道答案。所以很多道理和真相，都是常識推演一下就可以知道答案。

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值39,250元(收盤價：39.25元，漲0.1元)。調整後的停損價為35.00元，目標價為42.50元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,39.25,39078,2727,7.5]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  39.25  39078  2727   7.5

# %%
##### 使用2022年3月11日到今日收盤價(2023年7月11日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230711.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-9-13']['Open']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 估算目標價
bottom_price_date = '2022-10-21'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('目標價 ＝ {:.2f}元'.format(target_price))
target_price_date = '2023-06-02'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(2.5,15,15), colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 35.00元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-07-11
# 目標價 ＝ 42.50元

# %%
import myutils

# 尋找轉折點
_,_,max_min = myutils.FindingTurningPoints(df_k_line,'close',order=10,real_body=True)
print(max_min)

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定轉折線
seq_of_seq_of_points = []
for _current in range(0,len(max_min)) :
    _next = _current + 1
    if _next < len(max_min) :
        seq_of_seq_of_points.append([(max_min.iloc[_current]['Date'],max_min.iloc[_current]['Price']),(max_min.iloc[_next]['Date'],max_min.iloc[_next]['Price'])])
    else :
        break
        
# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=1, colors='xkcd:azure', alpha=0.6))
mpf.plot(df_k_line,**kwargs)
# Out:
#                 Date  Price Type
# DateIndex
# 8         2022-03-23  47.45   HI
# 41        2022-05-12  36.15   LO
# 59        2022-06-08  40.10   HI
# 76        2022-07-01  26.10   LO
# 86        2022-07-15  36.05   HI
# 103       2022-08-09  30.40   LO
# 115       2022-08-25  36.30   HI
# 124       2022-09-07  31.50   LO
# 126       2022-09-12  34.90   HI
# 154       2022-10-21  27.50   LO
# 185       2022-12-05  33.40   HI
# 209       2023-01-09  29.20   LO
# 232       2023-02-21  32.10   HI
# 272       2023-04-25  28.30   LO
# 277       2023-05-03  31.35   HI
# 294       2023-05-26  28.95   LO
# 312       2023-06-21  37.65   HI

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 手動設定頸線
neckline_x = [date_to_index(df_k_line,'2022-05-12'),date_to_index(df_k_line,'2023-06-21')]
neckline_y = [df_k_line.loc['2022-05-12']['Close'],df_k_line.loc['2023-06-21']['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_price = slope * date_to_index(df_k_line,'2022-05-05') + intercept
neckline_start_date = '2022-04-22'
neckline_end_price = slope * date_to_index(df_k_line,today_date) + intercept
neckline_end_date = today_date

# 設定目標價
target_pirce = df_k_line.loc['2022-03-23']['Close']
target_state_date = '2022-03-23'
target_end_date = today_date

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(target_state_date,target_pirce),(target_end_date,target_pirce)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

print('頸線 ＝ {:.2f} ， 目標價 ＝ {:.2f}'.format(neckline_end_price,target_pirce))

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(1,1), colors=('xkcd:sky blue','xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線 ＝ 37.72 ， 目標價 ＝ 47.45

# %% [raw]
# * 實作FindingDirectionalChangePoints( )

# %%
# 來源 ： https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/directional_change.py

def directional_change(close: np.array, high: np.array, low: np.array, sigma: float):
    
    up_zig = True # Last extreme is a bottom. Next is a top. 
    tmp_max = high[0]
    tmp_min = low[0]
    tmp_max_i = 0
    tmp_min_i = 0

    tops = []
    bottoms = []

    for i in range(len(close)):
        if up_zig: # Last extreme is a bottom
            if high[i] > tmp_max:
                # New high, update 
                tmp_max = high[i]
                tmp_max_i = i
            elif close[i] < tmp_max - tmp_max * sigma: 
                # Price retraced by sigma %. Top confirmed, record it
                # top[0] = confirmation index
                # top[1] = index of top
                # top[2] = price of top
                top = [i, tmp_max_i, tmp_max]
                tops.append(top)

                # Setup for next bottom
                up_zig = False
                tmp_min = low[i]
                tmp_min_i = i
        else: # Last extreme is a top
            if low[i] < tmp_min:
                # New low, update 
                tmp_min = low[i]
                tmp_min_i = i
            elif close[i] > tmp_min + tmp_min * sigma: 
                # Price retraced by sigma %. Bottom confirmed, record it
                # bottom[0] = confirmation index
                # bottom[1] = index of bottom
                # bottom[2] = price of bottom
                bottom = [i, tmp_min_i, tmp_min]
                bottoms.append(bottom)

                # Setup for next top
                up_zig = True
                tmp_max = high[i]
                tmp_max_i = i

    return tops, bottoms

# %%
##### 尋找轉折點函式 #####
# prices     : 價格 (DataFrame)
# percentage : 百分比 (int) 
def FindingDirectionalChangePoints( prices, percentage=5) :
    # 價格資料確認與處理
    if prices is None and type(prices) is not DataFrame:
        return None
    in_prices = prices.copy()
    if 'Open' not in in_prices.columns or 'High' not in in_prices.columns or 'Low' not in in_prices.columns or 'Close' not in in_prices.columns :
        return None    
    if 'Date' not in in_prices.columns and in_prices.index.dtype == 'datetime64[ns]' :
        in_prices.index.name = 'Date'
        in_prices = in_prices.reset_index()
    if 'Date' not in in_prices.columns :
        return None
    # 參數轉換
    prices_close=np.array(in_prices['Close'])
    prices_high=np.array(in_prices['High'])
    prices_low=np.array(in_prices['Low'])
    sigma = float(percentage) / 100.0
    total_price = len(prices_close)
    # 呼叫directional_change函式
    tops, bottoms = directional_change(prices_close,prices_high,prices_low,sigma)
    local_min = np.array(bottoms)
    local_max = np.array(tops)
    local_min_idx = local_min[:,1]
    local_max_idx = local_max[:,1]
    # 合併局部最大(波峰)與局部最小(波谷)轉折點
    local_max_min_point=[]
    for idx in range(total_price):
        if idx in local_max_idx :
            local_max_min_point.append((idx,in_prices.iloc[idx]['Date'],in_prices.iloc[idx]['High'],'HI'))
        elif idx in local_min_idx :
            local_max_min_point.append((idx,in_prices.iloc[idx]['Date'],in_prices.iloc[idx]['Low'],'LO'))
    local_max_min_point = pd.DataFrame(local_max_min_point,columns=['DateIndex','Date','Price','Type'])
    # 轉換為輸出格式
    max_min = local_max_min_point.set_index('DateIndex')
    return local_min_idx,local_max_idx,max_min

# %%
# 尋找轉折點
min_idx,max_idx,max_min = FindingDirectionalChangePoints(df_k_line)
print(min_idx,max_idx)
print(max_min)

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定轉折線
seq_of_seq_of_points = []
for _current in range(0,len(max_min)) :
    _next = _current + 1
    if _next < len(max_min) :
        seq_of_seq_of_points.append([(max_min.iloc[_current]['Date'],max_min.iloc[_current]['Price']),(max_min.iloc[_next]['Date'],max_min.iloc[_next]['Price'])])
    else :
        break
        
# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=1, colors='xkcd:azure', alpha=0.6))
mpf.plot(df_k_line,**kwargs)
# Out:
# [ 31.  41.  49.  67.  70.  76.  89. 104. 124. 138. 150. 154. 180. 210.
#  227. 273. 285. 317.] [  9.  36.  48.  57.  69.  72.  86.  98. 116. 127. 144. 152. 173. 186.
#  219. 233. 278. 312.]
#                 Date  Price Type
# DateIndex
# 9         2022-03-24  47.80   HI
# 31        2022-04-27  38.75   LO
# 36        2022-05-05  41.50   HI
# 41        2022-05-12  36.10   LO
# 48        2022-05-23  38.35   HI
# 49        2022-05-24  36.25   LO
# 57        2022-06-06  40.85   HI
# 67        2022-06-20  27.30   LO
# 69        2022-06-22  30.00   HI
# 70        2022-06-23  27.25   LO
# 72        2022-06-27  29.60   HI
# 76        2022-07-01  26.00   LO
# 86        2022-07-15  36.55   HI
# 89        2022-07-20  31.90   LO
# 98        2022-08-02  34.90   HI
# 104       2022-08-10  29.60   LO
# 116       2022-08-26  36.75   HI
# 124       2022-09-07  31.50   LO
# 127       2022-09-13  35.70   HI
# 138       2022-09-28  28.10   LO
# 144       2022-10-06  32.35   HI
# ...

# %% [markdown]
# * 深度學習計算資源 ： [Colab 訂閱價格](https://colab.research.google.com/signup)
