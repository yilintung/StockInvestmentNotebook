# %% [markdown]
# ### 工作進度
# * 新的筆記架構仍待定，之前規劃的方向：
#   - 第一部分：大盤解盤
#     * 加權指數
#     * 櫃買指數
#   - 第二部分：個股解盤 ← 老師觀察股、自選觀察股
#   - * 補充籌碼面資訊？
#   - 第三部分：股票老師資訊
#     * 盤前快訊
#     * 畫線或繪圖的量化

# %% [markdown]
# #### 引入模組與定義公用函式

# %%
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
#### 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 指數解盤

# %% [markdown]
# * 加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=832x480>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-03<br />
# 十字線 : 2025-07-03<br />
# 吞噬 : 2025-07-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 2690.71億元 ，十日均量 ＝ 3653.75億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-04死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-06-30該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢分析<br />
# 從K線圖來看，近期價格呈現上漲趨勢。價格持續在5日和10日移動平均線之上，顯示短期趨勢偏多。20日移動平均線也呈現上升趨勢，進一步支持中期的多頭走勢。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有明顯增加，顯示出多頭動能強勁。然而，近期成交量略有減少，需注意是否有量價背離的風險。<br />
# <br />
#  支撐與壓力判斷<br />
# 目前支撐位可參考10日移動平均線，約在22,500點附近。壓力位則在近期高點23,000點左右。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線和D線在高檔區域出現回檔，K線已經跌破D線，顯示短期可能有修正壓力。需注意是否會進一步跌破50的中線。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線仍在MACD線之上，但柱狀體縮短，顯示多頭動能減弱。需觀察是否會出現死叉信號。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於上升趨勢，但短期內可能面臨回檔壓力。建議投資者在22,500點附近尋找支撐，若跌破則需考慮停損。若價格能夠突破23,000點，則有望進一步上行。投資者應密切關注成交量變化及技術指標的進一步走勢。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>孕育線／懷抱線 : 2025-07-01</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為低位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 822.3億元 ，十日均量 ＝ 954.56億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-04死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-02當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現盤整狀態。K線圖顯示價格在230至240點之間波動，短期移動平均線（5日、10日）與中期移動平均線（20日、60日）糾結，顯示出市場缺乏明確方向。<br />
# <br />
#  價量關係<br />
# 成交量整體平穩，未見明顯放量或縮量現象。這表明市場參與者對當前價格區間的認同度較高，短期內可能維持盤整。<br />
# <br />
#  支撐與壓力<br />
# 支撐位大約在230點，壓力位則在240點。價格多次在這兩個位置反彈或回檔，顯示出其重要性。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線（紅線）與D線（藍線）在50附近交錯，並未進入超買或超賣區，顯示出市場動能不足，短期內可能繼續盤整。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線（紅線）與MACD線（藍線）接近零軸，且柱狀體（OSC）變化不大，顯示出市場動能較弱，短期內缺乏明顯趨勢。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於盤整階段，價格在230至240點之間波動。成交量平穩，KD與MACD指標均顯示動能不足，短期內可能繼續維持盤整。建議投資者在此區間內謹慎操作，等待明確的突破信號再行進場。若價格突破240點，可能會迎來新的上漲趨勢；若跌破230點，則需注意風險管理。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ###  個股解盤

# %% [markdown]
# * 統一(1216)
#   ![messageImage_1751859079956.jpg](attachment:46f77a0b-2b5c-46a6-8272-2a4062c35017.jpg)

# %%
stock_analysis(analysis,'1216')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>孕育線／懷抱線 : 2025-07-03</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 7454張 ，十日均量 ＝ 26671張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重底，型態範圍由2024-11-20開始到2025-06-30結束，估算目標價為88.11。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線走平，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-07死亡交叉。並且2025-07-07於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-30當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 近期價格呈現上漲趨勢，K線多為紅K，顯示多頭力量較強。短期移動平均線（5日、10日）向上穿越中期移動平均線（20日、60日），形成多頭排列，進一步確認上漲趨勢。<br />
# <br />
#  價量關係<br />
# 成交量在價格上漲時有所增加，顯示價量配合良好，支持上漲趨勢。然而，近期成交量略有減少，需留意後續量能是否能持續放大以支撐價格上行。<br />
# <br />
#  支撐與壓力判斷<br />
# 目前支撐位可參考20日移動平均線附近，約在80元左右。壓力位則在前高點附近，約在85元左右。<br />
# <br />
#  KD指標解讀<br />
# KD指標目前位於超買區域，K線略高於D線，顯示短期內可能有回檔壓力，但整體仍維持多頭格局。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線位於MACD線之上，且灰色柱體持續在零軸上方增長，顯示多頭動能持續增強。<br />
# <br />
#  綜合評價<br />
# 整體來看，該股目前處於上漲趨勢，價量配合良好，技術指標支持多頭格局。然而，由於KD指標進入超買區域，短期內可能面臨回檔壓力。建議投資者可考慮在支撐位附近進行佈局，並設置適當的停損點以控制風險。若價格突破壓力位，則可考慮加碼進場。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 老師資訊

# %% [markdown]
# 📢【K線捕手｜7/7盤前快訊】上升楔形 × 觀望氛圍 × 避險思維升溫
# 📌雖然美股仍維持多頭格局，但亞股呈現兩樣情，短線多方力道轉弱，多數進入橫盤整理。台股更出現上升楔形的雛形，此型態屬於價格收斂，常出現在多頭尾聲，具備反轉向下的警訊。
# 🔺上升楔形特徵為：高點與低點持續墊高但漸趨收斂，形成向上傾斜的楔形結構，通常伴隨成交量萎縮，顯示市場動能減弱。雖然價格持續創高，但一旦跌破下緣支撐（目前約落在10日與20日線），常視為轉空訊號。偶有向上假突破，卻常淪為一日行情。
# 🧠 小提醒：若發生在 漲勢末段，如果跌破支撐，須防漲多拉回，若發生在中期空頭反彈中，更容易成為假象回升後的再度下跌。加上7月9日關稅談判到期，市場仍有變數，又剛好出現此技術型態，務必多加謹慎小心。
# 台股近期波動不大，但指數仍守穩 5 日線支撐，且中期轉折指標20 日線持續上揚，顯示中期趨勢尚未翻空。不過市場觀望情緒濃厚，成交量縮至 3041 億，靜待 7/9 美國關稅結果出爐。
# 📊 外資動向觀察：
# 買超前10名：聯電、日月光投控、元大滬深300正2、亞泥、玉山金、第一金、彰銀、中信金、華南金。元大台灣50持續在賣超第一名，值得注意的是，外資近兩月持續加碼「元大台灣50反1」，而期貨空單持續維持在5萬口之上，顯示即便現貨買超，避險思維也同步升溫。
# 🧭 操作策略與技術指標提醒：
# 上升楔形雛型浮現，20日線為多空轉折觀察重心，密切注意7月9日消息面釐清後的走勢。
# 📬 每週一三五出刊 👉《K線追擊周報》
# 🌟 學習 × 操作 × 盤感同步提升
# ![messageImage_1751843257534.jpg](attachment:c550478e-56a2-488e-9ff3-5099128863c5.jpg)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import datetime
import sqlite3

from talib.abstract import *

# %%
def get_monday_to_sunday(today, weekly=0):
    last = weekly * 7
    today = datetime.datetime.strptime(str(today), "%Y-%m-%d")
    monday = datetime.datetime.strftime(today - datetime.timedelta(today.weekday() - last), "%Y-%m-%d")
    monday_ = datetime.datetime.strptime(monday, "%Y-%m-%d")
    sunday = datetime.datetime.strftime(monday_ + datetime.timedelta(monday_.weekday() + 6), "%Y-%m-%d")
    return monday, sunday

# %%
stock_id           = 'TAIEX'
current_date       = datetime.datetime.today()
daily_end_date     = current_date.strftime('%Y-%m-%d')
daily_start_date,_ = get_monday_to_sunday((current_date - datetime.timedelta(days=730)).strftime('%Y-%m-%d'))

# %%
# 連線資料庫
conn = sqlite3.connect('data/stock.db')

# %%
# 從資料庫中載入「台股總覽 TaiwanStockInfo」
df_stock_info = pd.read_sql("SELECT * FROM StockInfo", conn)

# 將載入的「台股總覽 TaiwanStockInfo」進行格式轉換
df_stock_info.set_index(df_stock_info['StockID'],inplace=True)
df_stock_info = df_stock_info.drop(columns=['StockID'])

# %%
# 取得該股票代碼的產業分類
industry_category = df_stock_info.loc[stock_id]['IndustryCategory']

# %%
# 讀取日Ｋ價格資料
sql_cmd = "SELECT * FROM DailyPrice WHERE StockID='{}' AND (Date BETWEEN '{}' AND '{}')".format(stock_id,daily_start_date,daily_end_date)
daily_price_df = pd.read_sql( sql_cmd, conn)

# %%
# 格式轉換：日期格式、成交量(成交值)
daily_price_df           = daily_price_df.drop(columns=['SerialNo','StockID'])
daily_price_df['Date']   = daily_price_df['Date'].astype('datetime64[ns]')
daily_price_df.set_index(daily_price_df['Date'],inplace=True)
daily_price_df.drop(columns=['Date'],inplace=True)
if industry_category == 'Index' or industry_category == '大盤' :
    daily_price_df           = daily_price_df.drop(columns=['Volume'])
    daily_price_df           = daily_price_df.rename(columns={'Value':'Volume'})
    daily_price_df['Volume'] = daily_price_df['Volume'].div(100000000.00)
    daily_price_df['Volume'] = daily_price_df['Volume'].round(2)
else :
    daily_price_df           = daily_price_df.drop(columns=['Value'])
    daily_price_df['Volume'] = daily_price_df['Volume'].div(1000)
    daily_price_df['Volume'] = daily_price_df['Volume'].round()
    daily_price_df['Volume'] = daily_price_df['Volume'].astype('int64')

# %%
# 日Ｋ價格資料轉換為talib格式
daily_price_df_talib          = daily_price_df.copy()
daily_price_df_talib.columns  = [ i.lower() for i in daily_price_df_talib.columns]
        
# 計算移動平均線
talib_sma5        = SMA( daily_price_df_talib, timeperiod=5)
talib_sma10       = SMA( daily_price_df_talib, timeperiod=10)
talib_sma20       = SMA( daily_price_df_talib, timeperiod=20)
talib_sma60       = SMA( daily_price_df_talib, timeperiod=60)
talib_sma120      = SMA( daily_price_df_talib, timeperiod=120)
talib_sma240      = SMA( daily_price_df_talib, timeperiod=240)
# 設定名稱
talib_sma5.name   = 'SMA5'
talib_sma10.name  = 'SMA10'
talib_sma20.name  = 'SMA20'
talib_sma60.name  = 'SMA60'
talib_sma120.name = 'SMA120'
talib_sma240.name = 'SMA240'
# 合併各條均線
talib_sma_df      = pd.concat([talib_sma5, talib_sma10, talib_sma20, talib_sma60, talib_sma120, talib_sma240], axis=1)
# 取小數點後兩位
sma_df            = talib_sma_df.round(2)

# %%
# 設定價格範圍
range_prices = daily_price_df['2025-03-28':]
# 設定均線範圍
range_sma    = sma_df['2025-03-28':]

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定楔形壓力線
resistance_line_start_date  = '2025-05-13'
resistance_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
resistance_line_x           = [date_to_index(range_prices,'2025-05-16'),date_to_index(range_prices,'2025-06-12')]
resistance_line_y           = [range_prices.loc['2025-05-16']['Close'],range_prices.loc['2025-06-12']['Open']]
slope,intercept             = np.polyfit(resistance_line_x,resistance_line_y,1)
resistance_line_start_price = slope * date_to_index(range_prices,resistance_line_start_date) + intercept
resistance_line_end_price   = slope * date_to_index(range_prices,resistance_line_end_date) + intercept

# 設定楔形支撐線
support_line_start_date  = '2025-06-02'
support_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
support_line_x           = [date_to_index(range_prices,'2025-06-02'),date_to_index(range_prices,'2025-06-30')]
support_line_y           = [range_prices.loc['2025-06-02']['Low'],range_prices.loc['2025-06-30']['Close']]
slope,intercept             = np.polyfit(support_line_x,support_line_y,1)
support_line_start_price = slope * date_to_index(range_prices,support_line_start_date) + intercept
support_line_end_price   = slope * date_to_index(range_prices,support_line_end_date) + intercept

seq_of_seq_of_points=[
    [(resistance_line_start_date,resistance_line_start_price),(resistance_line_end_date,resistance_line_end_price)],
    [(support_line_start_date,support_line_start_price),(support_line_end_date,support_line_end_price)]
]

# 設定均線
added_plots = [
    mpf.make_addplot(range_sma['SMA5'],width=0.8,color='xkcd:red brown'),
    mpf.make_addplot(range_sma['SMA10'],width=0.8,color='xkcd:dark sky blue'),
    mpf.make_addplot(range_sma['SMA20'],width=1.0,color='xkcd:violet'),
    mpf.make_addplot(range_sma['SMA60'],width=0.8,color='xkcd:orange')
]

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=added_plots, alines=dict(alines=seq_of_seq_of_points, linewidths=(1.5,1.0,1.0), colors=('xkcd:red','xkcd:red'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(range_prices,**kwargs)
