#
# 櫃買指數長天期的上升趨勢線已經跌破：
# ![messageImage_1691111011841.jpg](attachment:524a8fc0-f96c-4f2b-93c7-a1fca1599f34.jpg)
# ![messageImage_1691111059863.jpg](attachment:6b13c29e-9c70-4064-918c-0a4c9dca84c9.jpg)
#
# AI還沒有止跌現象：
# ![messageImage_1691111294679.jpg](attachment:2a1791ec-d90a-4ff2-8456-31d6ed4e8940.jpg)
#
# 台幣持續貶值：
# ![messageImage_1691111531370.jpg](attachment:b4e271e3-1961-46de-9a43-25db8d7de70f.jpg)
#
# 義隆(2458)：
# ![messageImage_1691111968207.jpg](attachment:dea6c473-65b2-47ad-b045-bf3c910e11c0.jpg)
#
# 加權和櫃買都很努力在守支撐：
# ![messageImage_1691112036070.jpg](attachment:99a687bc-9932-4413-b890-05fd7bbba44c.jpg)
# ![messageImage_1691112047822.jpg](attachment:5961515b-151d-49fa-b2a9-d047c16db5e2.jpg)
#
# 加權指數目前的點位很重要，是中長期的複合支撐，上升趨勢線+季線+前低：
# ![messageImage_1691112590046.jpg](attachment:8a515b52-1521-417f-8440-04a712ffcae6.jpg)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2022年9月5日到今天收盤(2023年8月4日)的日K線資料繪製 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_230804.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10', 'DIF12-26','MACD9','OSC','K(9,3)','D(9,3)'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10', 'DIF12-26','MACD9','OSC','K(9,3)','D(9,3)']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 人工設定上升趨勢線(紅)
trendline_up_x = [date_to_index(df_k_line,'2022-10-25'),date_to_index(df_k_line,'2023-05-12')]
trendline_up_y = [df_k_line.loc['2022-10-25']['Close'],df_k_line.loc['2023-05-12']['Close']]
slope,intercept = np.polyfit(trendline_up_x,trendline_up_y,1)
trendline_up_start_date = '2022-10-25'
trendline_up_start_price = slope * date_to_index(df_k_line,'2022-10-25') + intercept
trendline_up_end_date = '2023-08-04'
trendline_up_end_price = slope * date_to_index(df_k_line,'2023-08-04') + intercept

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定上升趨勢線
seq_of_seq_of_points=[
    [(trendline_up_start_date,trendline_up_start_price),(trendline_up_end_date,trendline_up_end_price)]
                     ]

# 設定均線
added_plots={
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.4,color='xkcd:salmon')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=1.0, colors='xkcd:red', alpha=0.6))
mpf.plot(df_k_line,**kwargs)

# %%
import myutils

# 尋找轉折點
_,_,max_min = myutils.FindingTurningPoints(df_k_line,'close',order=5)
print(max_min)

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定均線與轉折點    
turning_points_len = len(np.array(df_k_line['Close']))
turning_points = np.array([np.nan]*turning_points_len)
for point in max_min.iterrows() :
    turning_points[point[0]] = point[1]['Price']    
apds = [
    mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=50,color='xkcd:sky blue')
]

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=apds)
mpf.plot(df_k_line,**kwargs)
# Out:
#                 Date     Price Type
# DateIndex
# 8         2022-08-04  14702.20   LO
# 17        2022-08-17  15465.45   HI
# 32        2022-09-07  14410.05   LO
# 35        2022-09-13  14894.41   HI
# 64        2022-10-25  12666.12   LO
# 91        2022-12-01  15012.80   HI
# 111       2022-12-29  14085.02   LO
# 135       2023-02-14  15654.48   HI
# 141       2023-02-22  15418.77   LO
# 148       2023-03-07  15857.89   HI
# 155       2023-03-16  15221.12   LO
# 174       2023-04-17  15963.55   HI
# 180       2023-04-25  15370.73   LO
# 189       2023-05-09  15727.70   HI
# 193       2023-05-15  15475.05   LO
# 216       2023-06-15  17334.98   HI
# 222       2023-06-27  16887.90   LO
# 227       2023-07-04  17140.77   HI
# 231       2023-07-10  16652.80   LO
# 236       2023-07-17  17334.29   HI
# 240       2023-07-21  17030.70   LO
# 245       2023-07-28  17292.93   HI

# %%
# 設定上升趨勢線：目視轉折點已設定趨勢線
trendline_up_x = [64,193]
trendline_up_y = [max_min.loc[trendline_up_x[0]]['Price'],max_min.loc[trendline_up_x[1]]['Price']]
slope,intercept = np.polyfit(trendline_up_x,trendline_up_y,1)
trendline_up_start_date = '2022-10-25'
trendline_up_start_price = slope * date_to_index(df_k_line,'2022-10-25') + intercept
trendline_up_end_date = '2023-08-04'
trendline_up_end_price = slope * date_to_index(df_k_line,'2023-08-04') + intercept

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定上升趨勢線
seq_of_seq_of_points=[
    [(trendline_up_start_date,trendline_up_start_price),(trendline_up_end_date,trendline_up_end_price)]
                     ]

# 設定均線
added_plots={
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.4,color='xkcd:salmon')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=1.0, colors='xkcd:blue', alpha=0.6))
mpf.plot(df_k_line,**kwargs)

# %% [markdown]
# 今天台股短線上算是守的不錯：
# ![messageImage_1691117449008.jpg](attachment:1610e8c5-1141-4231-b94a-38d626e7266c.jpg)
# ![messageImage_1691117458827.jpg](attachment:c9fcc578-b48e-463f-bbff-fc787443d8fb.jpg)

# %% [markdown]
# 【[把它當小說看就好04-青少年理財養成術](https://www.facebook.com/kevinyang20180801/posts/pfbid0UKwk9NSL9Ey8uxUqwSRXXBRwss38nywHxPMYG3eNn7RHLBzSmGF7kfcZoijtS42Rl)】
# 常常有同學問這個問題：「老師你會投資股票，會不會教你的小孩呢？」、「打算甚麼時候教他呢？」青少年以前，關於投資理財，父母該位小孩做些甚麼準備？我想首先是給予基本的教育，現在的社會瀰漫著一種教育無用論的可怕迷思，但基本的教育絕對是必須的，大家去看國內外的富豪家族，無不傾進全力栽培下一代。
# 尤其是如果存著這種想法：「我留給兒子的錢，就算打斷腿都花不完！不用太會讀書啦！」會這樣想的家長，通常是在小孩沒變成殘廢之前，錢就差不多敗光了。小富才會富不過三代，大富可以富幾百年，到現在仍然興旺，這當中的差異，關鍵就是教育和人才培養。
# 我自己的小孩目前只有國一，雖然學習金融知識跟建立理財觀念要趁早，例如儲蓄跟消費的觀念(細節下一篇再寫)，但是進入金融商品的交易，我覺得不宜過早，凡事過猶不及，大家試想，如果一個高中生，沒有經歷過真實人生的酸甜苦澀、人情冷暖，不知金錢得來不易。
# 然後只是因為長輩給了50萬，買了股票，陰錯陽差之下，就賺了5萬元，已經超過一般人的月薪，這樣對小孩的金錢觀和價值觀很容易扭曲，因此我覺得完成學業之後，至少要加上3年以上的職場和社會歷練，再開始實戰投資會比較適合。
# 而且未來有一個很重要的條件，是我一定會要求的，就是用來創業或是投資的第一筆錢，必須是要靠自己努力賺來，這樣賺賠才會有感，對學習經驗累積比較有正面幫助，投資心態也會比較健康，等到專業跟時間成熟，才可以挹注小孩資金。

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * **[參賽](https://ithelp.ithome.com.tw/users/20161619/ironman/5955)** ： 2023 iThome 鐵人賽：用Python程式進行股票技術分析。
# * 驗證：自動價格趨勢線([Automated Price Trend Lines in Python](https://www.youtube.com/watch?v=wbFoefnidTU))：

# %%
def check_trend_line(support: bool, pivot: int, slope: float, y: np.array):
    # compute sum of differences between line and prices, 
    # return negative val if invalid 
    
    # Find the intercept of the line going through pivot point with given slope
    intercept = -slope * pivot + y[pivot]
    line_vals = slope * np.arange(len(y)) + intercept
     
    diffs = line_vals - y
    
    # Check to see if the line is valid, return -1 if it is not valid.
    if support and diffs.max() > 1e-5:
        return -1.0
    elif not support and diffs.min() < -1e-5:
        return -1.0

    # Squared sum of diffs between data and line 
    err = (diffs ** 2.0).sum()
    return err;

def optimize_slope(support: bool, pivot:int , init_slope: float, y: np.array):
    
    # Amount to change slope by. Multiplyed by opt_step
    slope_unit = (y.max() - y.min()) / len(y) 
    
    # Optmization variables
    opt_step = 1.0
    min_step = 0.0001
    curr_step = opt_step # current step
    
    # Initiate at the slope of the line of best fit
    best_slope = init_slope
    best_err = check_trend_line(support, pivot, init_slope, y)
    assert(best_err >= 0.0) # Shouldn't ever fail with initial slope

    get_derivative = True
    derivative = None
    while curr_step > min_step:

        if get_derivative:
            # Numerical differentiation, increase slope by very small amount
            # to see if error increases/decreases. 
            # Gives us the direction to change slope.
            slope_change = best_slope + slope_unit * min_step
            test_err = check_trend_line(support, pivot, slope_change, y)
            derivative = test_err - best_err;
            
            # If increasing by a small amount fails, 
            # try decreasing by a small amount
            if test_err < 0.0:
                slope_change = best_slope - slope_unit * min_step
                test_err = check_trend_line(support, pivot, slope_change, y)
                derivative = best_err - test_err

            if test_err < 0.0: # Derivative failed, give up
                raise Exception("Derivative failed. Check your data. ")

            get_derivative = False

        if derivative > 0.0: # Increasing slope increased error
            test_slope = best_slope - slope_unit * curr_step
        else: # Increasing slope decreased error
            test_slope = best_slope + slope_unit * curr_step
        

        test_err = check_trend_line(support, pivot, test_slope, y)
        if test_err < 0 or test_err >= best_err: 
            # slope failed/didn't reduce error
            curr_step *= 0.5 # Reduce step size
        else: # test slope reduced error
            best_err = test_err 
            best_slope = test_slope
            get_derivative = True # Recompute derivative
    
    # Optimize done, return best slope and intercept
    return (best_slope, -best_slope * pivot + y[pivot])

def fit_trendlines_single(data: np.array):
    # find line of best fit (least squared) 
    # coefs[0] = slope,  coefs[1] = intercept 
    x = np.arange(len(data))
    coefs = np.polyfit(x, data, 1)

    # Get points of line.
    line_points = coefs[0] * x + coefs[1]

    # Find upper and lower pivot points
    upper_pivot = (data - line_points).argmax() 
    lower_pivot = (data - line_points).argmin() 
   
    # Optimize the slope for both trend lines
    support_coefs = optimize_slope(True, lower_pivot, coefs[0], data)
    resist_coefs = optimize_slope(False, upper_pivot, coefs[0], data)

    return (support_coefs, resist_coefs) 

def fit_trendlines_high_low(high: np.array, low: np.array, close: np.array):
    x = np.arange(len(close))
    coefs = np.polyfit(x, close, 1)
    # coefs[0] = slope,  coefs[1] = intercept
    line_points = coefs[0] * x + coefs[1]
    upper_pivot = (high - line_points).argmax() 
    lower_pivot = (low - line_points).argmin() 
    
    support_coefs = optimize_slope(True, lower_pivot, coefs[0], low)
    resist_coefs = optimize_slope(False, upper_pivot, coefs[0], high)

    return (support_coefs, resist_coefs)

# %%
# 擷取區間並抽取收盤價
df_k_line_test = df_k_line['2022-10-25':]
prices_close = np.array(df_k_line_test['Close'])

# 使用收盤價區間找出符合的趨勢線
trendlines = fit_trendlines_single(prices_close)
print(trendlines)
# Out:
# ((21.774641213311615, 12666.12), (18.578747908015078, 14511.173806483592))

# %%
# 設定上升趨勢線(支撐)與下降趨勢線(壓力)
up_slope  = trendlines[0][0]
up_intercept = trendlines[0][1]
trendline_up_start_date = '2022-10-25'
trendline_up_start_price = up_slope * date_to_index(df_k_line_test,'2022-10-25') + up_intercept
trendline_up_end_date = '2023-08-04'
trendline_up_end_price = up_slope * date_to_index(df_k_line_test,'2023-08-04') + up_intercept

down_slope = trendlines[1][0]
down_intercept = trendlines[1][1]
trendline_down_start_date = '2022-10-25'
trendline_down_start_price = down_slope * date_to_index(df_k_line_test,'2022-10-25') + down_intercept
trendline_down_end_date = '2023-08-04'
trendline_down_end_price = down_slope * date_to_index(df_k_line_test,'2023-08-04') + down_intercept

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
seq_of_seq_of_points=[
    [(trendline_up_start_date,trendline_up_start_price),(trendline_up_end_date,trendline_up_end_price)],
    [(trendline_down_start_date,trendline_down_start_price),(trendline_down_end_date,trendline_down_end_price)]
                     ]

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,1.0), colors=('xkcd:red','xkcd:blue'), alpha=0.6))
mpf.plot(df_k_line,**kwargs)

# %%
# 抽取最高價與最低價
prices_high=np.array(df_k_line_test['High'])
prices_low=np.array(df_k_line_test['Low'])

# 使用最高價與最低價區間找出符合的趨勢線
trendlines = fit_trendlines_high_low(prices_high,prices_low,prices_close)
print(trendlines)
# Out:
# ((21.866791344044987, 12613.653208655955), (17.55397483410085, 14678.422679479276))

# %%
# 設定上升趨勢線(支撐)與下降趨勢線(壓力)
up_slope  = trendlines[0][0]
up_intercept = trendlines[0][1]
trendline_up_start_date = '2022-10-25'
trendline_up_start_price = up_slope * date_to_index(df_k_line_test,'2022-10-25') + up_intercept
trendline_up_end_date = '2023-08-04'
trendline_up_end_price = up_slope * date_to_index(df_k_line_test,'2023-08-04') + up_intercept

down_slope = trendlines[1][0]
down_intercept = trendlines[1][1]
trendline_down_start_date = '2022-10-25'
trendline_down_start_price = down_slope * date_to_index(df_k_line_test,'2022-10-25') + down_intercept
trendline_down_end_date = '2023-08-04'
trendline_down_end_price = down_slope * date_to_index(df_k_line_test,'2023-08-04') + down_intercept

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
seq_of_seq_of_points=[
    [(trendline_up_start_date,trendline_up_start_price),(trendline_up_end_date,trendline_up_end_price)],
    [(trendline_down_start_date,trendline_down_start_price),(trendline_down_end_date,trendline_down_end_price)]
                     ]

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,1.0), colors=('xkcd:red','xkcd:blue'), alpha=0.6))
mpf.plot(df_k_line,**kwargs)

# %% [markdown]
# ### 史塔克財金工作室 進階班
# * 講義存放連結：https://mega.nz/folder/g2gkSIJa
# * [最難的一堂課_230804_筆記.pptx](https://mega.nz/file/9zAxjYbK)
