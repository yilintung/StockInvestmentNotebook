# %% [markdown]
# 【[周末影音解盤](https://tinyurl.com/y6mv6xc8)】短中期弱，力守支撐
# 國際股市和台股短線轉弱，趨勢已經翻空，或是仍有一線生機？
# 趨勢要止穩轉強，必須先具備兩個條件？
# 台幣趨貶動能不足，資金流向那些族群？
# 完整內容請參考2023/08/06解盤~
# https://reurl.cc/y7NoOa

# %% [markdown]
# ### TODO
