| INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:55:20.747 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:55:54.323 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:55:59.599 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:56:31.581 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:56:38.213 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-09-17 21:56:54.139 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 日K：2025-09-17

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤前**：[K線捕手十秒鐘看台股](https://www.facebook.com/kevinyang20180801/posts/pfbid033L4wgNa1DRtS2DbzdvGZaiwWyMNBCrBYSRTkCy8JvChbYgKtu7JaK48cpPa2xou6l)
# > 由於台積電填息後再創歷史新高來到1285，加權指數隨之續漲創高，沿著5日線推升，盤中最高來到25664。櫃買指數雖然也是續漲，但短線結構屬於狹幅盤整。兩個指數的籌碼面也沒有太大的瑕疵。
# 技術面觀察很單純，加權指數關鍵支撐是5日線，櫃買指數則是10日線。不過個別股票留意，雖然指數上漲，昨天普遍個股跟漲，但有的是反彈、有的是盤頭，有的是續漲，三種個股要分清楚。
# (完整版本請參考《K線追擊周報》數位訂閱)
# > ![548547014_1394057792728144_383203339841361638_n.jpg](attachment:a9b87a9c-b44f-4794-9277-324529be82ea.jpg)

# %%
# 盤整區間
def line_drawing_callback( range_prices) :

    seq_of_seq_of_points = []
    linewidths           = []
    colors               = []

    # 設定盤整區壓力線
    resistance_line_start_date  = '2025-08-07'
    resistance_line_end_date    = '2025-09-08'
    resistance_line_price       = range_prices.loc['2025-08-27']['Close']
    seq_of_seq_of_points.append([(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')

    # 設定盤整區支撐線
    support_line_start_date  = '2025-08-07'
    support_line_end_date    = '2025-09-08'
    support_line_price       = range_prices.loc['2025-08-22']['Close']
    seq_of_seq_of_points.append([(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤前：盤整區間繪製
image = mysys.DrawOnKlineChart('TAIEX','2025-07-25','2025-09-16',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2025-09-16<br />
# 孕育線／懷抱線 : 2025-09-12 , 2025-09-17</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 4396.87億元 ，十日均量 ＝ 4780.54億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.24點。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-17死亡交叉。並且2025-09-17於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-08當周黃金交叉。並且2025-09-08該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，K線多為紅K，顯示多頭力量較強。短期移動平均線（5日、10日）均向上，且價格位於所有移動平均線之上，顯示出強勁的上升動能。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有增加的趨勢，顯示出價量配合良好，支持上漲趨勢。然而，最近幾日成交量略有減少，需留意是否有量能不足的情況。<br />
# <br />
#  支撐與壓力<br />
# 支撐位可參考5日移動平均線附近，約在25400點左右。壓力位則在近期高點附近，約在25600點。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線與D線均在超買區域，且K線略微下彎，需警惕可能的回檔風險。<br />
# <br />
#  MACD指標<br />
# MACD指標顯示DIF線與MACD線均在零軸上方，且DIF線高於MACD線，顯示多頭趨勢仍在延續，但柱狀體有縮短跡象，需注意趨勢可能轉弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於上升趨勢中，但需注意短期內可能的回檔風險。建議投資者在支撐位附近考慮進場，並在壓力位附近適時停利。若價格跌破短期移動平均線，則需考慮停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2025-09-11 , 2025-09-15<br />
# 孕育線／懷抱線 : 2025-09-12 , 2025-09-17</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1420.8億元 ，十日均量 ＝ 1510.58億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-10死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-08-04當周黃金交叉。並且2025-09-08該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析，以下是對當前市場狀況的技術分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現出上漲趨勢，但在最近幾個交易日出現了小幅回檔。短期移動平均線（5日和10日）仍高於中期移動平均線（20日和60日），顯示整體趨勢仍偏多。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有所增加，但在最近的回檔中略有減少，顯示出多頭動能有所減弱。若成交量持續萎縮，可能預示著短期內的調整壓力。<br />
# <br />
#  支撐與壓力<br />
# 支撐位可參考近期低點附近，約在256點左右。壓力位則在近期高點附近，約在260點以上。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線和D線均在50以下，且K線低於D線，顯示短期內有進一步調整的可能性。若K線能夠重新上穿D線，則可能重新啟動上漲趨勢。<br />
# <br />
#  MACD指標<br />
# MACD指標顯示DIF線略高於MACD線，但柱狀體呈現負值且逐漸擴大，顯示短期內空頭力量增強，需留意可能的進一步回檔。<br />
# <br />
#  綜合評價<br />
# 整體而言，市場仍處於上升趨勢中，但短期內可能面臨調整壓力。建議投資者謹慎操作，若價格跌破支撐位，需考慮停損。若價格能夠在支撐位企穩並伴隨成交量放大，則可考慮逢低布局。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 盟立(2464)
#   看法：短線轉弱，跌破下彎的5日線與10日線；但中期仍於區間盤整中，20日線(上揚)與盤整區間支撐有守。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2464')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2025-09-11</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 4891張 ，十日均量 ＝ 7666張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中繼型態之上升旗形，型態範圍由2025-04-09開始到2025-09-16結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線下彎，短期翻空；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-12死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-08當周黃金交叉。並且2025-09-08該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，但在最後一個交易日出現回檔跡象。短期移動平均線（5日、10日）仍在中期移動平均線（20日、60日）之上，顯示整體趨勢仍偏多。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有增加的趨勢，但在最近幾個交易日有所減少，顯示多頭動能減弱，需留意後續成交量變化。<br />
# <br />
#  支撐與壓力<br />
# 支撐位可參考20日移動平均線附近，約在72元左右。壓力位則在近期高點附近，約在78元。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線與D線均向下，且K線已跌破50，顯示短期內有進一步回檔的風險。<br />
# <br />
#  MACD指標<br />
# MACD柱狀體由正轉負，且DIF線與MACD線出現死叉，顯示短期內可能進一步調整。<br />
# <br />
#  綜合評價<br />
# 整體來看，雖然中長期趨勢仍偏多，但短期內有回檔壓力。建議投資者謹慎觀察，若價格跌破支撐位，需考慮停損。若成交量能重新放大並突破壓力位，則可考慮加碼。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-26'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-15']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-04-10'
    bottom_price = range_prices.loc['2025-04-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-08-15'

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2464','2024-12-25','2025-09-17',line_drawing_callback)
display(image)
# Out:
# 估算目標價為78.10元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-131)：外資小賣(-93)、投信中立(0)、自營小賣(-38)。
# 主力小賣(-125)。
# 分公司買賣家數差分散(-67)。
# 融資減(-202)、融券減(-12)。

# %% [markdown]
# * 仁寶(2324)
#   看法：試圖突破迷你底型，但未有效突破因而收盤時留下長上影線。底太淺以致於空間不大並且前方有壓，因此以短多視之。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2324',buttom_pattern = True)
# Out:
# 底型反轉交易策略：
# <PIL.Image.Image image mode=RGB size=866x479>
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x483>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 67535張 ，十日均量 ＝ 37099張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2025-01-02開始到2025-03-24結束，估算目標價為33.75元。<br />
# 尚未成形底型反轉之底部型態，型態範圍由2025-04-02開始到2025-09-17結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-17死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-01當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，尤其在最近幾個交易日中，價格突破了多條移動平均線，顯示出強勁的上升動能。<br />
# <br />
#  價量關係<br />
# 成交量在價格上漲時顯著增加，顯示出多頭的強烈支持，價量配合良好。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：30元附近，該位置曾多次成為價格回檔的支撐。<br />
# - 壓力位：32.7元附近，為近期高點，可能成為短期壓力。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線在高位回落，但仍在超買區域，需注意可能的回檔風險。<br />
# <br />
#  MACD指標<br />
# MACD線與信號線均在零軸上方，且柱狀體持續增長，顯示出強烈的多頭趨勢。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於強勢上漲階段，短期內可能會有回檔，但中期趨勢仍然看漲。建議投資者在回檔時考慮進場，並在接近壓力位時適時停利。注意風險管理，設置適當的停損點。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-27'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-08-05']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-04-09'
    bottom_price = range_prices.loc['2025-04-09']['Open']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2324','2025-01-16','2025-09-17',line_drawing_callback)
display(image)
# Out:
# 估算目標價為35.45元
# <PIL.Image.Image image mode=RGB size=866x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-2743)：外資小賣(-2124)、投信小賣(-1830)、自營大買(+1211)。
# 主力小買(+2113)。
# 分公司買賣家數差集中(+22)。
# 融資大增(+3392)、融券中立(-6)。

# %% [markdown]
# * 旺宏(2337)
#   看法：今天正式突破，但上去會遇到多層壓力。屬於記憶體族群補漲，若該族群轉弱有可能波段就結束了，也因此未必能到滿足區。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2337')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=837x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-15 , 2025-09-16<br />
# 孕育線／懷抱線 : 2025-09-15</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 92170張 ，十日均量 ＝ 52825張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>底型反轉之底部型態，型態範圍由2024-12-31開始到2025-02-13結束，估算目標價為21.45元。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線走平，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-11黃金交叉。並且2025-09-17於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-28當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析：<br />
# <br />
#  價格趨勢<br />
# 近期股價呈現明顯的上漲趨勢，尤其在最近幾個交易日中，價格突破了多條移動平均線，顯示出強勁的多頭動能。<br />
# <br />
#  價量關係<br />
# 成交量在價格上漲時顯著增加，顯示出市場對此上漲趨勢的支持，價量配合良好，屬於多頭市場。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：23元附近，為近期回檔可能的支撐點。<br />
# - 壓力位：25元附近，為短期內可能遇到的壓力。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線高於D線，且位於超買區，顯示出強烈的多頭趨勢，但需注意可能的回檔風險。<br />
# <br />
#  MACD指標解讀<br />
# MACD線與信號線之間的距離擴大，且柱狀體持續增長，顯示出強勁的上漲動能。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於強勢上漲階段，短期內可能會有回檔，但中期趨勢仍然看好。建議投資者在回檔時考慮進場，並設置適當的停損點以控制風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2024-10-28'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-03-27']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-01-13'
    bottom_price = range_prices.loc['2025-01-13']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2337','2024-08-08','2025-09-17',line_drawing_callback)
display(image)
# Out:
# 估算目標價為28.75元
# <PIL.Image.Image image mode=RGB size=866x479>

# %% [markdown]
# 籌碼面：
# 法人小買(+1317)：外資小買(+373)、投信小買(+1300)、自營小賣(-356)。
# 主力大買(+4119)。
# 分公司買賣家數差集中(+1)。
# 融資大增(+3135)、融券大增(+571)。
