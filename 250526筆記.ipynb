# ![messageImage_1748232390981.jpg](attachment:47037aee-28af-4af1-9e38-7326286834f7.jpg)
#
# 萬海(2615)
# ![messageImage_1748227851532.jpg](attachment:64cfaa7d-fa2f-496f-952f-739c15ed6ca8.jpg)

# %% [markdown]
# [說真的](https://www.facebook.com/kevinyang20180801/posts/pfbid01Um78pMEy2skUkgPGeUgnyobxC982cSKyxbLXwSN3yJMVn8ZEtMgWWC1LMHjjMDol)，我沒有盯夜盤漲跌的習慣，基本上就是隔天早上看結果就好了，尤其是六日盡量會讓腦袋放空。
# 但同學都會逼我看，因為很擔心星期五下跌，禮拜一會有賣壓，但我跟他說，短線轉折出現回檔修正，不是預期中的事情嗎?
# 那應該已經事先就做好預防措施還有調節，就不會緊張不知所措。股價或者是指數的走勢，如果和你的規劃一樣，那應該是心情很平靜。
# 除非是走勢跟預測的相反，或是落差太大，才需要緊張。
#
# 📢【[K線捕手｜操作節奏教戰守則](https://www.facebook.com/kevinyang20180801/posts/pfbid0i3UXmMtEWfkgzpUFCbcjS9RvEspxnKYodNMMN8JeiNYHzPAFt1X3hg5Us3hZkfZhl)】一張圖看懂多空節奏！掌握轉折不再亂出手
# 📉短線轉弱 → 放慢腳步，放輕心情，來回顧這波反彈怎麼走的！
# 當市場進入回檔整理階段，不代表就要完全離場，而是應該放慢交易節奏、冷靜觀察盤勢，趁這個空檔好好複盤這一波反彈的結構，從指數多空強弱的變化中，找到節奏調整的關鍵！
# 🎨 指數節奏四階段解析：
# 🔵 藍色區間：急跌→適合短空，但不能追空
# 📉 最適合做空的時機，節奏快、波動大。
# ⚠️ 小心急跌反彈，末跌段放量下殺後，應避免追空，反而要注意轉多訊號！
# 🔴 紅色區間：強彈→隨便買隨便漲
# 🚀 不分強弱勢股齊漲，是做多最輕鬆的時間。
# ❗ 但也是風險最高的階段，動作要快、紀律要嚴，否則容易追高被套！
# 🟠 橘色區間：穩中透強→選股變重要
# 📈 經過回測支撐、週KD金叉＋20日線上揚，是穩健做多區。
# ✅ 風險低、但上漲個股僅剩8成，選股與成本控制要更精準。
# 🟡 黃色區間：補漲尾聲→風險升高
# 🪫 多方動能趨緩，主升段已過。
# 📉 勝率約剩6成，進場風險提高，應採「多看少做」策略。
# 🧭 指數是航海的羅盤，不是單一個股的地圖
# ✔️ 它幫助我們調整多空方向、資金比重、風險控管。
# ✔️ 但每檔個股仍有自己的型態、位階與趨勢。
# 🎯 把指數看懂，再配合個股策略，你的操作將更順手、更有信心！
# ![500198560_1291100826357175_808443569834702581_n.jpg](attachment:e31fb753-a717-4081-b469-23a23a5c13be.jpg)

# %% [markdown]
# ![788832.jpg](attachment:75a7bada-3f1d-4b07-9532-e0c94d069338.jpg)
# ![788833.jpg](attachment:7d274627-419b-435d-a713-856dbf7726df.jpg)

# %% [markdown]
# 🎯最新影音上架
# 台股回檔有撐嗎？三大訊號告訴你！個股轉強突破能不能追？
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3180

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統：規劃與開發
#   - 更新技術分析資料庫

# %%
import os
import sys
import pandas as pd
import datetime
import sqlite3
import requests
import time

from dotenv import load_dotenv, find_dotenv
from FinMind.data import DataLoader

# %%
# API 使用次數
def api_usage() :
    url = "https://api.web.finmindtrade.com/v2/user_info"
    payload = {
        "token": token,
    }
    resp = requests.get(url, params=payload)
    return resp.json()["user_count"],resp.json()["api_request_limit"]

# python 取得時間範圍內日期列表
# 來源：https://www.cnblogs.com/xiao-xue-di/p/11900649.html
def date_range(beginDate, endDate):
    dates = []
    dt = datetime.datetime.strptime(beginDate, "%Y-%m-%d")
    date = beginDate[:]
    while date <= endDate:
        dates.append(date)
        dt = dt + datetime.timedelta(1)
        date = dt.strftime("%Y-%m-%d")
    return dates

# %%
# 設定FinMind API
load_dotenv(find_dotenv())
token = os.environ.get('FINMIND_TOKEN')
api = DataLoader()
api.login_by_token(api_token=token)

# %%
# 取得範圍日期列表
price_date_list = date_range('2025-05-19', '2025-05-26')

# %%
# 連線資料庫
conn = sqlite3.connect('data/stock.db')
cursor = conn.cursor()

# %%
# 設定支援外鍵
conn.execute('PRAGMA foreign_keys = ON;')

res = conn.execute('PRAGMA foreign_keys;')
res.fetchone()
# Out:
# (1,)

# %% [markdown]
# > （Ａ）更新台股總覽

# %%
# 從資料庫中載入「台股總覽 TaiwanStockInfo」
df_stock_info = pd.read_sql("SELECT * FROM StockInfo", conn)
display(df_stock_info)
# Out:
#                     StockID StockName IndustryCategory  Type
# 0                      0050    元大台灣50              ETF  twse
# 1                      0051   元大中型100              ETF  twse
# 2                      0052      富邦科技              ETF  twse
# 3                      0053      元大電子              ETF  twse
# 4                      0054    元大台商50              ETF  twse
# ...                     ...       ...              ...   ...
# 2934                  TAIEX      加權指數               大盤  twse
# 2935               Textiles   紡織纖維類指數            Index  twse
# 2936                Tourism   觀光事業類指數            Index  twse
# 2937                   TPEx      櫃買指數               大盤  tpex
# 2938  TradingConsumersGoods   貿易百貨類指數            Index  twse
#
# [2939 rows x 4 columns]

# %%
# 台股總覽 TaiwanStockInfo #
df = api.taiwan_stock_info()
display(df)
df_tw_stock_info = df.drop(columns=['date'])
df_tw_stock_info = df_tw_stock_info.rename(columns={'stock_id':'StockID','stock_name':'StockName','industry_category':'IndustryCategory','type':'Type'})
df_tw_stock_info.drop_duplicates(subset=['StockID'], keep='first', inplace=True)
df_tw_stock_info = df_tw_stock_info[['StockID','StockName','IndustryCategory','Type']]
display(df_tw_stock_info)
# Out:
# 2025-05-26 20:03:59.853 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockInfo, data_id:
#      industry_category               stock_id stock_name  type        date
# 0                  ETF                   0050     元大台灣50  twse  2025-05-26
# 1                  ETF                   0051    元大中型100  twse  2025-05-26
# 2                  ETF                   0052       富邦科技  twse  2025-05-26
# 3                  ETF                   0053       元大電子  twse  2025-05-26
# 4                  ETF                   0054     元大台商50  twse  2024-12-04
# ...                ...                    ...        ...   ...         ...
# 3958                大盤                  TAIEX       加權指數  twse        None
# 3959             Index               Textiles    紡織纖維類指數  twse        None
# 3960             Index                Tourism    觀光事業類指數  twse        None
# 3961                大盤                   TPEx       櫃買指數  tpex        None
# ...

# %%
# 確認「台股總覽 TaiwanStockInfo」是否更新？
# 參考 ： https://www.learncodewithmike.com/2021/10/pandas-compare-values-between-dataframes.html
# 參考 ： https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
df_diff = df_stock_info.merge(df_tw_stock_info, how='outer', indicator=True)
# 左邊為原始df_stock_info，右邊為最新df_tw_stock_info
display(df_diff.loc[lambda x : x['_merge'] == 'left_only']) 
display(df_diff.loc[lambda x : x['_merge'] == 'right_only'])
# Out:
#      StockID StockName IndustryCategory      Type     _merge
# 246    00881   國泰台灣5G+              ETF      twse  left_only
# 2616    7805       威聯通         電腦及週邊設備業  emerging  left_only
#      StockID  StockName IndustryCategory      Type      _merge
# 2939   00881   國泰台灣科技龍頭              ETF      twse  right_only
# 2940  009805   新光美國電力基建              ETF      twse  right_only
# 2941  009808   華南永昌優選50              ETF      twse  right_only
# 2942  00982A   主動群益台灣強棒              ETF      twse  right_only
# 2943  00983B  大華優利美公債20            上櫃ETF      tpex  right_only
# 2944  00984B  大華優利美A債15            上櫃ETF      tpex  right_only
# 2945    7758       睿騰能源           電子零組件業  emerging  right_only
# 2946    7805        威聯通             數位雲端  emerging  right_only
# 2947    7828       創新服務             半導體業  emerging  right_only
# 2948    7832      智新生技*            生技醫療業  emerging  right_only
# 2949    7833       綠岩能源             綠能環保  emerging  right_only
# ...

# %%
# 更新資料庫中的「台股總覽 TaiwanStockInfo」
df_diff = df_diff.loc[lambda x : x['_merge'] == 'right_only']
for idx in range(df_diff.shape[0]) :
    info   = df_diff.iloc[idx]
    sqlcmd = "SELECT * FROM DailyPrice WHERE StockID='{}'".format(df_diff.iloc[idx]['StockID'])
    df     = pd.read_sql_query(sqlcmd, conn)
    if df.empty is True :
        conn.execute("INSERT INTO StockInfo(StockID,StockName,IndustryCategory,Type) VALUES(?,?,?,?)", (info['StockID'],info['StockName'],info['IndustryCategory'],info['Type']))
    else :
        sqlcmd = "UPDATE StockInfo SET 'StockName'='{}','IndustryCategory'='{}','Type'='{}' WHERE StockID='{}'".format(info['StockName'],info['IndustryCategory'],info['Type'],info['StockID'])
        conn.execute(sqlcmd)
conn.commit()

# %% [markdown]
# > （Ｂ）更新價格資料

# %%
# 從資料庫中載入「台股總覽 TaiwanStockInfo」
df_stock_info = pd.read_sql("SELECT * FROM StockInfo", conn)
display(df_stock_info)
# Out:
#      StockID StockName IndustryCategory      Type
# 0       0050    元大台灣50              ETF      twse
# 1       0051   元大中型100              ETF      twse
# 2       0052      富邦科技              ETF      twse
# 3       0053      元大電子              ETF      twse
# 4       0054    元大台商50              ETF      twse
# ...      ...       ...              ...       ...
# 2945    7828      創新服務             半導體業  emerging
# 2946    7832     智新生技*            生技醫療業  emerging
# 2947    7833      綠岩能源             綠能環保  emerging
# 2948    7834      來毅數位            資訊服務業  emerging
# 2949    7839       達人網             數位雲端  emerging
#
# [2950 rows x 4 columns]

# %%
# 更新資料庫
for price_date in price_date_list :
    
    # API 使用次數 #
    user_count,api_request_limit = api_usage()
    if user_count > (api_request_limit - 100) :
        print('抓取資料速度過快（user_count＝ {} ，api_request_limit ＝ {}），等三十分鐘後再行抓取'.format(user_count,api_request_limit))
        time.sleep(30*60)
        
    # 股價日成交資訊 TaiwanStockPrice：一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
    sqlcmd = "SELECT * FROM DailyPrice WHERE Date='{}'".format(price_date)
    df     = pd.read_sql_query(sqlcmd, conn)
    if df.empty is True :
        while True :
            try :
                df = api.taiwan_stock_daily(start_date=price_date,)
            except Exception as e:
                print('日K：日期{}發生錯誤{}，重試'.format(price_date,e))
                continue
            break
        if df.empty is not True :
            print('日K：{}'.format(price_date))
            df_daily_price = df.drop(columns=['spread','Trading_turnover'])
            df_daily_price = df_daily_price.rename(columns={'date':'Date','stock_id':'StockID','Trading_Volume':'Volume','Trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_daily_price = df_daily_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_daily_price = df_daily_price[df_daily_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_daily_price.to_sql('DailyPrice', conn, if_exists='append', index=False)
        else :    
            time.sleep(1)
    else :
        print('日K：日期{}資料已存在於資料庫中'.format(price_date))
        time.sleep(1)
    
    # 台股週 K 資料表 TaiwanStockWeekPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
    sqlcmd = "SELECT * FROM WeeklyPrice WHERE Date='{}'".format(price_date)
    df     = pd.read_sql_query(sqlcmd, conn)
    if df.empty is True :
        url = "https://api.finmindtrade.com/api/v4/data"
        parameter = {
            "dataset": "TaiwanStockWeekPrice",
            "start_date": price_date,
            "token": token,
        }
        while True :
            resp = requests.get(url, params=parameter)
            if resp.status_code == 200 :
                break
            else :
                print('周K：日期{}發生錯誤，回應狀態碼 ＝ {}'.format(price_date,resp.status_code))
                if resp.status_code == 402 :
                    time.sleep(10*60)
        data = resp.json()
        df_weekly_price = pd.DataFrame(data["data"])
        if df_weekly_price.empty is not True :
            print('周K：{}'.format(price_date))
            df_weekly_price = df_weekly_price.drop(columns=['yweek','spread','trading_turnover'])
            df_weekly_price = df_weekly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_weekly_price = df_weekly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_weekly_price = df_weekly_price[df_weekly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_weekly_price.to_sql('WeeklyPrice', conn, if_exists='append', index=False)
        else :    
            time.sleep(1)
    else :
        print('周K：日期{}資料已存在於資料庫中'.format(price_date))
        time.sleep(1)
    
    # 台股月 K 資料表 TaiwanStockMonthPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
    sqlcmd = "SELECT * FROM MonthlyPrice WHERE Date='{}'".format(price_date)
    df     = pd.read_sql_query(sqlcmd, conn)
    if df.empty is True :
        url = "https://api.finmindtrade.com/api/v4/data"
        parameter = {
            "dataset": "TaiwanStockMonthPrice",
            "start_date": price_date,
            "token": token, 
        }
        while True :
            resp = requests.get(url, params=parameter)
            if resp.status_code == 200 :
                break
            else :
                print('月K：日期{}發生錯誤，回應狀態碼 ＝ {}'.format(price_date,resp.status_code))
                if resp.status_code == 402 :
                    time.sleep(10*60)
        data = resp.json()
        df_monthly_price = pd.DataFrame(data["data"])
        if df_monthly_price.empty is not True :
            print('月K：{}'.format(price_date))
            df_monthly_price = df_monthly_price.drop(columns=['ymonth','spread','trading_turnover'])
            df_monthly_price = df_monthly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','trading_money':'Value','open':'Open','max':'High','min':'Low','close':'Close'})
            # 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價、成交量與成交值
            df_monthly_price = df_monthly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume', 'Value']]
            # 排除掉非TaiwanStockInfo內的股票
            df_monthly_price = df_monthly_price[df_monthly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
            df_monthly_price.to_sql('MonthlyPrice', conn, if_exists='append', index=False)
        else :    
            time.sleep(1)
    else :
        print('月K：日期{}資料已存在於資料庫中'.format(price_date))
        time.sleep(1)
# Out:
# 日K：日期2025-05-19資料已存在於資料庫中
# 周K：2025-05-19
# 日K：日期2025-05-20資料已存在於資料庫中
# 日K：日期2025-05-21資料已存在於資料庫中
# 日K：日期2025-05-22資料已存在於資料庫中
# 2025-05-26 20:04:50.546 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 日K：2025-05-23
# 2025-05-26 20:04:59.127 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 2025-05-26 20:05:03.813 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 2025-05-26 20:05:08.372 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
# 日K：2025-05-26

# %%
# 修改並關閉資料庫
conn.commit()
conn.close()
