# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤中快訊】短線偏多，中期箱型
# 伴隨台幣維持第四天強升，加權指數今天開高，隨即遇到前高壓力走弱，顯見前高反壓仍大，不過還維持上漲格局。相較之下櫃買指數，就比較弱勢，仍有盤頭的現象，下彎的20日線反壓還無法站上。
# 法人小回補，融資減碼，主力指標持平，就單一日而言，籌碼面中性偏多。原先提到行進過程中，4個重要訊號：外資未平倉口數、台幣升貶、類股結構、月KD變化。
# 外資平倉口數持平，台幣升值，類股結構僅有2類強勢偏多，23類股偏空方或是反彈，8類股維持盤整，月KD維持高檔鈍化。如果要續攻除了台幣升值之外，類股結構還需要加強，至少要有1/3類股翻多轉強，多方力道才會更紮實。
# 目前對多方最有利的條件，是美國四大指數，只有道瓊還在盤整區間，但標普500、那斯達克、費半指數，都突破盤整區續漲。 (出處：K線捕手楊忠憲粉絲團)
# ![359351144_754353900031873_9035342840060649740_n.jpg](attachment:9c8f691c-7591-4069-a53c-87c932e6a4e0.jpg)

# %% [markdown]
# [國安基金第8次護盤獲利46億！Q2出脫近4成持股](https://tinyurl.com/y6j2e2fz)
#
# [AI股爆量換手當沖也瘋狂](https://readers.ctee.com.tw/cm/20230714/a01aa1/1249043/share)
#
# [美元指數一度失守100](https://readers.ctee.com.tw/cm/20230714/a01aa1/1249044/share)
# 華爾街日報預料：7月將是Fed今年最後一次升息
# 有「聯準會（Fed）傳聲筒」之稱的華爾街日報記者蒂米羅斯（Nick Timiraos）撰文表示，由於6月消費者物價指數（CPI）年增幅創下逾兩年新低，Fed預料在7月升息後，將會停止升息的腳步。美國13日公布6月生產者物價指數（PPI）年增0.1％，創下2020年8月最低紀錄，也低於前值1.1％與預期的0.4％增幅。
# 核心PPI年增2.4％，也是2021年1月以來最低。PPI與CPI數據雙雙報喜，證實Fed自去年啟動升息以對抗頑強通膨以來，已取得一定成功，這將有助這波升息循環不久後將畫下句點。美股三大指數昨開盤延續周三多頭氛圍，美元指數一度失守100、創15個月新低
#
# [國發會：通膨最壞時間已過](https://ctee.com.tw/news/policy/901370.html)
# 美國通膨降溫的最新動態及其影響，政府部門密切關注。國發會副主委高仙桂13日表示，6月美國通膨率降至3％，中國大陸通膨率降至零，我國也降至2％以下，反映俄烏戰爭所引發的這一波通膨，最壞的時間已經過去，美、台不致於陷入「工資與物價螺旋上漲效應」，經濟可望加速復甦。

# %% [markdown]
# 期貨開高，站上第一個壓力區，但第二個壓力區還沒突破，維持中期大箱型區間：
# ![messageImage_1689295586268.jpg](attachment:f460ad8b-c12b-490f-a602-6a7ef96b52c1.jpg)
#
# 日本反彈到20日現有明顯反壓，開高走低：
# ![messageImage_1689295713222.jpg](attachment:1581b21f-764e-46cd-9010-dc40cbfd355d.jpg)
#
# 美國四大指數，道瓊還在盤整區間，但標普500、那斯達克、費半指數，都突破盤整區續漲。
# ![messageImage_1689296022976.jpg](attachment:0bee2ccb-7c25-4865-91e4-7ff2e845f1ea.jpg)
#
# 加權指數短線偏多，但尚未突破大箱型區間：
# ![messageImage_1689296466537.jpg](attachment:0cd8d1f7-bc97-46df-801e-9aa8b268808f.jpg)
#
# 櫃買指數也是上漲，不過型態上較弱，在下彎的20日線之下：
# ![messageImage_1689296531719.jpg](attachment:2b376aee-91ab-414e-ac2b-98cb4a8e3ae4.jpg)
#
# 台幣4天的時間，一次性的急升，不過已經到壓力區，再來要強升就比較有難度。
# ![messageImage_1689299540987.jpg](attachment:a8c21e15-a3ab-4045-8abb-c32f92ea47c4.jpg)
# 台幣這4天的強升，與台股走勢是是直接對應的，所以如果之後台幣升值力道趨緩，甚至由升轉貶，台股續攻動能會不足。
#
# 小幅突破昨天高點：
# ![messageImage_1689302873879.jpg](attachment:2679479e-af0e-46fd-b841-df7a08ffbeac.jpg)

# %% [markdown]
# 富邦越南(00885) 好像沒甚麼人在討論這個，但慢慢漲 ：
# ![messageImage_1689300312443.jpg](attachment:2cac8745-93c0-4ace-822c-7f2837f280d7.jpg)
#
# 敬鵬(2355)：
# ![messageImage_1689300312443.jpg](attachment:3cf4e5f5-9dc8-4686-92a2-6fbc13285bdc.jpg)
#
# 威盛(2388)：
# ![messageImage_1689301039724.jpg](attachment:c50006c3-3341-43d0-8093-2d7306288e2e.jpg)
#
# 長榮航(2618)：
# ![messageImage_1689301128830.jpg](attachment:8c531ca9-3f96-4e9a-9bca-4207031d4308.jpg)
#
# 中美晶(5483)：
# ![messageImage_1689304295227.jpg](attachment:734c2ba8-4dbf-4a87-b588-be9c31238cb6.jpg)
#
# 撼訊(6150)：
# ![messageImage_1689307836000.jpg](attachment:51fe300a-ad71-4057-8401-029d3c757d29.jpg)

# %% [markdown]
# #### 【[進入股市的第一堂課](https://tinyurl.com/2w2esv44)】
# 「你還記得你進入股票的投資，是怎麼開始的嗎？」，多數人可能都會覺得這真是好笑至極的問題，甚至可能率性的回答：「不就帶著雙證件以及印章，去券商開戶，然後就開始了！」是的，我想多數人都會這樣回答。那我再問一個類似的問題，「你還記得你開始開車，是怎麼開始的嗎？」你的答案應該不會這麼簡單了。
# 一般人大多會花錢去學開汽車，至少會請熟人或是有經驗的親戚朋友教，經過約莫一個月，然後每天1個小時以上的練習，接著才去考駕照，考到駕照之後，再經過一定時數的道路訓練，才真的上路，大多數人應該都是這樣的過程吧！但這樣的訓練，仍不能保證你不發生交通事故，上路隨時要戰戰兢兢，有時還要買一些保險，已防突發的意外。
# 相反的，假如你什麼都不會，完全沒經過學習的階段，我只給你一把鑰匙，和一台車，就叫你上路，會發生什麼事情，那將會是一場災難阿！沒錯，一般人買賣股票就是這樣！開戶像是鑰匙，資金就像車子。鑰匙（開戶）非常容易取得，有些閒錢，就上路了，於是輕則頭破血流，重則車毀人重傷。
# 而買賣一般股票，就像開國產車在平面道路空空閒晃，但是做期貨、作衍生性商品、有槓桿倍數，甚至放空，那等於是開超跑上高速公路，做對，賺很快，做錯，人車俱亡。如果你在平面道路開國產車都開不好，千萬不要隨便開超跑上高速公路。
# 股市最原始的目的之一，是便利上市櫃公司，能在公開市場籌措資金，藉以擴張公司。所以當初設計，必須是很容易入門，讓人人都能投資，但是這也是它可怕之處。我越學的深，對股票越是戒慎恐懼，但是一般散戶不是，完全沒有警戒心，越玩越大，越玩越熱…
# 但股票的風險和可怕，遠超過開車，數百倍、數千倍，甚至還有些投資人用財務槓桿操作，這更是讓自己深陷於極大的風險之中，而不自知。這樣形容好了，假如買買股票，是在高速公路上開車，那使用融資、融券、期貨這些更複雜的商品，等同於開著超跑在正式賽車道上，跟專業車手競賽，一般投資人往往只有被痛宰的命運，怎麼會有勝算。
# 記得某個投資前輩曾說，不要用「玩」、「炒」，甚至「賭」來形容股票，因為它真的是玩不起，也無法控制的。所以買賣股票前，我們除了要努力鑽研知識和專業，紮實的累積一定的經驗值，並做好各方面的準備之外，不要過分擴張信用，隨意投入自己不懂的商品，每次買賣股票前，都要像第一次上馬路開車時，那樣戒慎恐懼，如履薄冰。以上，我想應該是每個人在買賣股票前，要先上的第一堂課。 (出處：K線捕手楊忠憲粉絲團)

# %% [markdown]
# 【還記得我的漲停板指標嗎？】
# 邏輯是這樣，我的觀察股來源都是曾同學問到，我覺得不錯的股票，會一直放入電腦軟體的觀察股中，持續一直累加，一個月左右會增刪更新。
# 這是一種隨機抽樣的概念，我取的是大家觀察的熱門股，因此10檔以內漲停代表正常，盤勢很穩健多方，11-15檔表示已經過熱，16-20檔以上漲停，風險係數就會攀升，容易回檔整理。
# 所以並不是台股全部1800多檔中的10檔、15檔、20檔漲停，只有我的觀察股才算數。過去2年有長期觀察直播的同學，應該都有印象，這個指標準確率超過90%。
# ![messageImage_1689308831629.jpg](attachment:90d49774-8b99-4482-a28c-f85063cba26f.jpg)
# 14檔漲停
# 很久沒用了，看看這次準不準。

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值37550元(收盤價：37.55元，跌0.1元)。調整後的停損價為35.00元，目標價為42.50元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,37.55,37385,1034,2.84]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  37.55  37385  1034  2.84

# %%
##### 使用2022年3月11日到今日收盤價(2023年7月14日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230714.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-9-13']['Open']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 估算目標價
bottom_price_date = '2022-10-21'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('目標價 ＝ {:.2f}元'.format(target_price))
target_price_date = '2023-06-02'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(2.5,15,15), colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 35.00元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-07-14
# 目標價 ＝ 42.50元

# %% [markdown]
# * 本月將進行整合先前完成的程式碼(轉折點、頭肩底型態與趨勢線…等)與[neurotrader](https://www.youtube.com/@neurotrader888/videos)之程式碼：
#   - 位階
#     + [量化位階評價法](https://vocus.cc/article/62ada936fd89780001fe6208) ： 已完成 **StockRankEvaluate()** 函式，後續整理程式碼
#   - 轉折點
#     + 峰位∕谷底的演變程序([peak-and-trough progression](https://www.amazon.com/Technical-Analysis-Explained-Fifth-Successful/dp/0071825177)) 與 滾動窗口([Rolling Window](https://www.youtube.com/watch?v=X31hyMhB-3s&t=49s)) ： 已完成 **FindingTurningPoints()** 函式 \[已整合進**myutils套件**\]
#     + 方向變化([Directional Change](https://www.youtube.com/watch?v=X31hyMhB-3s&t=179s)) ： [directional_change.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/directional_change.py) 已完成 **FindingDirectionalChangePoints()** 函式 \[已整合進**myutils套件**\]
#     + 感知重要點([Perceptually Important Points](https://www.youtube.com/watch?v=X31hyMhB-3s&t=339s)) ： [perceptually_important.py](https://tinyurl.com/yc2bykhr) 已完成**FindingPerceptuallyImportantPoints()** 函式 \[已整合進**myutils套件**\]
#   - 趨勢線
#     + 自行開發 ： 模擬手工方式，由兩個轉折點中畫出一條趨勢線
#     + 自動價格趨勢線([Automated Price Trend Lines](https://www.youtube.com/watch?v=wbFoefnidTU)) ： [trendline_automation.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/trendline_automation.py)
#   - 型態
#     + 頭肩底(或 頭肩頂)演算法一([Algorithmically Detecting (and Trading) Technical Chart Patterns with Python](https://medium.com/automation-generation/algorithmically-detecting-and-trading-technical-chart-patterns-with-python-c577b3a396ed)) ： [tech_screener_notebook.ipynb](https://github.com/samchaaa/alpaca_tech_screener/blob/master/tech_screener_notebook.ipynb) ： 頭肩底函式已完成，待整理
#     + 頭肩底(或 頭肩頂)演算法二([Automated Head and Shoulders Chart Pattern in Python](https://www.youtube.com/watch?v=6iFqjd5BOHw)) ： [head_shoulders.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/head_shoulders.py)
#     + 旗型與三角旗型演算法([Flag and Pennant Pattern Recognition](https://www.youtube.com/watch?v=Lb5SPCTp4uY)) ： [flags_pennants.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/flags_pennants.py)

# %% [markdown]
# ### 史塔克財金工作室 進階班
# * 講義存放連結：https://mega.nz/folder/g2gkSIJa
