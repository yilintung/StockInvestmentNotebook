# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-07-09 21:20:44.415 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-07-09 21:20:44.490 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-07-09 21:20:44.503 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1707：股票名稱 ＝ 葡萄王，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1708：股票名稱 ＝ 東鹼，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1720：股票名稱 ＝ 生達，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1721：股票名稱 ＝ 三晃，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1725：股票名稱 ＝ 元禎，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1726：股票名稱 ＝ 永記，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1727：股票名稱 ＝ 中華化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1760：股票名稱 ＝ 寶齡富錦，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1776：股票名稱 ＝ 展宇，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2059：股票名稱 ＝ 川湖，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2301：股票名稱 ＝ 光寶科，產業類別 ＝ 電子工業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數開平盤附近，櫃買指數反彈稍強。
# >    ![messageImage_1783558842028.jpg](attachment:498d5072-b27d-45fe-bafb-8cf9ded1811f.jpg)

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>鎚子線／吊人線 : 2026-07-08<br />
# 吞噬 : 2026-07-09<br />
# 孕育線／懷抱線 : 2026-07-08</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 9967.89億元 ，十日均量 ＝ 11807.66億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2026-06-15開始到2026-07-09結束，估算目標價為40689.57點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數開平盤附近，櫃買指數反彈稍強。
# >    ![messageImage_1783558858489.jpg](attachment:76502e4b-bdaa-438a-b4e1-fe70ae6358a9.jpg)

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-07-08<br />
# 孕育線／懷抱線 : 2026-07-08</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 2362.8億元 ，十日均量 ＝ 2421.74億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之矩形，型態範圍由2026-06-22開始到2026-07-08結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 6165 ， 股票名稱 ＝ 浪凡
# 股票代碼 ＝ 6235 ， 股票名稱 ＝ 華孚
# 股票代碼 ＝ 6505 ， 股票名稱 ＝ 台塑化
# 股票代碼 ＝ 2101 ， 股票名稱 ＝ 南港
# 股票代碼 ＝ 1615 ， 股票名稱 ＝ 大山
# 股票代碼 ＝ 3047 ， 股票名稱 ＝ 訊舟

# %% [markdown]
# * 篩選結果
#   - 材料*-KY(4763)：多頭回檔
#     ![260709_2.png](attachment:fed1d793-cadc-4714-a312-aacd5c7106e7.png)
#   - 益航(2601)：穩健續漲
#     ![260709_3.png](attachment:55071723-cfd9-4d09-9d77-5deb317734b2.png)
#   - 鑽石投資(6901)：多頭回檔
#     ![260709_4.png](attachment:5de1aa86-13ea-4d8b-8708-5ef5390ed33f.png)
#   - 威強電(3022)：多頭回檔／已到壓力區
#     ![260709_5.png](attachment:663c6d6f-d1b6-433d-9bb2-aebf3e6ca5d7.png)
#   - 瑞祺電通(6416)：穩健續漲
#     ![260709_6.png](attachment:14224a06-e583-4126-b291-179431db30ce.png)
#   - 群創(3481)：盤整觀察
#     ![260709_7.png](attachment:68683212-aea8-4176-85cf-730127519789.png)
#   - 漢翔(2634)：多頭回檔
#     ![260709_8.png](attachment:0b41927c-416a-499c-9447-f74a6c06efee.png)

# %% [markdown]
# * 觀察股列表
#   ![260709_1.png](attachment:613eb21e-8e61-407e-bb49-2f0bd7dd92a2.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：回測支撐後的反彈。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>（未識別出Ｋ線型態）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1944張 ，十日均量 ＝ 3569張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>底型反轉之底部型態，型態範圍由2025-08-11開始到2026-07-02結束，2026-07-06時已達估算之目標價（59.00元）。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-08-08'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-06-11']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2026-07-02'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-04-28','2026-07-09',line_drawing_callback)
display(image)
# Out:
# 估算目標價為61.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-325)：外資小賣(-469)、投信小買(+135)、自營小買(+9)。
# 主力小買(+186)。
# 分公司買賣家數差分散(-8)。
# 融資中立(+3)、融券中立(0)。
