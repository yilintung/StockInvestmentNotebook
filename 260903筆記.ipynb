# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))

# %% [markdown]
# * 篩選結果
#   - 材料*-KY(4763)：盤整觀察
#     ![260903_2.png](attachment:5a68e3eb-7a4b-430f-bbdd-38d3fac7fd5d.png)
#   - 台新新光金(2887)：強勢多頭
#     ![260903_3.png](attachment:ec5ecd3c-088b-4f5e-b50f-f58ee11b712a.png)
#   - 興富發(2542)：穩健續漲
#     ![260903_4.png](attachment:0c5c0367-f7f2-4953-8e5a-e30ec06a609b.png)
#   - 玉山金(2884)：強勢多頭
#     ![260903_5.png](attachment:c9c20925-d43e-4912-afba-4e8e26585301.png)
#   - 國喬(1312)：盤整觀察
#     ![260903_6.png](attachment:0c8f5a45-38d5-4eff-8896-580a8fcb8b07.png)

# %% [markdown]
# * 觀察股列表
#   ![260903_1.png](attachment:62e7ec17-6835-400a-9335-f76012000bf4.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 裕隆(2201)
#   看法：拉回整理，籌碼轉弱。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2201')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2026-03-02'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-07-06']['Close']

    # 設定底部日期與價格
    bottom_date  = '2026-04-10'
    bottom_price = range_prices.loc['2026-04-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2201','2025-12-09','2026-09-03',line_drawing_callback)
display(image)

# %% [markdown]
# 籌碼面：
# 法人大賣(-2970)：外資大賣(-2277)、投信大賣(-417)、自營大賣(-276)。
# 主力大賣(-3144)。
# 分公司買賣家數差分散(-262)。
# 融資增(+16)、融券增(+45)。

# %% [markdown]
# * 盟立(2464)
#   股票老師看法：突破創高，但位階高，要會設移動支撐。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2464')

# %% [markdown]
# 籌碼面：
# 法人小買(+1163)：外資小買(+1055)、投信中立(0)、自營小買(+108)。
# 主力大買(+5891)。
# 分公司買賣家數差集中(+376)。
# 融資大減(-1922)、融券大增(+352)。
