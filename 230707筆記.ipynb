# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】中期翻空，一步之遙
# 連續幾日都提到「前加權指數都還在高檔盤整，只是空方條件明顯比多方條件多」，而且比較細心的同學，應該會發現週三分享會，是這麼多年以來，唯一沒有彩蛋的一次，只提醒大家顧好手上的持股就好，擬定好離場策略，不要再持股增加了，因為這多方本來就存在太多瑕疵，致命的一擊是早晚的問題。
# 很巧合的剛剛說完，加權指數昨天急跌294點，成交量3544億，而籌碼面的觀察，三大法人和主力指標都站在賣方，融資續買，散戶小台也續增，外資期貨未平倉口數，很長一段時間以來，首度由多單轉為空單1738口，整體籌碼面偏空。
# 而技術面的觀察，已經從中期盤整轉為出現下降軌道，高點越來越低，低點越來越低的空頭結構，要從中期盤整轉為中期空頭，只有一步之遙。原先最強的櫃買指數，也出現高檔出量又留上影線，雖然短中期尚未翻空，但有高檔轉弱的跡象。
# 延續昨天夜盤期指的走勢，續跌110點，今天必然也是跟進補跌，只是跌幅相對昨天收斂，基本上走空趨勢應該已經確認，大家比較想問的應該是多方還有沒有機會？第一種最強的走法，就是3天內站回16900支撐，但這機率相當低，第二種則是在修正過程中，未來20日線下彎的10交易日，堅守2-3周，沒有跌破支撐16500，這樣整理完就還有機會續漲。
# 最後提醒，除非你天賦異稟，選股能力極強，否則指數沒穩定之前，短時間不要急著低接，操作重點就是守住個股支撐，不會看綜合工具和轉折，就單獨看均線，雖然不是完全完整的交易工具，但聊勝於無，急漲股守3日線和5日線，緩漲股守5日線和10日線，均線跌破且下彎分批離場。 (歡迎分享，請載明出處K線捕手楊忠憲粉絲團)
# ![358452448_749406163859980_7496895255902154325_n.jpg](attachment:d56c73df-c395-484e-ab44-3ab0e2e97bd9.jpg)

# %% [markdown]
# [Fed又耍鷹股匯雙殺](https://readers.ctee.com.tw/cm/20230707/a01aa1/1247990/share)
#
# [下半年股市全面上漲？富邦金潑冷水](https://readers.ctee.com.tw/cm/20230707/a02aa2/1247997/share)
#
# [Fed官員一面倒 支持續升息](https://readers.ctee.com.tw/cm/20230707/a02aa2/1248000/share)
#
# [全球商品連跌 經濟衰退警鈴響](https://readers.ctee.com.tw/cm/20230707/a08aa8/1248028/share)

# %% [markdown]
# 期貨開低105點，有頭部現象：
# ![messageImage_1688690744322.jpg](attachment:9b2e05ce-1e08-4bc7-95b0-1c4690ee789c.jpg)
#
# 加權指數也開低，跌破頸線第二天：
# ![messageImage_1688691648745.jpg](attachment:50b60cc7-ff65-4ff4-bfc9-119f8dc96282.jpg)
#
# 櫃買指數跌破中期支撐：
# ![messageImage_1688691705886.jpg](attachment:65f6f983-e8aa-4921-8f9a-a4240a311eba.jpg)
#
# 加權指數的月線已經跌破，而且下彎：
# ![messageImage_1688691797585.jpg](attachment:e850507e-e3b2-41b7-ade3-49f1648315d6.jpg)
# 如果今天漲跌變化不大，周KD應該是死亡交叉了
# 所以昨天請大家觀察的3個中期空方訊號，已經都出現了。
# 今天雖然仍偏弱，但是跌勢趨緩。
#
# 我知道碰到120，但有努力在守，給他一點時間
# 趨勢當然都持續偏空，即使今天守120，不過會跌到多少，周末用影音解盤講得比較清楚，本周很重要，記得收看喔
#
# 跌點收斂到120以內：
# ![messageImage_1688696792880.jpg](attachment:64f23ea4-d3bc-48d6-a8f7-9e3fe4142bf2.jpg)

# %% [markdown]
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 6531愛普  反彈遇壓，短線轉弱
# 4763材料-ky  少數多方強勢股，但位階非常高，要會設移動式支撐
# 1795美時  做頭續跌中，籌碼偏空
# 6533晶心科  短線偏空，中期大箱型區間
# 1802台玻  偏弱勢箱型整理，籌碼偏空
# 6829千附精密  小箱型整理，籌碼不強
# 3707漢磊  短線偏多，中期箱型整理
# 3006晶豪科 有中期頭部雛形，籌碼不強
# 1605華新 中期頭部續跌中
# 3324雙鴻 高檔轉弱，中期支撐暫時有守，籌碼不強
# 1909榮成 短線轉弱，有中期頭部雛形
# 2731雄獅  做頭續跌中，籌碼偏空
# 3714富采  迷你頭部，續跌中，籌碼偏空
# 6438迅得  短線轉弱，有中期頭部雛形
# 3013晟銘電  少數多方強勢股，但位階非常高，要會設移動式支撐
# 3015全漢  高檔箱型整理，籌碼集中，但後續不明朗
# 3189景碩  狹幅盤整，籌碼中性
# 6491晶碩  短線反彈，中期盤整
# 6173信昌電  高檔箱型整理，籌碼集中，但後續不明朗
# 2439美律  短線轉弱回測支撐，中長期有底形
# 3163波若威  少數多方強勢股，但位階非常高，要會設移動式支撐
# 3122笙泉  打底整理尚未轉強，籌碼中性
# 3556禾瑞亞  短線轉弱測試支撐，籌碼不強
# 4532瑞智  短線急漲，但乖離過大，留意前高壓力
# 6125廣運  多方強勢股，但位階非常高，要會設移動式支撐
# 4927泰鼎  短線轉弱回測支撐，中長期有底形
# 3218大學光  短線轉弱，有頭部雛形
# 2356英業達  高檔盤整，但籌碼轉弱中
# 6150撼訊  迷你頭部雛形
#
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 2882國泰金  做頭續跌中，短線前低有支撐，但還不穩
# 2354鴻準  做頭續跌中，短線前低有支撐，慎防第二層頭部
# 8050廣積  短線轉弱但還在多方結構，位階高要會設移動支撐
# 8155博智  短線穩定，但中期有頭部雛形
# 6417韋僑  短線反彈，中期大箱型整理
# 3346麗清  多方強勢股，但位階非常高，要會設移動式支撐
# 8454富邦媒  若勢盤整，籌碼不強
# 2633台灣高鐵  中期頭部，急跌測試支撐
# 4155訊映  中長期頭部雛形，籌碼不集中
# 3356奇偶  短線轉弱，中期支撐有守，籌碼集中
# 3707漢磊  短線轉弱，中期箱型
# 2313華通  短線偏多，中期箱型整理
# 6443元晶  短中期都個別有頭部雛形
# 3046建碁  高檔轉弱，做頭起跌
# 2486一詮  高檔震盪，籌碼不集中
# 6781 AES  短線轉弱，中期支撐有守，籌碼集中
# 6290良維  中期箱型整理
# 3205佰研  短線轉弱，底形支撐有守
# 1513中興電  有迷你頭部，籌碼轉弱
# 2324仁寶  短線轉弱，中期支撐有守
# 6277宏正  高檔轉弱，支撐不穩
# 2409友達  短線轉弱，支撐還不穩
# 6546正基  箱型整理
# 6274台燿  短線反彈，中期高檔箱型
# 8358金居  有迷你頭部，續跌中
# 6187萬潤  多方結構，但接近底形滿足區
# 6462神盾  仍多方結構，底形續漲中，籌碼集中
# 3706神達  高檔震盪，籌碼轉弱中
#
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 2355敬鵬  中期底形，籌碼集中，續漲中
# 3035智原  多方續漲，籌碼集中，但離滿足區不遠
# 4953緯軟  中期頭部，緩跌中
# 4749新應材  中期頭部雛形
# 1560中砂  短中期偏空，支撐還不穩
# 8255朋程  中期頭部雛形，籌碼偏空
# 6257矽格  盤整突破回測支撐，籌碼集中
# 4162智擎  弱勢盤整，籌碼中性
# 2645長榮太  中期箱型，趨勢不明朗
# 3710連展投控  短中長期偏空，籌碼弱，不見支撐
# 6197佳必琪  多方強勢股，但位階非常高，要會設移動式支撐
# 2368金像電  短線轉弱，測試中期支撐，籌碼不穩
# 5425台半  盤整，籌碼偏空
# 6441廣錠  迷你頭部雛形，籌碼偏空
# 8358金居  有迷你頭部續跌中
# 8069元太  短線轉弱，有迷你頭部雛形
# 2427三商電  高檔整理，籌碼不強
# 2476鉅祥  弱勢盤整，籌碼分散
# 3019亞光  箱型整理，籌碼中性偏多
# 6112邁達特  高檔整理，籌碼不穩定
# 2388威盛  高檔箱型，籌碼不集中
# 8086宏捷科  短線續漲籌碼集中，空間不明朗
# 3022威強電  中期箱型，籌碼不強
# 2454聯發科  弱勢盤整，籌碼不集中
# 1760寶齡富錦  弱勢盤整，籌碼不強
# 1514亞力  短線盤整，中期支撐有守
# 1905華紙  短線轉弱，測試支撐，有多指標背離現象
#
# 整理完大家的提問之後，對方向會更明朗，很多迷你頭部出現，但是因為迷你所以其實這些個股很快就會跌到支撐，因為這些殺傷力還不大，大盤不至於出現急跌。所以雖然指數有賣壓，但還不至於有系統性風險的出現，關鍵是在修正過程中，中期支撐會不會有守。而能否有守的關鍵正是這些迷你頭部，會不會進一步擴大成中期頭部，或是原本已經是中期頭部會不會開始起跌。反正今天空方如開盤說的，有稍微趨緩，甚麼是關鍵的的中期支撐，完整內容記得看本周影音解盤。

# %% [markdown]
# 【[複習一下周二的貼文](https://tinyurl.com/292efna8)】
# 其實這是常見的老問題了，同學說現在有不少股票還是在漲，可是位階很高，還是怕怕的，都眼睜睜的看著股票漲，但不敢出手。
# 這是人性很正常的反應，所以人性先天上的毛病，是不可能改變的，但可以透過策略去平衡，比如可投資的資金是100萬，真的完全投入風險高，那可以只用30萬進場，然後30萬再分配到3檔個股。
# 如此一來，不但控制了風險，又能參與到指數跟股票上漲的獲利，但是假如真的怕到連1成的資金都不敢投入，買完股票半夜都睡不好，那表示你現在的心理狀態，不適合進場投資，適度的休息一下，也不是壞事。
# 不過切記，真的要這樣做，雖然幸運一點避開大幅修正的風險，同時也要承受軋空手的風險，但千萬不要沒有策略，一直瞎忍耐，等到漲到相對高點，才又忍不住跳進去，這樣反而更麻煩。

# %% [markdown]
# 【[股價一直下跌，到底發生什麼事了？](https://tinyurl.com/45djjv7a)】
# 當股價下跌時，投資人最常問的問題是「發生什麼事了？」但是這是最重要的嗎？聊這個主題之前，先跟大家說一個佛教的故事。
# 釋迦牟尼有一個門徒，非常喜歡思考，尤其是關於「十四難」（註）的問題，而「十四難」是釋迦牟尼告訴門徒，是不需要思考的問題。但有一天這個好奇的門徒終於忍不住再次質問釋迦牟尼，他想得到「十四難」的答案，否則就要離開釋迦牟尼了。釋迦牟尼感慨說：「徒兒你真是愚痴！生、老、病、死的問題才是當務之急。
# 至於你問的十四難，只是無意義的辯論而已，對於實際的解脫煩惱而言，一點幫助也沒有。」並且做了一個這樣的比喻。如果有一天有人被毒箭射中了，親人急着幫他找醫生取出毒箭治療，但是這個人卻說不行。他要先知道醫生姓什麼？住哪裡？父母是誰？今年幾歲？還要問清楚身上的箭是出自那一座山？用什麼樹木造的？用什麼羽毛當箭翎？什麼人製作的？射箭的弓是什麼材質做的？箭上的毒藥出自何地？藥名是什麼？
# 這位中箭受傷的人，非要等到問清全部的問題，才肯接受治療。這時，釋迦牟尼停頓了一下，反問他的門徒：「這個人可不可以等到全部問題問完了，才拔箭上藥啊？」門徒不假思索地回答：「不可以。如果等到那個時候，早就毒發身亡，命喪黃泉了。」釋迦牟尼慈悲地笑了笑繼續說：「你現在的處境就是如此。你被毒箭射中了，不趕快求醫治病，非得要等「十四難」問題解答了，才願意拔箭療傷。」
# 這個故事告訴我們有時候，不是不追求真理，而是那不是目前最迫切的事情。
# 在股市投資中，常常重演這樣的戲碼，當股價崩跌時，就會有投資人一直急切的詢問，到底發生什麼事了。但這是不是重點阿！重要是在於下跌了你該怎麼辦？比方在盤中已經出現爆量長黑，就像毒箭射過來，你要先閃避，再不然萬一中箭，就要趕快急救，而不是還一直到處問發生什麼事。或是跳空帶大量，跌破關鍵支撐價位，頭部成型，該當機立斷，就該當機立斷。
# 天上突然降下傾盆大雨，你要做什麼？先躲雨？還是呆呆站在雨中，然後用line問朋友和google氣象新聞：現在是西北雨、梅雨、颱風，或是頂樓有人倒水…多數人應該都會說當然是先躲雨，可惜在股市中，大家常常選擇的是後者。當股價下跌時，不做停損或是應變決策，然後只是問發生什麼事了，或有甚者，全身已經淋濕了 還幻想等一下就要出太陽了。船要沉了，不趕快跳船，還在找沈船的原因是最危險的。
# 註：《大智度論》中記載「十四難」，是釋迦摩尼曾提出的一系列有關哲學問題，傳至中國有翻成十四無記。無記指沒有正確解答、沒有益處，因此釋迦牟尼不會做出回答。
#
# 其實我以前不是這樣寫，我是用了另一個故事。
#
# 【可能會看完的人很少，但我還是想說】
# 停損絕對不是只告訴學生要停損兩個字就解決，平時沒有學習停損工具，停損機制的設定，紮實的交易鍛鍊，心理素質的建立，我自己的課程要花200多張投影片，只為了教會停損。
# 所以才一直強調，投資歸根究柢成敗的關鍵，就是明確的交易，否則一旦當持股下跌，還是傻傻回頭追尋那些虛無飄渺的消息，明明就是聽消息做股票，卻說那是研究基本面和產業趨勢。
# 其實我在學習的初期，很早就發現這個盲點，但是身邊的朋友卻不這樣想¬，我反而變成異類，我還為此檢討了自己一陣子，後來才發現這就是蘇格拉底和柏拉圖說的洞穴寓言。我是從洞穴中走出來的人，已經知道真實世界的樣貌，滿懷欣喜地告訴洞穴裡的夥伴，但卻被當成是瘋子和異端。
# https://www.youtube.com/watch?v=jmzMDU4_5Jw

# %% [markdown]
# [有同學問我為什麼知道](https://tinyurl.com/3nxa7h88)，今天會守在120點之內？其實早盤解盤已經給了答案，只是會不會看，就是下降軌道內的支撐。
# 不過前提是你要畫得出來，還有知道他的意義。不會畫趨勢線、畫圖形，歡迎來補課，實體、直播同步招生！
# ![358057417_749561073844489_5428451280449588213_n.jpg](attachment:bc8fc00f-94b4-4fbd-9ef2-e51cead2887d.jpg)
#
# 報名連結→https://smart.businessweekly.com.tw/ecourse/product.aspx?PROD_TYPE_NO=PROD000015931

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值35,600元(收盤價：35.60元，跌0.75元)。調整後的停損價為35.00元，目標價為42.50元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,35.6,35444,-907,-2.5]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價    現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  35.6  35444  -907  -2.5

# %%
##### 使用2022年3月18日到今日收盤價(2023年7月7日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230707.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-9-13']['Open']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 估算目標價
bottom_price_date = '2022-10-21'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('目標價 ＝ {:.2f}元'.format(target_price))
target_price_date = '2023-06-02'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(2.5,15,15), colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 35.00元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-07-07
# 目標價 ＝ 42.50元

# %%
# 均線趨勢判定程序
def moving_average_trend(sma):
    now_sma  = sma.iloc[-1].to_dict()
    prev_sma = sma.iloc[-2].to_dict()
    # 確認均線方向：↑ : 'u' , ↓ : 'd' , ＝ : '='
    sma5_dir = 'u' if now_sma['SMA5'] > prev_sma['SMA5'] else 'd' if now_sma['SMA5'] < prev_sma['SMA5'] else '='
    sma10_dir = 'u' if now_sma['SMA10'] > prev_sma['SMA10'] else 'd' if now_sma['SMA10'] < prev_sma['SMA10'] else '='
    sma20_dir = 'u' if now_sma['SMA20'] > prev_sma['SMA20'] else 'd' if now_sma['SMA20'] < prev_sma['SMA20'] else '='
    sma60_dir = 'u' if now_sma['SMA60'] > prev_sma['SMA60'] else 'd' if now_sma['SMA60'] < prev_sma['SMA60'] else '='
    sma120_dir = 'u' if now_sma['SMA120'] > prev_sma['SMA120'] else 'd' if now_sma['SMA120'] < prev_sma['SMA120'] else '='
    sma240_dir = 'u' if now_sma['SMA240'] > prev_sma['SMA240'] else 'd' if now_sma['SMA240'] < prev_sma['SMA240'] else '='
    # 短期趨勢
    if sma5_dir == sma10_dir :
        if sma5_dir == 'u' :
            print('短期趨勢：上升')
        elif sma5_dir == 'd' :
            print('短期趨勢：下降')
    else :
        print('短期趨勢：盤整')
    # 中期趨勢
    if sma20_dir == sma60_dir :
        if sma20_dir == 'u' :
            print('中期趨勢：上升')
        elif sma20_dir == 'd' :
            print('中期趨勢：下降')
    else :
        print('中期趨勢：盤整')
    # 長期趨勢
    if sma120_dir == sma240_dir :
        if sma120_dir == 'u' :
            print('長期趨勢：上升')
        elif sma120_dir == 'd' :
            print('長期趨勢：下降')
    else :
        print('長期趨勢：盤整')

# %%
# 均線趨勢判斷
moving_average_trend(df_sma)
# Out:
# 短期趨勢：盤整
# 中期趨勢：上升
# 長期趨勢：上升
