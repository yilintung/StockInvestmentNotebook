# %% [markdown]
# ### 工作進度
# * 新的「股票投資筆記」Jupyter Notebook仍在**試行**中，因此[yilintung/StockInvestmentNotebook](https://github.com/yilintung/StockInvestmentNotebook)仍保留舊的筆記本資料。
#   - 新的筆記架構仍待決定，因此這段時間將會進行各種嘗試。
# * 舊的「股票投資筆記」Jupyter Notebook所有筆記檔案存放於[01. 股票投資筆記](https://mega.nz/folder/s6JTBaLY#wv-Q_dGak2m4h55iOWuj_Q)。
# * [股票老師](https://www.facebook.com/kevinyang20180801)的資訊放在[02.楊忠憲K線追擊週報](https://mega.nz/folder/a85wHKwK#SA6HACStdXRvMsLd2Ct0tQ)中。

# %%
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id) :
    results,images = analysis.analysis(stock_id)
    if '整體評價' in images :
        display(images['整體評價'])
    print('解盤內容：')
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 指數解盤

# %% [markdown]
# * 加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# <PIL.Image.Image image mode=RGB size=811x482>
# 解盤內容：
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 4219.91億元 ，十日均量 ＝ 3876.29億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-30死亡交叉。並且2025-07-01於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-06-23該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# - 趨勢狀況：目前價格呈現上漲趨勢。K線多數為紅K，顯示多頭力量較強。<br />
# - 移動平均線：5日、10日、20日均線呈現多頭排列，且價格位於均線之上，顯示短中期趨勢向上。<br />
# <br />
#  價量關係<br />
# - 成交量：近期成交量有所增加，且多數紅K伴隨較高成交量，顯示價量配合良好，支持上漲趨勢。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：短期支撐可參考20日均線（紫色線）附近。<br />
# - 壓力位置：目前價格接近前高點，可能面臨壓力，需觀察是否能有效突破。<br />
# <br />
#  KD指標<br />
# - 指標狀況：K線（紅線）與D線（藍線）在高檔區域，且K線略高於D線，顯示短期仍有上漲動能，但需注意超買風險。<br />
# <br />
#  MACD指標<br />
# - 指標狀況：DIF線（紅線）高於MACD線（藍線），且OSC柱體為正，顯示多頭趨勢持續。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於上漲趨勢，價量配合良好，短期內可能繼續上行。然而，由於KD指標接近超買區域，需警惕可能的回檔風險。建議投資者可考慮在支撐位附近進行佈局，並設置適當的停損點以控制風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# <PIL.Image.Image image mode=RGB size=798x479>
# 解盤內容：
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2025-06-26<br />
# 吞噬 : 2025-06-30<br />
# 孕育線／懷抱線 : 2025-07-01</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 895.29億元 ，十日均量 ＝ 907.54億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線下彎，中期盤整；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-30死亡交叉。並且2025-07-01於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-02當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# - 趨勢狀況：近期價格呈現盤整狀態，K線在短期移動平均線（5日、10日）附近波動，並且接近中期移動平均線（20日、60日）。<br />
# - 支撐與壓力：支撐位大約在220點附近，壓力位在240點左右。<br />
# <br />
#  價量關係<br />
# - 成交量：成交量整體變化不大，顯示市場觀望情緒較重，價量配合不明顯。<br />
# <br />
#  KD 指標<br />
# - 指標狀態：KD指標在高位區域（接近80）出現交叉，可能預示短期內有回檔壓力。<br />
# <br />
#  MACD 指標<br />
# - 指標狀態：MACD線與信號線接近零軸，且柱狀體縮小，顯示動能不足，市場可能進入盤整或轉向。<br />
# <br />
#  綜合評價<br />
# 目前市場處於盤整狀態，短期內可能會有小幅回檔。建議投資者謹慎觀望，等待更明確的趨勢信號再行動。若價格突破240點壓力位，可能會有進一步上漲空間；若跌破220點支撐位，則需考慮停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股解盤

# %%
stock_analysis(analysis,'3625')
# Out:
# <PIL.Image.Image image mode=RGB size=798x479>
# 解盤內容：
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-06-30<br />
# 十字線 : 2025-06-30<br />
# 孕育線／懷抱線 : 2025-06-30</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：中小型股大量／大型股天量（成交量 ＝ 2485張 ，十日均量 ＝ 609張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-12-05開始到2025-02-17結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-07-01結束，估算目標價為17.84。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線走平，中期盤整；120日線下彎、240日線上揚，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-01黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以下，中期空方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-16當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，尤其是最近幾天出現了明顯的紅K線，顯示出強勁的上漲動能。<br />
# <br />
#  價量關係<br />
# 成交量在最近幾天顯著增加，尤其是最後一根K線伴隨著大量，顯示出多頭的強勢進場，價量配合良好。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：短期支撐可參考5日移動平均線（棕色線）附近。<br />
# - 壓力位置：上方壓力可能在60日移動平均線（橙色線）附近，若能突破，則有望進一步上行。<br />
# <br />
#  KD指標<br />
# KD指標中的K線和D線均在高位，且K線上穿D線，顯示出強烈的多頭信號，但需注意超買區域的風險。<br />
# <br />
#  MACD指標<br />
# MACD指標中，DIF線上穿MACD線，且灰色柱體（OSC）由負轉正，顯示出多頭趨勢正在增強。<br />
# <br />
#  綜合評價<br />
# 整體來看，該股目前處於強勢上漲階段，價量配合良好，技術指標也支持多頭趨勢。然而，由於KD指標已進入超買區域，短期內可能會有回檔風險。建議投資者可考慮在支撐位附近進行佈局，並設置適當的停損和停利點以控制風險。</p>
# </td>
# </tr>
# </tbody>
# </table>
