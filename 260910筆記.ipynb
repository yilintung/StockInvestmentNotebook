# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-09-10 21:33:38.594 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-09-10 21:33:38.649 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-09-10 21:33:38.667 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1720：股票名稱 ＝ 生達，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1752：股票名稱 ＝ 南光，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1760：股票名稱 ＝ 寶齡富錦，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2327：股票名稱 ＝ 國巨*，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2338：股票名稱 ＝ 光罩，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2341：股票名稱 ＝ 英群，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2369：股票名稱 ＝ 菱生，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2381：股票名稱 ＝ 華宇，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2388：股票名稱 ＝ 威盛，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2392：股票名稱 ＝ 正崴，產業類別 ＝ 電子零組件業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數和櫃買指數都開小低，測試短線支撐。
# > ![messageImage_1789002037050.jpg](attachment:7bed8f94-c146-47d0-9cb8-3540e20d349c.jpg)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=832x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-09-09<br />
# 十字線 : 2026-09-09<br />
# 鎚子線／吊人線 : 2026-09-10</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 7507.43億元 ，十日均量 ＝ 9861.12億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-07-29開始到2026-09-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：加權指數和櫃買指數都開小低，測試短線支撐。
# > ![messageImage_1789002051867.jpg](attachment:b507198e-cfdc-43c8-bab1-817bec52a412.jpg)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-09-09<br />
# 孕育線／懷抱線 : 2026-09-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1732.78億元 ，十日均量 ＝ 2331.65億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-07-30開始到2026-09-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 6152 ， 股票名稱 ＝ 百一
# 股票代碼 ＝ 5340 ， 股票名稱 ＝ 建榮
# 股票代碼 ＝ 2409 ， 股票名稱 ＝ 友達
# 股票代碼 ＝ 1309 ， 股票名稱 ＝ 台達化
# 股票代碼 ＝ 2903 ， 股票名稱 ＝ 遠百
# 股票代碼 ＝ 2636 ， 股票名稱 ＝ 台驊控股

# %% [markdown]
# * 篩選結果
#   - 高端疫苗(6547)：多頭回檔
#     ![260910_2.png](attachment:0a736219-ddc6-4dfb-a3e3-5a387be38413.png)
#   - 玉山金(2884)：強勢多頭
#     ![260910_3.png](attachment:897673da-1ad4-45dd-8cab-1d9590f739cd.png)
#   - 台航(2617)：盤整觀察
#     ![260910_4.png](attachment:94295885-285d-43d1-96c2-c23742dcd5f9.png)
#   - 光罩(2338)：技術突破
#     ![260910_5.png](attachment:1f8db070-b781-4e5b-90ad-c388fb2fb010.png)

# %% [markdown]
# * 觀察股列表
#   ![260910_1.png](attachment:ac589a02-f80b-498a-aebd-7fa740623117.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 裕隆(2201)
#   看法：短線偏弱，往下測試支撐。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2201')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-09-04<br />
# 十字線 : 2026-09-04<br />
# 吞噬 : 2026-09-10</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 3322張 ，十日均量 ＝ 6652張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2026-01-02開始到2026-09-10結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2026-03-02'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-07-06']['Close']

    # 設定底部日期與價格
    bottom_date  = '2026-04-10'
    bottom_price = range_prices.loc['2026-04-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))
    
    # 設定突破日期
    breakout_date = '2026-09-01'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2201','2025-12-09','2026-09-10',line_drawing_callback)
display(image)
# Out:
# 估算目標價為32.25元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-349)：外資小賣(-567)、投信中立(+4)、自營小買(+214)。
# 主力小賣(-569)。
# 分公司買賣家數差分散(-191)。
# 融資減(-214)、融券減(-5)。
