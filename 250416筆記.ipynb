# ![741722.jpg](attachment:4de93cde-9554-4607-b466-91fab269caf6.jpg)
# ![741723.jpg](attachment:f82cfa54-f416-4d25-93b3-067f99a82326.jpg)
#
#
# 很多人會把今天開低，歸咎於輝達的利空，但事實真的如此嗎？重點是，周末分享會在這些利多利空新聞沒有出來之前，就已經預先提醒反彈應該會在上半周暫時告一段落了。市場的趨勢多空轉換永遠都早有跡象，股價反應的也永遠是未來，只是多數人總是後知後覺，還在等基本面和新聞佐證。
# 真正懂市場的人都知道：股價反應的從來不是現在，而是未來。也因此，那些走在前面的人，早在新聞還沒報、數據還沒出來之前，就已經默默完成了部位調整。然而，多數投資人依然習慣追逐「看得見」的基本面、等待新聞「證實」自己心中的預期，卻忽略了這些資訊往往只是過去的映照。
# 當大家終於看到新聞、企業財報亮眼，市場早已反應結束；當數據一片慘淡、信心崩潰時，聰明的資金卻已經開始悄悄布局反轉。記住，市場不是等你看清楚才動的，而是等你「相信」的那一刻，已經來不及了。要成為市場中的贏家，不是看誰資訊多，而是看誰能讀懂「技術面訊號」背後的語言。永遠都是這樣，股價先漲一波，利多就會出來了，先下跌一波之後，利空就會出來了。
# [震撼！輝達宣布認列55億美元費用 賣給中國的 H20 晶片遭美管制](https://money.udn.com/money/story/123398/8677313?from=ednappsharing)
# 不要為漲跌找理由，而是要在漲跌之間，看出趨勢、位階、型態、支撐、壓力、轉折...，並能夠擬定自己的交易策略，這才是成熟交易人該做的事情，追消息永遠追不完，而且是緩不濟急的。
#
# 量能比預期的提早放大一些。

# %% [markdown]
# 陞泰(8072)
# ![messageImage_1744765454127.jpg](attachment:d879311f-00df-4a8c-b270-d109e4225f51.jpg)
# 噴出段現象，改採噴出段操作法。
#
# 八方雲集(2753)
# ![messageImage_1744765524622.jpg](attachment:1051f5d3-ba17-4c24-be69-8b9b3ee3f6a7.jpg)
# ![messageImage_1744770162055.jpg](attachment:2bf55ada-77e1-46c7-a1a6-f21a260c7e58.jpg)
#
# 期元大美元指反1(00684R)
# ![messageImage_1744769662510.jpg](attachment:09db5379-7476-4b26-91b5-6bf191c65d31.jpg)

# %% [markdown]
# 📢【[投資不是你以為的那麼單純：你在評論股票時，也在定義你自己](https://www.facebook.com/kevinyang20180801/posts/pfbid02iAstG8YeWSiaSRPQmwaEqLqwwNgAfEoFSvuNRJkDMqdQTkEaZSWSZTsPvmAmKMZBl)】
# 你有沒有發現——
# 同一檔股票，有人看多、有人看空；
# 一則利多消息，有人覺得是轉機，有人卻認為是出貨。
# 那是因為：
# 🔍 股票本身或許可以被量化、被分析，
# 但你如何解讀，才真正反映了你是誰。
# 💬 當你說：「這支股票快漲了！」
# 可能是你對機會的渴望。
# 💬 當你說：「這公司不行。」
# 也許你其實在對風險說不。
# 換句話說——
# 🪞 你怎麼看待一檔股票，比股票本身更能定義你自己。
# 📌 因為投資，不只是財務行為，
# 它更是一場與自己價值觀的深層對話。
# 在市場上：
#   - [技術分析精論：二十年來投資界最完整的技術分析全圖解(上)](https://www.books.com.tw/products/0010725781)、[技術分析精論：二十年來投資界最完整的技術分析全圖解(下)](https://www.books.com.tw/products/0010725792)
#   - [金融市場技術分析 (暢銷經典版) (上)](https://www.books.com.tw/products/0010903677)、[金融市場技術分析 (暢銷經典版) (下)](https://www.books.com.tw/products/0010903674)
#   - [約翰墨菲視覺分析：回歸最單純的圖形解析，解讀全球市場最深層的故事](https://www.books.com.tw/products/0010859153)
#   - [股票交易精鍊手冊：提升個人化選股、買賣程序到資產配置的張力交易法](https://www.books.com.tw/products/0010851121)（原文書資料[連結](https://www.wiley.com/WileyCDA/Section/id-828237.html)）
# * 「程式交易、人工智慧」相關書籍整理：
#   - [Python金融市場賺大錢聖經：寫出你的專屬指標](https://www.books.com.tw/products/0010901963) （程式碼[連結](https://github.com/arleigh418/python-and-Taiwan-stock-market)）
#   - [最強 AI 投資分析：打造自己的股市顧問機器人，股票趨勢分析×年報解讀×選股推薦×風險管理](https://www.books.com.tw/products/0010973679)（程式碼[連結](https://www.flag.com.tw/bk/t/f3933)）
#   - [LangChain開發手冊：OpenAI × LCEL 表達式 × Agent 自動化流程 × RAG 擴展模型知識 × 圖形資料庫 × LangSmith 除錯工具](https://www.books.com.tw/products/0010989271)（程式碼[連結](https://www.flag.com.tw/bk/t/F4763)）
#   - [ChatGPT 開發手冊 Turbo×Vision 進化版：用 OpenAI Chat/Assistants API‧Function calling 設計 GPTs action‧LINE/Discord bot‧股市分析/自動助理](https://www.books.com.tw/products/0010978530)（程式碼[連結](https://www.flag.com.tw/bk/t/F4762)）
#   - [問ChatGPT也不會的Python量化交易聖經：從分析到真實交易一本全會](https://www.books.com.tw/products/0011016236)（程式碼[連結](https://github.com/ZJHuang915/PythonQuantTrading)）
#   - [Python：量化交易Ta-Lib技術指標139個活用技巧](https://www.books.com.tw/products/0010933669?srsltid=AfmBOooVGfM9S6uk4ZR7J7tR_lyJsLpy2w6HrStUle4cKKKJZ3bbnuzO)（歷史資料與範例程式[連結](https://drive.google.com/drive/folders/1vx1tIUAeJeqBCVza4WlzRyggght6KnU-?usp=sharing)）
# * 量化技術分析系統
#   - 調整資料庫結構：
#     ![250416_1.png](attachment:97ea4d22-2592-4c90-9aa7-371f477aa3d8.png)
#   - 初步實作資料庫結構相關程序：

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils
import sqlite3
import requests

from dotenv import load_dotenv, find_dotenv
from FinMind.data import DataLoader

# %%
load_dotenv(find_dotenv())
token = os.environ.get('FINMIND_TOKEN')
api = DataLoader()
api.login_by_token(api_token=token)

# %%
# 測試用：刪除舊的資料庫
if os.path.exists('data/stock.db'):
    os.remove('data/stock.db')

# %%
# 連線資料庫
conn = sqlite3.connect('data/stock.db')
cursor = conn.cursor()

# %%
# 啟用外鍵支持
conn.execute('PRAGMA foreign_keys = ON;')

res = conn.execute('PRAGMA foreign_keys;')
res.fetchone()
# Out:
# (1,)

# %%
# 設定資料庫結構
cursor.execute('''
CREATE TABLE IF NOT EXISTS StockInfo
(
    StockID TEXT NOT NULL PRIMARY KEY ,
    StockName TEXT,
    IndustryCategory TEXT,
    Type TEXT
);
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS DailyPrice
(
    SerialNo INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
    StockID TEXT NOT NULL,
    Date TEXT,
    Open REAL,
    High REAL,
    Low REAL,
    Close REAL,
    Volume INTEGER,
    
    FOREIGN KEY (StockID) REFERENCES StockInfo (StockID)
);
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS WeeklyPrice
(
    SerialNo INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
    StockID TEXT NOT NULL,
    Date TEXT,
    Open REAL,
    High REAL,
    Low REAL,
    Close REAL,
    Volume INTEGER,
    
    FOREIGN KEY (StockID) REFERENCES StockInfo (StockID)
);
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS MonthlyPrice
(
    SerialNo INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
    StockID TEXT NOT NULL,
    Date TEXT,
    Open REAL,
    High REAL,
    Low REAL,
    Close REAL,
    Volume INTEGER,
    
    FOREIGN KEY (StockID) REFERENCES StockInfo (StockID)
);
''')
conn.commit()

# %%
# 台股總覽 TaiwanStockInfo #
df = api.taiwan_stock_info()
display(df)
df_stock_info = df.drop(columns=['date'])
df_stock_info = df_stock_info.rename(columns={'stock_id':'StockID','stock_name':'StockName','industry_category':'IndustryCategory','type':'Type'})
df_stock_info.drop_duplicates(subset=['StockID'], keep='first', inplace=True)
display(df_stock_info)
# 這裡無法使用df.to_sql方法來將DataFrame儲存至資料表中。使用df.to_sql方式儲存後會造成價格資料儲存到對應資料表(DailyPrice...)時會發生「foreign key mismatch error」錯誤，原因不明？
# TODO : 由於無法使用df.to_sql方法，因此重複執行時會出現錯誤(沒有if_exists='replace'方式)。
for idx in range(df_stock_info.shape[0]) :
    info = df_stock_info.iloc[idx]
    conn.execute("INSERT INTO StockInfo(StockID,StockName,IndustryCategory,Type) VALUES(?,?,?,?)", (info['StockID'],info['StockName'],info['IndustryCategory'],info['Type']))
# Out:
# 2025-04-16 20:30:45.204 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockInfo, data_id:
#      industry_category               stock_id stock_name  type        date
# 0                  ETF                   0050     元大台灣50  twse  2025-04-16
# 1                  ETF                   0051    元大中型100  twse  2025-04-16
# 2                  ETF                   0052       富邦科技  twse  2025-04-16
# 3                  ETF                   0053       元大電子  twse  2025-04-16
# 4                  ETF                   0054     元大台商50  twse  2024-12-04
# ...                ...                    ...        ...   ...         ...
# 3932                大盤                  TAIEX       加權指數  twse        None
# 3933             Index               Textiles    紡織纖維類指數  twse        None
# 3934             Index                Tourism    觀光事業類指數  twse        None
# 3935                大盤                   TPEx       櫃買指數  tpex        None
# 3936             Index  TradingConsumersGoods    貿易百貨類指數  twse        None
#
# [3937 rows x 5 columns]
#      IndustryCategory                StockID StockName  Type
# 0                 ETF                   0050    元大台灣50  twse
# 1                 ETF                   0051   元大中型100  twse
# 2                 ETF                   0052      富邦科技  twse
# 3                 ETF                   0053      元大電子  twse
# 4                 ETF                   0054    元大台商50  twse
# ...               ...                    ...       ...   ...
# 3932               大盤                  TAIEX      加權指數  twse
# 3933            Index               Textiles   紡織纖維類指數  twse
# 3934            Index                Tourism   觀光事業類指數  twse
# 3935               大盤                   TPEx      櫃買指數  tpex
# 3936            Index  TradingConsumersGoods   貿易百貨類指數  twse
#
# [2934 rows x 4 columns]

# %%
# 股價日成交資訊 TaiwanStockPrice：一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
df = api.taiwan_stock_daily(start_date='2025-04-15',)
display(df)
df_daily_price = df.drop(columns=['Trading_money','spread','Trading_turnover'])
df_daily_price = df_daily_price.rename(columns={'date':'Date','stock_id':'StockID','Trading_Volume':'Volume','open':'Open','max':'High','min':'Low','close':'Close'})
# 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價與成交量
df_daily_price = df_daily_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume']]
# 排除掉非TaiwanStockInfo內的股票
df_daily_price = df_daily_price[df_daily_price['StockID'].isin(df_stock_info['StockID'].to_list())]
display(df_daily_price)
df_daily_price.to_sql('DailyPrice', conn, if_exists='append', index=False)
# Out:
# 2025-04-16 20:30:46.251 | INFO     | FinMind.data.finmind_api:get_data:148 - download TaiwanStockPrice, data_id:
#              date               stock_id  Trading_Volume  Trading_money  \
# 0      2025-04-15                   0050        19827286     3265491048
# 1      2025-04-15                   0051          156750       10531491
# 2      2025-04-15                   0052          629915      101124455
# 3      2025-04-15                   0053           10105         873733
# 4      2025-04-15                   0055          106549        2815468
# ...           ...                    ...             ...            ...
# 47131  2025-04-15                  TAIEX      5242983763   305561723714
# 47132  2025-04-15                   TPEx       774516000    69478505000
# 47133  2025-04-15               Textiles        24311966     1894815138
# 47134  2025-04-15                Tourism         4634695      514371137
# 47135  2025-04-15  TradingConsumersGoods        13490916      739699062
#
#            open       max       min     close  spread  Trading_turnover
# 0        164.05    165.50    163.30    165.35    1.65             37396
# 1         66.20     67.80     66.20     67.70    1.50               385
# 2        160.00    161.65    159.20    161.10    1.95              1269
# 3         86.00     87.05     86.00     87.05    1.50               101
# 4         26.27     26.50     26.26     26.50    0.37               417
# ...         ...       ...       ...       ...     ...               ...
# 47131  19609.90  19895.43  19576.15  19857.67  344.58           2458147
# 47132    209.06    216.63    209.06    216.48    7.87            704532
# 47133    518.80    533.55    518.80    531.87   13.07             18140
# 47134    109.59    112.40    109.59    111.98    2.39              8047
# 47135    254.69    259.14    254.69    257.85    3.16              9574
#
# [47136 rows x 10 columns]
#              Date                StockID      Open      High       Low  \
# 0      2025-04-15                   0050    164.05    165.50    163.30
# 1      2025-04-15                   0051     66.20     67.80     66.20
# 2      2025-04-15                   0052    160.00    161.65    159.20
# 3      2025-04-15                   0053     86.00     87.05     86.00
# 4      2025-04-15                   0055     26.27     26.50     26.26
# ...           ...                    ...       ...       ...       ...
# 47131  2025-04-15                  TAIEX  19609.90  19895.43  19576.15
# 47132  2025-04-15                   TPEx    209.06    216.63    209.06
# 47133  2025-04-15               Textiles    518.80    533.55    518.80
# 47134  2025-04-15                Tourism    109.59    112.40    109.59
# 47135  2025-04-15  TradingConsumersGoods    254.69    259.14    254.69
#
#           Close      Volume
# 0        165.35    19827286
# 1         67.70      156750
# 2        161.10      629915
# 3         87.05       10105
# 4         26.50      106549
# ...         ...         ...
# 47131  19857.67  5242983763
# 47132    216.48   774516000
# 47133    531.87    24311966
# 47134    111.98     4634695
# 47135    257.85    13490916
#
# [2623 rows x 7 columns]
# 2623

# %%
# 台股週 K 資料表 TaiwanStockWeekPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用) #
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockWeekPrice",
    "start_date": "2025-04-07",
    "token": token,
}
resp = requests.get(url, params=parameter)
print(resp.status_code)
data = resp.json()
df_weekly_price = pd.DataFrame(data["data"])
display(df_weekly_price)
df_weekly_price = df_weekly_price.drop(columns=['yweek','trading_money','spread','trading_turnover'])
df_weekly_price = df_weekly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','open':'Open','max':'High','min':'Low','close':'Close'})
# 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價與成交量
df_weekly_price = df_weekly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume']]
# 排除掉非TaiwanStockInfo內的股票
df_weekly_price = df_weekly_price[df_weekly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
display(df_weekly_price)
df_weekly_price.to_sql('WeeklyPrice', conn, if_exists='append', index=False)
# Out:
# 200
#                     stock_id    yweek       max       min  trading_volume  \
# 0                       0050  2025W15    164.55    145.00       490402467
# 1                       0051  2025W15     65.70     57.40         2628176
# 2                       0052  2025W15    160.65    139.00        17460514
# 3                       0053  2025W15     85.15     75.00          371226
# 4                       0055  2025W15     26.62     24.00         7355968
# ...                      ...      ...       ...       ...             ...
# 48251                  TAIEX  2025W15  20153.57  17306.97    146553683360
# 48252                   TPEx  2025W15    232.45    183.97      3386898000
# 48253               Textiles  2025W15    579.47    465.30       341347168
# 48254                Tourism  2025W15    117.60    100.00        55703422
# 48255  TradingConsumersGoods  2025W15    266.66    240.49       225788573
#
#        trading_money  trading_turnover        date     close      open  \
# 0        75662034905            636562  2025-04-07    164.55    158.40
# 1          162630010              4380  2025-04-07     64.45     65.70
# 2         2620223945             14858  2025-04-07    160.65    156.05
# 3           30109546               851  2025-04-07     85.15     83.85
# 4          189585551              4808  2025-04-07     26.05     25.44
# ...              ...               ...         ...       ...       ...
# 48251  6468060983466          59920044  2025-04-07  19528.77  20153.57
# 48252   254925957000           2888326  2025-04-07    204.94    232.45
# 48253    13106907314            164370  2025-04-07    508.28    579.47
# 48254     5277817456             74062  2025-04-07    109.63    117.60
# 48255    12788971836            147394  2025-04-07    257.92    266.66
#
#         spread
# 0       -11.45
# 1        -8.55
# 2       -12.70
# 3        -8.00
# 4        -2.21
# ...        ...
# 48251 -1769.45
# 48252   -32.44
# 48253   -71.19
# 48254    -7.97
# 48255    -8.74
#
# [48256 rows x 11 columns]
#              Date                StockID      Open      High       Low  \
# 0      2025-04-07                   0050    158.40    164.55    145.00
# 1      2025-04-07                   0051     65.70     65.70     57.40
# 2      2025-04-07                   0052    156.05    160.65    139.00
# 3      2025-04-07                   0053     83.85     85.15     75.00
# 4      2025-04-07                   0055     25.44     26.62     24.00
# ...           ...                    ...       ...       ...       ...
# 48251  2025-04-07                  TAIEX  20153.57  20153.57  17306.97
# 48252  2025-04-07                   TPEx    232.45    232.45    183.97
# 48253  2025-04-07               Textiles    579.47    579.47    465.30
# 48254  2025-04-07                Tourism    117.60    117.60    100.00
# 48255  2025-04-07  TradingConsumersGoods    266.66    266.66    240.49
#
#           Close        Volume
# 0        164.55     490402467
# 1         64.45       2628176
# 2        160.65      17460514
# 3         85.15        371226
# 4         26.05       7355968
# ...         ...           ...
# 48251  19528.77  146553683360
# 48252    204.94    3386898000
# 48253    508.28     341347168
# 48254    109.63      55703422
# 48255    257.92     225788573
#
# [2621 rows x 7 columns]
# 2621

# %%
# 台股月 K 資料表 TaiwanStockMonthPrice (只限 backer、sponsor 會員使用) ： 一次拿特定日期，所有資料(只限 backer、sponsor 使用)
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockMonthPrice",
    "start_date": "2025-03-01",
    "token": token, 
}
resp = requests.get(url, params=parameter)
print(resp.status_code)
data = resp.json()
df_monthly_price = pd.DataFrame(data["data"])
display(df_monthly_price)
df_monthly_price = df_monthly_price.drop(columns=['ymonth','trading_money','spread','trading_turnover'])
df_monthly_price = df_monthly_price.rename(columns={'date':'Date','stock_id':'StockID','trading_volume':'Volume','open':'Open','max':'High','min':'Low','close':'Close'})
# 保存格式：日期、股票代碼、開盤價、最高價、最低價、收盤價與成交量
df_monthly_price = df_monthly_price[['Date', 'StockID', 'Open', 'High', 'Low', 'Close', 'Volume']]
# 排除掉非TaiwanStockInfo內的股票
df_monthly_price = df_monthly_price[df_monthly_price['StockID'].isin(df_stock_info['StockID'].to_list())]
display(df_monthly_price)
df_monthly_price.to_sql('MonthlyPrice', conn, if_exists='append', index=False)
# Out:
# 200
#                     stock_id   ymonth       max       min  trading_volume  \
# 0                       0050  2025M03    189.50    172.20       776972113
# 1                       0051  2025M03     79.55     71.25         2966889
# 2                       0052  2025M03    188.65    168.50        26103903
# 3                       0053  2025M03    101.30     90.80          476807
# 4                       0055  2025M03     29.13     27.86         4888220
# ...                      ...      ...       ...       ...             ...
# 53897                  TAIEX  2025M03  22979.97  20695.90    402933864379
# 53898                   TPEx  2025M03    262.20    230.40     20618531000
# 53899               Textiles  2025M03    632.27    569.84      1204377446
# 53900                Tourism  2025M03    125.12    114.81        99424175
# 53901  TradingConsumersGoods  2025M03    283.55    263.28       495617677
#
#         trading_money  trading_turnover        date     close      open  \
# 0        142169897364           1352411  2025-03-01    172.75    188.80
# 1           226531977              8986  2025-03-01     71.35     78.85
# 2          4719176238             47414  2025-03-01    169.00    186.40
# 3            46414643              2816  2025-03-01     91.10    100.45
# 4           139860458              9576  2025-03-01     27.86     29.04
# ...               ...               ...         ...       ...       ...
# 53897  20734066355096         168617265  2025-03-01  20695.90  22734.05
# 53898   2115594725000          17635391  2025-03-01    230.40    259.37
# 53899     62230659556            746495  2025-03-01    569.84    626.02
# 53900     11074178184            224823  2025-03-01    115.15    122.29
# 53901     25871228630            333288  2025-03-01    263.28    281.76
#
#         spread
# 0       -19.75
# 1        -8.00
# 2       -22.80
# 3       -11.70
# 4        -1.18
# ...        ...
# 53897 -2357.28
# 53898   -29.52
# 53899   -56.18
# 53900    -7.14
# 53901   -18.48
#
# [53902 rows x 11 columns]
#              Date                StockID      Open      High       Low  \
# 0      2025-03-01                   0050    188.80    189.50    172.20
# 1      2025-03-01                   0051     78.85     79.55     71.25
# 2      2025-03-01                   0052    186.40    188.65    168.50
# 3      2025-03-01                   0053    100.45    101.30     90.80
# 4      2025-03-01                   0055     29.04     29.13     27.86
# ...           ...                    ...       ...       ...       ...
# 53897  2025-03-01                  TAIEX  22734.05  22979.97  20695.90
# 53898  2025-03-01                   TPEx    259.37    262.20    230.40
# 53899  2025-03-01               Textiles    626.02    632.27    569.84
# 53900  2025-03-01                Tourism    122.29    125.12    114.81
# 53901  2025-03-01  TradingConsumersGoods    281.76    283.55    263.28
#
#           Close        Volume
# 0        172.75     776972113
# 1         71.35       2966889
# 2        169.00      26103903
# 3         91.10        476807
# 4         27.86       4888220
# ...         ...           ...
# 53897  20695.90  402933864379
# 53898    230.40   20618531000
# 53899    569.84    1204377446
# 53900    115.15      99424175
# 53901    263.28     495617677
#
# [2625 rows x 7 columns]
# 2625

# %%
# 修改並關閉資料庫
conn.commit()
conn.close()

# %% [markdown]
# * 驗證：StockChartPatterns類別
#   - 對照：同一張K線圖在ChartGPT的回覆（使用[ChatGPT Plus](https://openai.com/chatgpt/pricing/)）。

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            # 驗證：型態最後一個轉折點離價格資料距離
            print('◆ 型態最後一個轉折點離價格資料距離 ＝ {} '.format( date_to_index(prices,prices.iloc[-1].name) - date_to_index(prices,pattern_window.iloc[-1]['Date']) ))
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '上升旗形' or pattern_name == '下降旗形' or pattern_name == '看跌三角旗形' or pattern_name == '看漲三角旗形'  : 
                line1_start_date = pattern_window.iloc[1]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line1_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line2_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if pattern['type'] == '頭肩頂' or pattern['type'] == '雙頂' or pattern['type'] == '圓弧頂' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 15.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2023年8月10日到今日(2025年4月16日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250416.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
support_line_start_date = '2024-01-05'
support_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
support_price           = df_k_line.loc['2025-04-10']['Low']
resistance_line_start_date = '2024-03-07'
resistance_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
resistance_price           = df_k_line.loc['2024-08-06']['Low']
seq_of_seq_of_points=[
    [(support_line_start_date,support_price),(support_line_end_date,support_price)],
    [(resistance_line_start_date,resistance_price),(resistance_line_end_date,resistance_price)]
]
print('支撐線指數 ＝ {:.2f} ， 壓力線指數 ＝ {:.2f}'.format(support_price,resistance_price))

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.2, colors=('xkcd:red','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)
# Out:
# 支撐線指數 ＝ 18256.47 ， 壓力線指數 ＝ 19662.74

# %%
### 繪製壓力與支撐線 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
support_line_start_date = '2024-01-05'
support_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
support_price           = df_k_line.loc['2024-01-17']['Close']
resistance_line_start_date = '2024-03-07'
resistance_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
resistance_price           = df_k_line.loc['2024-08-05']['Close']
seq_of_seq_of_points=[
    [(support_line_start_date,support_price),(support_line_end_date,support_price)],
    [(resistance_line_start_date,resistance_price),(resistance_line_end_date,resistance_price)]
]
print('支撐線指數 ＝ {:.2f} ， 壓力線指數 ＝ {:.2f}'.format(support_price,resistance_price))

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.2, colors=('xkcd:red','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)
# Out:
# 支撐線指數 ＝ 17161.79 ， 壓力線指數 ＝ 19830.88

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':25})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 25}]
# ＤＥＢＵＧ ： 五個轉折點區間超過 max_bars ＝ 240 範圍
# ＤＥＢＵＧ ： 五個轉折點區間超過 max_bars ＝ 240 範圍
# ＤＥＢＵＧ ： 六個轉折點區間超過 max_bars ＝ 240 範圍
# ＤＥＢＵＧ ： 六個轉折點區間超過 max_bars ＝ 240 範圍
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 55        2023-10-31  16001.27   LO
# 224       2024-07-11  24390.03   HI
# 239       2024-08-05  19830.88   LO
# 289       2024-10-18  23620.57   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 116
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 239       2024-08-05  19830.88   LO
# 289       2024-10-18  23620.57   HI
# 318       2024-11-29  22202.28   LO
# 344       2025-01-07  23824.72   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 61
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 289       2024-10-18  23620.57   HI
# 318       2024-11-29  22202.28   LO
# 344       2025-01-07  23824.72   HI
# 348       2025-01-13  22488.33   LO
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 57
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 239       2024-08-05  19830.88   LO
# 289       2024-10-18  23620.57   HI
# 318       2024-11-29  22202.28   LO
# 344       2025-01-07  23824.72   HI
# 348       2025-01-13  22488.33   LO
# 370       2025-02-21  23730.25   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 35

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-04-22 ， 型態結束日期 ＝ 2025-02-04

# %% [markdown]
# *你說*：分析K線圖走勢，並列出價格型態
#
# **ChatGPT 說**：
# 📉 趨勢分析
# 1\.	2023年8月到2024年3月：多頭趨勢
# o	價格持續攀升，形成穩定的上升趨勢，並伴隨著溫和放大的成交量，顯示買盤動能強。
# 2\.	2024年4月到2024年7月：加速上漲與高點
# o	價格在短期內快速上漲，出現尖頂狀態，可能為過熱信號。
# o	高點出現在2024年7月左右，形成波段高點。
# 3\.	2024年8月到2025年3月：橫盤震盪
# o	價格無明顯方向，處於高檔區間震盪整理。
# 4\.	2025年4月前：急跌
# o	明顯的斷崖式下跌，價格迅速下探，出現大量長黑K。
# o	成交量明顯放大，出現恐慌性賣壓。
# 5\.	2025年4月中：反彈
# o	出現反彈走勢，紅K連續出現，有技術性反彈或死貓跳 (dead cat bounce) 的可能。
#
# 📊 價格型態辨識
# 1\.	上升三角形突破（2024年初）
# o	價格不斷測試高點阻力，最終向上突破，進入快速上升期。
# 2\.	頭肩頂（Head and Shoulders）
# o	2024年5月～2024年11月，可能構成左肩、頭部與右肩的形態，為典型的反轉型態。
# 3\.	M頭 / 雙峰（Double Top）
# o	若不完全符合頭肩頂，也可視為雙峰結構，出現於高檔位置，之後價格急轉直下。
# 4\.	崩跌＋放量（Breakdown with Volume）
# o	2025年初出現明顯跌破支撐線，伴隨大量成交量，確認跌勢。
# 5\.	反彈缺口或島形反轉初期？
# o	在圖的最右側，有跳空反彈跡象，若延續上漲，可構成島形反轉（Island Reversal）的可能性，需持續觀察。
#
# 🧠 結論與建議
# •	目前處於風險區間，雖有反彈，但下跌壓力仍在，應關注反彈是否能站穩前波支撐（現已成壓力）。
# •	若是做多者，建議觀望或短線操作，確認底部訊號再進場。
# •	做空者可考慮在反彈無力時找進場點，但需謹慎控風險。
#
# *你說*：畫出支撐線與壓力線
#
# **ChatGPT 說**：
# ![250416_1.png](attachment:f3caf76d-2ade-495d-8826-e81b32435312.png)
# 上圖中，我已標示出兩條重要的技術線：
# •	🔴 紅色虛線（壓力線 Resistance）：約在價格 22,000 附近，這裡是前波高點區間，現在可能成為反彈的壓力位。
# •	🟢 綠色虛線（支撐線 Support）：約在價格 18,000 附近，這是急跌後短期止穩的區域，目前是關鍵支撐帶。
