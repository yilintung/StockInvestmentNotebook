# %% [markdown]
# ### [K線捕手](https://www.facebook.com/kevinyang20180801/)

# %% [markdown]
# [快訊》川普：對所有進口商品徵10％全面關稅 對表現不佳國家徵更高關稅](https://www.ctee.com.tw/news/20250403700297-430701)
#
# [美對特定國家關稅稅率 台灣32％ 中國大陸34％](https://www.ctee.com.tw/news/20250403700308-430701)
#
# ![722396.jpg](attachment:922b7f65-68c3-4c57-9747-d4fb67736505.jpg)

# %% [markdown]
# ### [**智股網** 課程](https://www.iqvalue.com/elite/course)
#
# 同學們：
#
# 還記得VIX指標嗎?這是底部模組中的其中一項指標，根據過去歷史經驗，底部通常會在VIX恐慌指數來到高點的時候出現，但目前VIX指數仍在相對低檔的位置。
#
# 第二個，台股的底部會有伴隨量增的情況，但目前為止交易量還是在相對的低檔之下，也就是說籌碼還沒有真的開始換手。
#
# 所以這兩項條件都不符合的情況下，說現在就是底部可能還言之過早。
#
# 關於關稅的議題，我喜歡把許多事情反過來想，這樣反而能夠更看清事實的真相。
#
# 現在大家都在說，4月2日利空出盡，市場將會築底反彈，但我心裡想的是 —— 如果沒有反彈的話，原因可能會是什麼呢？批如說：
#
# 1\.	對等關稅真的一旦開打，其他國家就會乖乖認慫了嗎？然後就束手就擒了嗎？完全不會提出任何反制的政策？
#
# 2\.	要是其他國家真的開始反制了，那利空壓力不就再升級？因為這將使得整個全球貿易環境進一步的惡化。
#
# 3\.	川普之後還還會不會推出比對等關稅更狠的招呢？例如直接搞個「全球統一課徵20%以上的關稅」，那影響層面可就更大了。
#
# 總之，變數實在太多，還有，關稅議題事實上市場已經消化過一段時間了，除非他真的給你搞一個更狠的招，所以接下來的危機會是針對AI泡沫化以及過剩議題之上。

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統
#   - 調整StockChartPatterns類別
#     * 取消在類別建構子中『建立OpenAI物件』，改在型態識別（使用ＧＰＴ－４ｏ多模態模型）方法中加入client參數以接收OpenAI物件。（參考[OpenAI Python API library](https://pypi.org/project/openai/)）
#     * 對照：同一張K線圖在ChartGPT的回覆（使用[ChatGPT Plus](https://openai.com/chatgpt/pricing/)）。

# %% [markdown]
# *你說*：價格型態
#
# **ChatGPT 說**：
# 這張圖是典型的K線圖（Candlestick Chart）加上成交量（Volume）圖，用來分析股價走勢。從圖中我們可以觀察出一些重要的價格型態與趨勢變化：
#
# 🔍 關鍵觀察：
# 1\.	頭部型態（可能為頭肩頂 Head and Shoulders）
# o	圖中高點出現在2024年12月到2025年2月之間，出現一個中間高、兩側低的結構，類似「頭肩頂」形態。
# o	這是一種反轉型態，通常暗示從多頭轉為空頭。
# 2\.	跌破頸線與急跌
# o	當價格在2025年3月初跌破頸線後，出現一波急速下跌。
# o	跌幅顯著，且伴隨著成交量放大，代表賣壓強勁，空頭明顯。
# 3\.	短期反彈（死貓跳？）
# o	在最近一段時間，出現小幅反彈，但尚未突破重要壓力區，可能只是技術性反彈。
# o	若反彈無法站回之前頸線位，後續可能再度下探。
#
# 📈 成交量解讀：
# •	下跌伴隨高量：通常表示籌碼正在轉移，空方力量強大。
# •	反彈量縮：反映買盤信心不足。
#
# 🧠 技術分析建議：
# •	空方趨勢明顯，應保守看待。
# •	若是做多，建議等待突破壓力區並放量，才考慮進場。
# •	做空者可觀察反彈是否遇阻，再尋找切入點。
#
# *你說*：畫出頸線
#
# **ChatGPT 說**：
# ![250403_1.png](attachment:5d8241db-e87f-4ae5-9a92-12131933a359.png)
# 這條藍色虛線就是頸線（Neckline），根據圖中的頭肩頂結構，它代表了多空力量的重要分水嶺。
# 📌 解讀：
# •	當價格跌破頸線後，出現明顯的下跌趨勢，這通常視為空頭確認訊號。
# •	最近的反彈尚未站回頸線上方，若未突破該線位，後續仍有下探風險。
#
# *你說*：畫出支撐壓力區
#
# **ChatGPT 說**：
# ![250403_2.png](attachment:f3231974-d35a-4245-84ca-d88db383e9c8.png)
# 圖中已經標示出：
# 🔴 壓力區（Resistance Zone）：
# •	原本的頸線上方，是之前多次形成支撐的位置。
# •	現在轉為壓力區，若反彈至此區間常會遇阻。
# 🟢 支撐區（Support Zone）：
# •	近期價格急跌後的暫時止穩位置。
# •	若未來再次跌破該區，可能出現更大波段下跌。
#
# *你說*：列出型態，並以JSON格式輸出(包含類型與起訖時間)
#
# **ChatGPT 說**：
# 以下是從圖中辨識出的價格型態，並以 JSON 格式輸出，每一個型態都包含：
# •	type: 型態名稱
# •	start_date: 型態起始日期
# •	end_date: 型態結束日期
# ⚠️ 註：日期為視覺估計值，來源為圖中X軸。
# ```
# [
#   {
#     "type": "Head and Shoulders Top",
#     "start_date": "2024-11-01",
#     "end_date": "2025-02-15"
#   },
#   {
#     "type": "Breakdown below Neckline",
#     "start_date": "2025-02-15",
#     "end_date": "2025-03-15"
#   },
#   {
#     "type": "Dead Cat Bounce (Technical Rebound)",
#     "start_date": "2025-03-15",
#     "end_date": "2025-03-25"
#   }
# ]
# ```
#
# *你說*：標記「頭部」與「左右肩」位置
#
# **ChatGPT 說**：
# ![250403_3.png](attachment:ed5c7cf9-ad4b-4684-96e8-62e1c091e0cb.png)
# 🔺 標記說明：
# •	Left Shoulder（左肩）：出現在2024年11月初，為第一次高點。
# •	Head（頭部）：出現在2024年12月中，是最高峰。
# •	Right Shoulder（右肩）：出現在2025年1月下旬，略低於頭部。
# 這三個高點圍繞著藍色虛線（頸線）展開，形成經典的反轉訊號。
#
# *你說*：畫出「量能與頭肩頂搭配」的完整結構
#
# **ChatGPT 說**：
# ![250403_4.png](attachment:6840c72b-1ee9-4751-9ec5-7cd9468801b1.png)
# 📉 價格結構（頭肩頂）：
# •	左肩 → 頭部 → 右肩，配合頸線清楚顯示出反轉型態。
#
# 📊 成交量觀察：
# •	Head（頭部）處有大量能：代表市場仍有活躍交易。
# •	Right Shoulder（右肩）成交量明顯萎縮：表示上攻乏力，反轉機率升高，是典型的右肩「量縮」。
#
# 這是經典的「價跌量縮、確認反轉」訊號。

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 建立OpenAI物件
load_dotenv(find_dotenv())
api_key = os.environ.get('OPENAI_API_KEY_TOKEN')
client = OpenAI(api_key = api_key)

# %%
##### 使用2024年7月22日到今日(2025年4月2日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250402.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線
support_line_start_date  = '2024-08-02'
support_line_end_date    = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
support_line_x           = [date_to_index(df_k_line,'2024-08-08'),date_to_index(df_k_line,'2024-09-10'),date_to_index(df_k_line,'2024-09-11')]
support_line_y           = [df_k_line.loc['2024-08-08']['Open'],df_k_line.loc['2024-09-10']['Close'],df_k_line.loc['2024-09-11']['Close']]
slope,intercept          = np.polyfit(support_line_x,support_line_y,1)
support_line_start_price = slope * date_to_index(df_k_line,support_line_start_date) + intercept
support_line_end_price   = slope * date_to_index(df_k_line,support_line_end_date) + intercept

seq_of_seq_of_points=[
    [(support_line_start_date,support_line_start_price),(support_line_end_date,support_line_end_price)]
]

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.0, colors='xkcd:bright blue', alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別(GPT-4o版)
# NOTE : 未將OpenAI物件傳入RecognitionUsingGPT4o方法
patterns = chart_pattern.RecognitionUsingGPT4o()
print(patterns)
# Out:
# ＤＥＢＵＧ ： 未將OpenAI物件傳入RecognitionUsingGPT4o方法中！
# []

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o(client=client)
print(patterns)
# Out:
# [{'type': 'Head and Shoulders', 'start': '2024-10-07', 'end': '2025-02-03'}, {'type': 'Double Top', 'start': '2024-11-13', 'end': '2025-01-15'}, {'type': 'Downtrend', 'start': '2025-02-03', 'end': '2025-03-11'}]

# %%
for pattern in patterns :
    print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
    range_price = df_k_line[pattern['start']:pattern['end']]
    if pattern['type'] == 'Head and Shoulders' or pattern['type'] == 'Double Top' or pattern['type'] == 'Triple Top' :
        # 使用自動趨勢線繪製頸線
        chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
        params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
        seq_of_seq_of_points = lines[0]
        # 設定K線格式
        mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
        s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
        # 繪製K線圖
        kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
        mpf.plot(df_k_line,**kwargs)
    elif pattern['type'] == 'Downtrend' :
        # 使用自動趨勢線繪製通道
        chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
        params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
        seq_of_seq_of_points = lines
        # 設定K線格式
        mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
        s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
        # 繪製K線圖
        kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=1.8, colors=('xkcd:red','xkcd:blue'), alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
        mpf.plot(df_k_line,**kwargs)
    else :
        # TODO : 待確認與實作
        pass
# Out:
# 型態類型 ＝ Head and Shoulders ， 型態開始日期 ＝ 2024-10-07 ， 型態結束日期 ＝ 2025-02-03
# 型態類型 ＝ Double Top ， 型態開始日期 ＝ 2024-11-13 ， 型態結束日期 ＝ 2025-01-15
# 型態類型 ＝ Downtrend ， 型態開始日期 ＝ 2025-02-03 ， 型態結束日期 ＝ 2025-03-11
