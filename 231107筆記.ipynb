# ![messageImage_1699317926936.jpg](attachment:d42046fb-022f-4d8a-a9bf-d9f7033ee6b1.jpg)
#
# 加權指數開小低，接近平盤：
# ![messageImage_1699318856196.jpg](attachment:2d2109ea-ee59-4f0b-87c9-5406160c4689.jpg)
#
# 櫃買指數相對強，往中長期壓力挑戰中：
# ![messageImage_1699319632393.jpg](attachment:ba276926-1ba0-40a2-baa5-d0bbe432117d.jpg)
#
# 台幣小幅回貶，維持中期箱型：
# ![messageImage_1699319779408.jpg](attachment:f221d6ab-d9a6-448b-8e03-b26657ea34c1.jpg)
#
# 加權指數目前勉強回到平盤，不過預估量明顯萎縮，只有2100億左右
#
# 陸港股都到壓力區，今天開小低：
# ![messageImage_1699321710572.jpg](attachment:3f709e88-3dad-410e-ae08-d83d65467da9.jpg)
# ![messageImage_1699321731444.jpg](attachment:1221c58e-fabc-4b04-8da2-65590d82399d.jpg)

# %% [markdown]
# 還是忍不住說，個股真的比ETF來的有效率太多。ETF一整年漲幅，可能沒有個股2星期漲得多，而且會佔掉資金額度，失去靈活性。
# ![messageImage_1699318954726.jpg](attachment:05382cd4-92f9-4e69-8a67-361c86989b6a.jpg)

# %% [markdown]
# 美律(2439)
# ![messageImage_1699319267438.jpg](attachment:0de41ee3-ea58-464a-b8a2-884f2958c8fd.jpg)
# ![messageImage_1699319286569.jpg](attachment:0836514a-639d-452f-81e2-2816c8938ebb.jpg)
#
# 昇佳電子(6732)
# ![messageImage_1699321073308.jpg](attachment:557e4f8a-5f51-48f6-87b7-236ca643b488.jpg)
#
# 晶相光(3530)
# ![messageImage_1699321830372.jpg](attachment:ad7cb70a-ccf8-4baf-a9e0-7d306719a901.jpg)
#
# 華新科(2492)
# ![messageImage_1699322158721.jpg](attachment:e50d3fbd-994b-4969-b94d-b1698f44c596.jpg)
#
# 東和鋼鐵(2006)
# ![messageImage_1698799006175.jpg](attachment:869eb6e5-26e8-48f6-a01b-46136ad93dbe.jpg)

# %% [markdown]
# #### 【新手投資，基本要點】
# 1.持股檔數，不要超過5檔(這是上限，不一定要到5檔)。
# 2.買進後一個月仍然不動，建議要換股。
# 3.買股要有3要件：a.選好股b.找到買點/發動點c.估算有效目標價或15%以上漲幅。三個條件俱備才能買，如果不存在，就不能買。
# 4.買進前，就要設定好你的停損條件。
#
# 想買股票前隨時再複習一下，會避免很多問題

# %% [markdown]
# ![233537.jpg](attachment:0a220860-caac-490e-8f31-a5443fc8aea6.jpg)
# ![233538.jpg](attachment:d643f6c8-e571-43ac-aa38-31e37980936a.jpg)

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * **規劃**建立台股「技術型態」資料集：參照「[用Python程式進行股票技術分析](https://ithelp.ithome.com.tw/users/20161619/ironman/5955)」之「[Day28 建立技術型態資料集](https://ithelp.ithome.com.tw/articles/10329779)」內容。另外參照書籍 [Encyclopedia of Chart Patterns](http://users.atw.hu/cybermanus/forex/Kiemelt.konyvek/Bulkowski%20%2CThomas%20N.Encyclopedia%20of%20Chart%20Patterns.pdf)（中譯：[股價型態總覽﹒上](https://www.books.com.tw/products/0010146071)、[股價型態總覽﹒下](https://www.books.com.tw/products/0010146072)）：
#   - The Database
#     If you want to discover how much you do not know about a chart formation,try teaching a computer to recognize one.
#     I spent several months doing that preparing for this book. The program helped me locate, analyze, and log well over 15,000 formations.
#     It is not a substitute for my eyes or my brain, just another tool to augment my talent.
#     Consider it another set of dispassionate eyes, a friend nudging you and saying, "Look at this one here. It's a bump-andrun reversal."
#     When the starting gun went off, I selected 500 stocks, all with durations of 5 years (each from mid-1991 to mid-1996) of daily price data on which to collect statistics.
#     I included the 30 Dow Jones industrials and familiar names with varying market capitalizations.
#     Stocks included in the study needed a heartbeat (they were not unduly flat over the 5-year period) and did not have consistently large daily price ranges (too thinly traded or volatile).
#     I usually removed stocks that went below a $1.00, assuming bankruptcy was right around the corner. Most of the names in the database are popular American companies that trade on the NYSE, AMEX, or NASDAQ.
#     The numerous illustrations accompanying each chapter give a representative sample of the stocks involved.
#     Occasionally a chart formation came along that presented a problem.
#     It was so scarce that 2,500 years (500 stocks times 5 years) of daily price data were simply not enough. So I pulled from the database I use on a daily basis.
#     It contains about 300 issues and begins where the other one ends.
# * 追蹤：麗臺(2465)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2021年12月21日到今日收盤(2023年11月07日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2465_231107.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_x_date = ['2022-11-08','2023-10-16']
neckline_x = [date_to_index(df_k_line,neckline_x_date[0]),date_to_index(df_k_line,neckline_x_date[1])]
neckline_y = [df_k_line.loc[neckline_x_date[0]]['Open'],df_k_line.loc[neckline_x_date[1]]['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_date = '2022-06-07'
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
print('頸線開始（{}）價格 ＝ {:.2f}元 ， 頸線結束（{}）價格 ＝ {:.2f}元'.format(neckline_start_date,neckline_start_price,neckline_end_date,neckline_end_price))

# 估算目標價
bottom_price_date = '2022-09-30'
breakthrough_date = '2023-10-25'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
breakthrough_price = slope * date_to_index(df_k_line,breakthrough_date) + intercept
print('頸線突破（{}）價格 ＝ {:.2f}元'.format(breakthrough_date,breakthrough_price))
target_price = (on_neckline_price - bottom_price) + breakthrough_price
print('目標價 ＝ {:.2f}元'.format(target_price))

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakthrough_date,breakthrough_price),(breakthrough_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6))

mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線開始（2022-06-07）價格 ＝ 38.89元 ， 頸線結束（2023-11-07）價格 ＝ 52.42元
# 頸線突破（2023-10-25）價格 ＝ 52.07元
# 目標價 ＝ 70.41元
