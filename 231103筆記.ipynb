#
# [台積電最後一盤爆6,300張買單收547元 市值激增4,927億](https://money.udn.com/money/story/5607/7546870?from=edn_hottestlist_cate_side)
# [美國聯準會（Fed）維持利率不變](https://www.facebook.com/kevinyang20180801/posts/pfbid02vTirGkmALfUxMZ9LwanCxcUj174stc4GgoPrq9iDrtQzhLNbgh2anYwNnEao6ZBSl)，周三美股收紅，AI指標股輝達（Nvidia）反彈上漲3.79%，超微收漲9.69%；台股今日開高走高，早盤以16,094.26點開高，權王台積電及AI股、半導體股等領漲，半導體股、電腦周邊、電子組件等類股都大漲逾3%收盤。
# 權王台積電更是開高走高收最高，進一步推升大指數上攻，同樣收在今日的最高點，以16,396.95點作收，上漲358.39點，漲幅2.23%，收復5日線及月線，台積電貢獻大盤指數逾160點，廣達、聯發科收紅，同樣都貢獻大盤指數逾10點。
# 台積電以536元開出，最後一盤再往上拉2元，股價收在週四最高點，大漲19元，單日市值激增4,927億元，股價收在547元，一舉站上5日線、月線、季線。

# %% [markdown]
# 日本持續開高，中期大箱型區間：
# ![messageImage_1698968217312.jpg](attachment:982ad3d8-57dd-420a-81a6-73868cdc443f.jpg)
#
# 期貨開高，在月線和季線之間：
# ![messageImage_1698972330713.jpg](attachment:98ca82a4-4fa2-47f0-8cd0-d2ba514be645.jpg)
#
# 加權指數進入壓力區間，維持小漲：
# ![messageImage_1698973236462.jpg](attachment:f99d680e-e574-4b0b-8c35-8e1c94daec07.jpg)
#
# 櫃買指數開高，維持中期盤整：
# ![messageImage_1698973313678.jpg](attachment:5d08a3ef-28ac-4d0e-ba4d-4d31cbed8e65.jpg)
#
# 台幣升值，測試20日線：
# ![messageImage_1698973470302.jpg](attachment:b902f40c-5372-4c22-8549-d250cb1a840d.jpg)
#
# 本周比較特別，影音解盤會從周K線切入，其實趨勢會更加明朗，周末大家記得收看~
# ![messageImage_1698973659490.jpg](attachment:b3601764-c608-448d-89d0-4ab0e347e45f.jpg)

# %% [markdown]
# [我也是有參與做多，只是資金跟檔數都很低。](https://www.facebook.com/kevinyang20180801/posts/pfbid02PA6yiAetMoJsqNGKLmkHhTHxTEWc9DtzNDzKDBViBFxvyYXAdvVZc8NPGrYcxJVkl)
# 除非你是操作指數型商品，否則解大盤跟國際股市，不能作為直接的交易工具，而是用來決定做多做空、控制風險、調節資金比重。
# 我覺得是短多，所以做多，但因為中期偏空，所以資金比重低，且檔數不能高，這樣進出比較靈活，還沒到積極重壓的時候。
#
# 【[倒車開上高速公路](https://www.facebook.com/kevinyang20180801)】
# 常常聽我解盤的投資人，一定都聽過我說不鼓勵做空，有兩個原因，一個是理性的層面，因為做空真的比做多難，難不是來自於方法，而是來自於工具。做多和做空的方法本質上是一模一樣的，但是難在作空的工具，有時間風險、槓桿倍數、價值遞減、強制回補等問題...，會讓交易難度大大提升。
# 除此之外，還有大腦思惟的切換，當偏空思考一路做空，究竟能不能靈活到趨勢反轉時，迅速的空單回補，甚至再度反手做多，精準判斷趨勢轉折，還有理性客觀的交易，這又是另一個難題了。
# 以前初學股票時，問過一個前輩，做空到底有多難？他曾用開車上路做了一個妙喻，假如你開車上路，但你是倒著開，你說難還是不難？更何況是倒車上高速公路。所以我的操作，只有停車，停車再開，加速行駛和高速行駛，但沒有倒著開。

# %% [markdown]
# 華新科(2492)
# ![messageImage_1698973366777.jpg](attachment:64652ade-c22b-42ee-9954-5ae8a647d4dc.jpg)
#
# 新日興(3376)
# ![messageImage_1698976016988.jpg](attachment:a1c7a526-ead5-4124-8cd0-4a25174e03e6.jpg)

# %% [markdown]
# ![231270.jpg](attachment:93b4feb3-ebef-4042-9a6f-27da1e53aa41.jpg)
# ![231271.jpg](attachment:9cb7659c-f0d6-4e07-bded-6b27e5015c97.jpg)

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * **規劃**建立台股「技術型態」資料集：參照「[用Python程式進行股票技術分析](https://ithelp.ithome.com.tw/users/20161619/ironman/5955)」之「[Day28 建立技術型態資料集](https://ithelp.ithome.com.tw/articles/10329779)」內容
# * 追蹤：麗臺(2465)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2021年12月21日到今日收盤(2023年11月3日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2465_231103.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_x_date = ['2022-11-08','2023-10-16']
neckline_x = [date_to_index(df_k_line,neckline_x_date[0]),date_to_index(df_k_line,neckline_x_date[1])]
neckline_y = [df_k_line.loc[neckline_x_date[0]]['Open'],df_k_line.loc[neckline_x_date[1]]['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_date = '2022-06-07'
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_date = '2023-11-03'
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
print('頸線開始價格 ＝ {:.2f} ， 頸線結束價格 ＝ {:.2f}'.format(neckline_start_price,neckline_end_price))

# 估算目標價
bottom_price_date = '2022-09-30'
breakthrough_price_date = '2023-10-25'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
breakthrough_price = slope * date_to_index(df_k_line,breakthrough_price_date) + intercept
print('頸線突破價格 ＝ {:.2f}元'.format(breakthrough_price))
target_price = (on_neckline_price - bottom_price) + breakthrough_price
print('目標價 ＝ {:.2f}元'.format(target_price))

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakthrough_price_date,breakthrough_price),(breakthrough_price_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6))

mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線開始價格 ＝ 38.89 ， 頸線結束價格 ＝ 52.35
# 頸線突破價格 ＝ 52.07元
# 目標價 ＝ 70.41元
