# %% [markdown]
# [🌱 你是不是想問我：該怎麼辦？](https://www.facebook.com/kevinyang20180801/posts/pfbid02s6xy4mLGcsroWEs88cHx9rdZvDCTCfYiYXBVyLZRnzYjfWyFTSEKvoTiWjXyTrTyl)
# 其實，這是一個再常見不過的問題，但也是最難回答的。因為每個人投入股市的條件、背景、風險承受度、投資目的都不同，所以——沒有「標準答案」，只有「適合你的答案」。
# 💰 資產配置：先了解你的「本金結構」
# 在進場前，先問問自己這些問題：
# 我投入的資金佔總資產的比重是多少？
# 這筆錢是閒置資金，還是來自借貸？
# 我有其他負債嗎？這筆錢會影響我的生活開銷嗎？
# 我有預留生活準備金嗎？
# 我的薪資水平能夠支撐多久的虧損？
# 家人支持我做投資嗎？他們的態度會影響我的決策嗎？
# 這些問題的答案，會直接影響你承擔風險的能力。
# 📊 商品組合結構：你到底買了些什麼？
# 要看清楚你手上的投資組合：
# 你是短線交易還是長期持有？
# 每檔個股的初始成本是多少？
# 現在持有的個股有哪些？張數和成本分別是多少？
# 如果虧損，你能接受的最大幅度是多少？
# 了解自己「在哪裡、擁有什麼、能失去多少」，才有機會談策略。
# 🧠 心法與策略：你是哪一種投資人？
# 問問自己：
# 我能在漲跌之間保持理性嗎？
# 我的個性是積極型還是保守型？
# 我習慣做多還是擅長做空？
# 如果某筆資金退出市場，接下來該怎麼運用？
# 這些反映的是你投資的核心思維與風格，沒有對錯，只有合不合適。
# 🎯 所以，我一直在推廣「獨立選股，自主交易」的理念。
# 因為數百萬的投資人，會產生數百萬種交易行為。
# 沒有任何一套策略適合所有人，只有你最適合你自己那一套。
# 📌 結論是：
# 這個答案，不在別人手上，而在你心中。或許你正面臨這樣的難題，這並不是三言兩語就能解決的問題，而是需要一對一深入討論3到4個小時才能釐清。然而，即使為你量身訂做專屬策略，最終你可能還是難以做出決定。更重要的是，這個策略的有效性取決於當下的股價，一旦時間過去、股價波動，原先的策略可能就不再適用。此外，技術分析也會隨著股價的漲跌變化，產生不同的訊號，進一步影響判斷。因此，掌握市場動態並做出靈活應對，駕馭你所選擇的股票才是關鍵所在。
#
# 【[最近在檢討一件事](https://www.facebook.com/kevinyang20180801/posts/pfbid031udeVg7XWqnCrZvYVgD4gudhd5JPcDg6qWP2bPrVfJocPmXG8z14bdtaoWd32unMl)】是的，這是廣告文
# 最近，我陷入了深深的思考，甚至懷疑起自己的人生，分享內容到底是哪裡出了問題？
# 事情是這樣的，很多同學跟我反映，說我的盤前解盤、盤中的技術分析、籌碼變化，他們聽得一頭霧水，感覺像是在聽外星語。但奇怪的是，當他們看數位訂閱的K線追擊周報影音內容時，卻覺得簡單明瞭、清楚易懂，甚至還能倒背如流！
# 於是開始檢討和思考，最後我得到一個結論，長期以來的問題癥結，應該是我的作文能力不好…，所以在我作文能力沒改善之前，有想完全理解我想表達的意思，請參考K線追擊週報數位訂閱。
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3118

# %% [markdown]
# ![729338.jpg](attachment:8718d29e-eb5b-4c76-b170-a7e86fa6e3f6.jpg)
# ![729339.jpg](attachment:2cdad35f-542a-447a-98a4-a22b6eb9fc8b.jpg)

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統：規劃
#   - 使用[LangGraph](https://langchain-ai.github.io/langgraph/tutorials/introduction/)程式庫進行系統整合。
#     * 將會建立新的「股票投資筆記」系統以作為對應。
#   - 利用[FinMInd](https://finmindtrade.com/analysis/#/Sponsor/sponsor)建立技術分析資料庫。
#   - 解盤(explanation) — 整合技術分析工具（參照[黑馬股３](https://www.books.com.tw/products/0011010836)　Ｐ．５５）
#     * K棒 **3 ~ 5天**
#     * *K線圖*
#     * 成交量 **1 ~ 3個月**
#     * 趨勢線／型態
#     * 移動平均線
#     * 日KD指標
#     * 日MACD指標
#     * 周KD指標
#     * 月KD指標
#   - 選股(picking)：
#     * 強勢股：漲幅前100名，且前一天成交量大於500張的個股（參照[黑馬股３](https://www.books.com.tw/products/0011010836)　Ｐ．１１２）
#     * 大量股：今天成交量／昨天成交量前100名，且成交量大於1,000張的個股（參照[黑馬股３](https://www.books.com.tw/products/0011010836)　Ｐ．１１２）
#     * 中價位且ADX指標上升穿越20
#       ![250407_1.png](attachment:f26fea00-9e74-451c-9d4b-1539e48dfc9d.png)
# * 驗證：StockChartPatterns類別
#   - 該類別為「趨勢線／型態」技術工具之實作
#   - 交叉驗證在ChatGPT上的輸出

# %% [markdown]
# *你說*：分析K線圖
#
# **ChatGPT 說**：
# 這張是典型的K線圖，包含價格走勢（上方）和成交量（下方）。以下是幾個關鍵觀察與分析：
#
# 📉 價格走勢分析（K線圖上半部）：
# 1\.	近期下跌明顯：
# 最近一段時間出現劇烈下跌，尤其是圖中接近右側（2025年3月中旬後），價格從約22000下滑至接近20000以下，出現一根長黑K線，代表大幅下跌，可能有利空消息或市場恐慌。
# 2\.	跳空缺口（Gap down）：
# 在圖的最後幾根K線中，有一個明顯的跳空下跌（開盤價遠低於前一根K線的收盤價），這通常暗示強烈的賣壓或突發消息。
# 3\.	過去有盤整區間：
# 2024年10月至2025年2月間，價格大致維持在22000～24000區間震盪，形成盤整格局，但近期已跌破盤整區下緣。
#
# 📊 成交量分析（圖下半部）：
# 1\.	近期成交量爆增：
# 在價格大跌時，成交量也明顯放大，這顯示出市場參與者大幅增加，可能是拋售潮或恐慌性賣壓。
# 2\.	紅黑成交量柱：
# o	黑色代表當日股價上漲（日K收高於開盤）
# o	紅色則代表股價下跌
# 最近紅柱居多，顯示市場偏空。
#
# 🧭 總體判斷：
# •	趨勢方向：明顯轉為下跌。
# •	市場情緒：恐慌情緒上升。
# •	觀察重點：後續是否能止跌回穩，或是否還會出現更大的下探。
#
# *你說*：列出圖中的價格型態
#
# **ChatGPT 說**：
# 從這張K線圖中，我們可以觀察到幾個值得注意的價格型態（Price Patterns）：
#
# 🔍 1. 頭肩頂（Head and Shoulders Top） - 可能形成
# •	位置：大約在 2024年12月至2025年2月之間。
# •	左肩：2024年12月初的高點。
# •	頭部：2025年1月的高點，明顯高於左右肩。
# •	右肩：2025年2月出現一個類似的高點但略低。
# •	頸線：大約在22000附近，一旦跌破通常視為轉空訊號。
# •	✅ 確認：圖中已跌破頸線，接著出現強烈下跌，這個型態算是成立了。
#
# 🔍 2. 跳空下跌（Breakaway Gap）
# •	位置：2025年3月中旬後。
# •	明顯的跳空缺口，且伴隨大量成交，屬於突破型跳空，暗示趨勢反轉或持續下跌。
#
# 🔍 3. 盤整區（Consolidation / Sideways Range）
# •	位置：從2024年10月到2025年2月這段時間。
# •	價格維持在約22000到24000之間震盪，形成橫向整理區。
# •	當價格跌破22000時，盤整區失守，也可視為箱型整理跌破，是轉弱訊號。
#
# 🔍 4. 長黑K線（Bearish Marubozu）
# •	位置：最右側的那根巨大陰線。
# •	幾乎沒有上下影線，開盤後一路下殺，屬於「實體極大」的黑K，代表賣壓極重，後市不妙。
#
# 📌 總結型態：
#
# 型態名稱：頭肩頂
# 特徵時間區間：2024年12月 - 2025年2月
# 意涵：轉折下跌訊號
#
# 型態名稱：跳空下跌
# 特徵時間區間：2025年3月中旬後
# 意涵：趨勢反轉/加速下跌
#
# 型態名稱：盤整區（箱型整理）
# 特徵時間區間：2024年10月 - 2025年2月
# 意涵：支撐跌破轉弱
#
# 型態名稱：長黑K
# 特徵時間區間：2025年3月下旬
# 意涵：短期極空訊號

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = df_k_line[pattern['start']:pattern['end']]
            if pattern['type'] == 'Head and Shoulders' or pattern['type'] == 'Double Top' or pattern['type'] == 'Triple Top' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(df_k_line,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2024年5月30日到今日(2025年4月7日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250407.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線
support_line_start_date  = '2024-08-02'
support_line_end_date    = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
support_line_x           = [date_to_index(df_k_line,'2024-08-08'),date_to_index(df_k_line,'2024-09-10'),date_to_index(df_k_line,'2024-09-11')]
support_line_y           = [df_k_line.loc['2024-08-08']['Open'],df_k_line.loc['2024-09-10']['Close'],df_k_line.loc['2024-09-11']['Close']]
slope,intercept          = np.polyfit(support_line_x,support_line_y,1)
support_line_start_price = slope * date_to_index(df_k_line,support_line_start_date) + intercept
support_line_end_price   = slope * date_to_index(df_k_line,support_line_end_date) + intercept

seq_of_seq_of_points=[
    [(support_line_start_date,support_line_start_price),(support_line_end_date,support_line_end_price)]
]

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.0, colors='xkcd:bright blue', alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 8         2024-08-05  19830.88   LO
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# 117       2025-01-13  22488.33   LO
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 8         2024-08-05  19830.88   LO
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# 117       2025-01-13  22488.33   LO
# 139       2025-02-21  23730.25   HI

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ Head and Shoulders ， 型態開始日期 ＝ 2024-10-07 ， 型態結束日期 ＝ 2025-02-03
# 型態類型 ＝ Double Top ， 型態開始日期 ＝ 2024-11-13 ， 型態結束日期 ＝ 2025-02-03
# 型態類型 ＝ Price Gap ， 型態開始日期 ＝ 2025-03-11 ， 型態結束日期 ＝ 2025-03-18

# %%
import io
import base64
from openai import OpenAI

client = OpenAI(api_key = os.environ.get('OPENAI_API_KEY_TOKEN'))

# %%
from PIL import Image

def get_first_last(mask, axis: int):
    """ Find the first and last index of non-zero values along an axis in `mask` """
    mask_axis = np.argmax(mask, axis=axis) > 0
    a = np.argmax(mask_axis)
    b = len(mask_axis) - np.argmax(mask_axis[::-1])
    return int(a), int(b)

def crop_borders(img, crop_color):
    np_img = np.array(img)
    mask = (np_img != crop_color)[..., 0]  # compute a mask
    x0, x1 = get_first_last(mask, 0)       # find boundaries along x axis
    y0, y1 = get_first_last(mask, 1)       # find boundaries along y axis
    return img.crop((x0, y0, x1, y1))

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 繪製K線圖
img = io.BytesIO()
kwargs = dict(type='candle', style=s, figratio=(16,9), volume=True, savefig=dict(fname=img,format='png'))
mpf.plot(df_k_line,**kwargs)

# 刪除空白
image    = Image.open(img).convert("RGB")
image    = crop_borders(image, crop_color=(255, 255, 255))
crop_img = io.BytesIO()
image.save(crop_img,format='PNG')
display(image)

# 將影像檔(PNG)編碼為Base64
base64_image = base64.b64encode(crop_img.getvalue()).decode()
# Out:
# <PIL.Image.Image image mode=RGB size=808x487>

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "user", "content": [
                {"type": "text", "text": "分析以下K線圖。 reply 繁體中文"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# 這張K線圖顯示了一段時間內的價格走勢和交易量變化。以下是一些觀察：
#
# 1. **價格趨勢**：
#    - 在2024年7月至8月期間，價格有明顯的上升趨勢。
#    - 之後價格進入了一段橫盤整理期，波動較小。
#    - 到2025年初，價格開始下跌，並在3月出現大幅下跌。
#
# 2. **交易量**：
#    - 在價格上升和下跌的關鍵時期，交易量明顯增加，顯示出市場活躍度提高。
#    - 特別是在2025年3月的大幅下跌時，交易量達到高峰，可能表示大量拋售。
#
# 3. **市場情緒**：
#    - 價格的急劇下跌和高交易量可能反映出市場的恐慌情緒。
#    - 在橫盤整理期間，交易量相對穩定，顯示出市場觀望情緒。
#
# 這些觀察可以幫助投資者了解市場趨勢和潛在的買賣機會，但具體的投資決策還需考慮其他因素和進一步的分析。

# %%
### 實驗：K線圖X軸調整後對GPT-4o輸出之影響 ###
# 參考：https://github.com/matplotlib/mplfinance/issues/573

import datetime

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

ticks         = []
tlabs         = []
current_month = 0
current_year  = 0

first_label  = False
for idx in range(df_k_line.shape[0]) :
    timestamp = df_k_line.iloc[idx].name
    timestamp_month = timestamp.month
    timestemp_year  = timestamp.year
    if current_month == 0 or current_year == 0:
        current_month = timestamp_month
        current_year  = timestemp_year
    if idx == 0 :
        ticks.append(idx)
        tlabs.append(timestamp.strftime('%Y-%b-%d'))
        first_label = True
    if (current_month+1) == timestamp_month:
        if first_label == True :
            first_label = False
        else :
            ticks.append(idx)
            tlabs.append(timestamp.strftime('%Y-%b'))
        current_month = timestamp_month
    elif (current_year+1) == timestemp_year and first_label == False :
        if first_label == True :
            first_label = False
        else :
            ticks.append(idx)
            tlabs.append(timestamp.strftime('%Y-%b'))
        current_year  = timestemp_year
        current_month = timestamp_month
        
# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(16,9), volume=True, returnfig=True)
fig, axlist = mpf.plot(df_k_line,**kwargs)
axlist[-2].set_xticks(ticks,labels=tlabs,ha='right')
# 保存圖檔
img = io.BytesIO()
fig.savefig(img,format='png')

# 刪除空白
image    = Image.open(img).convert("RGB")
image    = crop_borders(image, crop_color=(255, 255, 255))
crop_img = io.BytesIO()
image.save(crop_img,format='PNG')

# 將影像檔(PNG)編碼為Base64
base64_image = base64.b64encode(crop_img.getvalue()).decode()

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "user", "content": [
                {"type": "text", "text": "請列出以下K線圖中有哪些價格型態。並描述近期型態的狀況。"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# 在這張K線圖中，可以觀察到以下幾種價格型態：
#
# 1. **頭肩頂**：在2025年1月至3月期間，價格出現了一個頭肩頂的型態，這是一種反轉型態，通常預示著價格可能會下跌。
#
# 2. **雙頂**：在2024年11月至2025年1月期間，價格出現了兩次高點，形成雙頂型態，這也是一種看跌的反轉型態。
#
# 3. **下降趨勢**：從2025年3月開始，價格明顯下跌，形成一個下降趨勢。
#
# 近期型態的狀況：
#
# - **急劇下跌**：在2025年4月，價格出現了急劇下跌，伴隨著高交易量，這可能表示市場情緒的急劇轉變或重大消息的影響。
# - **高交易量**：近期的高交易量顯示出市場參與者的活躍，可能預示著價格的進一步波動。
#
# 這些型態和趨勢顯示出市場的波動性增加，投資者應謹慎行事。

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "您是一位股票技術分析師，可以從K線圖識別出價格型態"},
        {"role": "user", "content": [
                {"type": "text", "text": "請識別以下K線圖中有哪些價格型態，並使用JSON格式輸出型態的類型與起訖區間。"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#     {
#         "type": "Head and Shoulders",
#         "start": "2024-Nov",
#         "end": "2025-Feb"
#     },
#     {
#         "type": "Double Top",
#         "start": "2025-Jan",
#         "end": "2025-Mar"
#     }
# ]
# ```
