# 輝達（NVIDIA）執行長黃仁勳力挺機器人，繼先前高喊「AI本質上就是機器人」之後，最新點名「三種機器人有望大規模生產」，並首度將無人機列為「有望大規模生產的機器人」之一。
# 黃仁勳持續唱多機器人產業，並首度釋出看旺無人機量產前景的訊息，法人認為，不僅所羅門等老牌機器人概念股持續看俏，更將點燃漢翔（2634）、雷虎（8033）、中光電（5371）、圓剛（2417）及聰泰（5474）等無人機相關業者營運成長引擎。
#
# [CoWoS檢測告急和大卡位 攜手龍頭業者合資大芯科技 搶食大餅](https://money.udn.com/money/story/5612/8384403?fbclid=IwZXh0bgNhZW0CMTAAAR2kr--p0jNZ-3IiG-6ji375DCJzVqFZNHiaZ3syTtX-4v2T7p61tvNhAtk_aem__9_rSvGMO4R2ilj9c1Hogg)
# CoWoS先進封裝檢測告急，和大（1536）攜手台積鏈馳援。和大集團董事長沈國榮昨（25）日宣布，和大、高鋒將攜手國內半導體先進封裝溫控技術龍頭業者，於下月共同投資成立新公司大芯科技，聚焦後段測試分選機（Handler）與溫度控制（ATC, Active Thermal Control）系統，以當前最先進的檢測技術，搶食千億元大市場。

# %% [markdown]
# 期貨開低下跌：
# ![535443.jpg](attachment:8caab0d3-1902-4f1a-972a-6789a1c801ed.jpg)
#
# 加權指數開低，吃掉昨天漲幅，而且多跌約100點：
# ![messageImage_1732582839167.jpg](attachment:9fcab6dc-45ba-447a-9af4-01c5cf921046.jpg)
#
# 櫃買指數20日線和前低有壓，也是有拉回，但相對抗跌：
# ![messageImage_1732582912565.jpg](attachment:fc92fb9e-c11d-4237-91d3-e550b91c91fe.jpg)
#
# 先前的上升趨勢線，已經跌破9個交易日，都還沒有站回：
# ![messageImage_1732583392238.jpg](attachment:d02d44e1-875b-4475-86b6-d5786473cfa3.jpg)
#
# 之前和早上有預告，今天會出遠門，再來大家自己加油囉！
#
# 指數開低，觀察股難免跟著走弱，不過剛剛掃描一遍，大致上支撐都有守住：
# ![messageImage_1732584325157.jpg](attachment:a578f4cd-a9cb-4d59-bb48-67934a79050a.jpg)
#
# 我之前畫的三角收斂，修正一下，如果以這樣看，似乎已經跌破：
# ![messageImage_1732584704607.jpg](attachment:1bff8ee0-8898-4ef8-b5e4-3f242e107d0e.jpg)
#
# 很多人會因為昨天開高，就覺得好像行情變好了，但我常說解盤不能只看一天漲跌，要看趨勢、位階、型態，支撐、壓力、轉折，還有類股或個股跌多空強弱結構，所以即使昨天指數開盤看似大漲，並沒有改變上述條件，盤勢並沒有真正轉強，仍屬於偏弱勢整理。

# %% [markdown]
# 晚上在CMONEY有線上分享會，會有完整的國際股市跟台股解盤，有興趣的同學7點記得收看~
#
# 🎥免費直播重磅來襲！
# 【Ｋ線捕手楊忠憲】講座課前會：波段獲利的兩大絕招
#
# 🌟 直播重點：
# ✔ 探討投資操作中的常見誤區
# ✔ 分享實戰經驗與應對策略
# ✔ 為你的投資之路增添信心
#
# 📅 直播時間： 2024/11/26（二）19:00
# 🔗 直播連結： https://www.youtube.com/live/AijrIQXGpqo
#
# 直播中還會不定時發放抵用券給大家領取！記得準時來參加！

# %% [markdown]
# 美食-KY(2723)頸線：
# ![messageImage_1732572976528.jpg](attachment:9ed8e2a6-1c67-4f63-a923-81b326c79f64.jpg)
#
# 想請問兆利：
# 1.老師早上的頸線位置是195,但是我畫出來是192,所以畫頸線時要對的非常精準是嗎？這樣在算目標價時是不是會有落差呢？
# **我覺得195還是比較好，頸線規劃必須明確，因為不只是會影響到目標價估算，也會影響突破訊號的確認。**
# 2.今天突破後又拉回,這樣算突破失敗嗎？後續該如何觀察呢？
# **所以以我的標準昨天還沒突破。**
# 3.量能今天量縮但是還維持10日均量之上,以量能而言還算是安全對嗎？
# **既然沒有真的突破，就不需要帶量。**
# ![messageImage_1732573369149.jpg](attachment:9fc87673-d7d2-47d2-9b23-5029ef522dbb.jpg)
#
# 請教長園科，老師課程中說到，因為長空頭下跌，且站上年線，所以會用較樂觀的頸線，想請問長空頭時間大約多久以上或是至少多久以上呢？
# **一年以上。**
#
# 世紀鋼(9958)
# ![241126_1.png](attachment:c0e66f5d-1c31-4194-9362-f95814d1949d.png)

# %% [markdown]
# ### 本日進度
# * 暫時空手，觀察後續盤勢發展。
# * 觀察股：友訊(2332)
#   - 今日技術指標：
#     * 5日線與10日線上揚：短期多方；20日線與60日線上揚：中期多方
#     * 日KD指標：K值為79.53 ↑，D值為74.17 ↑，多方
#     * 日MACD指標：DIF線為0.67 ↑，MACD線為0.45 ↑，中期多方
#   - 今日籌碼：
#     * 法人？？()：外資？？()、投信中立()、自營？？()
#     * 主力？？()
#     * 買賣家數？？()
#     * 融資？()、融券？()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2023年7月7日到今日(2024年11月26日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2332_241126.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_start_date = '2023-09-15'
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_x = [date_to_index(df_k_line,'2023-12-04'),date_to_index(df_k_line,'2024-11-08')]
neckline_y = [df_k_line.loc['2023-12-04']['Close'],df_k_line.loc['2024-11-08']['Open']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
breakout_date = '2024-11-19'
breakout_price = slope * date_to_index(df_k_line,breakout_date) + intercept
print('頸線開始價格 ＝ {:.2f}元 ， 頸線突破價格 ＝ {:.2f}元 ， 頸線結束價格 ＝ {:.2f}元'.format(neckline_start_price,breakout_price,neckline_end_price))

# 估算目標價
bottom_price_date = '2024-08-07'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
target_price = (on_neckline_price - bottom_price) + on_neckline_price
print('底部最低價格 ＝ {:.2f}元 ； 估算目標價 ＝ {:.2f}元（ 今日收盤價 ＝ {:.2f}元 ）'.format(bottom_price,target_price,df_k_line.iloc[-1]['Close']))
# Out:
# 頸線開始價格 ＝ 20.33元 ， 頸線突破價格 ＝ 20.97元 ， 頸線結束價格 ＝ 20.98元
# 底部最低價格 ＝ 16.15元 ； 估算目標價 ＝ 25.47元（ 今日收盤價 ＝ 22.25元 ）

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakout_date,breakout_price),(breakout_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
    
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1100)
mpf.plot(df_k_line,**kwargs)

# %%
# 取區間範圍
range_start_date = '2024-07-16'
df_k_line_range = df_k_line[range_start_date:]
df_sma_range = df_sma[range_start_date:]
neckline_start_date = df_k_line_range.iloc[0].name.strftime("%Y-%m-%d")
neckline_end_date = df_k_line_range.iloc[-1].name.strftime("%Y-%m-%d")
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
    
# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma_range['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma_range['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma_range['SMA60'],width=0.5,color='xkcd:dark orange')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.5,1.0,1.0), colors=('xkcd:orange yellow','xkcd:red','xkcd:blue'), alpha=0.6))
mpf.plot(df_k_line_range,**kwargs)
