# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-04-14 21:22:49.051 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-14 21:22:49.116 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-14 21:22:49.127 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 新增股票代碼。代碼 ＝ 00997A：股票名稱 ＝ 主動群益美國增長，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1709：股票名稱 ＝ 和益，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1720：股票名稱 ＝ 生達，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1726：股票名稱 ＝ 永記，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1727：股票名稱 ＝ 中華化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1752：股票名稱 ＝ 南光，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1776：股票名稱 ＝ 展宇，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2059：股票名稱 ＝ 川湖，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2301：股票名稱 ＝ 光寶科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2302：股票名稱 ＝ 麗正，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2315：股票名稱 ＝ 神達，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數和櫃買指數同創新高。
# > ![messageImage_1776128442605.jpg](attachment:1b4486db-2aea-470e-8327-320d2471fe80.jpg)

# %%
def line_drawing_callback( range_prices) :

    surport_line_start_date = '2026-02-24'
    surport_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line_price      = range_prices.loc['2026-02-25']['Close'] 

    seq_of_seq_of_points=[
        [(surport_line_start_date,surport_line_price),(surport_line_end_date,surport_line_price)]
    ]

    linewidths=[3.0]
    
    colors=['xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：支撐
image = mysys.DrawOnKlineChart('TAIEX','2026-01-26','2026-04-14',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-13<br />
# 十字線 : 2026-04-09 , 2026-04-13<br />
# 鎚子線／吊人線 : 2026-04-09</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 10172.78億元 ，十日均量 ＝ 7961.68億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重底，型態範圍由2026-03-03開始到2026-04-08結束，估算目標價為37317.96點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：加權指數和櫃買指數同創新高。
# >  ![messageImage_1776128462675.jpg](attachment:42ad0472-c14f-4472-b7aa-7da8ede949b5.jpg)

# %%
def line_drawing_callback( range_prices) :
    
    surport_line1_start_date = '2026-03-17'
    surport_line1_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line1_price      = ( range_prices.loc['2026-03-18']['Close']  + range_prices.loc['2026-03-26']['High'] ) / 2

    surport_line2_start_date = '2026-02-26'
    surport_line2_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line2_price      = (range_prices.loc['2026-04-01']['High'] + range_prices.loc['2026-04-01']['Open']) / 2

    seq_of_seq_of_points=[
        [(surport_line1_start_date,surport_line1_price),(surport_line1_end_date,surport_line1_price)],
        [(surport_line2_start_date,surport_line2_price),(surport_line2_end_date,surport_line2_price)]
    ]

    linewidths=[5.0,2.5]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：支撐
image = mysys.DrawOnKlineChart('TPEx','2026-01-26','2026-04-14',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2026-04-09</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 2663.2億元 ，十日均量 ＝ 2091.78億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2025-11-20開始到2026-03-24結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 2340 ， 股票名稱 ＝ 台亞
# 股票代碼 ＝ 2495 ， 股票名稱 ＝ 普安
# 股票代碼 ＝ 6716 ， 股票名稱 ＝ 應廣
# 股票代碼 ＝ 3088 ， 股票名稱 ＝ 艾訊
# 股票代碼 ＝ 3162 ， 股票名稱 ＝ 精確
# 股票代碼 ＝ 5457 ， 股票名稱 ＝ 宣德
# 股票代碼 ＝ 5410 ， 股票名稱 ＝ 國眾
# 股票代碼 ＝ 6227 ， 股票名稱 ＝ 茂綸
# 股票代碼 ＝ 8105 ， 股票名稱 ＝ 凌巨
# 股票代碼 ＝ 6909 ， 股票名稱 ＝ 創控
# 股票代碼 ＝ 2402 ， 股票名稱 ＝ 毅嘉
# 股票代碼 ＝ 2425 ， 股票名稱 ＝ 承啟
# 股票代碼 ＝ 1528 ， 股票名稱 ＝ 恩德
# 股票代碼 ＝ 4555 ， 股票名稱 ＝ 氣立
# 股票代碼 ＝ 2465 ， 股票名稱 ＝ 麗臺
# 股票代碼 ＝ 2460 ， 股票名稱 ＝ 建通
# 股票代碼 ＝ 2527 ， 股票名稱 ＝ 宏璟
# 股票代碼 ＝ 3312 ， 股票名稱 ＝ 弘憶股
# 股票代碼 ＝ 3356 ， 股票名稱 ＝ 奇偶
# 股票代碼 ＝ 3028 ， 股票名稱 ＝ 增你強

# %% [markdown]
# * 篩選結果
#   - 川寶(1595)：技術突破
#     ![260414_2.png](attachment:30132b16-f284-4767-acfd-a520c999a247.png)
#   - 禾瑞亞(3556)：盤整觀察
#     ![260414_3.png](attachment:c7204eab-07b5-4c05-bc2a-c40f7f820a65.png)
#   - 晉倫(6151)：技術突破
#     ![260414_4.png](attachment:b742e0d0-598a-4847-9aff-e72a1f9a6bf2.png)
#   - 富采(3714)：技術突破
#     ![260414_5.png](attachment:98db8314-b9cf-4652-92be-496dac250588.png)
#   - 時碩工業(4566)：穩健續漲
#     ![260414_6.png](attachment:8b1014d8-f7fd-4815-902e-cee63a1a2143.png)
#   - 全友(2305)：多頭回檔
#     ![260414_7.png](attachment:fef935ee-8788-41d1-8afe-5a8323865f49.png)
#   - 台塑(1301)：技術突破
#     ![260414_8.png](attachment:1e7032e8-87df-43af-8924-2f83733e6db9.png)
#   - 森鉅(8942)：穩健續漲
#     ![260414_9.png](attachment:dc5e506c-65fa-4728-9041-4114aec742b1.png)
#   - 怡利電(2497)：技術突破
#     ![260414_11.png](attachment:6999ba66-22e4-4bbe-a273-b6e3bd0982ab.png)
#   - 聚鼎(6224)：技術突破
#     ![260414_10.png](attachment:cad637cb-795f-4a7c-98f4-66303a86c33c.png)

# %% [markdown]
# * 觀察股列表
#   ![260414_1.png](attachment:ae7943ad-f525-401c-805e-696e56907623.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：走勢溫吞，在頸線之上狹幅整理。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>墓碑線 : 2026-04-10<br />
# 吞噬 : 2026-04-14</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 2606張 ，十日均量 ＝ 2187張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-08-11開始到2026-04-14結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-10-09','2026-04-14',line_drawing_callback)
display(image)
# Out:
# 估算目標價為57.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-1218)：外資大賣(-1103)、投信小賣(-81)、自營小賣(-34)。
# 主力大賣(-985)。
# 分公司買賣家數差分散(-248)。
# 融資增(+16)、融券減(-4)。
