# 還記得當初的學習熱情嗎？這一季的創新教學等你來發掘，快來看看有什麼不一樣！
# 👫 邀請好友一起探索
# 點擊下方連結，即可加入試聽課程群組。還可以呼朋引伴，和親友一起來參加，讓學習變成一件充滿樂趣的事！
# 📅 完整資訊·1月17日揭曉
# 所有課程細節將在試聽當天為您揭曉，讓我們一起迎接全新的學習旅程！
# 👉 馬上加入試聽群組：
# https://line.me/R/ti/g/HbgLY99bZd
#
# 加入本群組就算報名試聽課程完成，晚上7點會上傳課程連結，如果同學有親友也要想要試聽，可以直接邀請進來群組。

# %% [markdown]
# ![613446.jpg](attachment:815c968d-a1ac-44c2-9f1a-a676261b954e.jpg)
# ![613447.jpg](attachment:84350216-2eb8-4a1b-8f6a-c91bde09747e.jpg)

# %% [markdown]
# ### 本日進度
# * [K線追擊週報](https://smarttest.businessweekly.com.tw/e-subscription/channel?c=GROUP00014146)訂閱與否於農曆新年假期後決定。
# * 用自動化趨勢線確認近期大盤走勢

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
# 正規化函式
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# 轉換正規化斜率成角度
def convert_normalized_slope_to_angle(prices,lines) :
    
    # 取價格區間
    prices_range     = None
    line1_start_date = lines[0][0][0]
    line1_end_date   = lines[0][1][0]
    line2_start_date = lines[1][0][0]
    line2_end_date   = lines[1][1][0]
    if line1_start_date == line2_start_date and line1_end_date == line2_end_date :
        prices_range = prices[line1_start_date:line1_end_date]
    if prices_range is None :
        return None
    
    # 趨勢線價格正規化
    line_prices_list = []
    line_prices_list.append(lines[0][0][1])
    line_prices_list.append(lines[0][1][1])
    line_prices_list.append(lines[1][0][1])
    line_prices_list.append(lines[1][1][1])
    line_prices = np.array(line_prices_list)
    line_prices_norm = normalization(line_prices)
    
    # 求斜率並轉換成角度
    line1_x      = [0, 1]
    line1_y      = [line_prices_norm[0],line_prices_norm[1]]
    line2_x      = [0, 1]
    line2_y      = [line_prices_norm[2],line_prices_norm[3]]
    line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
    line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
    
    # 以視覺方式【正方形】呈現：支撐線(紅色)、壓力線(藍色)
    mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
    s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
    kwargs = dict(type='candle', style=s, figratio=(10,10), alines=dict(alines=lines, linewidths=1.0, colors=('xkcd:red','xkcd:blue'), alpha=0.6))
    mpf.plot(prices_range,**kwargs)
    
    return line1_angle,line2_angle

# %%
##### 使用2024年7月17日到2025年1月16日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250116.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 5日
start_date = df_k_line.iloc[-5].name.strftime("%Y-%m-%d")
end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
params,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close',start_date,end_date)
print(params,lines)

# 但從回傳參數中的斜率換算成角度
line1_angle = np.rad2deg(np.arctan(params[0][0]))
line2_angle = np.rad2deg(np.arctan(params[1][0]))
print('支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))
# Out:
# ((13.119837402344533, 22475.210162597657), (2.8659721679695496, 23067.46)) [[('2025-01-10', 22475.210162597657), ('2025-01-16', 22527.689512207035)], [('2025-01-10', 23067.46), ('2025-01-16', 23078.923888671878)]]
# 支撐線(紅色)斜率之角度＝85.64度 ， 壓力線(藍色)斜率之角度＝70.77度
# 正規化後 ： 支撐線(紅色)斜率之角度＝4.97度 ， 壓力線(藍色)斜率之角度＝1.09度

# %%
# 20日
start_date = df_k_line.iloc[-20].name.strftime("%Y-%m-%d")
end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
params,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close',start_date,end_date)
print(params,lines)

# 但從回傳參數中的斜率換算成角度
line1_angle = np.rad2deg(np.arctan(params[0][0]))
line2_angle = np.rad2deg(np.arctan(params[1][0]))
print('支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))
# Out:
# ((-1.4644492159960558, 22511.714449215997), (41.21712842072279, 23330.114458951328)) [[('2024-12-19', 22511.714449215997), ('2025-01-16', 22483.88991411207)], [('2024-12-19', 23330.114458951328), ('2025-01-16', 24113.23989894506)]]
# 支撐線(紅色)斜率之角度＝-55.67度 ， 壓力線(藍色)斜率之角度＝88.61度
# 正規化後 ： 支撐線(紅色)斜率之角度＝-0.98度 ， 壓力線(藍色)斜率之角度＝25.67度

# %%
# 箱型區間？
params,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close','2024-09-20','2025-01-16')
print(params,lines)

# 但從回傳參數中的斜率換算成角度
line1_angle = np.rad2deg(np.arctan(params[0][0]))
line2_angle = np.rad2deg(np.arctan(params[1][0]))
print('支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))
# Out:
# ((0.9333451676726052, 22159.346122287057), (3.7124407792448753, 23557.458506752835)) [[('2024-09-20', 22159.346122287057), ('2025-01-16', 22233.080390533192)], [('2024-09-20', 23557.458506752835), ('2025-01-16', 23850.74132831318)]]
# 支撐線(紅色)斜率之角度＝43.03度 ， 壓力線(藍色)斜率之角度＝74.92度
# 正規化後 ： 支撐線(紅色)斜率之角度＝2.50度 ， 壓力線(藍色)斜率之角度＝9.84度

# %%
##### 使用2024年7月10日到2025年1月13日收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_OTC_250113.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 下降通道
params,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close','2024-08-13','2025-01-10')
print(params,lines)

# 但從回傳參數中的斜率換算成角度
line1_angle = np.rad2deg(np.arctan(params[0][0]))
line2_angle = np.rad2deg(np.arctan(params[1][0]))
print('支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))
# Out:
# ((-0.0663292400050224, 255.67), (-0.1868606132604836, 283.12930943650326)) [[('2024-08-13', 255.67), ('2025-01-10', 248.9044175194877)], [('2024-08-13', 283.12930943650326), ('2025-01-10', 264.0695268839339)]]
# 支撐線(紅色)斜率之角度＝-3.79度 ， 壓力線(藍色)斜率之角度＝-10.58度
# 正規化後 ： 支撐線(紅色)斜率之角度＝-11.18度 ， 壓力線(藍色)斜率之角度＝-29.11度

# %% [markdown]
# * 後續課題：用趨勢線與轉折點判斷趨勢（多頭、空頭、**盤整**）
#   - [道氏理論VS.判斷趨勢](https://www.books.com.tw/products/0010935881)
#   - 參照「[Day17 趨勢、位階、型態（１）](https://ithelp.ithome.com.tw/articles/10320336)」內容
#   - **主要技術原則**：千萬不要追求完美，關鍵在於一致性 （[技術分析精論：二十年來投資界最完整的技術分析全圖解(上)](https://www.books.com.tw/products/0010725781)）

# %%
# 道氏理論：判斷股票走勢
def dow_theory(high_low_points) :
    high_point = None
    low_point = None
    check_results = []
    for idx in range(0,len(high_low_points)) :
        point = high_low_points.iloc[idx]
        if point['Type'] == 'HI' :
            if high_point is not None :
                x = [high_point.name,point.name]
                y = [high_point['Price'],point['Price']]
                slope,intercept = np.polyfit(x,y,1)
                if slope > 0 :
                    check_results.append(1)
                elif slope < 0 :
                    check_results.append(-1)
                else :
                    check_results.append(0)
            high_point = point
        elif point['Type'] == 'LO' :
            if low_point is not None :
                x = [low_point.name,point.name]
                y = [low_point['Price'],point['Price']]
                slope,intercept = np.polyfit(x,y,1)
                if slope > 0 :
                    check_results.append(1)
                elif slope < 0 :
                    check_results.append(-1)
                else :
                    check_results.append(0)
            low_point = point
    identical = (len(set(check_results)) == 1)
    if identical is True:
        if check_results[0] == 1 :
            return('多頭')
        elif check_results[0] == -1 :
            return('空頭')
    return('盤整')

# %%
##### 使用2024年7月17日到2025年1月16日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250116.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 60日
start_date = df_k_line.iloc[-60].name.strftime("%Y-%m-%d")
end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")

### 用自動化趨勢線判斷趨勢 ### 
_,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close',start_date,end_date)

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# TODO：驗證條件待確認
if line1_angle > 5.0 and line2_angle > 5.0 :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 多頭區間')
elif line1_angle < -5.0 and line2_angle < -5.0 :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 空頭區間')
else :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 盤整區間')
    
### 用轉折點判斷趨勢 ###
turning_points = myutils.test_DetectTurningPoints(df_k_line[start_date:end_date],df_sma[start_date:end_date],mode='close',period=20)
print('★ 由轉折點判斷趨勢為 ＝ {}'.format(dow_theory(turning_points)))
# Out:
# 正規化後 ： 支撐線(紅色)斜率之角度＝15.08度 ， 壓力線(藍色)斜率之角度＝9.40度
# ☆ 由自動化趨勢線判斷趨勢為 ＝ 多頭區間
# ＤＥＢＵＧ ： 峰谷最小寬度 ＝ 21 ， 最小化過濾器的距離參數 ＝ 10
# 轉折點總筆數 ＝ 6
#                 Date     Price Type
# DateIndex
# 11        2024-11-08  23553.89   HI
# 26        2024-11-29  22262.50   LO
# 32        2024-12-09  23273.25   HI
# 41        2024-12-20  22510.25   LO
# 52        2025-01-07  23651.27   HI
# 56        2025-01-13  22488.33   LO
# ★ 由轉折點判斷趨勢為 ＝ 盤整

# %%
##### 使用2024年7月10日到2025年1月13日收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_OTC_250113.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 下降通道
start_date = '2024-08-13'
end_date = '2025-01-10'

### 用自動化趨勢線判斷趨勢 ### 
_,lines = myutils.test_TrendlineAutomation(df_k_line,'open_close',start_date,end_date)

# 斜率正規化後轉換成角度
line1_angle,line2_angle = convert_normalized_slope_to_angle(df_k_line,lines)
print('正規化後 ： 支撐線(紅色)斜率之角度＝{:.2f}度 ， 壓力線(藍色)斜率之角度＝{:.2f}度'.format(line1_angle,line2_angle))

# TODO：驗證條件待確認
if line1_angle > 5.0 and line2_angle > 5.0 :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 多頭')
elif line1_angle < -5.0 and line2_angle < -5.0 :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 空頭')
else :
    print('☆ 由自動化趨勢線判斷趨勢為 ＝ 盤整')
    
### 用轉折點判斷趨勢 ###
turning_points = myutils.test_DetectTurningPoints(df_k_line[start_date:end_date],df_sma[start_date:end_date],mode='close',period=20)
print('★ 由轉折點判斷趨勢為 ＝ {}'.format(dow_theory(turning_points)))
# Out:
# 正規化後 ： 支撐線(紅色)斜率之角度＝-11.18度 ， 壓力線(藍色)斜率之角度＝-29.11度
# ☆ 由自動化趨勢線判斷趨勢為 ＝ 空頭
# ＤＥＢＵＧ ： 峰谷最小寬度 ＝ 21 ， 最小化過濾器的距離參數 ＝ 10
# 轉折點總筆數 ＝ 6
#                 Date   Price Type
# DateIndex
# 13        2024-08-30  274.58   HI
# 20        2024-09-10  256.00   LO
# 47        2024-10-23  274.07   HI
# 64        2024-11-18  251.78   LO
# 77        2024-12-05  263.39   HI
# 84        2024-12-16  250.10   LO
# ★ 由轉折點判斷趨勢為 ＝ 空頭

# %% [markdown]
# * 平日應用班 資訊
#   - 今天是試聽，沒有講義，舊生可以這邊掛號。
