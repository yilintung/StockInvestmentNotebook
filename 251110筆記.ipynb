# %% [markdown]
# ### 工作進度
# * 「股票投資筆記」Python程式語言環境之建立方式
#   - 製作[Miniforge](https://github.com/conda-forge/miniforge)免安裝版：
#     `start /wait "" Miniforge3-Windows-x86_64.exe /S /InstallationType=JustMe /AddToPath=0 /RegisterPython=0 /NoRegistry=1`
#   - 建立虛擬環境：
#     `conda create --name StockNotes python=3.10`
#     `conda activate StockNotes`
#
#     `conda install -c conda-forge jupyterlab --yes`
#     `conda install -c conda-forge numpy scipy --yes`
#     `conda install -c conda-forge matplotlib mplfinance --yes`
#     `conda install -c conda-forge ta-lib --yes`
#     `conda install -c conda-forge python-dotenv --yes`
#     `pip install openai`
#     `pip install openpyxl`
#     `pip install Markdown`
#     `pip install tabulate`
#     `pip install markdown-grid-tables`
#     `pip install FinMind`
#
#     `conda env export --name StockNotes --file StockNotes.yml`
# * 更新[251103筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/251103%E7%AD%86%E8%A8%98.ipynb)之「工作進度」內容，以整合[251106筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/251106%E7%AD%86%E8%A8%98.ipynb)中有「**個股觀察**」項目之說明。
# * **筆記內容架構**與**量化技術分析系統**相關資訊請參閱[251103筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/251103%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-11-10 21:42:36.828 | INFO     | FinMind.data.finmind_api:get_data:158 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2336：股票名稱 ＝ 致伸，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2341：股票名稱 ＝ 英群，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2442：股票名稱 ＝ 新美齊，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2446：股票名稱 ＝ 全懋，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2447：股票名稱 ＝ 鼎新，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2452：股票名稱 ＝ 乾坤，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2456：股票名稱 ＝ 奇力新，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2473：股票名稱 ＝ 思源，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2494：股票名稱 ＝ 廣業科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3002：股票名稱 ＝ 歐格，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3009：股票名稱 ＝ 奇美電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3013：股票名稱 ＝ 晟銘電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3018：股票名稱 ＝ 隆銘綠能，產業類別 ＝ 其他電子業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-11-06 , 2025-11-10<br />
# 十字線 : 2025-11-06<br />
# 鎚子線／吊人線 : 2025-11-05<br />
# 吞噬 : 2025-11-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 5042.13億元 ，十日均量 ＝ 5669.93億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25點。<br />
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x482>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>鎚子線／吊人線 : 2025-11-05<br />
# 吞噬 : 2025-11-04<br />
# 高檔夜星 : 2025-11-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1061.01億元 ，十日均量 ＝ 1273.45億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股觀察

# %% [markdown]
# * 技術面＋籌碼面分類整理表
#   ![S__98394247.jpg](attachment:a4b35b0d-ce04-4499-989a-f1c870ce2505.jpg)

# %% [markdown]
# * 華東(8110)
#   ![messageImage_1762736453003.jpg](attachment:60da93f6-25d3-43f4-8424-f04c6cc02b7b.jpg)
# * 台塑化(6505)
#   ![messageImage_1762744909403.jpg](attachment:4e33424b-f934-454d-8379-8e121869c5c8.jpg)
#   ![messageImage_1762748724581.jpg](attachment:97092def-e016-494c-a1c0-265ec26274b8.jpg)
# * 創見(2451)
#   ![messageImage_1762736678919.jpg](attachment:83257d53-0267-4bb8-9006-2840e2eb7342.jpg)
# * 創意(3443)
#   ![messageImage_1762736692799.jpg](attachment:7c4172ba-3da0-45bc-bc93-68ae8a43202b.jpg)
# * 群聯(8299)
#   ![messageImage_1762736706201.jpg](attachment:e04ff634-ec4d-4ba8-b80e-da285e64f698.jpg)
# * 中石化(1314)
#   ![messageImage_1762739115131.jpg](attachment:8f917941-c688-4443-8a49-d11711d03749.jpg)
# * 超豐(2441)
#   ![messageImage_1762739040086.jpg](attachment:f409181a-b1c3-4e5c-bc66-fbb22c6668c4.jpg)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 台塑化(6505)
#   看法：股票老師周五晚上改用「黃金分割率」估算目標價。
#   ![251110_1.png](attachment:dc0d92ed-56ff-4037-8587-7591f7e0cd72.png)
#   已到「黃金分割率」滿足區，但離底型滿足仍有一段距離。持續追蹤觀察。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'6505')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>孕育線／懷抱線 : 2025-11-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股天量（成交量 ＝ 18991張 ，十日均量 ＝ 9214張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之矩形，型態範圍由2025-07-31開始到2025-10-03結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2024-11-08'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-07-31']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-01-10'
    bottom_price = range_prices.loc['2025-01-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-10-23'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('6505','2024-09-18','2025-11-10',line_drawing_callback)
display(image)
# Out:
# 估算目標價為55.30元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大買(+7507)：外資大買(+7258)、投信小買(+142)、自營小買(+107)。
# 主力大買(+5317)。
# 分公司買賣家數差集中(+64)。
# 融資增(+19)、融券增(+31)。
