# %% [markdown]
# ### 工作進度
# * 新的筆記架構仍待定。
#   - 筆記中要放多少[股票老師](https://mega.nz/folder/a85wHKwK#SA6HACStdXRvMsLd2Ct0tQ)的資訊？
# * 問題：櫃買指數在KD指標仍會判斷錯誤。嘗試修改mysys.StockAnalysis類別程序以解決該問題：
#   - 調整「整體評價」程序輸入給GPT-4o模型的圖片，主要是修改其X軸日期標示的間隔。
#   - 將近五日的KD指標值給GPT-4o模型參考：*解讀時若有需要可參考最近五個交易日資料 ： xxx，但結果不要提及參考資料*。
# * 規劃將近期筆記(雖然筆記架構尚未正式確定)上傳至現有的[GitHub倉庫](https://github.com/yilintung/StockInvestmentNotebook)中。

# %% [markdown]
# #### 引入模組與定義公用函式

# %%
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# #### 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 指數解盤

# %% [markdown]
# * 加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=832x480>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-03<br />
# 十字線 : 2025-07-03<br />
# 吞噬 : 2025-07-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 3311.34億元 ，十日均量 ＝ 3699.09億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-04死亡交叉。並且2025-07-04於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-06-30該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前價格呈現上漲趨勢，K線多為紅K，顯示多頭力量較強。短期移動平均線（5日、10日）均向上，且位於中期移動平均線（20日、60日）之上，顯示短期趨勢強勁。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有增加的趨勢，顯示價量配合良好，支持上漲趨勢。然而，近期成交量略有減少，需注意後續量能是否能持續放大。<br />
# <br />
#  支撐與壓力<br />
# 支撐位可參考20日移動平均線附近，約在22000點左右。壓力位則在近期高點附近，約在23000點。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線與D線均位於超買區（&gt;80），且K線略微下彎，顯示短期可能有回檔壓力，需注意是否會進一步下跌至超買區以下。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線與MACD線均在零軸之上，且DIF線高於MACD線，顯示多頭趨勢仍在延續。然而，灰色柱體（OSC）顯示動能略有減弱，需注意後續變化。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於上漲趨勢中，但短期內可能面臨回檔壓力。建議投資者在此階段謹慎操作，若持有多單可考慮在壓力位附近進行部分停利，並密切關注成交量變化及技術指標的進一步走勢。若價格跌破支撐位，需考慮適時停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>吞噬 : 2025-06-30<br />
# 孕育線／懷抱線 : 2025-07-01</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1035.65億元 ，十日均量 ＝ 944.69億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-04死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-02當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 從K線圖來看，近期價格呈現盤整狀態。短期移動平均線（5日、10日）與中期移動平均線（20日、60日）糾結在一起，顯示出市場缺乏明確的方向。<br />
# <br />
#  價量關係<br />
# 成交量在盤整期間並未顯著增加，顯示出市場參與者的觀望情緒。價格的波動並未伴隨明顯的成交量變化，顯示出目前的價量關係較為疲弱。<br />
# <br />
#  支撐與壓力判斷<br />
# 支撐位置大約在230點附近，這是近期價格多次回檔的低點。壓力位置則在240點左右，這是近期價格多次上攻未果的高點。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線與D線在高位交錯，並且K線已經從超買區回落，顯示出短期內可能有回檔壓力。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線與MACD線接近零軸，且OSC柱體變化不大，顯示出市場動能不足，短期內可能繼續盤整。<br />
# <br />
#  綜合評價<br />
# 目前市場處於盤整狀態，短期內缺乏明確的趨勢方向。建議投資者保持觀望，等待價格突破支撐或壓力位置後再行操作。若價格突破240點，可能會有進一步上漲空間；若跌破230點，則需注意風險控制。</p>
# </td>
# </tr>
# </tbody>
# </table>
