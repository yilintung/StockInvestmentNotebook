# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數開低，回測支撐。
# >    ![messageImage_1783040451862.jpg](attachment:25cf073c-38c0-478a-9db8-56a02d6087f9.jpg)

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：櫃買指數也是開低，但跌幅較小，相對抗跌。
# >    ![messageImage_1783040532694.jpg](attachment:7cfe4dcb-8971-4b4c-a28c-4c48310f50fa.jpg)

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))

# %% [markdown]
# * 篩選結果
#   - 大成(1210)：穩健續漲
#     ![260703_2.png](attachment:e9515aa6-31b9-426f-b4e0-b93df6777cb5.png)
#   - 錦明(3230)：穩健續漲
#     ![260703_3.png](attachment:e1d1575b-fb36-4036-9fd3-1b286b445a85.png)
#   - 冠西電(2466)：穩健續漲
#     ![260703_4.png](attachment:ecf8d582-92d8-499f-943d-ac7020f48d89.png)
#   - 晟田(4541)：穩健續漲
#     ![260703_5.png](attachment:a784ca1a-f739-49e1-ad5f-27f349656bee.png)
#   - 群創(3481)：盤整觀察
#     ![260703_6.png](attachment:f131c4c8-a44a-4068-9b44-28fbed6b453c.png)
#   - 東聯(1710)：穩健續漲
#     ![260703_7.png](attachment:f49704f8-bb9b-4f21-be77-149838c31cc3.png)
#   - 台塑(1301)：技術突破(突破盤整區間)
#     ![260703_8.png](attachment:5877349c-3fb5-49d6-8770-aa8d7b2da398.png)
#   - 集盛(1455)：技術突破
#     ![260703_9.png](attachment:cee152a6-a925-4e2f-b156-fbb6fb3257b9.png)
#   - 普誠(6129)：多頭回檔
#     ![260703_10.png](attachment:f3f5436d-4215-40d0-a147-70f58c818913.png)
#   - 材料*-KY(4763)：技術突破
#     ![260703_11.png](attachment:5d777d2d-f937-44e9-b67a-bf07762abe0d.png)
#   - 裕隆(2201)：盤整觀察
#     ![260703_12.png](attachment:2294e6f1-8e5d-4462-ba69-07c2282e3c6f.png)
#   - 福懋(1434)：技術突破
#     ![260703_13.png](attachment:29c4cf50-7421-4228-9ece-da06558bed3e.png)
#   - 智擎(4162)：已到壓力區(年線反壓)
#     ![260703_14.png](attachment:3ff4cf56-2d39-416c-a037-b41562690be2.png)
#   - 中裕(4147)：穩健續漲
#     ![260703_15.png](attachment:1c16be84-6ac6-493e-8efe-7df73b38fdba.png)

# %% [markdown]
# * 觀察股列表
#   ![260703_1.png](attachment:e5f0ee3e-098b-4c02-9a37-8c34b5bca362.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：突破後續漲。但遇前波假突破壓力拉回，收上影線。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-08-08'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-06-11']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2026-07-02'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-04-28','2026-07-03',line_drawing_callback)
display(image)
# Out:
# 估算目標價為61.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。
