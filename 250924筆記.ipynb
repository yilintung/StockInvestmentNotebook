# %% [markdown]
# ### 工作進度
# * 【置頂】**新的筆記內容架構**與**量化技術分析系統**相關資訊請參閱[250801筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250801%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 本日「K線追擊週報」LINE群組資訊：[楊忠憲K線追擊週報_250924日報.docx](https://mega.nz/file/CtoU0YJT#SratfgmyEMlXS2Lckqx5TjcwbdN5_SQUTwbE-7kuuXw)。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-09-24 21:48:04.835 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 新增股票代碼。代碼 ＝ 00981T：股票名稱 ＝ 平衡凱基雙核收息，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1710：股票名稱 ＝ 東聯，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1730：股票名稱 ＝ 花仙子，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1732：股票名稱 ＝ 毛寶，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1760：股票名稱 ＝ 寶齡富錦，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1786：股票名稱 ＝ 科妍，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2311：股票名稱 ＝ 日月光，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2315：股票名稱 ＝ 神達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2325：股票名稱 ＝ 矽品，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2341：股票名稱 ＝ 英群，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2350：股票名稱 ＝ 環電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2352：股票名稱 ＝ 佳世達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2361：股票名稱 ＝ 鴻友，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2368：股票名稱 ＝ 金像電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2369：股票名稱 ＝ 菱生，產業類別 ＝ 半導體業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤前**：[K線捕手](https://www.facebook.com/kevinyang20180801)｜[9/24盤前快訊](https://www.facebook.com/kevinyang20180801/posts/pfbid02MsnwFkj3oVaoEwSEmHDb2nYMHqgD8HiRNfxEtXDTybLEXadp7QzwZG4B7nHVxwBDl)
# > 昨日台股強勢創高，短線多頭氣勢不減。只要資金動能續航，挑戰 27,000 並非遙不可及。但在市場情緒亢奮之際，更要保持冷靜與風險意識。
# 🔹 多方條件
# 📈 法人與融資買盤持續
# 📈 技術面沿 5 日線推升
# 📈 價量結構仍屬健康
# 🔹 空方條件
# 📉 指數上漲但個股漲跌不均
# 📉 資金集中權值股
# 📉 熱門股漲多後出現熄火跡象
# > ![552357704_1400823402051583_5513521760113130433_n.jpg](attachment:73e05de7-d1d2-49ce-9a4b-af6c473e74b0.jpg)

# %%
# 盤整區間
def line_drawing_callback( range_prices) :

    seq_of_seq_of_points = []
    linewidths           = []
    colors               = []

    # 設定盤整區壓力線
    resistance_line_start_date  = '2025-09-11'
    resistance_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_price       = range_prices.loc['2025-09-22']['Close']
    seq_of_seq_of_points.append([(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')

    # 設定盤整區支撐線
    support_line_start_date  = '2025-09-11'
    support_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_price       = range_prices.loc['2025-09-15']['Close']
    seq_of_seq_of_points.append([(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤前：盤整區間繪製
image = mysys.DrawOnKlineChart('TAIEX','2025-08-29','2025-09-23',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 5151.88億元 ，十日均量 ＝ 5038.55億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.24點。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x480>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1476.86億元 ，十日均量 ＝ 1519.06億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 盟立(2464)
#   看法：測試盤整支撐。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2464')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-19<br />
# 十字線 : 2025-09-22</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1955張 ，十日均量 ＝ 5724張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中繼型態之上升旗形，型態範圍由2025-04-09開始到2025-09-23結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-26'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-15']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-04-10'
    bottom_price = range_prices.loc['2025-04-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-08-15'

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2464','2024-12-25','2025-09-24',line_drawing_callback)
display(image)
# Out:
# 估算目標價為78.10元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-97)：外資小賣(-77)、投信中立(0)、自營小賣(-20)。
# 主力小賣(-240)。
# 分公司買賣家數差分散(-126)。
# 融資減(-72)、融券增(+19)。

# %% [markdown]
# * 仁寶(2324)
#   看法：轉強，已到滿足區且略為超漲；但接下來會遇到壓力區，因此這檔會再觀察幾個交易日。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2324',buttom_pattern = True)
# Out:
# 底型反轉交易策略：
# <PIL.Image.Image image mode=RGB size=866x479>
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=837x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-19<br />
# 吞噬 : 2025-09-18<br />
# 孕育線／懷抱線 : 2025-09-19</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股天量（成交量 ＝ 130436張 ，十日均量 ＝ 57087張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2025-01-02開始到2025-03-24結束，估算目標價為33.75元。<br />
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析
# > ![messageImage_1758676809556.jpg](attachment:c4d689ec-0491-43e4-bab8-4ac33fbbe9dd.jpg)

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-27'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-08-05']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-05-15'
    bottom_price = range_prices.loc['2025-05-15']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2324','2024-05-29','2025-09-24',line_drawing_callback)
display(image)
# Out:
# 估算目標價為33.80元
# <PIL.Image.Image image mode=RGB size=866x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-20883)：外資大賣(-23221)、投信小賣(-2047)、自營大買(+4385)。
# 主力大買(+12759)。
# 分公司買賣家數差集中(+16)。
# 融資大增(+16223)、融券大增(+386)。

# %% [markdown]
# * 南茂(8150)
#   看法：平盤附近小幅拉回。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'8150')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-22</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 5285張 ，十日均量 ＝ 5257張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-14結束，估算目標價為32.20元。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-11'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-06-11']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-08-19'
    bottom_price = range_prices.loc['2025-08-19']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-09-17'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('8150','2024-05-08','2025-09-24',line_drawing_callback)
display(image)
# Out:
# 估算目標價為36.55元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小買(+379)：外資小買(+397)、投信中立(-10)、自營小賣(-8)。
# 主力小賣(-49)。
# 分公司買賣家數差分散(-40)。
# 融資減(-25)、融券增(+4)。
