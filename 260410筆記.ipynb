# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-04-10 21:36:47.017 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-10 21:36:47.067 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-10 21:36:47.079 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1710：股票名稱 ＝ 東聯，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1725：股票名稱 ＝ 元禎，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1727：股票名稱 ＝ 中華化，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1730：股票名稱 ＝ 花仙子，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1731：股票名稱 ＝ 美吾華，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1732：股票名稱 ＝ 毛寶，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1733：股票名稱 ＝ 五鼎，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1783：股票名稱 ＝ 和康生，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1789：股票名稱 ＝ 神隆，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2059：股票名稱 ＝ 川湖，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2302：股票名稱 ＝ 麗正，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2303：股票名稱 ＝ 聯電，產業類別 ＝ 電子工業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數開高，距離前高只有一步之遙。
# > ![messageImage_1775782856749.jpg](attachment:71fb250e-36cf-4477-93fc-cd8edf61a288.jpg)

# %%
def line_drawing_callback( range_prices) :

    resistance_line_start_date = '2026-02-06'
    resistance_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_price      = range_prices.loc['2026-02-25']['Close'] 

    surport_line_start_date = '2026-01-21'
    surport_line_end_date   = resistance_line_end_date
    surport_line_price      = range_prices.loc['2026-02-03']['Open'] 


    seq_of_seq_of_points=[
        [(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)],
        [(surport_line_start_date,surport_line_price),(surport_line_end_date,surport_line_price)]
    ]

    linewidths=[3.0,2.5]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：箱型區間
image = mysys.DrawOnKlineChart('TAIEX','2026-01-02','2026-04-10',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：綜合觀點
# > ![01.png](attachment:3f386404-eadb-4113-a26a-95516f1e19d5.png)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2026-04-09<br />
# 鎚子線／吊人線 : 2026-04-09</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 8718.08億元 ，十日均量 ＝ 7563.57億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重底，型態範圍由2026-03-03開始到2026-04-08結束，估算目標價為37317.96點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數續創新高。
# > ![messageImage_1775782974547.jpg](attachment:1a53821e-acc2-4206-a59c-192218cdc3da.jpg)

# %%
def line_drawing_callback( range_prices) :
    
    surport_line1_start_date = '2026-03-17'
    surport_line1_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line1_price      = ( range_prices.loc['2026-03-18']['Close']  + range_prices.loc['2026-03-26']['High'] ) / 2

    surport_line2_start_date = '2026-02-25'
    surport_line2_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line2_price      = (range_prices.loc['2026-04-01']['High'] + range_prices.loc['2026-04-01']['Open']) / 2

    seq_of_seq_of_points=[
        [(surport_line1_start_date,surport_line1_price),(surport_line1_end_date,surport_line1_price)],
        [(surport_line2_start_date,surport_line2_price),(surport_line2_end_date,surport_line2_price)]
    ]

    linewidths=[5.0,2.5]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：支撐
image = mysys.DrawOnKlineChart('TPEx','2026-02-24','2026-04-10',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2026-04-09</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 2597.6億元 ，十日均量 ＝ 2007.9億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2025-11-20開始到2026-03-24結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 3444 ， 股票名稱 ＝ 利機
# 股票代碼 ＝ 7704 ， 股票名稱 ＝ 明遠精密
# 股票代碼 ＝ 6175 ， 股票名稱 ＝ 立敦
# 股票代碼 ＝ 1409 ， 股票名稱 ＝ 新纖
# 股票代碼 ＝ 2476 ， 股票名稱 ＝ 鉅祥

# %% [markdown]
# * 篩選結果
#   - 晉倫(6151)：盤整觀察
#     ![260410_2.png](attachment:35a21666-a305-495d-af21-76edd69154c7.png)
#   - 全友(2305)：穩健續漲／已到壓力區
#     ![260410_3.png](attachment:58b27d9f-dc67-443b-9df8-336107e6f981.png)
#   - 公準(3178)：盤整觀察
#     ![260410_4.png](attachment:a1ee0f69-b79a-4084-b013-ad584dfb51ad.png)
#   - 艾訊(3088)：技術突破
#     ![260410_5.png](attachment:0ca3c0db-101b-48ad-9909-99842e36d764.png)
#   - 森鉅(8942)：技術突破
#     ![260410_6.png](attachment:5326b309-f30e-4a0a-8092-5d4227bef86c.png)
#   - 明遠精密(7704)：技術突破
#     ![260410_8.png](attachment:f40c70b3-0a17-45c3-92cc-4273f4774869.png)

# %% [markdown]
# * 觀察股列表
#   ![260410_1.png](attachment:8bf3f67b-f970-4466-9271-4282dd428072.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：走勢溫吞，在頸線之上狹幅整理。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-02<br />
# 墓碑線 : 2026-04-10</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1269張 ，十日均量 ＝ 2116張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-08-11開始到2026-04-10結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-10-09','2026-04-10',line_drawing_callback)
display(image)
# Out:
# 估算目標價為57.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小買(+385)：外資小買(+399)、投信小賣(-)、自營中立(+1)。
# 主力小買(+180)。
# 分公司買賣家數差集中(+45)。
# 融資減(-26)、融券中立(0)。
