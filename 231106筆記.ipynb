# 非蘋手機相關晶片廠本季營運報喜，在大陸品牌客戶處於華為新機所創造的復甦氛圍中，以及新興市場庫存去化告一段落，紛紛開始加單，而且韓系客戶也因折疊機銷售佳而下更多單等三大動能挹注下，聯發科（2454）、聯詠、敦泰、天鈺、矽創等手機相關IC廠，都有機會搭上這波客戶加單潮，營運熱轉。
#
# [美元高利定存 喊到6.6％](https://money.udn.com/money/story/5613/7553560?from=edn_hotestlist_storybottom)
# 美國聯準會（Fed）11月1日再次宣布政策利率不變，同時暗示升息暫時結束，也很難扭轉強勢美元，符合市場認為美債殖利率突破5％等同一次升息威力預期。強勢高利美元持續吸引資金流入，外銀針對富人給出的11月高利美元專案，同步喊破6％、達6.6％，就是要留住並吸引這些貴客。

# %% [markdown]
# 日本開小高後小壓回：
# ![messageImage_1699228978082.jpg](attachment:d587a132-b510-48ba-8049-7f6ba5216465.jpg)
#
# 期貨開高，剛好在大箱型區間中軸：
# ![messageImage_1699231568890.jpg](attachment:a831763f-7d6c-4083-8167-3fb49225e7e6.jpg)
#
# 加權指數開高，在大箱型區間的中軸線附近：
# ![messageImage_1699232457743.jpg](attachment:15300805-2304-47fc-9f85-2bcae23ca6c7.jpg)
#
# 櫃買指數開高，維持小箱型整理區間：
# ![messageImage_1699232545488.jpg](attachment:ddd7556b-0fcb-4ece-b210-2e75c449d2cc.jpg)
#
# 台幣短線升值，中期箱型整理：
# ![messageImage_1699232998182.jpg](attachment:78e76e14-6a7f-4b0d-a4f6-66de431b3863.jpg)
#
# 陸港股都開高小漲：
# ![messageImage_1699235916545.jpg](attachment:798f4571-6f0d-4364-9289-77e39cdcd2db.jpg)
# ![messageImage_1699235938517.jpg](attachment:67705590-c0ca-416c-9f0d-b8099f0c1816.jpg)

# %% [markdown]
# 【[永遠存在的問題](https://www.facebook.com/kevinyang20180801/posts/pfbid0iBM61gSjY9FhbUEaPx5ohN2uRx3GVADtNEJxYoVdTRjyQEZVmUQaNykNTDoPJGCVl)】
# 其實我解盤習慣都會把多空條件都陳述，再從這些多空條件綜合歸納出結果，但就以現在來說，同一版的解盤，當天會有人跟我說：「老師對後面走勢應該是看多吧！」，但也有人會說：「感覺您看的挺悲觀的。」
# 一千個人眼中，有一千個哈姆雷特。所以這是一直存在的問題，同一個版本的解盤，一千個閱讀者眼中，也有一千個答案。我每天解盤內容和教學，永遠只有一個版本，不過每個人看到內容，會有各自的理解跟想法，產生數萬種版本的答案。
# 不過媒體怎麼看、財經專家怎麼看、甚至於我怎麼看，其實都不重要。所以最重要的是你自己怎麼看，要做多還是做空，因為錢在你手中，而最後執行交易的是自己，賺賠也是自己才能掌握。
# 投資就像走迷宮，每個人用各自的方法走出迷宮，選擇路徑就像方法，找到出口就是獲利，只要要可以獲利，路徑可以有無限多種，只要能到達終點，出口也可以有很多個，所以不管如何解讀都無妨，希望人人都能夠找到最適合自己的答案。
#
# 【[股票永遠買不完，嚴守持股檔數紀律](https://www.facebook.com/kevinyang20180801/posts/pfbid02BxCMpGRapzTKgmgayGrrgpMVxXnuM5fBgJ1Yxq9N5zYUwj4AZ2mDbi6qXApHAtRwl)】
# 金融市場永遠不缺的就是題材跟消息，當局者迷，旁觀者清。要做到不被這些訊息干擾，但又能參與到上漲的利潤，並且賣在相對高點，這是所有投資人的終極目標。而要完成這個目標最關鍵取決於你是否有完整的投資系同，諸如選股以及過濾系統、買進條件的設定、買進後的調節、明確的停利停損工具…。
# 其實本質上停利與停損，使用的工具是相同的，只是因為成本的高低，而產生賺賠，成本低賺錢賣出，稱為停利，成本高賠錢賣出，稱為停損。我自己的賣出工具和策略3-6和3-7有完整論述和說明。
# 沒有人知道這些多如過江之鯽的資訊，哪一個最後會被市場認同，最後誰真的會長大、長胖，但有一件事情是肯定的，請務必把手中的股票先處理好，再來看新的東西，做到不貪心，才能夠專心，否則最終手上的股票不是一籃子，而是會多到像一座山。

# %% [markdown]
# 新日興(3376)
# ![messageImage_1699237222862.jpg](attachment:be8bef43-4779-4b2b-a6c2-c58623f13ee7.jpg)
#
# 華新科(2492)
# ![messageImage_1699237238368.jpg](attachment:be812584-bf87-4767-8f47-083a0ee93366.jpg)
#
# 台灣高鐵(2633)
# ![messageImage_1699239516971.jpg](attachment:27ebc1f7-a7a6-486f-a5a0-9a24942d5bcb.jpg)

# %% [markdown]
# 今天雖然漲幅不小，不過很明顯的，在下降軌道的壓力區以及120日線，有明顯壓力：
# ![messageImage_1699245411950.jpg](attachment:d8fc91de-8307-4776-9a59-a7764eb34f91.jpg)
#
# 櫃買指數相對強勢，突破藍色的小箱型整理區，但也立刻面臨新的中長天期的壓力：
# ![messageImage_1699245612342.jpg](attachment:fd27d1aa-8d62-46cc-8085-a1b90a08d609.jpg)

# %% [markdown]
# ![232803.jpg](attachment:5b6a20d8-6a32-47f2-ad8b-deeb6dd2c015.jpg)
# ![232804.jpg](attachment:5da504a3-aaa6-43e6-b18a-d98f4fa33ff0.jpg)

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * **規劃**建立台股「技術型態」資料集：參照「[用Python程式進行股票技術分析](https://ithelp.ithome.com.tw/users/20161619/ironman/5955)」之「[Day28 建立技術型態資料集](https://ithelp.ithome.com.tw/articles/10329779)」內容。
# * 追蹤：麗臺(2465)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2021年12月21日到今日收盤(2023年11月6日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2465_231106.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_x_date = ['2022-11-08','2023-10-16']
neckline_x = [date_to_index(df_k_line,neckline_x_date[0]),date_to_index(df_k_line,neckline_x_date[1])]
neckline_y = [df_k_line.loc[neckline_x_date[0]]['Open'],df_k_line.loc[neckline_x_date[1]]['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_date = '2022-06-07'
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
print('頸線開始價格 ＝ {:.2f} ， 頸線結束價格 ＝ {:.2f}'.format(neckline_start_price,neckline_end_price))

# 估算目標價
bottom_price_date = '2022-09-30'
breakthrough_price_date = '2023-10-25'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
breakthrough_price = slope * date_to_index(df_k_line,breakthrough_price_date) + intercept
print('頸線突破價格 ＝ {:.2f}元'.format(breakthrough_price))
target_price = (on_neckline_price - bottom_price) + breakthrough_price
print('目標價 ＝ {:.2f}元'.format(target_price))

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakthrough_price_date,breakthrough_price),(breakthrough_price_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6))

mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線開始價格 ＝ 38.89 ， 頸線結束價格 ＝ 52.39
# 頸線突破價格 ＝ 52.07元
# 目標價 ＝ 70.41元
