# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 延續[260319筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260319%E7%AD%86%E8%A8%98.ipynb)之「技術開發」項目，規劃AI Agent解盤程序。過程可以參考[ChatGPT](https://chatgpt.com/share/69ef135b-cdb4-83e8-a453-30bbaa2e6909)對話紀錄。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-04-27 20:02:09.464 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-27 20:02:09.517 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-04-27 20:02:09.538 | INFO     | FinMind.data.finmind_api:get_data:153 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1701：股票名稱 ＝ 中化，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1704：股票名稱 ＝ 榮化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1724：股票名稱 ＝ 台硝，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2336：股票名稱 ＝ 致伸，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2350：股票名稱 ＝ 環電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2403：股票名稱 ＝ 友尚，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2437：股票名稱 ＝ 旺詮，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2447：股票名稱 ＝ 鼎新，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2448：股票名稱 ＝ 晶電，產業類別 ＝ 光電業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數站上4萬點。
# >    ![messageImage_1777251640039.jpg](attachment:050805b8-cfe4-4fdc-acf5-0eedd467316f.jpg)

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 12480.28億元 ，十日均量 ＝ 10707.86億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重底，型態範圍由2026-03-03開始到2026-04-08結束，估算目標價為37317.96點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：櫃買指數也上漲，但還沒創高和站回短線支撐。
# >    ![messageImage_1777251711389.jpg](attachment:14d00812-f8a9-4679-bf95-474be94315bd.jpg)

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-24<br />
# 吞噬 : 2026-04-23<br />
# 孕育線／懷抱線 : 2026-04-24<br />
# 高檔夜星 : 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 2769.39億元 ，十日均量 ＝ 3070.41億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2025-11-20開始到2026-03-24結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 2726 ， 股票名稱 ＝ 雅茗-KY
# 股票代碼 ＝ 4933 ， 股票名稱 ＝ 友輝
# 股票代碼 ＝ 2440 ， 股票名稱 ＝ 太空梭
# 股票代碼 ＝ 2356 ， 股票名稱 ＝ 英業達
# 股票代碼 ＝ 3432 ， 股票名稱 ＝ 台端
# 股票代碼 ＝ 3051 ， 股票名稱 ＝ 力特

# %% [markdown]
# * 篩選結果
#   - 威盛(2388)：多頭回檔
#     ![260427_2.png](attachment:c6577452-65f3-4ca1-a77c-e87e75e053ba.png)
#   - 笙泉(3122)：穩健續漲
#     ![260427_3.png](attachment:8226ffad-748c-47f9-bba7-21b90a1171cc.png)
#   - 南帝(2108)：盤整觀察
#     ![260427_4.png](attachment:4237e0df-6634-4e87-9baf-6c21329d97f7.png)

# %% [markdown]
# * 觀察股列表
#   ![260427_1.png](attachment:31c628e7-07d2-420e-9940-f74061befd42.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 盟立(2464)
#   看法：遇前高壓力拉回。
#   ![260427_5.png](attachment:5feae01e-e1fd-42b6-96d3-387d16b6aced.png)
#   ![260427_6.png](attachment:5da60e34-d4c7-4f45-b4d6-c64e0f6a8f4b.png)

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。

# %%
stock_analysis(analysis,'2464')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-04-21 , 2026-04-27<br />
# 吞噬 : 2026-04-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 36441張 ，十日均量 ＝ 19256張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2026-01-05開始到2026-03-09結束，估算目標價為52.10元。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# 籌碼面：
# 法人大賣(-3116)：外資大賣(-3074)、投信中立(0)、自營小賣(-42)。
# 主力大賣(-2227)。
# 分公司買賣家數差集中(+3)。
# 融資大增(+891)、融券大增(+236)。
