# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[251201筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/251201%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 第一季參與：平日夜間班課程
#   - 新開雲端硬碟資料夾：**03.上課講義與筆記** 。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數續漲創高。
# > ![messageImage_1767315690419.jpg](attachment:7743a4e2-b07a-4030-9aa6-b8881895b597.jpg)

# %%
# 支撐線
def line_drawing_callback( range_prices) :

    # 支撐線
    support_line_start_date = range_prices.iloc[0].name.strftime("%Y-%m-%d")
    support_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_price      = range_prices.loc['2025-12-11']['High']
    
    seq_of_seq_of_points=[
        [(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)]
    ]

    linewidths=[2.5]
    
    colors=['xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：支撐線
image = mysys.DrawOnKlineChart('TAIEX','2025-10-28','2026-01-02',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數一樣續漲創高。
# > ![messageImage_1767315739741.jpg](attachment:df8e1d16-51ba-474f-a59f-43857d063cd9.jpg)

# %%
# 支撐線
def line_drawing_callback( range_prices) :

    # 支撐線
    support_line_start_date = range_prices.iloc[0].name.strftime("%Y-%m-%d")
    support_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_price      = range_prices.loc['2025-12-22']['Close']
    
    seq_of_seq_of_points=[
        [(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)]
    ]

    linewidths=[3.0]
    
    colors=['xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：支撐線
image = mysys.DrawOnKlineChart('TPEx','2025-10-28','2026-01-02',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')

# %% [markdown]
# ### 個股觀察

# %% [markdown]
# ![260102_1.png](attachment:d4d801f8-e220-490a-b448-52a3c3b13f2d.png)

# %% [markdown]
# * 聯德(3308)
#   ![260102_2.png](attachment:81c6caa5-af84-42f9-8276-e1300d3f36ae.png)
# * 聯德控股-KY(4912)
#   ![260102_3.png](attachment:670a3c10-d9a1-49c3-bfdf-d41f59b0a643.png)
# * 聯電(2303)
#   ![260102_4.png](attachment:8e26a95f-f74e-4466-ab6a-1cc7f2705fdf.png)
# * 東捷(8064)
#   ![260102_5.png](attachment:bab0b4d7-98c0-46fe-afe2-72b518e4a7d8.png)
# * 華邦電(2344)
#   ![260102_6.png](attachment:003b9e6e-5aed-499f-8484-02eb13178fe1.png)
# * 映泰(2399)
#   ![260102_7.png](attachment:f11e9472-cc00-45e4-aded-54e819e1c030.png)
# * 千興(2025)
#   ![260102_8.png](attachment:ea18f7ed-efde-4057-83e3-14a82e99641d.png)
# * 怡利電(2497)
#   ![260102_9.png](attachment:18c69115-1bd7-4fba-88b5-1ed6a36e1ca4.png)
# * 建通(2460)
#   ![260102_10.png](attachment:5d1ba8f8-17be-4116-92ef-c683cf7c090d.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 聯穎(3550)
#   看法：。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'3550')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-13'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-09-02']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-04-10'
    bottom_price = range_prices.loc['2025-04-10']['Open']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-12-31'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('3550','2025-02-14','2026-01-02',line_drawing_callback)
display(image)

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。

# %% [markdown]
# * 千興(2025)
#   看法：。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2025')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-15'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-12-02']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-11-20'
    bottom_price = range_prices.loc['2025-11-20']['Open']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2026-01-02'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2025','2025-08-28','2026-01-02',line_drawing_callback)
display(image)
# Out:
# 估算目標價為11.20元
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。
