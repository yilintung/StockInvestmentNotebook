# 回顧一下本週走勢，周一急跌、週二續跌但盤中止穩，週三出現反彈，但到了今天因為已經很接近壓力區，加上量能又急縮，所以上攻力道趨緩，只能維持平盤之上。
# 延續昨天觀點，反彈到壓力區如果不能補量上攻，由於整體還是空方掌控市場，未來還是要再度回測支撐。
# ![messageImage_1741298130337.jpg](attachment:b1909d80-be72-4f08-b008-11daec1316d3.jpg)
# ![messageImage_1741298214712.jpg](attachment:95930f30-3201-4b19-b740-3cae05c1b41c.jpg)
#
# [股市中的無為：學會順勢而為 📉📈](https://www.facebook.com/kevinyang20180801/posts/pfbid0ncoyrbE9FeZ1aVRhL5ioVa7jSz5z1CHQys8WeThkPybgzAHFrzBtknmSad2vYwual)
# 📌 同學說：「老師，最近真的好難做，做多做空都賠！」
# 📌 我回答：「但難做這件事，不是早就知道了嗎？為什麼不休息一下？」
# 在股票市場中，最大的風險 不是來自行情不好，而是明知行情不好，卻還執意重倉操作。這樣只是在給自己製造不必要的麻煩！
# 📖 什麼是無為？（維基百科）
# 無為，並非什麼都不做，而是經過理性的判斷，順應時勢與趨勢，讓事物保持其自然發展，而非強行干預。真正的無為，最終能達到\**「無為而無不為」\**的境界。
# 當市場處於混沌不明、多空皆難的時候，法人因為職責所限必須交易，但散戶卻擁有彈性，可以選擇觀望。與其盲目操作，不如停下來思考，等待更好的時機再出手。
# 👉 學會「無為」，才能在市場中走得更遠！ 🚀

# %% [markdown]
# ![683737.jpg](attachment:27e6a974-fd29-4a01-9975-56ad7c48684e.jpg)
# ![683738.jpg](attachment:e9bc5704-e111-4eed-a2d2-b42e821fd90d.jpg)

# %% [markdown]
# ### 本日進度
# * 將股票技術型態識別相關函式整合進StockChartPatterns類別。
#   - 三角形識別條件待檢討。
#   - 識別今日大盤（加權指數）型態。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
import os
import io
import base64

from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx = pattern_window.iloc[0].name
                pattern_start_date_idx = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx = pattern_window.iloc[0].name
                pattern_start_date_idx = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(df_k_line,**kwargs)

# %%
from PIL import Image

# 移除空白區域函式
# 來自：https://stackoverflow.com/questions/73604477/i-am-trying-to-crop-an-image-to-remove-extra-space-in-python

def get_first_last(mask, axis: int):
    """ Find the first and last index of non-zero values along an axis in `mask` """
    mask_axis = np.argmax(mask, axis=axis) > 0
    a = np.argmax(mask_axis)
    b = len(mask_axis) - np.argmax(mask_axis[::-1])
    return int(a), int(b)

def crop_borders(img, crop_color):
    np_img = np.array(img)
    mask = (np_img != crop_color)[..., 0]  # compute a mask
    x0, x1 = get_first_last(mask, 0)  # find boundaries along x axis
    y0, y1 = get_first_last(mask, 1)  # find boundaries along y axis
    return img.crop((x0, y0, x1, y1))

# %%
##### 使用2024年8月15日到今日(2025年3月7日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250307.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line)

# %%
patterns = chart_pattern.Recognition(turning_point_args={'mode':'open_close', 'order':10})

# %%
patterns_visualization(df_k_line,patterns)
# Out:
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 19        2024-09-11  21031.00   LO
# 42        2024-10-18  23620.57   HI
# 51        2024-11-01  22438.93   LO
# 56        2024-11-08  23608.11   HI
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 42        2024-10-18  23620.57   HI
# 51        2024-11-01  22438.93   LO
# 56        2024-11-08  23608.11   HI
# 71        2024-11-29  22202.28   LO
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 56        2024-11-08  23608.11   HI
# 71        2024-11-29  22202.28   LO
# 75        2024-12-05  23308.29   HI
# 86        2024-12-20  22510.25   LO
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 97        2025-01-07  23824.72   HI
# 101       2025-01-13  22488.33   LO
# 123       2025-02-21  23730.25   HI
# 129       2025-03-04  22508.80   LO
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 19        2024-09-11  21031.00   LO
# 42        2024-10-18  23620.57   HI
# 51        2024-11-01  22438.93   LO
# 56        2024-11-08  23608.11   HI
# 71        2024-11-29  22202.28   LO
# 75        2024-12-05  23308.29   HI

# %%
##### 使用2024年7月3日到2025年1月2日收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250102.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 確認三角形問題
# TODO : 問題尚未解決
patterns = chart_pattern.Recognition(turning_point_args=[{'mode':'open_close', 'order':5},{'mode':'open_close', 'order':10}])
patterns = {'三角形':patterns['三角形']}
display(patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點參數列表 ＝ [{'mode': 'open_close', 'order': 5}, {'mode': 'open_close', 'order': 10}]
# ＤＥＢＵＧ ： 價格資料總數 ＝ 124
# ＤＥＢＵＧ ： 價格資料總數 ＝ 124
# {'三角形': [{'argument': {'mode': 'open_close', 'order': 5},
#    'window':                 Date     Price Type
#    DateIndex
#    6         2024-07-11  24390.03   HI
#    21        2024-08-05  19830.88   LO
#    32        2024-08-20  22464.07   HI
#    35        2024-08-23  22042.59   LO
#    38        2024-08-28  22370.66   HI},
#   {'argument': {'mode': 'open_close', 'order': 5},
#    'window':                 Date     Price Type
#    DateIndex
#    71        2024-10-18  23620.57   HI
#    80        2024-11-01  22438.93   LO
#    85        2024-11-08  23608.11   HI
#    91        2024-11-18  22546.54   LO
#    96        2024-11-25  22996.05   HI},
#   {'argument': {'mode': 'open_close', 'order': 10},
#    'window':                 Date     Price Type
#    DateIndex
#    85        2024-11-08  23608.11   HI
#    100       2024-11-29  22202.28   LO
#    104       2024-12-05  23308.29   HI
#    115       2024-12-20  22510.25   LO
#    119       2024-12-26  23276.08   HI}]}

# %%
patterns_visualization(df_k_line,patterns)
# Out:
# ＃＃＃ 三角形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 5}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 6         2024-07-11  24390.03   HI
# 21        2024-08-05  19830.88   LO
# 32        2024-08-20  22464.07   HI
# 35        2024-08-23  22042.59   LO
# 38        2024-08-28  22370.66   HI
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 5}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 71        2024-10-18  23620.57   HI
# 80        2024-11-01  22438.93   LO
# 85        2024-11-08  23608.11   HI
# 91        2024-11-18  22546.54   LO
# 96        2024-11-25  22996.05   HI
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 10}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 85        2024-11-08  23608.11   HI
# 100       2024-11-29  22202.28   LO
# 104       2024-12-05  23308.29   HI
# 115       2024-12-20  22510.25   LO
# 119       2024-12-26  23276.08   HI

# %% [markdown]
# * 利用GPT-4o來識別型態
#   - 延續[前天](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250305%E7%AD%86%E8%A8%98.ipynb)進度，驗證今日大盤（加權指數）型態與走勢。

# %%
load_dotenv(find_dotenv())
api_key = os.environ.get('OPENAI_API_KEY_TOKEN')
client = OpenAI(api_key = api_key)

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 繪製K線圖
img = io.BytesIO()
kwargs = dict(type='candle', style=s, figratio=(16,9), volume=True, savefig=dict(fname=img,format='png'))
mpf.plot(df_k_line,**kwargs)

# 刪除空白
image    = Image.open(img).convert("RGB")
image    = crop_borders(image, crop_color=(255, 255, 255))
crop_img = io.BytesIO()
image.save(crop_img,format='PNG')
display(image)

# 將影像檔(PNG)編碼為Base64
base64_image = base64.b64encode(crop_img.getvalue()).decode()
# Out:
# <PIL.Image.Image image mode=RGB size=808x487>

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "您是一位股票技術分析師，可以從K線圖識別出價格型態"},
        {"role": "user", "content": [
                {"type": "text", "text": "請識別以下K線圖(收盤價大於開盤價為紅K線，收盤價小於開盤價為黑K線)中有哪些價格型態，並標註型態開始與結束時間。"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# 在這張K線圖中，我們可以識別出以下價格型態：
#
# 1. **頭肩底**：
#    - 開始時間：2024年7月中旬
#    - 結束時間：2024年9月初
#    - 特徵：左肩、頭部、右肩依次形成，並伴隨著成交量的變化。
#
# 2. **上升趨勢**：
#    - 開始時間：2024年8月中旬
#    - 結束時間：2024年9月底
#    - 特徵：價格持續上升，形成一系列較高的高點和低點。
#
# 3. **雙頂**：
#    - 開始時間：2024年10月中旬
#    - 結束時間：2024年11月中旬
#    - 特徵：兩個高點大致在同一水平，形成“M”形狀。
#
# 這些型態可以幫助預測未來的價格走勢，但請注意，技術分析僅為投資決策提供參考，實際操作需謹慎。

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {"role": "system", "content": "您是一位樂於助人的金融股票分析師，提供有關股票數據的見解。"},
        {"role": "user", "content": [
                {"type": "text", "text": "可以描述一下下面的圖表嗎？"},
                {"type": "image_url", "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"}
                }
            ]
        }
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# 這是一個股票的K線圖，顯示了從2024年7月到2024年12月的價格走勢和交易量。
#
# ### 價格走勢：
# - **K線圖**：圖中有紅色和黑色的K線，分別代表股價的上漲和下跌。
# - **趨勢**：在2024年7月初，股價大幅下跌，隨後在8月中旬開始回升，並在9月和10月達到高點。之後，價格在11月和12月呈現橫盤整理的趨勢。
#
# ### 交易量：
# - **柱狀圖**：底部的紅色和黑色柱狀圖顯示了每日的交易量。
# - **變化**：在價格大幅波動的時期，交易量也相應增加，特別是在7月的下跌和8月的回升期間。
#
# 整體來看，這段期間的市場經歷了顯著的波動，並在年底趨於穩定。
