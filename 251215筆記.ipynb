# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[251201筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/251201%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數開低，20日線和前低都暫時有守。
# > ![messageImage_1765760441959.jpg](attachment:d95939f6-fbf3-44ec-8f18-e1494aed0c5d.jpg)

# %%
# 支撐線
def line_drawing_callback( range_prices) :

    # 支撐線
    support_line1_start_date = '2025-11-26'
    support_line1_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line1_price      = (range_prices.loc['2025-11-27']['Close'] + range_prices.loc['2025-11-27']['Open']) / 2
    
    seq_of_seq_of_points=[
        [(support_line1_start_date,support_line1_price),(support_line1_end_date,support_line1_price)]
    ]

    linewidths=[3.0]
    
    colors=['xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：支撐線
image = mysys.DrawOnKlineChart('TAIEX','2025-11-19','2025-12-15',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數也是開低，但10日線暫時有守住。
# > ![messageImage_1765760523248.jpg](attachment:9b94932b-e123-4cb9-88bb-17542adf5c83.jpg)

# %%
# 支撐線
def line_drawing_callback( range_prices) :

    # 支撐線
    support_line1_start_date = '2025-11-27'
    support_line1_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line1_price      = range_prices.loc['2025-12-02']['Open']
    
    seq_of_seq_of_points=[
        [(support_line1_start_date,support_line1_price),(support_line1_end_date,support_line1_price)]
    ]

    linewidths=[3.0]
    
    colors=['xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：支撐線
image = mysys.DrawOnKlineChart('TPEx','2025-11-19','2025-12-15',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')

# %% [markdown]
# ### 個股觀察

# %% [markdown]
# ![251215_1.png](attachment:9e451a5d-0c39-4c02-adb4-0ba387ec99d0.png)

# %% [markdown]
# * 錸德(2349)
#   ![251215_2.png](attachment:b61b2157-69a6-4298-9de4-14ad005cdc9d.png)
# * 元晶(6443)
#   ![251215_3.png](attachment:c209e544-e8a8-4cab-9a0d-2f68749f488b.png)
# * 太景*-KY(4157)
#   ![251215_4.png](attachment:f2d00306-44a5-4a55-9970-bab2bfc01965.png)
# * 中信金(2891)
#   ![251215_5.png](attachment:7c47839f-4927-4bad-b452-23e123ae6e87.png)
# * 華邦電(2344)
#   ![251215_6.png](attachment:94717793-56e5-42b5-b432-44172a8fb39d.png)
# * 精英(2331)
#   ![251215_7.png](attachment:1629b1e7-28b7-460e-8e02-34b7019a20b3.png)
# * 正文(4906)
#   ![251215_8.png](attachment:30d58f4c-d23d-4972-acf6-3563e617754f.png)
# * 建通(2460)
#   ![251215_9.png](attachment:87a41f6c-8e8b-44ba-8ed6-55743dd884a5.png)
# * 科嶠(4542)
#   ![251215_10.png](attachment:aa5a524c-3dab-4c95-bb19-c9a4883993dc.png)
# * 久元(6261)
#   ![251215_11.png](attachment:9f4708ae-ce68-409e-9f05-a69faca11eab.png)
# * 勝德(3296)
#   ![251215_12.png](attachment:d4379bfd-bb10-462f-b48b-23bc9bc15a73.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 建通(2460)
#   看法：

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'2460')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-27'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-08-11']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-04-11'
    bottom_price = range_prices.loc['2025-04-11']['Open']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2460','2024-11-26','2025-12-15',line_drawing_callback)
display(image)

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。

# %% [markdown]
# * 正文(4906)
#   看法：

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'4906')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-31'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-08-27']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-08-13'
    bottom_price = range_prices.loc['2025-08-13']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('4906','2024-12-10','2025-12-15',line_drawing_callback)
display(image)

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。
