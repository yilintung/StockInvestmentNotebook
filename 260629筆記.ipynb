# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
# * 開始進行量化交易／程式交易之程序開發，已申請[Shioaji](https://sinotrade.github.io/zh/) API Key：
#   ![260628_1.png](attachment:4ea6eb31-779c-4cbe-82ce-180efaee8d87.png)

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-06-29 21:40:06.611 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-06-29 21:40:06.657 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-06-29 21:40:06.677 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 新增股票代碼。代碼 ＝ 009823：股票名稱 ＝ 群益S&P500，產業類別 ＝ 上櫃ETF，類型 ＝ tpex
# 修改股票資訊。代碼 ＝ 2315：股票名稱 ＝ 神達，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2361：股票名稱 ＝ 鴻友，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2384：股票名稱 ＝ 勝華，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2392：股票名稱 ＝ 正崴，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2397：股票名稱 ＝ 友通，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2417：股票名稱 ＝ 圓剛，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2419：股票名稱 ＝ 仲琦，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2433：股票名稱 ＝ 互盛電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2434：股票名稱 ＝ 統懋，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2442：股票名稱 ＝ 新美齊，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數小漲262點。
# >    ![messageImage_1782694864332.jpg](attachment:6360e794-3b3c-44d9-ba9f-79ffe231c87a.jpg)

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-06-25<br />
# 十字線 : 2026-06-25<br />
# 孕育線／懷抱線 : 2026-06-25 , 2026-06-29</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 10454.39億元 ，十日均量 ＝ 13952.29億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-05-20開始到2026-06-26結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：櫃買指數持續下跌走弱。
# >    ![messageImage_1782694921684.jpg](attachment:e6eab10f-ff48-4f23-8fdf-24ff3cc4af44.jpg)

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-06-29<br />
# 鎚子線／吊人線 : 2026-06-24<br />
# 吞噬 : 2026-06-23<br />
# 高檔夜星 : 2026-06-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1759.22億元 ，十日均量 ＝ 2519.26億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-04-01開始到2026-06-26結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 6743 ， 股票名稱 ＝ 安普新
# 股票代碼 ＝ 2012 ， 股票名稱 ＝ 春雨
# 股票代碼 ＝ 1710 ， 股票名稱 ＝ 東聯
# 股票代碼 ＝ 3717 ， 股票名稱 ＝ 聯嘉投控
# 股票代碼 ＝ 2906 ， 股票名稱 ＝ 高林

# %% [markdown]
# * 篩選結果
#   - 美利達(9914)：穩健續漲
#     ![260629_2.png](attachment:76e252f5-1e9a-4295-b4c2-ef240f58fb41.png)
#   - 材料*-KY(4763)：盤整觀察
#     ![260629_3.png](attachment:dcd54cc2-c76a-4380-8395-817a54196bc7.png)
#   - 錩新(2415)：技術突破
#     ![260629_4.png](attachment:a86be8c4-bb62-4527-a051-aa06a82c5c26.png)
#   - 巨大(9921)：盤整觀察
#     ![260629_5.png](attachment:88fb3385-ad26-47a4-b9da-ae10407739cb.png)

# %% [markdown]
# * 觀察股列表
#   ![260629_1.png](attachment:5beb88a6-2ca7-4880-bb20-175d97b68e67.png)

# %% [markdown]
# * 技術面+籌碼面分類整理表
#   ![517193.jpg](attachment:4f738a41-e6c7-418c-a8f8-cd46ffea1fe7.jpg)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 巨大(9921)
#   看法：嘗試突破頸線未成，收盤時留長上影線。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'9921')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x482>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-06-24 , 2026-06-29<br />
# 十字線 : 2026-06-24 , 2026-06-29<br />
# 吞噬 : 2026-06-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 3147張 ，十日均量 ＝ 1975張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2026-03-06開始到2026-06-29結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2026-03-03'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-06-15']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-04-28'
    bottom_price = range_prices.loc['2026-04-28']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('9921','2025-12-26','2026-06-29',line_drawing_callback)
display(image)
# Out:
# 估算目標價為88.70元
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-487)：外資小賣(-683)、投信小買(+198)、自營中立(-2)。
# 主力小賣(-275)。
# 分公司買賣家數差分散(-57)。
# 融資大增(+129)、融券中立(0)。
