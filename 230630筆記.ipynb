# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】弱勢盤整，支撐不穩
# 昨天提到加權指數有機會大漲，但量能很關鍵，止穩不用量，但如果要續漲翻多，那量就要補出來，不然就會變成空方的反彈，要轉為回升的格局，量必須要補到3300億，即使再降低點標準也要3000億，昨天只有2735億，所以開高後立刻壓回，能維持在平盤已經算是不錯的表現。
# 加權指數以16950為中軸，上下約50點狹幅整理，短線行進快一週，走勢稍嫌偏弱，漲幅不足量能也不夠，不過儘管如此，中期支撐尚未跌破。但其實如果是我個人操作，最好的策略其實就是低持股，甚至空手等待就好，不用急著重壓多空，尤其今天已經是本周最後一天交易日，下周又有美國國慶假期，但我知道大家多空持股比重高的投資人，還是會急著想知道，從目前整理多空比較表，很明顯看到空方條件較多，只是空方條件偏短線，而多方條件則是中期，所以還是以中性看待。
# (當行情膠著時，我會習慣把多空條件都客觀列出來比對，上一次做這件事情已經是去年8月中旬，印象很深刻是因為，小孩放暑假。而當時的結論是，盤整後會再轉弱，行情越膠著，代表多空拉鋸越嚴重，一旦多空分出勝負，走勢就會很快，一跌破支撐，立刻從15150續跌到12629。只是敘述過去情況，但本次和上次條件不盡相同，不能一概而論。)
# 有同學問那要再跌多少，20日扣抵才會出現危險？大約200點，所以其實也沒有很難，而最弱勢的反彈就是3-5天的盤整，不知道會不會出現這麼弱的走勢？從籌碼、價量關係、類股結構，是有這個風險。但不管如何，短線偏空測試支撐，這個格局還沒改變，關注手中持股的支撐就好，不要急著進場搶短，等趨勢更明朗一點，再做積極的操作，當然如果你上周就已經空手，那可以再多放幾天假。 (出處：K線捕手楊忠憲粉絲團)
# ![356863161_744003647733565_4950450291959961262_n.jpg](attachment:a9dccd11-a755-4784-80f0-c8dec2345efc.jpg)

# %% [markdown]
# 加權指數跌幅也稍微收斂：
# ![messageImage_1688096050740.jpg](attachment:15bff301-ea26-44ee-b136-c42b58856558.jpg)
#
# 台幣持續貶值：
# ![messageImage_1688096197060.jpg](attachment:2128cff7-1e4c-411f-bc21-9bb3b3f518a0.jpg)
#
# [長榮等12檔股票30日除息 台股指數將蒸發74.23點](https://tinyurl.com/5n725hcs)
# 證交所統計，30日將有長榮(2603)、台達電(2308)、日月光投控(3711)等12檔股票除息，影響加權指數蒸發74.23點，其中長榮就影響了指數47.52點。
#
# 扣掉除權息大幅蒸發點數，目前差不多是平盤。

# %% [markdown]
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 8996 高力2317  高檔盤整20日線有守，但籌碼不集中
# 4129 聯合  有迷你頭部，依照扣抵，20日線可能會下彎
# 晶心科6533  短線偏弱，中期高檔大箱型整理
# 晶技3042  短線轉弱，20日線有支撐
# 2317鴻海  中長期前高有反壓，短線拉回整理，籌碼中性
# 宏觀6568  有中期頭部雛形，籌碼偏空
# 3005神基  高檔急跌翻空
# 2328廣宇  短線偏空支撐不穩，籌碼不集中
# 4114健喬  短線小反彈，有中期頭部雛形，籌碼不集中
# 2405輔信  短線盤整，中期偏多
# 4414 如興  跌深反彈，止穩但尚未翻多
# 3013晟銘電  高檔箱型，20日有下彎風險
# 3049和鑫  短線遇前高拉回，中期持續打底
# 8046南電  迷你頭部續跌中
# 2105正新  高檔整理，籌碼集中
# 6470 宇智  突破大箱型區間，但位階高
# 2633 高鐵  有迷你頭部雛形，籌碼不集中。
# 3564其陽  短線轉弱，支撐不穩
# 3685元創精密  回測中期底形頸線，有守
# 2354鴻準  小箱型整理，籌碼中性
# 3715定穎投控  高檔轉弱，有迷你頭部
# 3122笙泉  箱型區間尚未有效突破，回測支撐
# 2439美律  短線盤整，中期支撐有守
# 2702華園  短線轉弱，中期大箱型區間整理
# 3673 TPK  高檔盤整，籌碼中性偏多
# 1785光洋科  中期小箱型整理，籌碼中性
# 3447展達  短線偏多，但已經到反壓區
# 2323中環  20日線暫時有守，籌碼轉弱中
# 6741-91APP  短線反彈，中期箱型整理
# 8155博智  有中期頭部雛形，籌碼偏空
#
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 1605華新  中長期頭部成形，籌碼偏空，續跌中
# 2303聯電  短線轉弱，支撐不穩
# 6505台塑化  中期頭部雛形，籌碼偏空
# 2313華通  短線偏多，中期箱型
# 2867三商壽  有底部型態，但尚未完全轉強
# 凌陽2401  短線轉弱，支撐有守
# 6770 台積電  短線轉弱，中期盤整
# 2492華新科  有中期頭部雛形
# 2851中再保  回測支撐有守，短線盤整
# 8446華研  急漲急跌，倒V形反轉
# 3260 威剛  高檔箱型整理，籌碼集中
# 8454富邦媒  弱勢盤整，尚未轉強
# 3707漢磊  短線轉弱，中期箱型整理
# 3189景碩  中期小箱型整理，籌碼集中
# 2476鉅祥  中期頭部續跌中
# 3413京鼎  高檔箱型整理，籌碼中性
# 4174浩鼎  短線轉強，但中長期前高反壓仍多
# 3105穩懋  短線轉弱，中期箱型整理
# 6462神盾  短線整理，中期偏多
# 4967十銓  短線反彈，中期大箱型整理
# 6187萬潤  短線轉弱，支撐不穩
# 6274台燿  有迷你頭部雛形
# 3056總太  高檔頭部起跌，還看不到支撐
# 3231緯創  高檔量縮整理，但位階非常非常非常高，要會設移動支撐
# 3532台勝科  有底部雛形，但尚未轉強
# 6676祥翊  高檔整理後續不明朗，位階高
# 00669R國泰美國道瓊反1  低檔箱型整理，但尚未轉強
# 6589台康生技  短線反彈，中期箱型區間
#
# ### 【K線捕手楊忠憲技術/籌碼概況說明】
# 以下不是我的選股，是網友主動提問，整理後公開無償分享，由於都是我自己逐字整理，不是用電腦程式或是軟體機器人，但同學提問數量眾多，礙於時間跟版面，無法詳答和附圖，只能簡略回答個股現況。相關內容依照技術面和籌碼面做整理，僅為個人看法無償分享，不做為任何交易之依據。任何投資都有風險，請審慎評估資金狀況、投資目標、風險承受程度及獨立交易的能力，並善設停利停損。
#
# 2609陽明  短線偏弱，中期箱型整理
# 4927泰鼎-KY  短線偏弱，有迷你頭部雛形，中期大箱型區間
# 3006晶豪科  短線偏弱，中期箱型
# 8255朋程  短線偏空，有中期頭部雛形
# 2352佳世達  短線轉弱，20日線暫時有守
# 4162智擎  有打底現象，但尚未轉強
# 5351鈺創  短線偏空，有中期頭部雛形
# 2474可成  短線轉弱，狹幅盤整，籌碼不強
# 3011今皓  短線創高續強，位階很高
# 1711永光  中期三角收斂
# 5475德宏  短線偏空，有中期頭部雛形
# 6944兆聯實業  短線偏多，中期箱型區間
# 3042晶技  短線轉弱，20日線暫時有守
# 6282 康舒  有迷你頭部，籌碼偏空
# 6150憾訊  有迷你頭部，籌碼偏空
# 1477聚陽  短線創高續強，位階高
# 6213聯茂  有迷你頭部，籌碼偏空
# 2206三陽科技  短線高檔轉弱，支撐不穩
# 5258虹堡  短線轉弱，測試中期支撐
# 6523達爾膚  短線偏空，有中期頭部雛形
# 1905華紙  高檔盤整，下周20日線扣高檔
# 2634漢翔  短線轉弱測試20日支撐，中期箱型
# 1504東元  有迷你頭部，籌碼偏空
# 6861睿生光電  低檔三角收斂整理，籌碼不強
# 6269台郡  中期頭部續跌中，籌碼偏空
#
# 出現迷你頭部或中期頭部雛形的個股，本周增加很多

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值34,750元(收盤價：34.75元，漲0.25元)。回到底部型態區間，持續觀察中。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,34.75,34597,-1754,-4.83]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  34.75  34597 -1754 -4.83

# %%
##### 使用2022年1月24日到今日收盤價(2023年6月30日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230630.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-08-25']['Close']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.8,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 36.30元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-06-30

# %% [markdown]
# * 下個月(7月)開始整合之前寫的程式(轉折點、頭肩底型態與趨勢線…等)與[neurotrader](https://www.youtube.com/@neurotrader888/videos)之程式碼：
#   - 位階
#     + [量化位階評價法](https://vocus.cc/article/62ada936fd89780001fe6208) ： 已完成 **StockRankEvaluate()** 函式，後續整理程式碼
#   - 轉折點
#     + 峰位∕谷底的演變程序([peak-and-trough progression](https://www.amazon.com/Technical-Analysis-Explained-Fifth-Successful/dp/0071825177)) 與 滾動窗口([Rolling Window](https://www.youtube.com/watch?v=X31hyMhB-3s&t=49s)) ： 已完成 **FindingTurningPoints()** 函式
#     + *方向變化([Directional Change](https://www.youtube.com/watch?v=X31hyMhB-3s&t=179s))* ： [directional_change.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/directional_change.py)
#     + *感知重要點([Perceptually Important Points](https://www.youtube.com/watch?v=X31hyMhB-3s&t=339s))* ： [perceptually_important.py](https://tinyurl.com/yc2bykhr)
#   - 趨勢線
#     + 自行開發 ： 模擬手工方式，由兩個轉折點中畫出一條趨勢線
#     + 自動價格趨勢線([Automated Price Trend Lines](https://www.youtube.com/watch?v=wbFoefnidTU)) ： [trendline_automation.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/trendline_automation.py)
#   - 型態
#     + 頭肩底(或 頭肩頂)演算法一([Algorithmically Detecting (and Trading) Technical Chart Patterns with Python](https://medium.com/automation-generation/algorithmically-detecting-and-trading-technical-chart-patterns-with-python-c577b3a396ed)) ： [tech_screener_notebook.ipynb](https://github.com/samchaaa/alpaca_tech_screener/blob/master/tech_screener_notebook.ipynb) ： 頭肩底函式已完成，待整理
#     + 頭肩底(或 頭肩頂)演算法二([Automated Head and Shoulders Chart Pattern in Python](https://www.youtube.com/watch?v=6iFqjd5BOHw)) ： [head_shoulders.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/head_shoulders.py)
#     + 旗型與三角旗型演算法([Flag and Pennant Pattern Recognition](https://www.youtube.com/watch?v=Lb5SPCTp4uY)) ： [flags_pennants.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/flags_pennants.py)

# %% [markdown]
# ### 史塔克財金工作室 進階班
# * 講義存放連結：https://mega.nz/folder/g2gkSIJa

# %% [markdown]
# ![LINE_ALBUM_230630.jpg](attachment:aa5edf3a-9f3f-40f2-b69d-2c8c85ec65b9.jpg)

# %% [markdown]
# * [你還不知道的技術指標_200630_筆記.pptx](https://mega.nz/file/97xCWQpQ)
