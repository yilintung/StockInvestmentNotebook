# %% [markdown]
# ### 📢【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】國安基金出手？別急著樂觀！
#
# 過去我們規劃的「三階段修正」，目前已經快速達到第二階段跌幅滿足區，跌勢趨緩、盤勢出現止穩跡象，正如我們週日影音解盤中預告：
# 📆「本週上半週有機會短線止穩。」
#
# 🎯 然而巧合的是，就在昨天，國安基金宣布今可能進場！
# 馬上就有同學私訊問我：「老師，你是不是早知道國安基金會進場？」
#
# 📊我的回覆只有一句：我無法預知未來，但我相信技術分析。技術分析會告訴你一切，只是你要看得懂、用得上！
#
# 💡 技術分析絕對不是「看圖說故事」，也不是「事後諸葛」，而是市場行為的語言，懂的人自然能領先布局。
#
# 🧭 不過提醒大家，現在只是“止穩”，還沒“止跌”
# 🔸 空方仍主導市場，真正趨勢反轉，必須在關鍵支撐區出現「明確轉折訊號」
# 🔸 就像我們在數位訂閱裡提到的：「止穩 ≠ 止跌」、「反彈 ≠ 翻多」
#
# 🤔 至於國安基金是否真的會出手？介入條件？效果如何？
# 這些將會在週三晚上的影音訂閱中，為大家深入解析！
#
# 📌【總結】
# ✅ 中長線結構仍偏空
# ✅ 短線跌深，應密切留意是否出現有效止穩訊號
# ⚠️ 操作上，不論做多做空都宜保守，在這個位置寧願保守應對，也千萬不要情緒化亂出手！
#
# 📢 完整深度解析，請見「K線追擊周報」數位訂閱！
# 📢 歡迎分享，請註明出處：K線捕手 楊忠憲粉絲團 🔥
# ![messageImage_1744153371085.jpg](attachment:1c73ae4f-fbe1-4d66-9f6a-c311d64d52cf.jpg)

# %% [markdown]
# [外資狠砍341億！台股熊市大門打開 分析師示警風暴未完](https://www.ctee.com.tw/news/20250408701222-430201?fbclid=IwY2xjawJix4hleHRuA2FlbQIxMAABHjAL-q2L9uVuQ8NzMpDhMJRGwj1vVwt5Y2TyQb2wDIzz_u0unOhIM2MOtTLo_aem_15APpEuij_thoOF_CHE8KQ)
# 亞股今（8）止血反彈，日股強升超過5%，但台股延續跌勢，台積電一度殺破800元，鴻海爆量摔跌停，拖累大盤一度重挫1,058點，終場指數下挫772點，收在18,459點，失守萬九大關，不過成交值放大增至5,489億元。
# 盤面上有黑馬殺出，安控股、金融股紛紛回神，哲固、陞泰、杭特、天鉞電、上海商銀飆漲停，兆豐金也大漲超過7%，遊戲股辣椒、宇峻、昱泉也突圍亮紅燈。
#
# [兆豐金強漲逾7％ 市值躋身台股前十](https://www.ctee.com.tw/news/20250408701420-430201?fbclid=IwY2xjawJiyL5leHRuA2FlbQIxMAABHl4UE_6SanL6F86BwSyNBRanA3btySBOkZfZ_sZQuO4umjdMpFrf49Qb_1vm_aem_dU-_AK_xEmQA6ZzzPfO0vg)
# 官股龍頭金控-兆豐金（2886）今（8）日股價發威，以38.25元大漲7.59％作收，成交值打敗日月光投控（3711），晉升至台股市值前十強，如此一來，台股市值前十高股中，金控股占了四強，包括富邦金（2881）、國泰金（2882）、中信金（2891）及兆豐金。
# 扮演政策控盤工作的金融類股指數今日逆勢上漲，收在1,910.69點上漲0.59％，成交值更擴大至385.71億元，較昨天的144.71億元大增1.67倍。金融股有政策護盤的著墨。
#
# [台股失守19K 上市櫃888檔跌幅逾9％ 這3檔安控股飆風再起](https://www.ctee.com.tw/news/20250408701005-430201?fbclid=IwY2xjawJiyNxleHRuA2FlbQIxMAABHl4UE_6SanL6F86BwSyNBRanA3btySBOkZfZ_sZQuO4umjdMpFrf49Qb_1vm_aem_dU-_AK_xEmQA6ZzzPfO0vg)
# 台股今（8）日持續下墜，以19,064.47點跳空開低，盤中一度低見18,180.48點，終場下跌772.4點，跌幅4.02％，以18,459.95點作收，失守19K，在台股崩跌下，各大券商發出融資追繳令，融資斷頭賣壓及停損賣盤陸續出現，讓昨天萎縮的交易金額增加逾2倍，達到5,500.9億元。
# 相較於昨日上市、櫃公司超過1,700家跌停，今日下跌家數有1,571家，當中跌幅突破9％的有888檔，雖以跌停價鎖死的個股仍多的觸目驚心，但仍有259家抗跌上揚。
#
# [美股收盤／美股狂喜後又翻落一年谷底 美關稅延後或調整希望渺茫](https://money.udn.com/money/story/123398/8661857?from=edn_maintab_index&fbclid=IwY2xjawJiyQhleHRuA2FlbQIxMAABHjAL-q2L9uVuQ8NzMpDhMJRGwj1vVwt5Y2TyQb2wDIzz_u0unOhIM2MOtTLo_aem_15APpEuij_thoOF_CHE8KQ)
# 標普500指數周二連續四個交易日下挫，一年來首度收在5,000點以下，早盤大漲後又出現逆轉，川普政府推動對中國大陸在內多國高關稅即將生效，投資人認為美國政府延後或調整的希望渺茫。
#
# [國安基金第九次出手進場護盤 5,000億元銀彈上膛](https://money.udn.com/money/story/5607/8661609?fbclid=IwY2xjawJiySVleHRuA2FlbQIxMAABHvXmiQnxNsqvQ9WFU0oQmshVv46MS5AMru90K_u1JUBuBJS09bkn9j9jZJky_aem_9wcPLso0HYq9-xtwXr199A)
# 川普關稅戰衝擊全球市場，台股清明連假後兩天下跌2,838點，投資人哀鴻遍野，國安基金昨（8）日召開臨時委員會議，決議進場護盤，這是國安基金第九次執行護盤任務，同時也創下進場護盤的指數點位在萬八之上的新高紀錄。
# 國安基金5,000億元銀彈上膛，根據過去操作經驗，預期包括台積電（2330）、聯發科（2454）、台達電（2308）、鴻海（2317）等權值股，將是護盤重心。
#
# [美光開全球第一槍！關稅轉嫁客戶 今起加收產品附加費](https://www.chinatimes.com/realtimenews/20250409001657-260410?fbclid=IwY2xjawJiyedleHRuA2FlbQIxMQABHsxr0AO3LmmyaO0wHHU3aSgjZCihQOBtnNnNkVdcrjLWhL5mw2towEgscoHq_aem_NaI7XHzg1QIQ-ePPrpko6w&chdtv)
#
# [美國高關稅今生效 川普警告台積電：若不在美建廠就繳100%的稅](https://tw.news.yahoo.com/%E7%BE%8E%E5%9C%8B%E9%AB%98%E9%97%9C%E7%A8%85%E4%BB%8A%E7%94%9F%E6%95%88-%E5%B7%9D%E6%99%AE%E8%AD%A6%E5%91%8A%E5%8F%B0%E7%A9%8D%E9%9B%BB%EF%BC%9A%E8%8B%A5%E4%B8%8D%E5%9C%A8%E7%BE%8E%E5%BB%BA%E5%BB%A0%E5%B0%B1%E7%B9%B3100%E7%9A%84%E7%A8%85-014417883.html)
# 美國各地海關自台灣時間9日中午12時起，開始對包含台灣等86國輸美貨品課徵新關稅。美國總統川普（Donald Trump）8日指出，他告訴台灣積體電路製造公司，若不履行投資美國的承諾、不在美國建廠，就要繳高達100%的稅。

# %% [markdown]
# 日本開低，但是守住關鍵支撐，短線進入狹幅震盪：
# ![messageImage_1744158511610.jpg](attachment:0c5e15f4-98dd-451d-89dc-ab6a1bede23e.jpg)
#
# 期貨開低，雖然小創新低，但跌勢已經比前兩天溫和許多：
# ![messageImage_1744159543963.jpg](attachment:7644dc2c-796f-468f-af03-be898441ae7f.jpg)
#
# 加權指數開低，小創新低，但跌勢趨緩：
# ![messageImage_1744160433675.jpg](attachment:e8049fae-6f04-4e4f-95a1-986ff8b36b47.jpg)
#
# 櫃買指數跌幅較大，中小型股壓力大：
# ![messageImage_1744160898581.jpg](attachment:450835a6-2c5f-4398-a391-14e308ec268a.jpg)
#
# 跌幅滿足：
# ![messageImage_1744161119184.jpg](attachment:eea95b97-f723-46c9-8134-68afa5ae2208.jpg)
#
# 可以觀察每一階段支撐區，是否有止跌現象跟條件，但不能預設低點。
#
# 早盤勉強撐了一下，但還沒有止跌現象：
# ![732704.jpg](attachment:a33be917-4ce4-43a6-aa82-69ce20a017fd.jpg)
# ![732705.jpg](attachment:788e13ac-d543-4778-966a-3e40ba409072.jpg)
#
# 持續修正中：
# ![732934.jpg](attachment:3bc49c6f-f1bc-4863-97ce-772a571d4f01.jpg)
# ![732935.jpg](attachment:97be178a-956f-4b04-a3e3-2001a98010df.jpg)

# %% [markdown]
# 上海商銀(5876)
# ![messageImage_1744164048255.jpg](attachment:6d8330cc-7333-4a03-88f3-4c2c6dea7632.jpg)
# 這檔真的是命很硬，外在系統性風險賣壓，漲幅滿足竟然到了。

# %% [markdown]
# 🚨【[你還在等解套？](https://www.facebook.com/kevinyang20180801/posts/pfbid0SN4EAqguiv7QSxenLGidCDLK9G3JFJAhzqWQrGt6BeiQ69M8frKRm4Mw2TgUznFHl)】為什麼聰明投資人都懂得「留子彈」？💰
# 💸每次大跌，才發現現金是王道？這堂市場的「血淚教訓」，你是不是也上過？當行情走弱，99%的股票齊跌，沒有資金調節習慣的人，只能眼睜睜看著帳面損失擴大，股票被套牢在高點，一動也動不了🔒
# 🛒而當市場落底、到處都是超值便宜貨，你卻只能乾瞪眼👀 因為——
# ❌ 沒有現金
# ❌ 沒有機會
# ❌ 只有等待...
# ✂️高檔不減碼，等於自斷後路
# 💎別人逢低撿鑽石你卻只能等解套、錯過翻身機會🚪
# 📘 新書第2️⃣和第3️⃣章節完整拆解：
# ✅ 如何做好風險控管🛡️
# ✅ 如何有效調節資金⚖️
# 讓你下次不再錯失良機🔥
# 👉 想學會這套投資人必備的資金戰略？
# 現在就點進來👇
# 博客來 https://bookstw.link/6zncxg
# 金石堂 https://pse.is/6znczn
# 誠品線上 https://pse.is/6znd3m
# MOMO https://pse.is/6znd6t
# 墊腳石 https://pse.is/6znd5j
# 三民 https://pse.is/6znddr
# 讀冊 https://pse.is/6zndfd
# 一起升級你的投資實力📈！
#
# 【[一眼看穿盤勢！趨勢判斷其實超簡單](https://www.facebook.com/kevinyang20180801/posts/pfbid02AY2zqzVER5DuQXzB8mcrhwbkfACyivcNDJAtaTvjd7eyPbUghpcf8WFLz1BtnPi4l)】
# 老實說，判斷趨勢真的沒那麼難——
# 只要搞懂一件事：現在的手氣好不好？
# ✔️ 如果你發現「買什麼都賺」，那恭喜，多頭行情正在對你微笑。
# ✔️ 如果你發現「怎麼空怎麼賺」，別懷疑，空頭正在發威。
# ❌ 但如果買也錯，賣也錯，心好累？那就八成是盤整期，市場在睡覺。
# 別再鑽牛角尖啦！有時候你的交易感受，就是最直接的趨勢答案。

# %% [markdown]
# ![733398.jpg](attachment:b7464730-86fc-4b77-a7bc-94a5202dc58d.jpg)
# ![733399.jpg](attachment:e98a5f4d-9f93-4e10-b67a-c1fba229e25a.jpg)

# %% [markdown]
# 其實股市中的歷史都一在的重演，而且是有跡可循的，這次你沒有逃過沒關係，記取教訓，下一次你就知道了，有興趣的同學可以回顧一下兩週前的解盤內容，體會會很深刻。
# https://www.youtube.com/watch?si=kCcbL4CXS0WzT5vs&v=aMo1sCHQDJY&feature=youtu.be

# %% [markdown]
# 今晚K線追擊週報數位訂閱主題：台股急跌趕底還是續跌？國安基金會出手嗎，有效嗎？
# https://smart.businessweekly.com.tw/e-subscription/project?c=GROUP00014146&p=PROD000019311

# %% [markdown]
# 今日影音已上架💫
# 台股急跌趕底還是續跌？國安基金會出手？有效嗎？
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3120

# %% [markdown]
# ### 本日進度
# * 驗證：StockChartPatterns類別
#   - 五個轉折點型態之判斷條件調整

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            # 驗證：型態最後一個轉折點離價格資料距離
            print('◆ 態最後一個轉折點離價格資料距離 ＝ {} '.format( date_to_index(prices,prices.iloc[-1].name) - date_to_index(prices,pattern_window.iloc[-1]['Date']) ))
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '上升旗形' or pattern_name == '下降旗形' or pattern_name == '看跌三角旗形' or pattern_name == '看漲三角旗形'  : 
                line1_start_date = pattern_window.iloc[1]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line1_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line2_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if pattern['type'] == '頭肩頂' or pattern['type'] == '雙頂' or pattern['type'] == '圓弧頂' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 20.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2016年11月11日到2017年1月3日之日線圖資料 #####

# 中繼圖形：上升旗型
# NOTE ： 資料來自「型態理論」講義

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2492_250224.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
# NOTE : 對照2025年2月25日筆記
patterns = chart_pattern.Recognition(turning_point_args={'mode':'open_close', 'order':5})
patterns = {'上升旗形':patterns['上升旗形']}
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}]
# ＃＃＃ 上升旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 5}
# ★ 型態資訊 ＝
#                  Date  Price Type
# DateIndex
# 12        2016-10-27  40.45   HI
# 21        2016-11-09  33.50   LO
# 35        2016-11-29  36.30   HI
# 39        2016-12-05  34.60   LO
# 46        2016-12-14  37.10   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 13

# %%
##### 使用2017年11月1日到2018年1月24日之日線圖資料 #####

# 中繼圖形：下降旗型
# NOTE ： 資料來自「型態理論」講義之「軟體操作」

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2353_250224.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
# NOTE : 對照2025年2月25日筆記
patterns = chart_pattern.Recognition(turning_point_args={'mode':'high_low', 'order':2})
patterns = {'下降旗形':patterns['下降旗形']}
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'high_low', 'order': 2}]
# ＃＃＃ 下降旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'high_low', 'order': 2}
# ★ 型態資訊 ＝
#                  Date  Price Type
# DateIndex
# 1         2017-11-02  15.50   LO
# 15        2017-11-22  22.15   HI
# 19        2017-11-28  20.40   LO
# 21        2017-11-30  21.15   HI
# 27        2017-12-08  19.40   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 32

# %%
##### 使用2023年8月2日到今日(2025年4月9日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250409.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 區間價格範圍（前幾天驗證之開始日期）
range_prices = df_k_line['2024-07-22':]

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(range_prices,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(range_prices,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 8         2024-08-05  19830.88   LO
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 56
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# 117       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 52
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 8         2024-08-05  19830.88   LO
# 58        2024-10-18  23620.57   HI
# 87        2024-11-29  22202.28   LO
# 113       2025-01-07  23824.72   HI
# 117       2025-01-13  22488.33   LO
# 139       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 30

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(range_prices,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-09-23 ， 型態結束日期 ＝ 2025-03-06

# %%
# 區間價格範圍（年線扣抵之開始日期）
range_prices = df_k_line['2024-04-11':]

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(range_prices,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(range_prices,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 78        2024-08-05  19830.88   LO
# 128       2024-10-18  23620.57   HI
# 157       2024-11-29  22202.28   LO
# 183       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 56
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 128       2024-10-18  23620.57   HI
# 157       2024-11-29  22202.28   LO
# 183       2025-01-07  23824.72   HI
# 187       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 52
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 78        2024-08-05  19830.88   LO
# 128       2024-10-18  23620.57   HI
# 157       2024-11-29  22202.28   LO
# 183       2025-01-07  23824.72   HI
# 187       2025-01-13  22488.33   LO
# 209       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 30

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(range_prices,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-06-12 ， 型態結束日期 ＝ 2025-03-26

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 244       2024-08-05  19830.88   LO
# 294       2024-10-18  23620.57   HI
# 323       2024-11-29  22202.28   LO
# 349       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 56
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 294       2024-10-18  23620.57   HI
# 323       2024-11-29  22202.28   LO
# 349       2025-01-07  23824.72   HI
# 353       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 52
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 244       2024-08-05  19830.88   LO
# 294       2024-10-18  23620.57   HI
# 323       2024-11-29  22202.28   LO
# 349       2025-01-07  23824.72   HI
# 353       2025-01-13  22488.33   LO
# 375       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 30

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-04-15 ， 型態結束日期 ＝ 2025-03-09
