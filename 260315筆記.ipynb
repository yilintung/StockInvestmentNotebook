# %% [markdown]
# ### 工作進度
# * 股票投資筆記Jupyter Notebook架構：
#   - 第一部分：**工作進度**
#     * 執行日常程序：
#       - 引入模組與定義公用函式。
#       - 更新量化技術分析資料庫。
#       - 建立「解盤」物件。
#     * 「量化技術分析系統」程式碼修改紀錄。
#     * 日常程序以外之相關工作項目。
#   - 第二部分：**大盤解盤**
#     * 『加權指數』與『櫃買指數』。
#     * 解盤程序：
#       - 執行mysys.StockAnalysis類別的analysis方法。
#       - （可選）補充股票老師在LINE[公開群組](https://www.facebook.com/kevinyang20180801/posts/pfbid033xPc3Fx3a5pEZHp8XQMvKR5JU2kMC1XrhE9AKiMfuVLenvsqjF9Y4iPskXZmm4MDl)中所提到之盤前或盤中資訊，並將手繪的趨勢線使用mysys.DrawOnKlineChart函式進行量化。
#   - 第三部分：**個股篩選**
#     * 選股來源：
#       - 老師觀察股 ： [K線追擊週報](https://smart.businessweekly.com.tw/e-subscription/project?c=GROUP00014146&p=PROD000019311)LINE群組。
#       - 自選觀察股 ： 執行mysys.StockAnalysis類別的screener方法。
#     * 從選股來源中選出符合條件之個股後，以列表方式呈現篩選結果：
#       - 基本資料：股票代號與股票名稱。
#       - 當日狀態：強勢多頭、穩健續漲、技術突破、多頭回檔、盤整觀察或已到目標價／壓力區。
#       - 圖表型態：（可選）在看盤軟體[新好神通](https://www.sinotrade.com.tw/newweb/trading-platform/SINOAP_NEW/?category=%E9%9B%BB%E8%85%A6%E7%89%88AP%E4%B8%8B%E5%96%AE&categoryCode=AP)上標註型態或繪製趨勢線之圖表（Ｋ線圖）。
#     * 將篩選結果列入看盤軟體[新好神通](https://www.sinotrade.com.tw/newweb/trading-platform/SINOAP_NEW/?category=%E9%9B%BB%E8%85%A6%E7%89%88AP%E4%B8%8B%E5%96%AE&categoryCode=AP)的《自選六》清單中。
#   - 第四部分：**個股解盤**
#     * 個股來源：
#       從看盤軟體[新好神通](https://www.sinotrade.com.tw/newweb/trading-platform/SINOAP_NEW/?category=%E9%9B%BB%E8%85%A6%E7%89%88AP%E4%B8%8B%E5%96%AE&categoryCode=AP)的《自選六》清單中挑選合適標的以進一步解盤。
#     * 解盤程序：
#       - 執行mysys.StockAnalysis類別的analysis方法。
#       - 在量化與ＡＩ分析結果中加入個人觀點。
#       - 將手繪的趨勢線進行量化，使用mysys.DrawOnKlineChart函式。
#       - 補充「籌碼面」資訊。
# * **個股篩選**中篩選結果之【當日狀態】，可參照以下表格：
#   ![260314_1.png](attachment:b7bb2985-c101-4eeb-a722-a115def7c15a.png)
# * 「量化技術分析系統」架構：
#    - 『解盤』的架構是依據「[專買黑馬股3：K線捕手楊忠憲教你用1張表逮飆股](https://www.books.com.tw/products/0011010836)」第三章的內容。但技術分析工具並不是照單全收而是做了挑選：解盤的前半段都是使用了量化技術分析工具為之（詳情後述），後半段【整體評價】則是使用人工智慧（[多模態模型](https://zh.wikipedia.org/zh-tw/%E5%A4%9A%E6%A8%A1%E6%80%81%E5%AD%A6%E4%B9%A0#%E5%A4%9A%E6%A8%A1%E6%80%81%E5%A4%A7%E8%AF%AD%E8%A8%80%E6%A8%A1%E5%9E%8B)）來產生分析結論：
#       ![251105_1.png](attachment:2b576450-c531-43f4-93dd-29fd8b739743.png)
#    - 各項量化技術分析工具分別說明於下：
#      * Ｋ線／Ｋ棒
#        使用[talib](https://github.com/TA-Lib/ta-lib-python)進行Ｋ線型態識別（[Pattern Recognition](https://github.com/TA-Lib/ta-lib-python?tab=readme-ov-file#pattern-recognition)）。
#      * Ｋ線圖
#        進行中期與長期的「[量化位階評價](https://vocus.cc/article/62ada936fd89780001fe6208)」。
#      * 成交量
#        價量關係（大量、爆量、天量），參照【價量關係_230317_筆記.pptx】。
#      * 型態
#        參照[TradingView](https://tw.tradingview.com/)的[圖表型態](https://tw.tradingview.com/support/solutions/43000706927/)。另外整合底型反轉交易策略的機制，參照【第一堂課-底型反轉_240809_筆記.pptx】。
#      * 移動平均線
#        參照「[專買黑馬股3：K線捕手楊忠憲教你用1張表逮飆股](https://www.books.com.tw/products/0011010836)」第三章 第89頁 表5。
#      * ＫＤ指標
#        判斷黃金交叉、死亡交叉、超買與超賣，確認短期多空。
#      * ＭＡＣＤ指標
#        中期多空判斷。
#      * 周Ｋ－周ＫＤ指標
#        判斷黃金交叉、死亡交叉、超買與超賣，確認中期多空。
#    - 整體評價
#      給出中期圖表(chart)，讓[GPT-5.2](https://platform.openai.com/docs/models/gpt-5.2)模型進行分析：
#      ![251105_2.png](attachment:b941f825-0533-4acc-bf5e-a56bc34e8b43.png)
# * 「股票投資筆記」Python程式語言環境之建立方式
#   - 製作[Miniforge](https://github.com/conda-forge/miniforge)免安裝版：
#     `start /wait "" Miniforge3-Windows-x86_64.exe /S /InstallationType=JustMe /AddToPath=0 /RegisterPython=0 /NoRegistry=1`
#   - 建立虛擬環境：
#     `conda create --name StockNotes python=3.10`
#     `conda activate StockNotes`
#
#     `conda install -c conda-forge jupyterlab --yes`
#     `conda install -c conda-forge numpy scipy --yes`
#     `conda install -c conda-forge matplotlib mplfinance --yes`
#     `conda install -c conda-forge ta-lib --yes`
#     `conda install -c conda-forge python-dotenv --yes`
#     `conda install -c conda-forge python-graphviz --yes`
#     `pip install openai`
#     `pip install openai-agents`
#     `pip install openpyxl`
#     `pip install Markdown`
#     `pip install tabulate`
#     `pip install markdown-grid-tables`
#     `pip install FinMind`
#
#     `conda env export --name StockNotes --format=environment-yaml --file StockNotes.yml`
# * 籌碼分析資訊整理
#   - 籌碼面大部分的資訊來自[三竹股市電腦版](https://marketing.mitake.com.tw/apstock/)：
#     ![251105_4.png](attachment:cbbb13ff-96e3-48ff-a9db-62c21f891796.png)
#   - 「分公司買賣家數差」則來自[嘉實系統](https://www.sysjust.com.tw/Products/XQ.aspx)：
#     ![251105_5.png](attachment:dc98d2c1-6803-4a45-bca2-a90198015ffd.png)
#     『買賣家數』與『買賣家數差』在不同看盤軟體中有不同的定義，參照[黑馬股２](https://www.books.com.tw/products/0010929705)第50頁。相關定義參考：
#     ![251105_6.png](attachment:e76d6708-c8fd-4cd8-a734-88f1bd81cf95.png)
#     官方([XQ](https://www.xq.com.tw/))的說明如下：
#   - [ChatGPT 開發手冊 Turbo×Vision 進化版：用 OpenAI Chat/Assistants API‧Function calling 設計 GPTs action‧LINE/Discord bot‧股市分析/自動助理](https://www.books.com.tw/products/0010978530)（[F4762 服務專區](https://www.flag.com.tw/bk/t/f4762)）
#   - [問ChatGPT也不會的Python量化交易聖經：從分析到真實交易一本全會](https://www.books.com.tw/products/0011016236)（[GitHub](https://github.com/ZJHuang915/PythonQuantTrading)）
#   - [Python：量化交易Ta-Lib技術指標139個活用技巧](https://www.books.com.tw/products/0010933669)（[範例程式下載](https://drive.google.com/drive/folders/1vx1tIUAeJeqBCVza4WlzRyggght6KnU-)）
#   - [OpenAI API 開發手冊 - 用 Responses API、Realtime API、MCP、Agents SDK、Function calling 打造即時語音、RAG、Agent 應用](https://www.books.com.tw/products/0011024362) （[《OpenAI API 開發手冊》服務專區](https://www.flag.com.tw/bk/t/f5762)）
#   - [LangGraph實戰開發AI Agent全攻略：掌握AI模型 × 工作流程 × 設計應用，從零打造智慧分工多代理協作系統（iThome鐵人賽系列書）](https://www.books.com.tw/products/0011030699)（[範例程式](https://github.com/Heng-xiu/LangGraph-Practical-Guide-to-Developing-AI-Agents)）
#   - [Python 大數據專案 X 工程 X 產品 資料工程師的升級攻略(第三版)](https://www.books.com.tw/products/0011045068)
# * 參考資訊（外部鏈結）
#   - 講義與筆記：
#     * [02. 投資課程筆記](https://mega.nz/folder/Y6JTUb5a#HqVnfdt2JJF8KyvLSkYrYg)
#     * [03. 史塔克財金工作室講義](https://mega.nz/folder/g2gkSIJa#Vom1AC3FBXqJgTip4_YDlQ)
#     * [04. 史塔克財金工作室–單一K線](https://mega.nz/folder/xnYl0CCB#Q2q_UdNgan__rhQRX0_7kw)
#     * [07. 史塔克財金工作室–多根K線](https://mega.nz/folder/hvZQ1LSC#rcA0x_DgXGMKMNsKCj0NFg)
#   - iThome鐵人賽2023「用Python程式進行股票技術分析」
#     * [原「萌王莉姆露」帳號相關資訊整理](https://ithelp.ithome.com.tw/articles/10341067)

# %% [markdown]
# ### 驗證 **量化技術分析系統**

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 建立「解盤」物件

# %%
# 開啟除錯模式(debug=True)進行驗證
analysis = mysys.StockAnalysis(debug=True)

# %% [markdown]
# * 驗證：加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# ＤＥＢＵＧ ： 日Ｋ開始日期 ＝ 2024-03-11 ，日Ｋ結束日期 ＝ 2026-03-15 ， 週Ｋ開始日期 ＝ 2024-03-11 ， 週Ｋ結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'close', 'order': 10, 'smoothing': 3}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 35）
# ＤＥＢＵＧ ： 此轉折高點與底部型態之前高點間不足１５％空間，結束底部型態確認。此轉折點 ＝
# Date     2025-05-16 00:00:00
# Price               21843.69
# Type                      HI
# Name: 159, dtype: object
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 133 （日期 ＝ 2025-04-09 ） ， 底部型態結束索引 ＝ 144 （日期 ＝ 2025-04-24 ）
# ＤＥＢＵＧ ： 趨勢線開始索引 ＝ 0（價格資料開始索引 ＝ 133），趨勢線結束索引 ＝ 11（價格資料結束索引 ＝ 144）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 144 ～ 164
# ＤＥＢＵＧ ： 確認底部型態突破，收盤價超過頸線３％。價格索引 ＝ 149 ， 日期 ＝ 2025-05-02 ， 突破時頸線價格 ＝ 19758.63元
# ＤＥＢＵＧ ： 底部最低價格 ＝ 17391.76元 ； 估算目標價 ＝ 22257.56元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 18 ，結束索引 ＝ 35）
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 19）
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 17）
# ＤＥＢＵＧ ： ◆ 找到的底部型態太靠前 ： 頸線結束日期 ＝ 2025-05-02 （索引 ＝ 149）， 價格資料的最後一個索引 ＝ 359
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'high_low', 'order': 5}, {'mode': 'open_close', 'order': 5}, {'mode': 'close', 'order': 10, 'smoothing': 3}, {'mode': 'close', 'order': 10, 'smoothing': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'open_close', 'order': 20}]
# ＤＥＢＵＧ ： 由轉折點識別之可能型態列表 ：
# [['上升楔形', {'mode': 'open_close', 'order': 5},                 Date     Price Type
# DateIndex
# 308       2025-12-18  27447.45   LO
# 336       2026-01-29  32828.02   HI
# 338       2026-02-02  31624.03   LO
# 349       2026-02-26  35457.76   HI], ['上升楔形', {'mode': 'high_low', 'order': 5},                 Date     Price Type
# DateIndex
# 234       2025-09-01  23885.41   LO
# 276       2025-11-04  28554.61   HI
# 289       2025-11-21  26395.98   LO
# 303       2025-12-11  28568.02   HI], ['矩形', {'mode': 'high_low', 'order': 5},                 Date     Price Type
# DateIndex
# 225       2025-08-19  24551.42   HI
# 226       2025-08-20  23620.24   LO
# 233       2025-08-29  24570.15   HI
# 234       2025-09-01  23885.41   LO], ['矩形', {'mode': 'high_low', 'order': 5},                 Date     Price Type
# DateIndex
# 77        2025-01-07  23943.95   HI
# 81        2025-01-13  22458.22   LO
# 88        2025-01-22  23642.08   HI
# 89        2025-02-03  22502.20   LO], ['矩形', {'mode': 'high_low', 'order': 5},                 Date     Price Type
# DateIndex
# 22        2024-10-18  23713.70   HI
# 31        2024-11-01  22231.94   LO
# 36        2024-11-08  23699.70   HI
# 51        2024-11-29  22055.38   LO]]
# ＤＥＢＵＧ ：   ╳ 無效的楔形型態！
# ＤＥＢＵＧ ：   ╳ 無效的楔形型態！
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-09-08 （索引 ＝ 239）， 價格資料的最後一個索引 ＝ 359
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-03-11 （索引 ＝ 114）， 價格資料的最後一個索引 ＝ 359
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-01-07 （索引 ＝ 77）， 價格資料的最後一個索引 ＝ 359
# ＤＥＢＵＧ ： 週K線範圍 ： 開始日期 ＝ 2025-12-08 ， 結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： ○ 系統提示詞（System Prompt） ＝
# 你是一位具備專業技術分析能力的股市分析師，請依據使用者提供的技術分析圖表進行結構化技術分析；圖表包含：主圖K線（紅K=收高於開、黑K=收低於開），其價格資料於參考資料中分別對應Open（開盤價）、High（最高價）、Low（最低價）、Close（收盤價）；並搭配四條移動平均線（棕色=5日線，代表短期趨勢，在參考資料中對應SMA5；天藍色=10日線，代表短期趨勢，在參考資料中對應SMA10；紫色=20日線，代表中期趨勢，在參考資料中對應SMA20；橙色=60日線，代表中期趨勢，在參考資料中對應SMA60），子圖一為成交量柱（顏色與K線同步，在參考資料中對應Volume），子圖二為KD指標（紅線=K線，在參考資料中對應slowk、藍線=D
"2026-03-12":49.43,"2026-03-13":55.9},"slowd":{"2026-03-09":28.06,"2026-03-10":24.13,"2026-03-11":28.33,"2026-03-12":36.69,"2026-03-13":47.2}}，但回覆時請勿提及）、MACD 指標解讀（必要時可參考最近五個交易日 MACD 資料：{"macd":{"2026-03-09":617.47,"2026-03-10":516.05,"2026-03-11":537.79,"2026-03-12":506.22,"2026-03-13":461.24},"macdsignal":{"2026-03-09":870.94,"2026-03-10":799.96,"2026-03-11":747.53,"2026-03-12":699.27,"2026-03-13":651.66},"macdhist":{"2026-03-09":-253.47,"2026-03-10":-283.91,"2026-03-11":-209.74,"2026-03-12":-193.04,"2026-03-13":-190.42}}，但回覆時請勿提及），並綜合上述分析給出整體評價。若支撐與壓力項目輸出中出現未附單位之價格數值，請自行修正後再輸出。
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x482>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-10 , 2026-03-13<br />
# 鎚子線／吊人線 : 2026-03-09<br />
# 孕育線／懷抱線 : 2026-03-12</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 7526.83億元 ，十日均量 ＝ 8502.29億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>（未識別出價格型態）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線下彎，短期翻空；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02當週死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體仍屬上漲趨勢中的高檔回檔：中期均線（20日、60日）維持上行，但短期價格自前高回落後，近幾日於約33,000點上方震盪整理。短期均線（5日、10日）走勢偏下，顯示短線修正尚未完全結束。<br />
# <br />
#  價量關係<br />
# 近期反彈與震盪過程中，成交量未見明顯放大，屬於量能跟進不足的整理型態。先前上攻至高檔時量能較活躍，但回檔後量能轉為收斂，短線偏向以時間換取空間。<br />
# <br />
#  支撐與壓力<br />
# - 支撐：約33,000點（近期低點區與短線震盪帶），跌破則下看約32,000點（60日線附近的中期支撐帶）。<br />
# - 壓力：約33,550–33,600點（10日線附近），再上方為約34,200點（近期反彈高點區），屬短線較明確的壓力區。<br />
# <br />
#  KD 指標解讀<br />
# KD自低檔回升，K線位於D線之上且同步走揚，顯示短線反彈動能仍在延續。但目前尚未進入超買區，屬於反彈修復階段，後續需觀察是否能在中高檔維持鈍化以支撐續攻。<br />
# <br />
#  MACD 指標解讀<br />
# DIF位於MACD線下方，且兩線整體仍偏下行，代表中短線動能仍偏弱、修正格局未完全扭轉。不過柱狀體雖在零軸下方，但負值縮小，顯示下跌動能有收斂跡象，偏向醞釀止跌回穩。<br />
# <br />
#  綜合評價<br />
# 目前屬中期偏多、短線整理偏弱：若能守住33,000點並帶量站回33,550–33,600點之上，短線有機會延伸反彈挑戰34,200點壓力。反之若跌破33,000點，回檔壓力將加大，較可能回測32,000點附近的中期支撐帶。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 驗證：櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# ＤＥＢＵＧ ： 日Ｋ開始日期 ＝ 2024-03-11 ，日Ｋ結束日期 ＝ 2026-03-15 ， 週Ｋ開始日期 ＝ 2024-03-11 ， 週Ｋ結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'close', 'order': 10, 'smoothing': 3}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 35）
# ＤＥＢＵＧ ： 此轉折高點與底部型態之前高點間不足１５％空間，結束底部型態確認。此轉折點 ＝
# Date     2025-05-15 00:00:00
# Price                 231.51
# Type                      HI
# Name: 158, dtype: object
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 133 （日期 ＝ 2025-04-09 ） ， 底部型態結束索引 ＝ 144 （日期 ＝ 2025-04-24 ）
# ＤＥＢＵＧ ： 趨勢線開始索引 ＝ 0（價格資料開始索引 ＝ 133），趨勢線結束索引 ＝ 11（價格資料結束索引 ＝ 144）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 144 ～ 164
# ＤＥＢＵＧ ： 確認底部型態突破，收盤價超過頸線３％。價格索引 ＝ 149 ， 日期 ＝ 2025-05-02 ， 突破時頸線價格 ＝ 216.44元
# ＤＥＢＵＧ ： 底部最低價格 ＝ 185.14元 ； 估算目標價 ＝ 247.79元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 16 ，結束索引 ＝ 35）
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 17）
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 15）
# ＤＥＢＵＧ ： ◆ 找到的底部型態太靠前 ： 頸線結束日期 ＝ 2025-05-02 （索引 ＝ 149）， 價格資料的最後一個索引 ＝ 359
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'high_low', 'order': 5}, {'mode': 'open_close', 'order': 5}, {'mode': 'close', 'order': 10, 'smoothing': 3}, {'mode': 'close', 'order': 10, 'smoothing': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'open_close', 'order': 20}]
# ＤＥＢＵＧ ： 由轉折點識別之可能型態列表 ：
# [['三重頂', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 306       2025-12-16  257.95   LO
# 336       2026-01-29  311.68   HI
# 342       2026-02-06  285.03   LO
# 351       2026-03-03  321.09   HI
# 355       2026-03-09  285.18   LO
# 358       2026-03-12  315.35   HI], ['上升楔形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 306       2025-12-16  257.95   LO
# 336       2026-01-29  311.68   HI
# 342       2026-02-06  285.03   LO
# 351       2026-03-03  321.09   HI], ['矩形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 250       2025-09-23  268.26   HI
# 253       2025-09-26  255.71   LO
# 260       2025-10-09  267.81   HI
# 262       2025-10-14  255.58   LO], ['矩形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 193       2025-07-04  235.36   HI
# 195       2025-07-08  226.44   LO
# 203       2025-07-18  237.59   HI
# 213       2025-08-01  228.40   LO], ['矩形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 158       2025-05-15  232.09   HI
# 169       2025-06-02  221.29   LO
# 177       2025-06-12  235.52   HI
# 184       2025-06-23  222.48   LO], ['矩形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 47        2024-11-25  262.48   HI
# 50        2024-11-28  250.46   LO
# 55        2024-12-05  264.25   HI
# 62        2024-12-16  250.10   LO], ['下降楔形', {'mode': 'high_low', 'order': 5},                 Date   Price Type
# DateIndex
# 36        2024-11-08  269.55   HI
# 42        2024-11-18  251.78   LO
# 47        2024-11-25  262.48   HI
# 50        2024-11-28  250.46   LO]]
# ＤＥＢＵＧ ： 週K線範圍 ： 開始日期 ＝ 2025-12-08 ， 結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： ○ 系統提示詞（System Prompt） ＝
# 你是一位具備專業技術分析能力的股市分析師，請依據使用者提供的技術分析圖表進行結構化技術分析；圖表包含：主圖K線（紅K=收高於開、黑K=收低於開），其價格資料於參考資料中分別對應Open（開盤價）、High（最高價）、Low（最低價）、Close（收盤價）；並搭配四條移動平均線（棕色=5日線，代表短期趨勢，在參考資料中對應SMA5；天藍色=10日線，代表短期趨勢，在參考資料中對應SMA10；紫色=20日線，代表中期趨勢，在參考資料中對應SMA20；橙色=60日線，代表中期趨勢，在參考資料中對應SMA60），子圖一為成交量柱（顏色與K線同步，在參考資料中對應Volume），子圖二為KD指標（紅線=K線，在參考資料中對應slowk、藍線=D線，在參考資料中對應slowd、綠色虛線標
-12":43.7,"2026-03-13":58.16}}，但回覆時請勿提及）、MACD 指標解讀（必要時可參考最近五個交易日 MACD 資料：{"macd":{"2026-03-09":2.92,"2026-03-10":2.32,"2026-03-11":2.93,"2026-03-12":3.39,"2026-03-13":3.81},"macdsignal":{"2026-03-09":4.94,"2026-03-10":4.41,"2026-03-11":4.12,"2026-03-12":3.97,"2026-03-13":3.94},"macdhist":{"2026-03-09":-2.01,"2026-03-10":-2.09,"2026-03-11":-1.19,"2026-03-12":-0.58,"2026-03-13":-0.13}}，但回覆時請勿提及），並綜合上述分析給出整體評價。若支撐與壓力項目輸出中出現未附單位之價格數值，請自行修正後再輸出。
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-12<br />
# 十字線 : 2026-03-12<br />
# 鎚子線／吊人線 : 2026-03-13<br />
# 吞噬 : 2026-03-13<br />
# 高檔夜星 : 2026-03-09</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1418.39億元 ，十日均量 ＝ 1577.19億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2026-01-12開始到2026-03-13結束，估算目標價為249.27點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線下彎，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-11黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-02-23當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體仍屬上漲趨勢，近期自低點快速反彈並回到短中期均線之上，收盤連續站穩在約310點附近。短期均線走揚並貼近價格，顯示多方仍掌握節奏，但上方前高區壓力使走勢轉為高檔震盪偏多。<br />
# <br />
#  價量關係<br />
# 反彈過程中成交量有放大，屬於價漲量增的偏多結構，有利於延續反彈動能。惟近一兩日量能略有降溫，代表追價力道稍收斂，短線可能以整理換手為主。<br />
# <br />
#  支撐與壓力<br />
# - 支撐：第一支撐看約305點（短期均線與近期整理區），跌破則看約300點（整數關卡與短中期均線匯聚帶）。再下方較關鍵支撐在約289點（中期均線附近）。<br />
# - 壓力：上方主要壓力落在約315點（近期高點區），若帶量突破，下一道壓力看約320點（前高與整數關卡）。<br />
# <br />
#  KD 指標解讀<br />
# KD 目前位於偏高區並持續上行，K線在D線之上，短線動能偏多。尚未明顯進入超買鈍化，但若接近80以上後出現轉折，需提防高檔拉回。<br />
# <br />
#  MACD 指標解讀<br />
# DIF 仍在 MACD 線下方，但兩者距離明顯收斂，且柱狀體由負值持續縮短，顯示空方動能減弱、反彈趨勢延續。若後續 DIF 能上穿 MACD 線並帶動柱狀體翻正，將更有利於多方續攻。<br />
# <br />
#  綜合評價<br />
# 目前屬上漲趨勢中的高檔震盪偏多：均線結構偏多、動能指標同步改善，但上方315～320點壓力仍需以量能確認突破。操作上可關注305點防守是否有效；若守穩且量能回升，偏向續攻，反之跌破305點則短線轉為回檔整理風險升高。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 驗證：大成(1210)
#   - 因為「[股票技術型態識別](https://github.com/yilintung/StockInvestmentNotebook/blob/main/mysys/StockChartPatterns.py)」類別中的「底部型態識別方法」無法正確識別這檔目前之底部型態，所以只能依賴人工方式來繪製該底部型態（參照[Utilities.py](https://github.com/yilintung/StockInvestmentNotebook/blob/main/mysys/Utilities.py)的DrawOnKlineChart函式）。

# %%
stock_analysis(analysis,'1210')
# Out:
# ＤＥＢＵＧ ： 日Ｋ開始日期 ＝ 2024-03-11 ，日Ｋ結束日期 ＝ 2026-03-15 ， 週Ｋ開始日期 ＝ 2024-03-11 ， 週Ｋ結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'close', 'order': 10, 'smoothing': 3}]
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 15）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 287 （日期 ＝ 2025-11-19 ） ， 底部型態結束索引 ＝ 347 （日期 ＝ 2026-02-24 ）
# ＤＥＢＵＧ ： 趨勢線開始索引 ＝ 0（價格資料開始索引 ＝ 287），趨勢線結束索引 ＝ 60（價格資料結束索引 ＝ 347）
# ＤＥＢＵＧ ： 頸線角度（絕對值）17.53°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 53.00）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 347 ～ 360
# ＤＥＢＵＧ ： 底部最低價格 ＝ 50.60元 ； 估算目標價 ＝ 55.40元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 8）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 287 （日期 ＝ 2025-11-19 ） ， 底部型態結束索引 ＝ 308 （日期 ＝ 2025-12-18 ）
# ＤＥＢＵＧ ： 趨勢線開始索引 ＝ 0（價格資料開始索引 ＝ 287），趨勢線結束索引 ＝ 21（價格資料結束索引 ＝ 308）
# ＤＥＢＵＧ ： 頸線角度（絕對值）17.16°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 53.00）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 308 ～ 328
# ＤＥＢＵＧ ： 底部最低價格 ＝ 50.60元 ； 估算目標價 ＝ 55.40元
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始索引 ＝ 0 ，結束索引 ＝ 13）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 288 （日期 ＝ 2025-11-20 ） ， 底部型態結束索引 ＝ 357 （日期 ＝ 2026-03-11 ）
# ＤＥＢＵＧ ： 趨勢線開始索引 ＝ 0（價格資料開始索引 ＝ 288），趨勢線結束索引 ＝ 69（價格資料結束索引 ＝ 357）
# ＤＥＢＵＧ ： 頸線角度（絕對值）18.94°過大，改用直線頸線（斜率 ＝ 0.00，截距 ＝ 52.70）
# ＤＥＢＵＧ ： 底部型態突破確認範圍 ： 357 ～ 360
# ＤＥＢＵＧ ： 底部最低價格 ＝ 50.40元 ； 估算目標價 ＝ 55.00元
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'high_low', 'order': 5}, {'mode': 'open_close', 'order': 5}, {'mode': 'close', 'order': 10, 'smoothing': 3}, {'mode': 'close', 'order': 10, 'smoothing': 5}, {'mode': 'open_close', 'order': 10}, {'mode': 'open_close', 'order': 20}]
# ＤＥＢＵＧ ： 由轉折點識別之可能型態列表 ：
# [['上升楔形', {'mode': 'close', 'order': 10, 'smoothing': 3},                 Date  Price Type
# DateIndex
# 132       2025-04-08   55.3   LO
# 166       2025-05-27   65.6   HI
# 183       2025-06-20   60.1   LO
# 192       2025-07-03   66.0   HI], ['上升楔形', {'mode': 'open_close', 'order': 5},                 Date  Price Type
# DateIndex
# 66        2024-12-20   50.4   LO
# 104       2025-02-24   56.6   HI
# 109       2025-03-04   55.1   LO
# 129       2025-04-01   58.4   HI], ['上升楔形', {'mode': 'high_low', 'order': 5},                 Date  Price Type
# DateIndex
# 66        2024-12-20   50.4   LO
# 104       2025-02-24   56.7   HI
# 116       2025-03-13   55.1   LO
# 124       2025-03-25   58.5   HI]]
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-07-21 （索引 ＝ 204）， 價格資料的最後一個索引 ＝ 246
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-04-07 （索引 ＝ 131）， 價格資料的最後一個索引 ＝ 246
# ＤＥＢＵＧ ： ◇ 從轉折點找到的型態太靠前 ： 頸線／趨勢線結束日期 ＝ 2025-04-07 （索引 ＝ 131）， 價格資料的最後一個索引 ＝ 246
# ＤＥＢＵＧ ： ＭＡＣＤ指標 － 中期多空不明 ： ＤＩＦ ＝ 0.2 ，ＭＡＣＤ ＝ -0.03
# ＤＥＢＵＧ ： 週K線範圍 ： 開始日期 ＝ 2025-12-08 ， 結束日期 ＝ 2026-03-09
# ＤＥＢＵＧ ： ○ 系統提示詞（System Prompt） ＝
# 你是一位具備專業技術分析能力的股市分析師，請依據使用者提供的技術分析圖表進行結構化技術分析；圖表包含：主圖K線（紅K=收高於開、黑K=收低於開），其價格資料於參考資料中分別對應Open（開盤價）、High（最高價）、Low（最低價）、Close（收盤價）；並搭配四條移動平均線（棕色=5日線，代表短期趨勢，在參考資料中對應SMA5；天藍色=10日線，代表短期趨勢，在參考資料中對應SMA10；紫色=20日線，代表中期趨勢，在參考資料中對應SMA20；橙色=60日線，代表中期趨勢，在參考資料中對應SMA60），子圖一為成交量柱（顏色與K線同步，在參考資料中對應Volume），子圖二為KD指標（紅線=K線，在參考資料中對應slowk、藍線=D線，在參考資料中對應slowd、綠色虛線標示超買>80與超賣<20），子圖三為MACD指標（紅線為DIF線，在參考資料中對應macd；藍線為MACD線，在參考資料中對應macdsignal；灰色柱狀體為OSC，在參考資料中對應macdhist），請於MACD解讀時以DIF與MACD線的相對位置、方向與柱狀體變化來判斷趨勢與動能，避免以快線或慢線作為描述方式，並避免將DIF或MACD線直接等同於快線或慢線；分析時請僅針對圖表所呈現的當前狀態進行判讀與結論整理，參考資料僅用於輔助確認相對位置與方向，不得直接引用其數值、日期或欄位名稱於輸出中，不需解釋指標計算方式、背景原理或一般性教學說明，避免使用泛化、推論型或教科書式語句；若輸出內容中出現日期，請統一使用「MM月DD日」格式（例如2月10日），不得使用MM/DD、YYYY-MM-DD或其他數字斜線格式；在支撐與壓力判斷上，若可合理判斷請務必給出具體價格或點位，若無明確依據請直接說明「尚未形成」，避免模糊描述；請將價格趨勢、價量關係、支撐與壓力、KD指標解讀、MACD指標解讀、綜合評價分段呈現，且每一段落請控制在2至3句以內；請使用專業且通順的繁體中文回覆，統一用詞：回調→回檔、止盈→停利、止損→停損，不需加入其他說明。
# ＤＥＢＵＧ ： ● 使用者提問詞（User Prompt） ＝
# 請依據下圖（圖中價格單位為：價格單位為元，成交量單位為張）進行技術分析，內容需包含：價格趨勢（上漲/盤整/下跌）、價量關係、支撐與壓力價格或點位（必要時可參考最近五個交易日的價格與移動平均線資料：{"Open":{"2026-03-09":50.4,"2026-03-10":51.5,"2026-03-11":51.5,"2026-03-12":52.3,"2026-03-13":52.9},"High":{"2026-03-09":51.6,"2026-03-10":51.8,"2026-03-11":52.1,"2026-03-12":53.7,"2026-03-13":53.4},"Low":{"2026-03-09":50.4,"2026-03-10":51.2,"2026-03-11":51.5,"2026-03-12":52.3,"2026-03-13":52.7},"Close":{"2026-03-09":51.3,"2026-03-10":51.4,"2026-03-11":51.7,"2026-03-12":52.9,"2026-03-13":52.9},"Volume":{"2026-03-09":2481,"2026-03-10":1285,"2026-03-11":2118,"2026-03-12":4588,"2026-03-13":2324},"SMA5":{"2026-03-09":50.92,"2026-03-10":50.96,"2026-03-11":51.22,"2026-03-12":51.72,"2026-03-13":52.04},"SMA10":{"2026-03-09":51.09,"2026-03-10":51.07,"2026-03-11":51.11,"2026-03-12":51.29,"2026-03-13":51.49},"SMA20":{"2026-03-09":51.06,"2026-03-10":51.04,"2026-03-11":51.08,"2026-03-12":51.19,"2026-03-13":51.3},"SMA60":{"2026-03-09":51.44,"2026-03-10":51.41,"2026-03-11":51.4,"2026-03-12":51.41,"2026-03-13":51.42},"SMA120":{"2026-03-09":51.94,"2026-03-10":51.93,"2026-03-11":51.91,"2026-03-12":51.91,"2026-03-13":51.91},"SMA240":{"2026-03-09":55.95,"2026-03-10":55.93,"2026-03-11":55.91,"2026-03-12":55.89,"2026-03-13":55.87}}，但回覆時請勿提及）、KD 指標解讀（必要時可參考最近五個交易日 KD 資料：{"slowk":{"2026-03-09":41.94,"2026-03-10":66.94,"2026-03-11":72.88,"2026-03-12":77.03,"2026-03-13":77.74},"slowd":{"2026-03-09":25.95,"2026-03-10":43.08,"2026-03-11":60.59,"2026-03-12":72.28,"2026-03-13":75.89}}，但回覆時請勿提及）、MACD 指標解讀（必要時可參考最近五個交易日 MACD 資料：{"macd":{"2026-03-09":-0.14,"2026-03-10":-0.1,"2026-03-11":-0.05,"2026-03-12":0.09,"2026-03-13":0.2},"macdsignal":{"2026-03-09":-0.15,"2026-03-10":-0.14,"2026-03-11":-0.12,"2026-03-12":-0.08,"2026-03-13":-0.03},"macdhist":{"2026-03-09":0.02,"2026-03-10":0.04,"2026-03-11":0.08,"2026-03-12":0.17,"2026-03-13":0.22}}，但回覆時請勿提及），並綜合上述分析給出整體評價。若支撐與壓力項目輸出中出現未附單位之價格數值，請自行修正後再輸出。
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=827x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-03-10 , 2026-03-13<br />
# 十字線 : 2026-03-13<br />
# 孕育線／懷抱線 : 2026-03-13</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量大於十日均量，但未至大量門檻（成交量 ＝ 2324張 ，十日均量 ＝ 2129張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>尚未成形底型反轉之底部型態，型態範圍由2025-09-17開始到2026-03-13結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線走平、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-09黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>（中期多空不明）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-03-02當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前屬於上漲走勢，近幾日連續收高並站上短中期均線，短期均線上彎且呈多頭排列雛形。價格已回到前波整理區上緣，偏向續強結構。<br />
# <br />
#  價量關係<br />
# 上漲段出現放量推升，量能在突破與拉升時明顯放大，顯示追價動能有效。最新一日量能較前一日降溫但價格仍守高，屬於高檔量縮整理，偏多但需留意後續是否再放量續攻。<br />
# <br />
#  支撐與壓力<br />
# 支撐先看 52.0元（短期均線與近兩日整理帶），跌破則看 51.5元（10日附近）與 51.3元（20日附近）作為次支撐。壓力落在 53.4～53.7元（近期高點區），若帶量突破，則上方壓力屬於尚未形成。<br />
# <br />
#  KD指標解讀<br />
# K與D同步走高且維持在高檔區，顯示多方動能仍在延續。惟已接近超買帶，若出現高檔鈍化後轉折下彎，短線較容易進入回檔整理。<br />
# <br />
#  MACD指標解讀<br />
# DIF位於MACD線之上且兩者同步上行，柱狀體持續放大，代表上漲趨勢與動能正在增強。若後續柱狀體縮小或DIF走平，將是動能降溫、轉為整理的早期訊號。<br />
# <br />
#  綜合評價<br />
# 整體偏多，屬於突破後的強勢段，短線以 52.0元能否守穩作為多方續航關鍵。操作上偏向順勢，但因KD高檔，追價宜等待量能再度放大或回檔不破支撐後再行布局。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-07-09','2026-03-13',line_drawing_callback)
display(image)
# Out:
# 估算目標價為57.40元
# <PIL.Image.Image image mode=RGB size=857x479>
