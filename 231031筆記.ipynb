# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】狹幅震盪，中期偏空
# 加權指數昨天在平盤上下50點，K線收小十字線，單日狹幅區間整理，成交量萎縮至2188億，外資現貨續賣，而期貨未平倉空單12483口，有多日都維持在萬口上下，已經從避險空單轉為積極做空。櫃買指數雖然漲幅不大，不過表現相對穩定，一路上都維持在平盤之上，可惜成交量也是偏低，近期維持區間整理。
# 台幣收在平盤附近，中性表現。類股指數部分，生技醫療、電子通路、數位雲端有短多，其他族群仍偏空方或是弱勢盤整，符合加權指數和櫃買指數表現。歐美股市昨晚表現普遍偏多，夜盤指數也出現小漲，不過短中期都還是空方結構，所以單一日的上漲還是只能視為反彈
# 如果先前8月就已經開始陸續做預防性減碼，現在應該不至於太恐慌。最後想提醒的是，千萬不能在空頭找希望，這是很危險的，並不是說多方百分之百沒有機會，但關鍵還是要做甚麼交易，試單、加碼、買足、減碼、停利、停損，都要有完整的規畫，而不是每次一套牢，就天天期待會突然翻多。
# 其實如果將時間軸拉長一點，表面上台股8月才開始走弱，但其實6月就已經開始構築下降軌道，而10月底正式做頭，到現在空頭趨勢都還沒有改變。當然我知道持股比重高的投資人，還是希望能聽到一些好消息，但是真的要翻多，最保守的要求至少要站上16200，這只是最基本的條件，至於還需要哪些條件，等16200真的能有效站穩再做討論。 (出處：K線捕手楊忠憲粉絲團)
# ![396699000_831324229001506_7889072377373206276_n.jpg](attachment:a8084f8b-cbd5-4d71-bc32-f4346cc256b9.jpg)

# %% [markdown]
# [美元強壓 新台幣面臨32.5元保衛戰](https://readers.ctee.com.tw/cm/20231031/a01aa1/1265189/share)
#
# [美財部Q4發債 恐再擴大](https://readers.ctee.com.tw/cm/20231031/a01aa1/1265191/share)
#
# [三大指標強攻 台股整軍待發](https://readers.ctee.com.tw/cm/20231031/a02aa2/1265193/share)
#
# [避險熱絡 金價再飆破2,000美元](https://readers.ctee.com.tw/cm/20231031/a07aa7/1265217/share)
#
# [美儲蓄率、實質所得下滑 消費力恐轉疲](https://readers.ctee.com.tw/cm/20231031/a07aa7/1265220/share)
#
# [市場押注亞洲央行重啟升息 預期六個月內平均調高13個基點](https://money.udn.com/money/story/5599/7540362)

# %% [markdown]
# 榮剛(5009)
# ![messageImage_1698705026865.jpg](attachment:14e3fda2-28d6-451d-afa5-614a310d6261.jpg)
# ![messageImage_1698705053609.jpg](attachment:84f9c9d5-ecbd-49b8-ae8e-982fe59537e6.jpg)
# **問**：想請問老師，5009榮剛(空)，老師當時提到這檔比較複雜且會盤整比較久，想請教老師是如何判斷還會再盤整呢? 我原本推想季線已在正上方，應該反壓大會k線碰到後下跌。還是因為頭部面積很大，但三線已經糾結，可能會變成所有均線糾結後才會等到跌破嗎?感謝老師解惑!
# **答**：因為他第一階段跌幅滿足已經完成，進入橫盤整理，暫時無法評估第二段空間，還有究竟會盤多久，畢竟已經盤了6個月了。
#
# 晶相光(3530)
# ![messageImage_1698712394711.jpg](attachment:d9739536-a499-44bf-a88e-96a8394e49dc.jpg)

# %% [markdown]
# 日本開小低，持續回側頸線支撐：
# ![messageImage_1698708772377.jpg](attachment:238e4691-82ec-4fc1-aa16-3eef33950b57.jpg)
#
# 韓國平盤之上小漲：
# ![114390.jpg](attachment:5ada8cd3-2bed-43e4-a4d7-54eb77844b8e.jpg)
#
# 期貨開平盤之上小漲，尚未站上壓力區：
# ![messageImage_1698713120249.jpg](attachment:85a29a2a-1139-4706-998c-dd4abc23c97e.jpg)
#
# 加權指數小漲：
# ![messageImage_1698714090478.jpg](attachment:349c5bc8-b457-4e1e-a84c-0e91d8b88ff1.jpg)
#
# 櫃買指數小漲：
# ![messageImage_1698714116782.jpg](attachment:d4bad518-893a-43f8-85a7-f0e003224dbf.jpg)
#
# 預估量也在2000億左右，量能偏低
#
# 持續維持平盤之上小紅：
# ![228070.jpg](attachment:4caa83df-0bb2-4952-a03a-e903ba3b28d2.jpg)
# ![228071.jpg](attachment:1d884c06-c74c-460a-9f0b-d7a3ecb95158.jpg)
#
# 韓國跌落平盤之下，小創波段新低。
# ![228088.jpg](attachment:8d2402b4-145e-4bfd-9958-9dd5964283ac.jpg)
# ![228089.jpg](attachment:795d9b80-f5b7-41cc-b31b-d2e009300e5d.jpg)
#
# 技嘉(2376)
# ![228117.jpg](attachment:2cb50681-52fb-451a-b02e-e0e135739a0c.jpg)
#
# 剛剛加權指數和櫃買指數，同時滑落平盤之下。
# ![228123.jpg](attachment:510eeb17-bc15-441d-a3ca-ea641fe45423.jpg)
# ![228124.jpg](attachment:ec020ef1-8d53-4acc-9c69-2ad2f61f019b.jpg)
#
# 上課曾經教過，最弱勢的反彈型態就是橫盤，最短的反彈天數就是3-5天，基本上加權指數符合這個現象，只有3個交易日又再度破底。
# ![228176.jpg](attachment:ac075918-f5c2-4342-b156-0a96c68717ec.jpg)
#
# 盤中持續修正， 還沒有看到明顯支撐。
# ![114585.jpg](attachment:95dcc04b-5f00-4e51-b350-19bb6ea6ca5f.jpg)
# ![114586.jpg](attachment:9f3d18a3-0793-4f41-901a-d906145ade46.jpg)
#
# 櫃買指數也小創新低：
# ![228333.jpg](attachment:8ec617e9-e976-4f8f-8942-947ce86b3a6a.jpg)

# %% [markdown]
# 【[關於第四季的行情](https://www.facebook.com/kevinyang20180801/posts/pfbid0EpdVmEnNY7RdpfuPAf7Fjr68JeYJpFsMTuGhAnG9qMPe1mRG9m6nNJiGK3eZTU3pl)】
# 很多同學問到近期一直反覆看到的新聞，就是第四季會有選舉行情，以及過去第四季普遍都是上漲居多，選舉行情已經重複提到太多次，只說結論-現在就是選舉行情，有興趣的同學自己爬文，就不再贅述。
# 接著討論第四季普遍是上漲這件事情，過去10年的統計數字，確實有7次上漲、1次走平、2次下跌，只是如果稍微懂統計學的人，就知道統計學的精神是樣本數必須夠多，才能推演未來的機率。
# 比方過去發生過1000次，當中有800次都是會上漲，這樣才具備統計意義，能夠推演第1001次的發生的有效性，但是倘若樣本只有10次、20次，對於未來推斷的有效性，其實是沒有意義，即使過去10次第四季都是走多，也都還不足以支持第11次的走勢。
# 更何況如果將統計延伸到上一個10年(2003-2012年)，數據就會不一樣，會看到完全不同的樣貌，上漲的年度僅只有2003、2005、2009、2010，因此上漲的機率會下滑到剩下40%，那表徵意義就更小了。所以還是就線論線，10月份即將結束，就繼續觀察11月和12月的變化，靜待反轉訊號出現即可。

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * 追蹤：麗臺(2465)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2021年12月21日到今日收盤(2023年10月31日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2465_231031.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定頸線
neckline_price = df_k_line.loc['2022-11-08']['Open']
neckline_start_date = '2022-06-07'
neckline_end_date = '2023-10-31'

# 估算目標價
bottom_price_date = '2022-09-30'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
target_price = (neckline_price - bottom_price) + neckline_price
print('頸線價格 ＝ {:.2f} ； 目標價 ＝ {:.2f}元'.format(neckline_price,target_price))
target_price_date = '2023-10-11'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]


# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 43.10 ； 目標價 ＝ 62.45元

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 設定頸線
neckline_x_date = ['2022-11-08','2023-10-16']
neckline_x = [date_to_index(df_k_line,neckline_x_date[0]),date_to_index(df_k_line,neckline_x_date[1])]
neckline_y = [df_k_line.loc[neckline_x_date[0]]['Open'],df_k_line.loc[neckline_x_date[1]]['Close']]
slope,intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_date = '2022-06-07'
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_date = '2023-10-31'
neckline_end_price = slope * date_to_index(df_k_line,neckline_end_date) + intercept
print('頸線開始價格 ＝ {:.2f} ， 頸線結束價格 ＝ {:.2f}'.format(neckline_start_price,neckline_end_price))

# 估算目標價
bottom_price_date = '2022-09-30'
breakthrough_price_date = '2023-10-25'
bottom_price = df_k_line.loc[bottom_price_date]['Open']
on_neckline_price = slope * date_to_index(df_k_line,bottom_price_date) + intercept
breakthrough_price = slope * date_to_index(df_k_line,breakthrough_price_date) + intercept
print('頸線突破價格 ＝ {:.2f}元'.format(breakthrough_price))
target_price = (on_neckline_price - bottom_price) + breakthrough_price
print('目標價 ＝ {:.2f}元'.format(target_price))

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,on_neckline_price)],
    [(breakthrough_price_date,breakthrough_price),(breakthrough_price_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.4,color='xkcd:violet')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors=('xkcd:royal blue','xkcd:orange yellow','xkcd:orange yellow'), alpha=0.6))

mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線開始價格 ＝ 38.89 ， 頸線結束價格 ＝ 52.23
# 頸線突破價格 ＝ 52.07元
# 目標價 ＝ 70.41元
