# %% [markdown]
# ### 📢【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】美股大漲，台股有望跟進補漲！
#
# 在周日的影音解盤中，就明確規劃：「上半週持續修正，下半週止穩反彈有望！」結果就在市場最恐慌的時候，川普突襲宣布延後90天關稅政策，美股與夜盤期指飆漲1718點！ 🚀
#
# 🤔有同學又問我：「老師你是不是早知道川普會講這個？」
# 當然不是！可能連川普本人在宣布前都還沒決定好，但這正是技術分析的價值——不靠消息面，也能提前掌握轉折的「時間」與「空間」！📈✨
#
# 📉從2月底、3月初就提醒大家：該減碼、空手、甚至做空，我在數位訂閱中提醒：昨天的1068點下殺，是第二波修正的超跌與趕底，不是第三波起跌，所以不宜過度追空！
#
# 🧠操作策略提醒：
#
# ✅ 空手／低持股者：可用小資金試單搶反彈。
# ⚠️ 高檔一路套牢者：現在加碼只是在攤平，風險依舊。
# 🔄 反彈後將進入橫向震盪，時間會週為單位，多方獲得喘息，但趨勢尚未翻多，不宜過度樂觀！
#
# 🎯技術面早已給出提示，重點是你看不看得懂。
# 想知道第三波是否會來？關鍵看這波反彈能否改善多方結構，數位訂閱會有完整解析！
#
# 📘完整深度解析，請見「K線追擊周報」數位訂閱！
# 📤歡迎分享，請註明出處：K線捕手 楊忠憲粉絲團 🔥
# ![messageImage_1744241153523.jpg](attachment:e6d4dc5a-633d-44d8-b496-c01141d47028.jpg)

# %% [markdown]
# [川普宣布新關稅措施暫緩90天 對大陸稅率升至125% 美股狂飆](https://money.udn.com/money/story/5599/8664470?from=edn_related_storybottom)
#
# [關刀橫掃 上市櫃4月營收不妙](https://www.ctee.com.tw/news/20250410700110-430201?fbclid=IwY2xjawJj5ZBleHRuA2FlbQIxMAABHitZGUeCYe-MgeVEvm06QQYbHhyWJZkRFcYL4wqXzfZaheWnAgvem177Rbuh_aem_k7uFKIlNvH3XFre49uKuGw)
# 因應川普對等關稅戰，客戶提前積極拉貨奏效，截至9日晚間為止雖然還有761家上市櫃公司未發布3月營收，但有高達71家寫下歷史新高，大幅優於2月及去年同期創新高家數的33家及59家，產業高度集中在電子股。惟川普關稅正式實施，企業提前拉貨紅利結束且開始暫緩出貨，法人看淡4月及第二季營收。
#
# [上市融資維持率 創史上新低 超越金融海嘯](https://www.ctee.com.tw/news/20250409702111-430201?fbclid=IwY2xjawJj5btleHRuA2FlbQIxMAABHgqVvWKsq1lX18a2DTTu04leawr-N3yRvX2HJliCcVxTlehDs_8-ASwomSoa_aem_bCpk9umgPFXSt0ZI6L4KLA)
# 川普對等關稅引發的台股股災進入第3天，台股墜入萬丈深淵，統計至9日上市融資維持率掉到118.1％，創下歷史新低，超越2008年10月27日金融海嘯的118.2％，顯示仍有不少投資人並未即時補錢，再加上股票跌停，賣也賣不掉。
#
# [美股收盤／道瓊狂漲近3,000點史上最大 川普暫緩關稅引市場狂歡](https://money.udn.com/money/story/123398/8664581?from=edn_maintab_index&fbclid=IwY2xjawJj5dtleHRuA2FlbQIxMAABHhmEe2PDxtVOZC75-p6hxIY3urlYsnUYFPi2VOVzLvqVcDPtXKyFk9Jp9eOM_aem_wdE3AlOaHgqaWpn1pqdF9g)
# 美國股市標普 500 指數周三狂漲 9.5%，創下 2008 年來最大單日漲幅，美國總統川普宣布，原本對數十國9日生效的額外關稅暫緩 90 天生效，對中國大陸的關稅稅率則提高至125%，投資人歡聲雷動。
# 道瓊工業指數狂漲2,962.86點，漲幅7.9%，至40,608.45點，創下史上最大漲點；標普500指數大漲474.13點，或9.5%，至5,456.90點，創下自2008年10月全球金融危機以來最大單日漲幅。那斯達克綜合指數狂奔 1,857.06 點，漲幅 12.2%，至 17,124.97 點，創下 2001 年 1 月網路泡沬以來最大漲幅。
#
# [股民怕斷頭四處籌錢 銀行信貸業務 跳增三成](https://money.udn.com/money/story/5607/8664307?from=edn_newestlist_cate_side&fbclid=IwY2xjawJj5gVleHRuA2FlbQIxMAABHhFUb1vp_RLKLOXdxb84aagb41VEEKxPf7SZ4h84n8GjiKaj7aWmgicnmJi9_aem_Wr9qJO_Fm3MEwav48qJoiA)
# 川普宣布對等關稅引發全球股災，台股血流成河，本周以來的三個交易日下跌3,906點，跌幅達18.3%，股民面對斷頭危機，連忙向銀行申請小額信貸救急，銀行業者昨（9）日透露，內部統計小額信貸業務量較平日增加逾三成，預估未來幾日業務量持續增加。
#
# [川普為什麼縮起來了？顯然有這四個原因](https://money.udn.com/money/story/5599/8664791?from=ednappsharing&fbclid=IwY2xjawJkGztleHRuA2FlbQIxMQABHooVIt537W_jSGXEq2rcy-pC6Qe36gS29Uhzvh9KGjSfXM4Dzny9zowYsGx8_aem_fbvJbsyeTS8cvBmXs8Ss1w)
#
# [台股融資斷頭傷到誰？金管會彭金隆：7成都是40~69歲](https://tw.stock.yahoo.com/news/%E5%8F%B0%E8%82%A1%E8%9E%8D%E8%B3%87%E6%96%B7%E9%A0%AD%E5%82%B7%E5%88%B0%E8%AA%B0%EF%BC%9F%E9%87%91%E7%AE%A1%E6%9C%83%E5%BD%AD%E9%87%91%E9%9A%86%EF%BC%9A7%E6%88%90%E9%83%BD%E6%98%AF4069%E6%AD%B2-030830673.html)

# %% [markdown]
# 日本強勢大漲：
# ![messageImage_1744242998188.jpg](attachment:5c188d72-85ec-4b86-b46b-e85107e7ac0d.jpg)
#
# 一生中應該很難得幾次，可以看到這種奇景，記得存檔留念：
# ![messageImage_1744245079013.jpg](attachment:80fe9c82-f4a0-48ca-ac6f-afafb751c4eb.jpg)
# ![734168.jpg](attachment:413d7350-b5f2-4e2a-ba05-d69970c47abe.jpg)
#
# 如果股齡不夠久，交易經驗少的投資人，這個星期應該會以為系統壞了~
# ![734214.jpg](attachment:412957c7-794c-4a83-8c19-a349b3a1449e.jpg)
# ![734215.jpg](attachment:c9b024bb-ce25-43d0-90fa-0709dca1d575.jpg)
# 真的像坐大怒神。
# 前幾天是想賣，但是賣不掉，今天是想買，但是買不到。
# 前幾天同學問我美債下跌，我忽略了一個很嚴重的變因，就是想小白想進場，我當時是想美債這麼穩的東西，應該沒事吧！但小白問完之後，就...
#
# 早上解盤有說，反彈完畢之後會進入橫盤，而且時間會以周為單位，但至於橫盤的支撐壓力區間是多少，要多走幾天才看的出來，區間大小也會影響盤整的時間長短，等確定支撐壓力區間，再跟大家說~
#
# 難得負貢獻，沒有股，空白，從缺😆：
# ![734371.jpg](attachment:06b1ea8a-e131-4c22-ab91-26bdb60c1be5.jpg)
# 和星期一剛剛好顛倒。
# 這個星期一直在改寫歷史。

# %% [markdown]
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 5512力麒  中長期偏空，短線反彈
# 6472保瑞  短線反彈，中長期支撐暫時有守
# 2454聯發科  短線反彈，中期偏空
# 2374佳能  短線反彈，中長期頭部型態還在
# 9802 鈺齊-KY  中長期偏空，短線反彈
# 2542興富發  中長期偏空，短線反彈
# 2303聯電  短線反彈，中期箱型整理
# 1795美時  短線反彈，長天期頭部仍在
# 6446藥華藥  短線反彈，中期頭部仍在
# 1314中石化  中長期偏空，短線反彈
# 6509聚和  中長期偏空，短線反彈
# 2812 台中銀  短線轉弱，中期支撐有守
#
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 2383台光電  短線反彈，中期偏空，長期支撐暫時有守
# 00708L元大期黃金  短線反彈，中期高檔盤整，長期還在多方架構
# 1702南僑  短線反彈，中長期偏空
# 2330 台積電  中長期天低暫時有守，短線反彈
# 8906 花王  短線反彈，中長期偏空
# 2027大成鋼  短線翻空，中期支撐有守
# 8255朋程  短線反彈，中長期偏空
# 6829千附精密  短中期偏空，長期箱型整理
# 6285啟碁  長天期頭部雛形，短線反彈
# 1514亞力  長天期頭部，短線反彈
# 3034聯詠  長天期頭部雛形，短線反彈
#
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 2308台達電  短線反彈，中長期偏空，長期支撐暫時有守，但不穩
# 00680L元大美債20正2  長期偏空，中期持續打底
# 00929復華科技優息  中長期偏空，短線反彈
# 2002中鋼  中長期偏空，短線反彈
# 3454 晶睿  短線反彈，中長期偏空，長期支撐暫時有守，但不穩
# 2886兆豐金  中長期偏空，長期支撐暫時有守，短線反彈
# 00878 國泰永續高股息  中長期偏空，短線反彈
# 1565精華  中長期偏空，弱勢反彈
# 1307三芳  中長期頭部，短線反彈
# 1376喬山  短線反彈，中期頭部雛形
# 6770 力積電  中長期偏空，短線弱勢反彈
# 5227立凱KY  中長期偏空，短線反彈
# 6206飛捷  中長期偏空，短線反彈
# 3213 茂訊  短線反彈，中期箱型
#
# 📊 整理完同學們對個股的觀察後，發現一個明顯趨勢——90%的個股都呈現短線反彈，但中長期偏空，甚至有些已經出現了中長期頭部的跡象。👀
#
# 儘管今天出現短線反彈，整體空方結構並未被徹底化解。未來要特別注意以下兩個重點：
#
# 1️⃣ 反彈或盤整過後，關鍵在於回測支撐是否能夠守住。
# 2️⃣ 在反彈或盤整期間，多方條件是否明顯增強？如果沒有，第三波修正的風險仍然存在，警報未解除，切勿掉以輕心。⚠️
#
# 保持警覺，密切關注市場動向！🔍

# %% [markdown]
# [前幾天是想賣](https://www.facebook.com/kevinyang20180801/posts/pfbid0x2SiMwJp1QVsDa4LZtrj8NAcdzvdN25rtcQg13vmZ6SRup7oRrY5bZsnMDtWjeRNl)，但是賣不掉，今天是想買，但是買不到。
# 股市今天沒下雨
# 紅紅的很熱(Ms Big Sunny)
# 星期一不忙：賣不出
# 星期二超忙
# 星期三更忙
# 星期四不忙：買不到
#
# [網友轉傳](https://www.facebook.com/kevinyang20180801/posts/pfbid0kZFAGFaTU46akYfEuB9VPKD49ZnhgLL5SZQuy6dRKB8W1PYfMUNbjf9Xz2jcHSDNl)分享~
# ![734395.jpg](attachment:5699b951-273a-423b-b79f-58761dbf883d.jpg)
#
# 前幾天崩跌大家沒心情學習，今天雖然一樣驚魂未定，但應該比較有心情看文章了，下面這一段請大家能耐心看完，絕對有幫助的...
# 📉【[股市下跌為何如此焦慮？學會這一點，才是你最該關心的](https://www.facebook.com/kevinyang20180801/posts/pfbid0K9zzEGCjmAk8pyMmHTio6VgTQkhPVo5KxyKLSnPsxUeKXPycQzsPwN5MDshQMJk6l)】
# 當股價一路下跌，投資人最常問的問題是：「發生了什麼事？」這看似合理的問題，卻未必是最重要的。來，讓我先跟大家分享一個佛教故事，幫助我們更清楚思考這個問題的關鍵。
# 釋迦牟尼有一位門徒，對「十四難」的問題非常執著。所謂「十四難」是釋迦牟尼所講的哲學問題，但這些問題對於實際的解脫並無幫助。某一天，這位好奇的門徒再次追問釋迦牟尼，希望得到答案。釋迦牟尼感嘆道：「你愚痴！生、老、病、死的問題才是最重要的，你問的十四難只是無意義的辯論。」
# 接著，釋迦牟尼以一個比喻來說明：“假設有人中毒箭了，親人急著帶他去醫生那裡治療，但這個人卻開始問，醫生是誰？住哪裡？箭是哪座山的？箭尾用什麼羽毛？等等… 他不願立即治療，非得先問清楚所有的細節。這樣的人能活下來嗎？”
# 門徒毫不猶豫地回答：“不可能，如果等到問完所有問題，早就毒發身亡了！”
# 釋迦牟尼微笑著說：“這就是你的處境。你被毒箭射中，卻停不下來問這些無關痛癢的問題，不趕快求醫，你可能就會錯過治療的最佳時機。”
# 📉這個故事告訴我們，有時候，問題不是你要多了解那些無關緊要的真相，而是要做出正確的決策，立刻行動。
# 在股市中，當股價崩跌時，很多投資人也會問：「到底發生了什麼事？」然而，這並不是當下最需要關心的問題。真正的重點應該是：在股價下跌的時候，你應該怎麼辦？
# 例如，當市場出現爆量長黑，就像中了毒箭一樣，你要先做的不是去問為何股價下跌，而是要快速決定是否停損、減碼，甚至是尋求止損方案，不急於尋找原因，而是解決眼前的危機。如果股價跳空跌破關鍵支撐位，形態出現反轉信號，那就要果斷行動，避免被風險拖累。
# 🎯記住，當股市的暴風雨來襲，最重要的是：先躲雨，而不是站在雨中不停問「是西北雨還是梅雨」。如果船要沉了，就應該趕快跳船，而不是繼續問為何船會沉。
# 👉做出應變、調整策略，這才是關鍵！
# 投資與人生一樣，很多時候需要快速決策，不要讓無意義的細節阻礙了你改變命運的機會！

# %% [markdown]
# ![734864.jpg](attachment:0acfc366-95f6-43fd-a444-bd47cc4bb104.jpg)
# ![734865.jpg](attachment:794b621d-6880-432e-9d4b-b213ab17f71f.jpg)

# %% [markdown]
# #### 🎉 歡迎加入數位訂閱行列！ 🎉
#
# 這段影片是你的專屬入門指南，解鎖訂閱內容的最大價值就從這裡開始！📌 只需10分鐘，讓你快速掌握關鍵資訊，確保每一分訂閱都發揮最大效益。
#
# 無論多忙，請務必觀看，這將是你最值得投資的10分鐘！ ⏳🎯
#
# 🔗 立即觀看
#
# https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=20&a=3010
#
# #### 🌟 全新體驗平日夜間班開放試聽 🌟
#
# 新一季課程隆重登場！這次的課程和以往不同，全面升級了教學方式和課程安排，讓學習更有趣、更有效！
#
# 👂 歡迎舊生搶先體驗
# 還記得當初的學習熱情嗎？這一季的創新教學等你來發掘，快來看看有什麼不一樣！
#
# 👫 邀請好友一起探索
# 點擊下方連結，即可加入試聽課程群組。還可以呼朋引伴，和親友一起來參加，讓學習變成一件充滿樂趣的事！
#
# 📅 完整資訊4月18日揭曉
# 所有課程細節將在試聽當天為您揭曉，讓我們一起迎接全新的學習旅程！
#
# 👉 馬上加入試聽群組：
# https://line.me/R/ti/g/hMwxU_jbPA

# %% [markdown]
# ### 本日進度
# * 建立新的「股票投資筆記」環境。

# %% [markdown]
# 安裝可攜版Miniforge3（來源 : https://github.com/conda-forge/miniforge ， https://conda-forge.org/download/ ）：
# ```
# start /wait "" Miniforge3-Windows-x86_64.exe /S /InstallationType=JustMe /AddToPath=0 /RegisterPython=0 /NoRegistry=1
# ```
#
# 建立環境：
# ```
# conda create --name StockNotes python=3.10
#
# conda activate StockNotes
# ```
#
# 安裝套件：
# ```
# onda install -c conda-forge jupyterlab --yes
#
# conda install -c conda-forge numpy scipy --yes
#
# conda install -c conda-forge matplotlib mplfinance --yes
#
# conda install -c conda-forge ta-lib --yes
#
# conda install -c conda-forge python-dotenv --yes
#
# conda install -c plotly plotly --yes
#
# pip install openai
#
# pip install langchain langchain_openai langgraph
#
# pip install pyfolio
#
# pip install backtrader
#
# pip install openpyxl
#
# pip install FinMind
# ```
#
# 匯出環境設定檔：
# ```
# conda env export --name StockNotes --file StockNotes.yml
# ```

# %% [markdown]
# * 驗證：StockChartPatterns類別

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            # 驗證：型態最後一個轉折點離價格資料距離
            print('◆ 態最後一個轉折點離價格資料距離 ＝ {} '.format( date_to_index(prices,prices.iloc[-1].name) - date_to_index(prices,pattern_window.iloc[-1]['Date']) ))
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '上升旗形' or pattern_name == '下降旗形' or pattern_name == '看跌三角旗形' or pattern_name == '看漲三角旗形'  : 
                line1_start_date = pattern_window.iloc[1]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line1_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line2_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if pattern['type'] == '頭肩頂' or pattern['type'] == '雙頂' or pattern['type'] == '圓弧頂' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 20.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2023年8月4日到今日(2025年4月10日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250410.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 360,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 57
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 53
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# 374       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 31

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 360,turning_point_args={'mode':'open_close', 'order':20})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 20}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 20}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 57
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 20}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 53
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 20}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# 374       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 31

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 360,turning_point_args={'mode':'open_close', 'order':25})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 25}]
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 59        2023-10-31  16001.27   LO
# 228       2024-07-11  24390.03   HI
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 112
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 57
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 53
# ＃＃＃ 看漲三角旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 59        2023-10-31  16001.27   LO
# 228       2024-07-11  24390.03   HI
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 83
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# 352       2025-01-13  22488.33   LO
# 374       2025-02-21  23730.25   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 31

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 360,turning_point_args={'mode':'open_close', 'order':30})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 30}]
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 30}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 59        2023-10-31  16001.27   LO
# 228       2024-07-11  24390.03   HI
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 112
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 30}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# 348       2025-01-07  23824.72   HI
# ◆ 態最後一個轉折點離價格資料距離 ＝ 57
# ＃＃＃ 看漲三角旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 30}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 59        2023-10-31  16001.27   LO
# 228       2024-07-11  24390.03   HI
# 243       2024-08-05  19830.88   LO
# 293       2024-10-18  23620.57   HI
# 322       2024-11-29  22202.28   LO
# ◆ 態最後一個轉折點離價格資料距離 ＝ 83

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-04-01 ， 型態結束日期 ＝ 2025-01-20

# %% [markdown]
# * 對照：[ChatGPT](https://chatgpt.com/)分析

# %% [markdown]
# *你說*：價格型態
# ![250410.png](attachment:ce5cd4c6-5251-4064-84df-c68836d6c962.png)
#
# **ChatGPT 說**：
# 這張圖顯示的是一種典型的頭肩頂（Head and Shoulders Top）的價格型態，並伴隨著劇烈的下跌。以下是一些關鍵觀察點：
#
# 📉 價格型態分析：
# 1\.	左肩（Left Shoulder）：
# o	2024年5月附近，價格先上漲後回落，形成第一個高點。
# 2\.	頭部（Head）：
# o	在2024年7月-8月期間，價格創下更高的高點，形成頭部。
# 3\.	右肩（Right Shoulder）：
# o	2024年10月至12月之間，價格再次上漲，但高點低於頭部，形成右肩。
# 4\.	頸線（Neckline）跌破：
# o	頸線大約落在22000左右，在2025年4月左右被明顯跌破，且伴隨著爆量（volume spike），確認了反轉訊號。
#
# 📊 成交量（Volume）分析：
# •	在下跌過程中，成交量明顯放大（尤其是跌破頸線當日），這是頭肩頂型態的確認訊號。
# •	量價配合良好，表示賣壓強勁。
#
# 🔍 總結：
# 這張圖非常典型地展現了頭肩頂反轉型態：
# •	前期長期上升趨勢 → 形成頭肩頂 → 頸線跌破 → 價格急劇下跌。
# •	若這是個股或指數，技術面顯示出強烈的反轉訊號，後續可能需要關注是否會進一步尋找支撐。
#
# *你說*：近期盤勢分析
#
# **ChatGPT 說**：
# 從你提供的這張圖來看，這是一張典型的股價K線圖，並附有成交量柱狀圖。以下是針對近期盤勢的分析：
# 📉 近期盤勢特徵
# 1\.	劇烈下跌：
# o	圖中右側明顯可見一波急跌，價格從高點迅速滑落，跌破多個支撐區間。
# o	跌幅大且快速，呈現出恐慌性賣壓的特徵。
# 2\.	成交量放大：
# o	在價格下跌期間，成交量顯著放大，尤其在圖的最右側一根紅K棒下方的紅色成交量柱特別高。
# o	顯示有大量賣壓，市場情緒偏向極度悲觀。
# 3\.	前期走勢：
# o	在下跌之前，走勢是震盪偏多，整體維持在一個相對高位，但已經出現高檔整理與橫盤跡象。
# o	高點大約出現在2024年8月前後。
#
# 🔍 技術面觀察
# •	短期趨勢：空頭明顯，短期內市場信心不足。
# •	支撐區域：目前價格已跌回2024年2月左右的水準，可能出現技術性反彈。
# •	壓力區域：跌破原有盤整區間（約22000點附近），未來若反彈至此區將面臨強壓。
#
# 🧠 可能原因（需進一步佐證）
# •	有可能是受到突發重大利空影響（如經濟數據、地緣政治、政策調整等）。
# •	亦有可能是技術性破線後引發程式交易與停損單集中出籠。
#
# 📌 建議應對策略
# •	短線操作者：避免逆勢操作，等待明確止跌訊號或反彈回測壓力區。
# •	長線投資人：可關注是否出現超跌反彈或底部訊號，分批布局需非常謹慎。
