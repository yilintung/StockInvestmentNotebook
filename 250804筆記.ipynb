# %% [markdown]
# ### 工作進度
# * **新的筆記內容架構**與**量化技術分析系統**相關資訊請參閱[250801筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250801%E7%AD%86%E8%A8%98.ipynb)之工作進度。
# * 本日「K線追擊週報」LINE群組日報：[楊忠憲K線追擊週報_250804日報.docx](https://mega.nz/file/CgJ2QSQZ#P8OKixAvfim75XcHd48vygq6708ImvoDQTwR05Q-6EA)。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-08-04 22:41:21.928 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 2336：股票名稱 ＝ 致伸，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2341：股票名稱 ＝ 英群，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2396：股票名稱 ＝ 精碟，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2447：股票名稱 ＝ 鼎新，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2452：股票名稱 ＝ 乾坤，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2469：股票名稱 ＝ 力信，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2473：股票名稱 ＝ 思源，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3053：股票名稱 ＝ 鼎營，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3061：股票名稱 ＝ 璨圓，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3063：股票名稱 ＝ 飛信，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3080：股票名稱 ＝ 威力盟，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3130：股票名稱 ＝ 一零四，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3271：股票名稱 ＝ 其樂達，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3367：股票名稱 ＝ 英華達，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3584：股票名稱 ＝ 介面，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3598：股票名稱 ＝ 奕力，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3638：股票名稱 ＝ F-IML，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3697：股票名稱 ＝ F-晨星，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4148：股票名稱 ＝ 全宇生技-KY，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4739：股票名稱 ＝ 康普，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4755：股票名稱 ＝ 三福化，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4763：股票名稱 ＝ 材料*-KY，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4764：股票名稱 ＝ 雙鍵，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4766：股票名稱 ＝ 南寶，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4770：股票名稱 ＝ 上品，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4915：股票名稱 ＝ 致伸，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4916：股票名稱 ＝ 事欣科，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4919：股票名稱 ＝ 新唐，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4927：股票名稱 ＝ 泰鼎-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4934：股票名稱 ＝ 太極，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4935：股票名稱 ＝ 茂林-KY，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4938：股票名稱 ＝ 和碩，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4942：股票名稱 ＝ 嘉彰，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4956：股票名稱 ＝ 光鋐，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4968：股票名稱 ＝ 立積，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 4989：股票名稱 ＝ 榮科，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5215：股票名稱 ＝ 科嘉-KY，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5225：股票名稱 ＝ 東科-KY，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5234：股票名稱 ＝ 達興材料，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5244：股票名稱 ＝ 弘凱，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5269：股票名稱 ＝ 祥碩，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 5471：股票名稱 ＝ 松翰，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6108：股票名稱 ＝ 競國，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6112：股票名稱 ＝ 邁達特，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6133：股票名稱 ＝ 金橋，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6165：股票名稱 ＝ 浪凡，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6176：股票名稱 ＝ 瑞儀，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6183：股票名稱 ＝ 關貿，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6192：股票名稱 ＝ 巨路，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6201：股票名稱 ＝ 亞弘電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6205：股票名稱 ＝ 詮欣，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6206：股票名稱 ＝ 飛捷，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6209：股票名稱 ＝ 今國光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6213：股票名稱 ＝ 聯茂，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6214：股票名稱 ＝ 精誠，產業類別 ＝ 資訊服務業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6215：股票名稱 ＝ 和椿，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6226：股票名稱 ＝ 光鼎，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6230：股票名稱 ＝ 尼得科超眾，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6239：股票名稱 ＝ 力成，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6255：股票名稱 ＝ 奈普，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6283：股票名稱 ＝ 淳安，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6285：股票名稱 ＝ 啟碁，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6286：股票名稱 ＝ 立錡，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6409：股票名稱 ＝ 旭隼，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6414：股票名稱 ＝ 樺漢，產業類別 ＝ 電腦及週邊設備業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6415：股票名稱 ＝ 矽力*-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6416：股票名稱 ＝ 瑞祺電通，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6446：股票名稱 ＝ 藥華藥，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6449：股票名稱 ＝ 鈺邦，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6451：股票名稱 ＝ 訊芯-KY，產業類別 ＝ 半導體業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6477：股票名稱 ＝ 安集，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6491：股票名稱 ＝ 晶碩，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6525：股票名稱 ＝ 捷敏-KY，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 6689：股票名稱 ＝ 伊雲谷，產業類別 ＝ 電子工業，類型 ＝ twse
# 新增股票代碼。代碼 ＝ 7850：股票名稱 ＝ 寶泰生醫，產業類別 ＝ 生技醫療業，類型 ＝ emerging
# 修改股票資訊。代碼 ＝ 8021：股票名稱 ＝ 尖點，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8105：股票名稱 ＝ 凌巨，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8112A：股票名稱 ＝ 至上甲特，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 8199：股票名稱 ＝ 廣鎵，產業類別 ＝ 電子工業，類型 ＝ twse
# ##### 更新技術分析資料 #####
# 2025-08-04 22:41:23.969 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:41:29.254 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:41:58.780 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:42:03.695 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:42:32.766 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:42:37.750 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:43:07.360 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:43:12.690 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 周K：2025-07-28
# 2025-08-04 22:44:03.099 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:44:08.206 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-08-04 22:44:13.431 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 日K：2025-08-04

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤前**：[K線捕手](https://www.facebook.com/kevinyang20180801)｜[8/4盤前快訊](https://www.facebook.com/kevinyang20180801/posts/pfbid02MCSyJ3ASLe2vaRPtAy6eQZM9G43E6F5hiBLgzqBksnX1TgfkSXj8RVygpsNQsv59l)
# > 📈 加權指數：20日線＆上升楔形支撐
# > ![528145828_1353137203486870_7899147515898530394_n.jpg](attachment:46d5a123-68c1-4428-8f59-3b22aa37501a.jpg)

# %%
# 上升楔形
def line_drawing_callback( range_prices) :

    seq_of_seq_of_points = []
    linewidths           = []
    colors               = []

    # 設定楔形壓力線
    resistance_line_start_date  = '2025-06-11'
    resistance_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_x           = [mysys.DateToIndex(range_prices,'2025-06-11'),mysys.DateToIndex(range_prices,'2025-07-31')]
    resistance_line_y           = [range_prices.loc['2025-06-11']['Close'],range_prices.loc['2025-07-31']['High']]
    slope,intercept             = np.polyfit(resistance_line_x,resistance_line_y,1)
    resistance_line_start_price = slope * mysys.DateToIndex(range_prices,resistance_line_start_date) + intercept
    resistance_line_end_price   = slope * mysys.DateToIndex(range_prices,resistance_line_end_date) + intercept
    seq_of_seq_of_points.append([(resistance_line_start_date,resistance_line_start_price),(resistance_line_end_date,resistance_line_end_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')
    
    # 設定楔形支撐線
    support_line_start_date  = '2025-06-23'
    support_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_x           = [mysys.DateToIndex(range_prices,'2025-07-09'),mysys.DateToIndex(range_prices,'2025-07-29')]
    support_line_y           = [range_prices.loc['2025-07-09']['Open'],range_prices.loc['2025-07-29']['Low']]
    slope,intercept          = np.polyfit(support_line_x,support_line_y,1)
    support_line_start_price = slope * mysys.DateToIndex(range_prices,support_line_start_date) + intercept
    support_line_end_price   = slope * mysys.DateToIndex(range_prices,support_line_end_date) + intercept
    seq_of_seq_of_points.append([(support_line_start_date,support_line_start_price),(support_line_end_date,support_line_end_price)])
    linewidths.append(1.5)
    colors.append('xkcd:red')
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤前：上升楔形繪製
image = mysys.DrawOnKlineChart('TAIEX','2025-03-17','2025-08-01',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：上升楔形確認

# %%
# 盤後：上升楔形繪製
image = mysys.DrawOnKlineChart('TAIEX','2025-03-17','2025-08-04',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x482>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-31<br />
# 十字線 : 2025-07-31</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 3395.97億元 ，十日均量 ＝ 3667.49億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-08-04死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-07-28該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前價格呈現上漲趨勢，K線多數為紅K，顯示多頭力量較強。短期移動平均線（5日、10日）位於中期移動平均線（20日、60日）之上，且均呈現上升趨勢，顯示短中期趨勢向好。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有增加的趨勢，顯示價量配合良好，支持價格上漲。近期成交量略有減少，需注意後續量能變化。<br />
# <br />
#  支撐與壓力<br />
# 支撐位置可參考20日移動平均線，約在23000點附近。壓力位置則在近期高點，約在23500點左右。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線（紅線）在D線（藍線）之上，且位於50以上，顯示多頭趨勢。然而，K線有向下交叉D線的跡象，需注意可能的回檔風險。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線（紅線）位於MACD線（藍線）之上，且灰色柱體（OSC）為正，顯示多頭趨勢。然而，柱體高度略有縮減，需注意趨勢可能轉弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於多頭趨勢，但需注意短期內可能的回檔風險。建議投資者在支撐位附近考慮進場，並在壓力位附近考慮停利。同時，密切關注成交量及技術指標的變化，以調整交易策略。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤前**：[K線捕手](https://www.facebook.com/kevinyang20180801)｜[8/4盤前快訊](https://www.facebook.com/kevinyang20180801/posts/pfbid02MCSyJ3ASLe2vaRPtAy6eQZM9G43E6F5hiBLgzqBksnX1TgfkSXj8RVygpsNQsv59l)
# > 📉 櫃買指數：季線能否止穩
# > ![527356051_1353137190153538_8742189068644249112_n.jpg](attachment:39cbd6ef-6d31-41cf-bd7e-af97d02e7ec8.jpg)

# %%
# 盤整區間
def line_drawing_callback( range_prices) :

    seq_of_seq_of_points = []
    linewidths           = []
    colors               = []
    
    # 設定箱型壓力線
    resistance_line_start_date  = '2025-05-09'
    resistance_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_price       = range_prices.loc['2025-07-18']['Open']
    seq_of_seq_of_points.append([(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)])
    linewidths.append(1.0)
    colors.append('xkcd:red')

    # 設定箱型支撐線
    support_line_start_date  = '2025-05-09'
    support_line_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_price       = range_prices.loc['2025-06-02']['Close']
    seq_of_seq_of_points.append([(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)])
    linewidths.append(1.0)
    colors.append('xkcd:red')
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤前：箱型區間繪製
image = mysys.DrawOnKlineChart('TPEx','2025-03-17','2025-08-01',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：箱型區間確認

# %%
# 盤後：箱型區間繪製
image = mysys.DrawOnKlineChart('TPEx','2025-03-17','2025-08-04',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-30<br />
# 十字線 : 2025-07-30 , 2025-08-04<br />
# 鎚子線／吊人線 : 2025-08-04<br />
# 孕育線／懷抱線 : 2025-07-30 , 2025-08-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 899.02億元 ，十日均量 ＝ 914.44億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線下彎，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-08-01黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-21當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢分析<br />
# 從K線圖來看，近期價格呈現盤整走勢。價格在230至235點之間波動，顯示出多空雙方力量相對均衡。<br />
# <br />
#  價量關係<br />
# 成交量在近期有小幅增加，尤其在紅K線出現時，顯示多頭力量略有增強。然而，整體成交量並未出現明顯放大，顯示市場觀望情緒仍在。<br />
# <br />
#  支撐與壓力判斷<br />
# - 支撐位置：230點附近，該位置多次測試未破，顯示有一定支撐力道。<br />
# - 壓力位置：235點，價格多次在此遇阻，顯示為短期壓力。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線（紅線）上升至74.59，接近超買區，但尚未進入。D線（藍線）也在上升，顯示短期內多頭力量增強，但需注意可能的回檔風險。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線（紅線）與MACD線（藍線）接近零軸，且灰色柱體（OSC）略有增長，顯示出多頭力量略有增強，但整體趨勢仍不明顯。<br />
# <br />
#  綜合評價<br />
# 目前市場處於盤整階段，短期內多頭力量略有增強，但成交量未明顯放大，顯示市場觀望情緒仍在。建議投資者在230點支撐位附近可考慮進場，但需密切關注235點壓力位的突破情況。若價格突破235點且成交量放大，則可考慮加碼；若未能突破，則需謹慎操作，防範回檔風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 台塑(1301)
#   看法：跳空跌破頸線，型態被破壞。因此7月30日的突破被視為假突破。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1301')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>鎚子線／吊人線 : 2025-07-31<br />
# 吞噬 : 2025-07-29</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 64386張 ，十日均量 ＝ 44368張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中繼型態之上升旗形，型態範圍由2025-01-10開始到2025-08-01結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線下彎，短期翻空；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-08-01死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-14當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，但在高點出現回檔跡象。K線圖顯示近期有較大幅度的下跌，可能進入盤整或下跌階段。<br />
# <br />
#  價量關係<br />
# 近期成交量顯著增加，尤其是在價格下跌時，顯示出空頭力量增強。這種價量配合通常預示著後市可能進一步下跌。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：目前價格接近20日移動平均線（紫色線），此處可能形成短期支撐。<br />
# - 壓力位置：上方壓力在近期高點附近，約42元。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線快速下跌並跌破D線，且已進入超賣區域，顯示短期內可能有反彈需求，但整體趨勢仍偏空。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線與MACD線出現死叉，且灰色柱體縮短，顯示出空頭趨勢增強。<br />
# <br />
#  綜合評價<br />
# 整體來看，近期價格出現回檔，成交量放大顯示空頭力量增強。KD指標進入超賣區，短期可能有反彈，但中期趨勢偏空。建議投資者謹慎操作，若持有多單，考慮在反彈時停利或減倉，並設置好停損位。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2024-11-29'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-03-21']['Open']

    # 設定底部到頸線差距
    bottom_date  = '2025-01-10'
    bottom_price = range_prices.loc['2025-01-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)],
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1301','2024-09-20','2025-08-04',line_drawing_callback)
display(image)
# Out:
# 估算目標價為49.55元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-7589)：外資小買(+1722)、投信中立(-5)、自營大賣(-9306)。
# 主力大賣(-15640)。
# 分公司買賣家數差分散(-84)。
# 融資大減(-4741)、融券大減(-697)。
