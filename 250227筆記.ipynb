#
# 海韻電(6203)
# ![messageImage_1740618634009.jpg](attachment:d215ee5e-8217-4c1e-a198-b9e2ef3a1422.jpg)
#
# 群聯(8299)
# ![messageImage_1740618661169.jpg](attachment:afe4705f-4f7f-4ac4-a46f-aa6463e8e017.jpg)
#
# 南電(8046)
# ![messageImage_1740618783497.jpg](attachment:535e1a32-e59e-4df0-b9f4-4daefeb5b704.jpg)

# %% [markdown]
# ![671096.jpg](attachment:dde79d2e-09f4-4339-bc6d-592ee81d8c1e.jpg)
# ![671097.jpg](attachment:6cfb9f17-3f54-4451-8615-ecd37e6c3454.jpg)

# %% [markdown]
# ### 本日進度
# * **驗證**型態辨識程序

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
from collections import defaultdict

# 原型版：初步開發
def chart_patterns_recognition_4point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)
    for i in range(4, (len(turning_points)+1)):
        
        # 在變數window中一次儲存4個局部最小值和局部最大值點
        window = turning_points.iloc[i-4:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存4個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        rtop_g1 = np.mean([e1,e3])
        rtop_g2 = np.mean([e2,e4])
        
        if e2 > e1 and e4 > e3 and e3 > e1 and e4 > e2 and (e2 - e1) > (e4 - e3) and abs(((e4 - e3) - (e2 - e1)) / (e2 - e1)) > 0.25 :
            # 上升楔型
            patterns['RISE_WEDGE'].append(window)
        elif e1 > e2 and e3 > e4 and e1 > e3 and e2 > e4 and (e1 - e2) > (e3 - e4) and abs(((e3 - e4) - (e1 - e2)) / (e1 - e2)) > 0.25 :
            # 下降楔型
            patterns['FALL_WEDGE'].append(window)
        elif (e1 > e2) and (abs(e1-rtop_g1)/rtop_g1 < 0.0075) and (abs(e3-rtop_g1)/rtop_g1 < 0.0075) and \
            (abs(e2-rtop_g2)/rtop_g2 < 0.0075) and (abs(e4-rtop_g2)/rtop_g2 < 0.0075) and (min(e1, e3) > max(e2, e4)):
            # 矩形
            patterns['RECT'].append(window)
        elif e1 < e3 and e3 < e2 and e3 < e4 and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e2-e4) <= np.mean([e2,e4])*0.05):
            # 雙重頂
            patterns['DOUBLE_TOP'].append(window)
        elif e1 > e3 and e3 > e2 and e3 > e4 and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e2-e4) <= np.mean([e2,e4])*0.05):
            # 雙重底
            patterns['DOUBLE_BOTTOM'].append(window)    
        
    return patterns

# 原型版：初步開發
def chart_patterns_recognition_5point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)    
    for i in range(5, len(turning_points)+1):
        
        # 在變數window中一次儲存5個局部最小值和局部最大值點
        window = turning_points.iloc[i-5:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存5個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        e5      = window.iloc[4]['Price']
        
        if (e1 > e2) and (e1 > e3) and (e3 > e5) and (e2 < e4):
            # 三角形
            patterns['TRIG'].append(window)
        elif (e1 > e2) and (e2 < e3) and (e4 < e5) and (e2 < e4) and (e3 < e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.10) and \
            (abs(e2-e4) >= np.mean([e2,e4])*0.015) and \
            (abs(e3-e5) >= np.mean([e3,e5])*0.015):
            # 上升旗形(看跌)
            patterns['BEAR_FLAG'].append(window)
        elif (e1 < e2) and (e2 > e3) and (e4 > e5) and (e2 > e4) and (e3 > e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.10) and \
            (abs(e2-e4) >= np.mean([e2,e4])*0.015) and \
            (abs(e3-e5) >= np.mean([e3,e5])*0.015):
            # 下降旗形(看漲)
            patterns['BULL_FLAG'].append(window)
        elif (e1 > e2) and (e2 < e3) and (e4 < e5) and (e2 <= e4) and (e3 > e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.10) and \
            (abs(e3-e5) >= np.mean([e3,e5])*0.015):
            # 看跌三角旗形
            patterns['BEAR_PENNANT'].append(window)
        elif (e1 < e2) and (e2 > e3) and (e4 > e5) and (e2 > e4) and (e3 <= e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.10) and \
            (abs(e2-e4) >= np.mean([e2,e4])*0.015) :
            # 看漲三角旗形
            patterns['BULL_PENNANT'].append(window)
            
    return patterns

# 原型版：初步開發
def chart_patterns_recognition_6point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)    
    for i in range(6, len(turning_points)+1):
        
        # 在變數window中一次儲存6個局部最小值和局部最大值點
        window = turning_points.iloc[i-6:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存6個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        e5      = window.iloc[4]['Price']
        e6      = window.iloc[5]['Price']

        if (e3 < e1) and (e5 < e1) and (e2 < e3) and (e4 < e2) and (e4 < e6) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e3-e5) <= np.mean([e3,e5])*0.05) and \
            (abs(e2-e4) >= np.mean([e2,e6])*0.05) and \
            (abs(e4-e6) >= np.mean([e2,e6])*0.05):
            # TODO : 判斷條件待確認，參照：https://ithelp.ithome.com.tw/articles/10317498
            # TODO : 頭肩底與三重底的區分？
            # 頭肩底
            patterns['IHS'].append(window)
        elif (e3 > e1) and (e5 > e1) and (e2 > e3) and (e4 > e2) and (e4 > e6) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e3-e5) <= np.mean([e3,e5])*0.05) and \
            (abs(e2-e4) >= np.mean([e2,e6])*0.05) and \
            (abs(e4-e6) >= np.mean([e2,e6])*0.05):
            # 頭肩頂
            # TODO : 頭肩頂與三重頂的區分？
            patterns['HS'].append(window)
        elif (e3 < e1) and (e5 < e1) and (e2 < e3) and (e4 < e5) and (e6 < e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e3-e5) <= np.mean([e3,e5])*0.05) and \
            (abs(e2-e4) <= np.mean([e2,e4,e6])*0.05) and \
            (abs(e4-e6) <= np.mean([e2,e4,e6])*0.10) :
            # 三重底
            # TODO : e4-e6特例？
            # TODO : 頭肩底與三重底的區分？
            patterns['TRIPLE_BOTTOM'].append(window)
        elif (e3 > e1) and (e5 > e1) and (e2 > e3) and (e4 > e5) and (e6 > e5) and \
            (abs(e1-e3) >= np.mean([e1,e3])*0.03) and \
            (abs(e3-e5) <= np.mean([e3,e5])*0.05) and \
            (abs(e2-e4) <= np.mean([e2,e4,e6])*0.05) and \
            (abs(e4-e6) <= np.mean([e2,e4,e6])*0.05) :
            # 三重頂
            # TODO : 頭肩頂與三重頂的區分？
            patterns['TRIPLE_TOP'].append(window)
    
    return patterns

# %%
##### 使用2024年8月8日到今天(2025年2月27日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250227.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 轉折點參數 ： mode=open_close,order=10
turning_points = myutils.test_DetectTurningPoints(df_k_line,df_sma,'open_close',order=10)
# Out:
# 轉折點總筆數 ＝ 11
#                 Date     Price Type
# DateIndex
# 8         2024-08-20  22464.07   HI
# 24        2024-09-11  21031.00   LO
# 47        2024-10-18  23620.57   HI
# 56        2024-11-01  22438.93   LO
# 61        2024-11-08  23608.11   HI
# 76        2024-11-29  22202.28   LO
# 80        2024-12-05  23308.29   HI
# 91        2024-12-20  22510.25   LO
# 102       2025-01-07  23824.72   HI
# 106       2025-01-13  22488.33   LO
# 128       2025-02-21  23730.25   HI

# %%
patterns = chart_patterns_recognition_4point_prototype(turning_points,max_bars=120)
print(patterns)
pattern = patterns['RECT'][0]

# TODO : 後處理
rect_upper_edge =  max(pattern.iloc[0]['Price'],pattern.iloc[2]['Price'])
rect_lower_edge =  min(pattern.iloc[1]['Price'],pattern.iloc[3]['Price'])

line1_start_date  = pattern.iloc[0]['Date'].strftime("%Y-%m-%d")
line1_end_date    = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
line1_start_price = rect_upper_edge
line1_end_price   = rect_upper_edge

line2_start_date  = line1_start_date
line2_end_date    = line1_end_date
line2_start_price = rect_lower_edge
line2_end_price   = rect_lower_edge

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定上升楔形
seq_of_seq_of_points=[
    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
    
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,1.0), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1100)
mpf.plot(df_k_line,**kwargs)
# Out:
# defaultdict(<class 'list'>, {'DOUBLE_TOP': [                Date     Price Type
# DateIndex
# 24        2024-09-11  21031.00   LO
# 47        2024-10-18  23620.57   HI
# 56        2024-11-01  22438.93   LO
# 61        2024-11-08  23608.11   HI], 'RECT': [                Date     Price Type
# DateIndex
# 47        2024-10-18  23620.57   HI
# 56        2024-11-01  22438.93   LO
# 61        2024-11-08  23608.11   HI
# 76        2024-11-29  22202.28   LO,                 Date     Price Type
# DateIndex
# 61        2024-11-08  23608.11   HI
# 76        2024-11-29  22202.28   LO
# 80        2024-12-05  23308.29   HI
# 91        2024-12-20  22510.25   LO]})

# %%
##### 使用2024年1月10日到今日(2025年2月27日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_6139_250227.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
_ = myutils.test_bottom_pattern_detection_prototype(df_k_line,df_sma,'open_close',5)
# Out:
# ＃＃＃＃＃＃＃＃＃＃
# 轉折點總筆數 ＝ 20
#                 Date  Price Type
# DateIndex
# 2         2024-01-12  155.5   LO
# 16        2024-02-01  172.5   HI
# 21        2024-02-19  163.5   LO
# 57        2024-04-12  366.0   HI
# 82        2024-05-20  206.0   LO
# 112       2024-07-02  270.5   HI
# 134       2024-08-05  203.0   LO
# 147       2024-08-22  249.5   HI
# 161       2024-09-11  197.5   LO
# 168       2024-09-23  218.5   HI
# 173       2024-09-30  208.5   LO
# 176       2024-10-07  237.5   HI
# 180       2024-10-14  218.0   LO
# 198       2024-11-08  235.0   HI
# 204       2024-11-18  212.0   LO
# 217       2024-12-05  239.0   HI
# 227       2024-12-19  200.5   LO
# 239       2025-01-07  237.0   HI
# 245       2025-01-15  225.5   LO
# 259       2025-02-13  265.0   HI
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始 ＝ 0 ，結束 ＝ 20）
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 82 （日期 ＝ 2024-05-20 ） ， 底部型態結束索引 ＝ 267 （日期 ＝ 2025-02-25 ）
# ＤＥＢＵＧ ： 頸線角度 ＝ -0.44°
# ＤＥＢＵＧ ： 底部最低價格 ＝ 197.50元 ； 估算目標價 ＝ 342.84元
# ＤＥＢＵＧ ： 目標價沒有過前高
# ...
