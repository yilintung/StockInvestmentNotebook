| INFO     | FinMind.data.finmind_api:get_data:158 - download TaiwanStockPrice, data_id:
# 2025-11-18 20:52:26.887 | INFO     | FinMind.data.finmind_api:get_data:158 - download TaiwanStockPrice, data_id:
# 2025-11-18 20:52:35.962 | INFO     | FinMind.data.finmind_api:get_data:158 - download TaiwanStockPrice, data_id:
# 日K：2025-11-18

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數跌破箱型區間。
# > ![messageImage_1763427629961.jpg](attachment:b0cf827c-dc52-4941-b31c-4caf3df92194.jpg)

# %%
# 支撐線
def line_drawing_callback( range_prices) :
    
    # 支撐線
    support_line_start_date = '2025-10-14'
    support_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    support_line_price      = range_prices.loc['2025-10-17']['Open']
    
    seq_of_seq_of_points=[
        [(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)],
    ]

    linewidths=[2.5]
    
    colors=['xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：支撐線跌破
image = mysys.DrawOnKlineChart('TAIEX','2025-10-01','2025-11-18',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=858x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-11-13<br />
# 孕育線／懷抱線 : 2025-11-12</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 6727.57億元 ，十日均量 ＝ 5794.39億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.24點。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線下彎，短期翻空；20日線下彎、60日線上揚，中期盤整；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-11-14死亡交叉。並且2025-11-18於超賣區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-10-20當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>技術分析<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現下跌趨勢，尤其是最後一個交易日的收盤價大幅低於開盤價，形成明顯的黑K線，顯示空方力量強勁。<br />
# <br />
#  價量關係<br />
# 成交量在下跌過程中有所增加，顯示出賣壓增強，價量配合呈現空頭格局。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：目前價格已經跌破多條短期移動平均線，接近60日移動平均線，該位置可能形成短期支撐。<br />
# - 壓力位置：上方壓力在短期移動平均線附近，尤其是5日和10日移動平均線。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線和D線均位於超賣區，且K線低於D線，顯示出市場可能有反彈需求，但目前仍處於弱勢。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線低於MACD線，且柱狀體持續在負值區域並擴大，顯示出空頭趨勢仍在延續。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於下跌趨勢，空方力量較強。短期內可能會在60日移動平均線附近尋求支撐，但若無法有效止跌，可能會進一步下探。建議投資者謹慎操作，若持有多單，應考慮設置停損位以控制風險。若有反彈跡象，需觀察成交量是否配合放大，確認反彈的有效性。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數也是瀕臨跌破。
# > ![messageImage_1763427677537.jpg](attachment:81f198ef-e260-4796-8150-6e5a54712406.jpg)

# %%
# 盤整區間
def line_drawing_callback( range_prices) :
    
    # 設定盤整區間上緣(壓力線)
    resistance_line_start_date = '2025-09-18'
    resistance_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_price      = range_prices.loc['2025-09-23']['Open']

    # 設定盤整區間下緣(支撐線)
    support_line_start_date = '2025-08-29'
    support_line_end_date   = resistance_line_end_date
    support_line_price      = range_prices.loc['2025-09-16']['Open']
    
    seq_of_seq_of_points=[
        [(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)],
        [(support_line_start_date,support_line_price),(support_line_end_date,support_line_price)],
    ]

    linewidths=[5.0,5.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
# 收盤：跌破盤整區間
image = mysys.DrawOnKlineChart('TPEx','2025-08-28','2025-11-18',line_drawing_callback)
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=848x479>

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為低位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1288.84億元 ，十日均量 ＝ 1255.82億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線下彎，短期翻空；20日線下彎、60日線上揚，中期盤整；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-11-17死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以下，中期空方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-09-22當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現下跌趨勢，尤其是最近幾個交易日，價格跌破多條移動平均線，顯示出明顯的空頭走勢。<br />
# <br />
#  價量關係<br />
# 成交量在價格下跌時有所增加，顯示出賣壓增強，價量配合呈現空頭格局。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位置：目前支撐位可能在250點附近，若跌破此點位，可能會進一步下探。<br />
# - 壓力位置：上方壓力在260點附近，若要反彈，需突破此壓力位。<br />
# <br />
#  KD指標<br />
# KD指標顯示在超賣區域，K線與D線均向下，顯示出短期內仍有下跌壓力，但也可能出現技術性反彈。<br />
# <br />
#  MACD指標<br />
# MACD指標顯示空頭趨勢，DIF線與MACD線均在零軸下方，且柱狀體持續擴大，顯示出下跌動能強勁。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於空頭趨勢，短期內可能會有技術性反彈，但整體下行壓力仍大。建議投資者謹慎操作，若持有空頭部位可考慮適時停利，若考慮進場多頭，需等待明確的反轉信號。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股觀察

# %% [markdown]
# * 元大台灣50反1(00632R)
#   ![messageImage_1763428129997.jpg](attachment:c08a23ca-a497-40fa-9a11-9dcb014ecdff.jpg)
# * 南亞(1303)
#   ![messageImage_1763428425856.jpg](attachment:13cf3b0a-ab45-428d-a11c-3fd8beea207f.jpg)
# * 今國光(6209)
#   ![messageImage_1763429725087.jpg](attachment:330bb4ec-79d1-45f3-a7dd-31ff3095a280.jpg)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 台化(1326)
#   看法：回測頸線支撐有守。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1326')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=837x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-11-17<br />
# 十字線 : 2025-11-17<br />
# 孕育線／懷抱線 : 2025-11-17</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 28470張 ，十日均量 ＝ 40378張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中繼型態之上升旗形，型態範圍由2025-01-10開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-03-27開始到2025-05-07結束，估算目標價為29.45元。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-11-17死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-11-03當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表分析，以下是對當前市場狀況的技術分析：<br />
# <br />
#  價格趨勢<br />
# 近期價格呈現上漲趨勢，尤其在11月中旬出現明顯的上升，突破了多條移動平均線。近期價格回檔，但仍在較高位置。<br />
# <br />
#  價量關係<br />
# 在價格上漲期間，成交量顯著增加，顯示出多頭動能強勁。然而，最近幾日成交量有所減少，需注意是否有動能減弱的跡象。<br />
# <br />
#  支撐與壓力<br />
# - 支撐位：短期支撐位可考慮在32元附近，該位置接近近期回檔低點。<br />
# - 壓力位：上方壓力位在35.6元左右，為近期高點。<br />
# <br />
#  KD指標<br />
# KD指標顯示K線已從超買區回落，D線仍在高位，顯示短期可能有進一步回檔的風險，但整體仍在強勢區域。<br />
# <br />
#  MACD指標<br />
# MACD指標顯示多頭趨勢明顯，DIF線高於MACD線，且柱狀體仍為正值，顯示多頭動能仍在，但需注意柱狀體縮短，可能預示動能減弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於多頭趨勢中，但短期內可能面臨回檔壓力。建議投資者在支撐位附近觀察是否有止跌跡象，若價格能夠企穩並伴隨成交量增加，則可考慮進一步加碼。若價格跌破支撐位，則需謹慎考慮停損。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2024-12-10'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-08-22']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-06-20'
    bottom_price = range_prices.loc['2025-06-20']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-11-13'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1326','2024-07-08','2025-11-18',line_drawing_callback)
display(image)
# Out:
# 估算目標價為41.35元
# <PIL.Image.Image image mode=RGB size=866x482>

# %% [markdown]
# 籌碼面：
# 法人大買(+4792)：外資大買(+5674)、投信中立(0)、自營大賣(-882)。
# 主力小買(+1240)。
# 分公司買賣家數差分散(-42)。
# 融資大減(-3622)、融券大增(+407)。
