# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260315筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260315%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：加權指數開平盤附近，前高附近震盪整理。
# > ![messageImage_1776042046380.jpg](attachment:42eba60e-9dff-4409-b90d-cdd12c8a399e.jpg)

# %%
def line_drawing_callback( range_prices) :

    resistance_line_start_date = '2026-02-24'
    resistance_line_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    resistance_line_price      = range_prices.loc['2026-02-25']['Close'] 

    seq_of_seq_of_points=[
        [(resistance_line_start_date,resistance_line_price),(resistance_line_end_date,resistance_line_price)]
    ]

    linewidths=[3.0]
    
    colors=['xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：前高壓力
image = mysys.DrawOnKlineChart('TAIEX','2026-01-15','2026-04-13',line_drawing_callback)
display(image)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數也是平盤附近，但是小創高。
# > ![messageImage_1776042121435.jpg](attachment:127bea74-7cce-475e-bdad-fef285cf8de4.jpg)

# %%
def line_drawing_callback( range_prices) :
    
    surport_line1_start_date = '2026-03-17'
    surport_line1_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line1_price      = ( range_prices.loc['2026-03-18']['Close']  + range_prices.loc['2026-03-26']['High'] ) / 2

    surport_line2_start_date = '2026-02-26'
    surport_line2_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    surport_line2_price      = (range_prices.loc['2026-04-01']['High'] + range_prices.loc['2026-04-01']['Open']) / 2

    seq_of_seq_of_points=[
        [(surport_line1_start_date,surport_line1_price),(surport_line1_end_date,surport_line1_price)],
        [(surport_line2_start_date,surport_line2_price),(surport_line2_end_date,surport_line2_price)]
    ]

    linewidths=[5.0,2.5]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
# 盤後：支撐
image = mysys.DrawOnKlineChart('TPEx','2026-02-26','2026-04-13',line_drawing_callback)
display(image)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))

# %% [markdown]
# * 篩選結果
#   - 時碩工業(4566)：穩健續漲
#     ![260413_2.png](attachment:2d116c61-2ef8-4403-8f57-ad0a76726d67.png)
#   - 森鉅(8942)：穩健續漲
#     ![260413_3.png](attachment:7daef742-02a4-48ac-8758-500a895fc673.png)
#   - 全友(2305)：穩健續漲
#     ![260413_4.png](attachment:6bf4abf0-743d-4b6d-9e49-89288358f887.png)
#   - 晉倫(6151)：盤整觀察
#     ![260413_5.png](attachment:b46fce4b-5e58-4ca1-8ef0-df57062f94c4.png)
#   - 和益(1709)：技術突破
#     ![260413_6.png](attachment:3ed3d292-700b-4a8e-95a9-9ec43074e0d7.png)
#   - 磐亞(4707)：已到目標價
#     ![260413_7.png](attachment:7da28af2-413e-45fa-abc5-6458174801b9.png)
#   - 單井(3490)：技術突破
#     ![260413_8.png](attachment:85298c61-fc16-4f96-ba25-a36485149cf2.png)

# %% [markdown]
# * 觀察股列表
#   ![260413_1.png](attachment:30e6f464-a64e-46c0-b6cd-a3e9c754c60d.png)

# %% [markdown]
# * 分類整理
#   ![S__107937797.jpg](attachment:f518ffb1-f0f1-42bd-9e89-3ddda8192e17.jpg)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：走勢溫吞，在頸線之上狹幅整理。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-10-23'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-11-10']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)]
    ]

    linewidths=[2.0,10.0,10.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-10-09','2026-04-13',line_drawing_callback)
display(image)

# %% [markdown]
# 籌碼面：
# 法人○○( )：外資○○( )、投信○○( )、自營○○( )。
# 主力○○( )。
# 分公司買賣家數差○○( )。
# 融資○○( )、融券○○( )。
