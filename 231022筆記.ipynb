# %% [markdown]
# **上週五**歐美股市都續弱，費半指數和那斯達克的中長天期頭部，都隱約出現了，夜盤台指期下跌114點：
# ![messageImage_1697849281596.jpg](attachment:ffb56c24-5e9c-4398-8b8c-bb95b37243fc.jpg)
# ![messageImage_1697849293539.jpg](attachment:46765d30-3f3d-436d-b13f-af1895e3f17c.jpg)
# ![messageImage_1697849310964.jpg](attachment:eaa675f6-57f0-4b8c-8bac-e63b9d4f50a4.jpg)

# %% [markdown]
# ### 【周末影音解盤】未來一周，留意支撐
# 週五夜盤國際股市表現偏空，明天台股是否會有壓力？
# 台股指數相對穩定，但破底類股持續攀升，究竟甚麼原因？
# 未來多方最關鍵的機會，要留意哪個國家呢？
# 完整內容請參考影音解盤~
# https://www.facebook.com/kevinyang20180801/videos/1758917231203554

# %% [markdown]
# ### 本日進度
# * 參考 ： [Algorithmic Chart Pattern Detection](https://analyzingalpha.com/algorithmic-chart-pattern-detection)
# * 參考 ： [PatternPy: The Premier Python Package for Trading Pattern Recognition](https://github.com/keithorange/PatternPy)
