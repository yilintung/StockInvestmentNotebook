# %% [markdown]
# ### 📢 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】反彈遇壓，三種走勢路徑曝光！⚠️
# 週五的數位訂閱、週日的分享會都有提醒，目前台股正處於反彈架構，且已逐漸接近關鍵壓力區。昨天（週一）加權指數一度開高大漲近 500點，卻在接近壓力區時開高走低，留下明顯上影線，正如預期反彈遇阻。
# 📰 關稅新聞非實質利多？ 週末傳出「關稅豁免」利多消息，市場反應樂觀，但分享會已提醒——這其實是新版關稅鋪陳，並非真正大利多。週一美國補充聲明，也逐步印證我們的研判。
# 📉 反彈受阻，三種未來走勢規劃出爐！
# 由於反彈遇壓，短線可能上攻空間有限，下半周或有機會回測支撐，數位訂閱規劃了三種版本的走勢，而本周是關鍵觀察期，多看少做一動不如一靜，因為多空操作難度都高。
# 📌 目前來看，第二種走勢機率較高——短線回測支撐後，進入短中期的區間盤整，靜待新方向。
# 🔍 個股觀察現象：空方結構仍強！
# 90% 以上的個股雖呈現短線反彈或盤整，中長期仍偏空，甚至有頭部型態未解除。目前空方條件明顯占上風！
# 🛡️ 中長期風險仍未解除，警戒不容鬆懈。
# 💡 操盤建議：多看少做，一動不如一靜！
# 操作難度高，不論多空建議減少資金投入比例，等待趨勢明朗再行動。
# 📘 完整深度解析，請見「K線追擊周報」數位訂閱！
# 📤 歡迎分享，請註明出處：K線捕手 楊忠憲粉絲團 🔥
# ![491865574_1252299490237309_3199608953194895435_n.jpg](attachment:cdbd01b2-b056-4d96-a55f-238cd48067d8.jpg)

# %% [markdown]
# [立誠上櫃IPO失利 首宗受股災影響的案例](https://www.ctee.com.tw/news/20250414701277-430201?fbclid=IwY2xjawJq8y5leHRuA2FlbQIxMAABHhv1wXI5PlVG5UU6MLXFgivh9lcuwqOo4U91P9a4QZ_2zg15PSEMf213oQY5_aem_1SyZPjO01m18YsqbEYg-0g)
# 立誠（6597）股票上櫃初次募股（IPO）案，原將寫下縮短IPO定價至掛牌時程的首例，卻因競拍競拍投標期間， 剛好遇到川普關稅戰掀起的股災，致競拍宣告流標，也成為這波股災第一宗宣告競拍流標，將擇待捲土重來。
#
# [台股小跌15點 貨櫃、散裝啟航 蘋概股紅起來](https://www.ctee.com.tw/news/20250414700783-430201?fbclid=IwY2xjawJq81BleHRuA2FlbQIxMAABHl082UoK9mjvUhwhJZKW-UvVUbZ3UWw67L-M_6I6dz2Ojk6JHwzwS8wmSHZ9_aem_qfpWwUpsmWhAsz2SHP8oTw)
# 美國近日公布電腦、伺服器和積體電等關稅豁免名單，為部分消費電子產品業者暫開人道走廊，然而川普也表示，目前排除智慧型手機及電腦的政策僅是短暫的，並承諾會對半導體行業進行國家安全貿易調查。
# 高盛、花旗環球等外資紛紛下修台積電目標價，今日台積電開高走跌，盤中一度觸及9字頭，在經過整理後，下跌2.7％，以865元作收；聯發科上揚1.08％，以1,385元作收；鴻海放量20萬餘張，上漲2.97％，以138.5元作收。
#
# [法說會前內外資集體下修目標價 台積電重返900元大關只開心了五分鐘](https://www.ctee.com.tw/news/20250414700688-430201?fbclid=IwY2xjawJq84dleHRuA2FlbQIxMAABHm-OvQuCmXBtGAMzTe4KSl2B0fg0FtKc1G6fKctiyH_EnFaHrQ2_WtlZljTb_aem_WAru7Fu0FNvJp48vG1_lTw)
# 護國神山台積電法說會即將在17日登場，在川普關稅大刀花招百出下，股市風險大增，內外資罕見在台積電法說會前集體下修其目標價，其中尤以花旗環球目標價降幅最大，一口氣由1,400元調降至1,050元，利空當頭，台積電重返900元大關只高興了五分鐘。
#
# [Fed 理事沃勒：如果對等關稅恢復 聯準會可能必須快速且連續降息](https://money.udn.com/money/story/5599/8674716?from=edn_maintab_index&fbclid=IwY2xjawJq88lleHRuA2FlbQIxMAABHtWjMp6SfCls1tJfzetRzKynPly2DIYq5N2jnu3B9qIXIXJJFUo_AtIVYM6f_aem_z0qyxC02F_A_KLT6baHwdg)
# 美國聯準會（Fed）理事沃勒14日表示，如果川普恢復4月2日所宣布的大規模「對等式」關稅，Fed可能必須快速進行一系列的「利空式」降息，以提振美國經濟。
# 川普9日宣布「對等式」關稅暫停90天。沃勒表示，如果暫停之後又再恢復，則美國有效關稅稅率將從3%急升到25%，屆時美國經濟將「減緩到爬行」，失業率將從目前的4.2%「大幅度地」上升到5%。
#
# [台幣32字頭將成新常態 匯銀解讀：央行釋最大誠意 未干預匯價](https://money.udn.com/money/story/5616/8674458?fbclid=IwY2xjawJq8_NleHRuA2FlbQIxMAABHl082UoK9mjvUhwhJZKW-UvVUbZ3UWw67L-M_6I6dz2Ojk6JHwzwS8wmSHZ9_aem_qfpWwUpsmWhAsz2SHP8oTw)
# 受到美元指數跌破100大關，美元轉空訊號浮現、新台幣匯價昨（14）日早盤一度強勁升值逾2角，最高觸及32.448元，改寫逾四個月盤中新高紀錄，收盤雖守住32.5元，但仍強升1.95角，以32.51元作收，成交量爆出36.215億美元，史上第六大。
#
# [〈台股盤前要聞〉台積電衝關900元遭外資砍殺、台幣爆量狂漲近2角、散戶Q1湧進台股](https://m.cnyes.com/news/id/5938657?utm_source=App&utm_medium=android&utm_campaign=5938657)
#
# [關稅戰最大苦主！皇翔3.11億買299張台積電　每股均價1042元](https://finance.ettoday.net/news/2943317?from=fb_et_news_comment&before=1&fbclid=IwY2xjawJq9KtleHRuA2FlbQIxMQABHh-wCztzQCoeVtcfo8uA4xLXgrQ8MFO8gmPV9e6qzDgP7NkP4iQWjaNxLnPy_aem_NVYiW5HsM-pp_yaPhRi8RA)

# %% [markdown]
# 日本反彈力道趨緩，短線的支撐和壓力區間：
# ![messageImage_1744674521334.jpg](attachment:502c8f19-62a4-4b7b-b62c-95804c2244f4.jpg)
#
# 期貨開在平盤附近，變化不大：
# ![messageImage_1744677959119.jpg](attachment:df68c764-cff0-4de6-80b7-cb690cf00cce.jpg)
#
# 加權指數和櫃買指數小漲，維持箱型整理區間：
# ![740393.jpg](attachment:f3a304a1-b6d1-437e-bb7a-e599621a2386.jpg)
# ![740394.jpg](attachment:10ecebb6-ebf2-4bed-832c-33f6791db4b9.jpg)
#
# 今天成交量低，漲幅也不大，少數個別股表現，應該沒有太大波動，大家可以專心上班喔！1-2小時，偶而偷瞄一下就好~
#
# 加權指數的量能還是偏低，但櫃買指數有稍微放大。
#
# 加權指數貢獻排行：
# ![740544.jpg](attachment:4c118ce0-4a96-460c-8ba3-9f6bc3b0191b.jpg)
#
# 加權指數反彈到黃金分割率0.5的位置，櫃買指數距離黃金分割率0.5還有一些空間：
# ![messageImage_1744692697640.jpg](attachment:b8b8a455-9339-4e7b-9fc7-988dd42c3e3a.jpg)
# ![messageImage_1744692722511.jpg](attachment:c99d5506-3b54-4092-925a-54a7b2d7e810.jpg)
# 但不管加權指數或櫃買指數，預估量能都在10日均量之下，仍屬反彈格局。

# %% [markdown]
# 陞泰(8072)
# ![messageImage_1744678321919.jpg](attachment:0b651c36-9a6c-4856-93d2-4c247e0b648e.jpg)
# ![messageImage_1744679339854.jpg](attachment:d97b9ebe-8329-4943-bf50-8e4bd67dd509.jpg)
#
# 八方雲集(2753)
# ![messageImage_1744680218643.jpg](attachment:4eba873b-2e69-4ab4-99c5-f1c508c28b01.jpg)

# %% [markdown]
# 📢【[投資獲利靠的是專業還是運氣？](https://www.facebook.com/kevinyang20180801/posts/pfbid031f7UNJmcGyJUda1M5L43UrG22ehpLhvUdENevDzx93mRbtXcr18r5ZR9gJiy5QQhl)💰🎯】
# 很多人回頭看股價走勢時，總會感嘆：「如果我當初沒賣，現在不是賺翻了嗎？」但問題是——
# 🤔 你當時買進的理由是什麼？
# 🤔 你真的能一路抱到現在嗎？
# 這不只是運氣問題，而是看穿本質的實力比拚！
# 📌 別讓倖存者偏差誤導你！
# 換個情境想想：使用同樣的選股模式，但可能結果天差地遠。
# 📉 如果你不是買台積電，而是買了宏達電、力積電？
# 📉 不是買中華電，而是買了中鋼或台塑呢？
# 🎯 投資真正關鍵在於「選擇依據是否穩定可靠」！
# 🧠 投資不是賭運氣，而是建立決策框架！
# ✅ 對市場條件的理解
# ✅ 對交易策略的執行力
# ✅ 對風險的控制與修正能力
# 這些才是穩定獲利的底層邏輯。
# 💡 投資的關鍵不是「看對」或「看錯」——
# 而是：
# 🔧 看對時，你做了什麼？
# 🛡️ 看錯時，你怎麼應對？
# 成功的投資者會：
# 🔹 用小成本試錯
# 🔹 用風控機制容錯
# 🔹 用紀律與系統找出可複製的獲利模型
# 📈 穩定，是靠修正；成長，是靠驗證！
# 記住：投資從來不是一場賭局，而是一場靠智慧與紀律決勝的馬拉松。
#
# 💡[不是最完美，但最實用的重生技巧](https://www.facebook.com/kevinyang20180801/posts/pfbid022iGemngTktgsSgiEssEP7YUgQHBmin4DAPLh3YAjeg8gRrVsL2MKcPhK5JC3hEcZl)
# 如果你手上的股票滿滿都是套牢股，每天看著帳面虧損心情低落，甚至開始懷疑自己的交易能力——你不是一個人，這是每個投資人都會遇到的階段。
# 這時候，有一個說不上完美、甚至有點逃避的做法，但它實用得驚人。
# 🔄 重新開一個全新的帳戶，只投入一小筆資金，從零開始。
# 用這個新帳戶，練習我教過的選股濾網、交易策略，不要急著翻身，也不要回頭看那些跌深股。只專注在新帳戶的操作、紀律和心態。
# 📈 等你發現這個小帳戶開始穩定賺錢，心態也會隨之改變。 屆時你再回頭看那些套牢的股票，你會有不一樣的想法，甚至知道該怎麼處理。
# 是的，這個方法有點「鴕鳥心態」：
# 暫時把大虧損的股票擺到一邊，彷彿它們不存在。
# 但當你卡住、無法動彈時，這就是「沒有辦法中的辦法」。
# 若你本身能夠冷靜、果斷地處理虧損部位，那當然不需要用這一招。
# 但如果你正陷入迷惘，不如就先從這個小步驟開始，重新找回主導權。

# %% [markdown]
# ![740724.jpg](attachment:c98e43d1-4fdd-43d3-b075-6b811f93b064.jpg)
# ![740725.jpg](attachment:ca204def-feb3-4d3d-9daa-fef2864232a4.jpg)

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統
#   - 規劃技術分析資料庫。
#   - 後續將參照「F3933 服務專區 — 第 3 章 — [Colab 筆記本](https://colab.research.google.com/drive/159e8KXPYfx_vUia3sUC-k0QwDjYiBUl5)」與「[FinMind](https://finmind.github.io/) — 台灣市場 — [技術面](https://finmind.github.io/tutor/TaiwanMarket/Technical/#taiwanstockprice)」等資料進行調整。
#   - 參照[昨日筆記](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250414%E7%AD%86%E8%A8%98.ipynb)：發現價格資料只會在當期（日、周、月）結束後才會產出，並不像看盤軟體會在進行過程中產生『暫時』的資料。

# %% [markdown]
# ![250415_1.png](attachment:aeff1399-e9df-4894-8ead-884b1e06cab3.png)
#
# ```
# /*
# Created: 2025/4/15
# Modified: 2025/4/15
# Model: SQLite 3.32
# Database: SQLite 3.32
# */
#
# -- Create tables section -------------------------------------------------
#
# -- Table StockInfo
#
# CREATE TABLE StockInfo
# (
#   StockID TEXT NOT NULL,
#   StockName TEXT,
#   IndustryCategory TEXT,
#   Type TEXT,
#   CONSTRAINT PK_StockInfo PRIMARY KEY (StockID)
# )
# ;
#
# -- Table DailyPrice
#
# CREATE TABLE DailyPrice
# (
#   SerialNo INTEGER NOT NULL
#         CONSTRAINT PK_DailyPrice PRIMARY KEY AUTOINCREMENT,
#   StockID TEXT NOT NULL,
#   Date TEXT,
#   Open REAL,
#   High REAL,
#   Low REAL,
#   Close REAL,
#   Volume INTEGER,
#   CONSTRAINT PK_DailyPrice PRIMARY KEY (SerialNo,StockID),
#   CONSTRAINT FK1_DailyPrice UNIQUE (StockID),
#   CONSTRAINT Daily
#     FOREIGN KEY (StockID)
#     REFERENCES StockInfo (StockID)
# )
# ;
#
# -- Table WeeklyPrice
#
# CREATE TABLE WeeklyPrice
# (
#   SerialNo INTEGER NOT NULL
#         CONSTRAINT PK_WeeklyPrice PRIMARY KEY AUTOINCREMENT,
#   StockID TEXT NOT NULL,
#   Date TEXT,
#   Open REAL,
#   High REAL,
#   Low REAL,
#   Close REAL,
#   Volume INTEGER,
#   CONSTRAINT PK_WeeklyPrice PRIMARY KEY (SerialNo,StockID),
#   CONSTRAINT FK1_WeeklyPrice UNIQUE (StockID),
#   CONSTRAINT Weekly
#     FOREIGN KEY (StockID)
#     REFERENCES StockInfo (StockID)
# )
# ;
#
# -- Table MonthlyPrice
#
# CREATE TABLE MonthlyPrice
# (
#   SerialNo INTEGER NOT NULL
#         CONSTRAINT PK_MonthlyPrice PRIMARY KEY AUTOINCREMENT,
#   StockID TEXT NOT NULL,
#   Date TEXT,
#   Open REAL,
#   High REAL,
#   Low REAL,
#   Close REAL,
#   Volume INTEGER,
#   CONSTRAINT PK_MonthlyPrice PRIMARY KEY (SerialNo,StockID),
#   CONSTRAINT FK1_MonthlyPrice UNIQUE (StockID),
#   CONSTRAINT Monthly
#     FOREIGN KEY (StockID)
#     REFERENCES StockInfo (StockID)
# )
# ;
# ```

# %% [markdown]
# * 驗證：StockChartPatterns類別
#   - 後續會將「技術型態」的主觀性質客觀化之開發做個收尾。
#   - 參考書籍：[股價型態總覽﹒上](https://www.books.com.tw/products/0010146071)、[股價型態總覽﹒下](https://www.books.com.tw/products/0010146072)、[讓證據說話的技術分析(上)](https://www.books.com.tw/products/0010410837)。

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化：型態後處理程序之雛形
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            # 驗證：型態最後一個轉折點離價格資料距離
            print('◆ 型態最後一個轉折點離價格資料距離 ＝ {} '.format( date_to_index(prices,prices.iloc[-1].name) - date_to_index(prices,pattern_window.iloc[-1]['Date']) ))
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '上升旗形' or pattern_name == '下降旗形' or pattern_name == '看跌三角旗形' or pattern_name == '看漲三角旗形'  : 
                line1_start_date = pattern_window.iloc[1]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line1_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line2_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
def normalization(data) :
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# %%
# 型態視覺化：型態後處理程序之雛形
def gpt4o_patterns_visualization(prices,patterns) :
    if type(patterns) is list :
        for pattern in patterns :
            print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
            range_price = prices[pattern['start']:pattern['end']]
            if pattern['type'] == '頭肩頂' or pattern['type'] == '雙頂' or pattern['type'] == '圓弧頂' :
                # 使用自動趨勢線繪製頸線
                chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
                params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
                # 將趨勢線進行正規化，求頸線真正的角度
                # 趨勢線價格正規化
                line_prices_list = []
                line_prices_list.append(lines[0][0][1])
                line_prices_list.append(lines[0][1][1])
                line_prices_list.append(lines[1][0][1])
                line_prices_list.append(lines[1][1][1])
                line_prices      = np.array(line_prices_list)
                line_prices_norm = normalization(line_prices)
                ## 求斜率並轉換成角度
                line1_x      = [0.0, 1.0]
                line1_y      = [line_prices_norm[0],line_prices_norm[1]]
                line2_x      = [0.0, 1.0]
                line2_y      = [line_prices_norm[2],line_prices_norm[3]]
                line1_angle  = np.rad2deg(np.arctan2(line1_y[1] - line1_y[0] , line1_x[1] - line1_x[0]))
                line2_angle  = np.rad2deg(np.arctan2(line2_y[1] - line2_y[0] , line2_x[1] - line2_x[0]))
                neckline_angle = abs(line1_angle)
                if neckline_angle > 15.0 :
                    lowest_point = sys.float_info.max
                    for index,price in range_price.iterrows() :
                        if price['Open'] < lowest_point :
                            lowest_point = price['Open']
                        if price['Close'] < lowest_point :
                            lowest_point = price['Close']
                    seq_of_seq_of_points = [(lines[0][0][0],lowest_point),(lines[0][1][0],lowest_point)]
                else :
                    seq_of_seq_of_points = lines[0]
                # 設定K線格式
                mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
                s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
                # 繪製K線圖
                kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
                mpf.plot(prices,**kwargs)
            else :
                # TODO : 待確認與實作
                pass
    else :
        # 回傳值不符合要求，列印出來以做確認
        print(patterns)

# %%
##### 使用2023年11月7日到今日(2025年4月15日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250415.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定支撐線與壓力線
support_line_start_date = '2024-01-05'
support_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
support_price           = df_k_line.loc['2025-04-10']['Low']
resistance_line_start_date = '2024-03-07'
resistance_line_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
resistance_price           = df_k_line.loc['2024-08-06']['Low']
seq_of_seq_of_points=[
    [(support_line_start_date,support_price),(support_line_end_date,support_price)],
    [(resistance_line_start_date,resistance_price),(resistance_line_end_date,resistance_price)]
]
print('支撐線指數 ＝ {:.2f} ， 壓力線指數 ＝ {:.2f}'.format(support_price,resistance_price))

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=2.2, colors=('xkcd:red','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)
# Out:
# 支撐線指數 ＝ 18256.47 ， 壓力線指數 ＝ 19662.74

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':25})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 25}]
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 50        2024-01-17  17161.79   LO
# 164       2024-07-11  24390.03   HI
# 179       2024-08-05  19830.88   LO
# 229       2024-10-18  23620.57   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 115
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 179       2024-08-05  19830.88   LO
# 229       2024-10-18  23620.57   HI
# 258       2024-11-29  22202.28   LO
# 284       2025-01-07  23824.72   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 60
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 229       2024-10-18  23620.57   HI
# 258       2024-11-29  22202.28   LO
# 284       2025-01-07  23824.72   HI
# 288       2025-01-13  22488.33   LO
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 56
# ＃＃＃ 看漲三角旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 50        2024-01-17  17161.79   LO
# 164       2024-07-11  24390.03   HI
# 179       2024-08-05  19830.88   LO
# 229       2024-10-18  23620.57   HI
# 258       2024-11-29  22202.28   LO
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 86
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 179       2024-08-05  19830.88   LO
# 229       2024-10-18  23620.57   HI
# 258       2024-11-29  22202.28   LO
# 284       2025-01-07  23824.72   HI
# 288       2025-01-13  22488.33   LO
# 310       2025-02-21  23730.25   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 34

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'high_low', 'order':25})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'high_low', 'order': 25}]
# ＃＃＃ 雙重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'high_low', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 50        2024-01-17  17151.58   LO
# 164       2024-07-11  24416.67   HI
# 180       2024-08-06  19662.74   LO
# 229       2024-10-18  23713.70   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 115
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'high_low', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 180       2024-08-06  19662.74   LO
# 229       2024-10-18  23713.70   HI
# 258       2024-11-29  22055.38   LO
# 284       2025-01-07  23943.95   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 60
# ＃＃＃ 看漲三角旗形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'high_low', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 50        2024-01-17  17151.58   LO
# 164       2024-07-11  24416.67   HI
# 180       2024-08-06  19662.74   LO
# 229       2024-10-18  23713.70   HI
# 258       2024-11-29  22055.38   LO
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 86
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'high_low', 'order': 25}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 180       2024-08-06  19662.74   LO
# 229       2024-10-18  23713.70   HI
# 258       2024-11-29  22055.38   LO
# 284       2025-01-07  23943.95   HI
# 288       2025-01-13  22458.22   LO
# 310       2025-02-21  23732.58   HI
# ◆ 型態最後一個轉折點離價格資料距離 ＝ 34

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()
gpt4o_patterns_visualization(df_k_line,patterns)
# Out:
# 型態類型 ＝ 頭肩頂 ， 型態開始日期 ＝ 2024-06-18 ， 型態結束日期 ＝ 2025-01-21
