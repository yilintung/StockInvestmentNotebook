# %% [markdown]
# #### 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# #### 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-07-23 22:56:34.176 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# ##### 更新技術分析資料 #####
# 2025-07-23 22:57:01.040 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:57:06.415 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:57:36.946 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:57:42.398 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:58:12.556 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:58:17.994 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:58:48.404 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:58:53.519 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 2025-07-23 22:59:10.670 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockPrice, data_id:
# 日K：2025-07-23

# %% [markdown]
# #### 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %%
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-18 , 2025-07-21</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 3609.09億元 ，十日均量 ＝ 3509.18億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.25。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-21死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-23當周黃金交叉。並且2025-07-14該周在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 從圖中可以看到，股價整體呈現上漲趨勢。K線大多數為紅色，顯示多頭力量較強。短期移動平均線（5日和10日）均向上，並且位於中期移動平均線（20日和60日）之上，顯示出強勁的上升動能。<br />
# <br />
#  價量關係<br />
# 成交量在上漲過程中有明顯增加，顯示出價量配合良好，支持上漲趨勢。然而，最近幾個交易日成交量略有減少，需注意是否會影響後續的上漲動能。<br />
# <br />
#  支撐與壓力判斷<br />
# 目前股價的支撐位可參考20日移動平均線，若股價回檔至此位置，可能會有支撐作用。壓力位則可觀察近期高點，若能有效突破，將有機會繼續上行。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線和D線均位於超買區域，且K線已經開始向下交叉D線，這可能預示著短期內有回檔的風險，需密切關注後續走勢。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線位於MACD線之上，且灰色柱體（OSC）為正值，顯示出多頭趨勢仍在延續。然而，需注意柱體有縮短的跡象，可能預示著動能減弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場仍處於上升趨勢中，但短期內可能面臨回檔壓力。建議投資者在此階段謹慎操作，若持有多單可考慮適時停利，並密切關注支撐位的表現。若股價能夠在支撐位獲得支撐並放量上漲，則可考慮加碼進場。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %%
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>墓碑線 : 2025-07-21</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 774.23億元 ，十日均量 ＝ 985.62億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線下彎、60日線上揚，中期盤整；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-22死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-02當周死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 近期價格呈現盤整狀態，K線在短期移動平均線（5日、10日）附近波動，並未出現明顯的上升或下降趨勢。中期移動平均線（20日、60日）則顯示出較為平緩的走勢，顯示市場缺乏明確的方向。<br />
# <br />
#  價量關係<br />
# 成交量在近期有些許放大，但並未出現明顯的價量配合現象。價格波動時，成交量並未顯著增加，顯示市場參與者對當前價格區間的興趣有限。<br />
# <br />
#  支撐與壓力判斷<br />
# 目前支撐位可觀察230點附近，該位置曾多次提供支撐。壓力位則在235點左右，價格多次在此遇阻回落。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線已經跌破D線，並且從高位快速下滑，顯示短期內有回檔壓力。K值接近超賣區，需留意是否會進一步下探。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線與MACD線接近零軸，且柱狀體縮短，顯示市場動能減弱，短期內可能維持盤整或小幅波動。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於盤整階段，缺乏明確的上升或下降動能。建議投資者謹慎觀望，等待價格突破支撐或壓力位後再行操作。若價格跌破支撐位，需考慮停損；若突破壓力位，則可考慮適度加碼。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 燿華(2367)
#   看法：突破後回測頸線，但籌碼不集中(法人持續賣超)。

# %%
stock_analysis(analysis,'2367')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股爆量（成交量 ＝ 24724張 ，十日均量 ＝ 13093張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-09-26開始到2025-01-09結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-07開始到2025-04-29結束，估算目標價為28.19。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線下彎，長期翻空</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-10黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-06-30當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>根據圖表進行技術分析如下：<br />
# <br />
#  價格趨勢<br />
# 近期股價呈現上漲趨勢，尤其在最近幾個交易日中，價格快速上升，突破了多條移動平均線。短期5日和10日均線向上，顯示出強勁的上升動能。<br />
# <br />
#  價量關係<br />
# 成交量在最近幾個交易日顯著增加，尤其是在價格上漲時，顯示出多頭的強勢。這種價量配合通常預示著上漲趨勢的延續。<br />
# <br />
#  支撐與壓力<br />
# 目前股價已經突破前期高點，形成新的支撐位，約在26元附近。壓力位則可能在30元左右，需觀察股價在此區域的表現。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線和D線在高位，且K線已經從超買區回落，這可能預示著短期內有回檔的風險。需要密切關注KD指標的變化，以防止過度回檔。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線在MACD線之上，且灰色柱體顯示出正值，表明目前仍處於多頭市場。然而，需注意柱體的縮短，可能預示著動能減弱。<br />
# <br />
#  綜合評價<br />
# 整體來看，股價目前處於上升趨勢，且價量配合良好。然而，需注意短期內可能的回檔風險，尤其是KD指標顯示超買後的回落。建議投資者在此階段謹慎操作，考慮在支撐位附近進行佈局，並設置適當的停損和停利點。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-25'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-13']['Open']

    # 設定底部到頸線差距
    bottom_date  = '2025-06-23'
    bottom_price = range_prices.loc['2025-06-23']['Open']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    # 設定突破日期
    breakout_date = '2025-07-22'
    
    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)],
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2367','2024-12-30','2025-07-23',line_drawing_callback)
# Out:
# 估算目標價為30.45元

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-4855)：外資大賣(-4732)、投信中立(0)、自營小賣(-123)。
# 主力大賣(-4163)。
# 分公司買賣家數差分散(-38)。
# 融資減(-60)、融券增(+80)。

# %% [markdown]
# * 台塑(1301)
#   看法：轉強有底部雛形，尚未突破。

# %%
stock_analysis(analysis,'1301')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-07-22</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 34692張 ，十日均量 ＝ 30429張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重底，型態範圍由2025-04-07開始到2025-07-18結束，估算目標價為42.97。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-14黃金交叉。並且2025-07-23於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>周Ｋ－周ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2025-07-14當周黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 近期價格呈現上漲趨勢，尤其在最近幾個交易日中，價格快速上升，突破了多條移動平均線，顯示出強勁的多頭動能。<br />
# <br />
#  價量關係<br />
# 成交量在價格上漲時同步放大，顯示出多頭的強勢，價量配合良好，支持價格的上漲趨勢。<br />
# <br />
#  支撐與壓力判斷<br />
# - 支撐位置：短期支撐可參考5日移動平均線，約在38元附近。<br />
# - 壓力位置：目前價格接近40元，可能面臨心理壓力位。<br />
# <br />
#  KD指標解讀<br />
# KD指標顯示K線與D線均位於超買區（&gt;80），但K線仍高於D線，顯示出強勢的多頭趨勢。然而，需注意可能的回檔風險。<br />
# <br />
#  MACD指標解讀<br />
# MACD指標中，DIF線高於MACD線，且灰色柱體持續增長，顯示出多頭趨勢強勁，短期內仍有上漲空間。<br />
# <br />
#  綜合評價<br />
# 整體來看，市場目前處於強勢多頭趨勢，價格上漲伴隨著成交量的放大，顯示出市場的買盤力量。然而，由於KD指標進入超買區，需警惕短期回檔的可能性。建議投資者可考慮在支撐位附近進行佈局，並設置適當的停損點以控制風險。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ![250723_1.png](attachment:10bcdbdd-bcaf-47ad-8cf2-66689d9f8098.png)

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2024-11-29'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-03-21']['Open']

    # 設定底部到頸線差距
    bottom_date  = '2025-01-10'
    bottom_price = range_prices.loc['2025-01-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(neckline_end_date,neckline_price),(neckline_end_date,target_price)],
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1301','2024-09-20','2025-07-23',line_drawing_callback)
# Out:
# 估算目標價為49.55元

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大買(+10976)：外資大買(+7957)、投信小買(+924)、自營大買(+2095)。
# 主力大買(+8751)。
# 分公司買賣家數差集中(+92)。
# 融資增(+904)、融券增(+486)。
