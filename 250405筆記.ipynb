# %% [markdown]
# ### [K線捕手](https://www.facebook.com/kevinyang20180801/)

# %% [markdown]
# [美股遭近5年最嚴重拋售 道瓊重挫近1700點](https://tw.news.yahoo.com/%E7%BE%8E%E8%82%A1%E9%81%AD%E8%BF%915%E5%B9%B4%E6%9C%80%E5%9A%B4%E9%87%8D%E6%8B%8B%E5%94%AE-%E9%81%93%E7%93%8A%E9%87%8D%E6%8C%AB%E8%BF%911700%E9%BB%9E-224332649.html)
#
# [川普關稅大刀引爆美股暴跌逾千點 台積電ADR重挫6％ 台股面臨2萬點保衛戰](https://tw.news.yahoo.com/%E5%B7%9D%E6%99%AE%E9%97%9C%E7%A8%85%E5%A4%A7%E5%88%80%E5%BC%95%E7%88%86%E7%BE%8E%E8%82%A1%E6%9A%B4%E8%B7%8C%E9%80%BE%E5%8D%83%E9%BB%9E-%E5%8F%B0%E7%A9%8D%E9%9B%BBadr%E9%87%8D%E6%8C%AB6-%E5%8F%B0%E8%82%A1%E9%9D%A2%E8%87%A82%E8%90%AC%E9%BB%9E%E4%BF%9D%E8%A1%9B%E6%88%B0-233653924.html)
#
# [快訊／中加徵美34%關稅！美股盤前狂殺千點 三大指期跳水](https://news.ebc.net.tw/news/business/482046?fbclid=IwY2xjawJda5JleHRuA2FlbQIxMQABHhDPiaMdq6MXOPvFSRYUk56GuSRdzQVftZ1pRxoq4qOLc7WZ8MQK31EMQaoq_aem_ldCNzwCr-GJng-Egn_Gmuw)

# %% [markdown]
# [川普又再度出招](https://www.facebook.com/kevinyang20180801/posts/pfbid035iZcAjPCFKM9PYe11wqP8WTeUCCdUbhxAybSJnGueAhQAGmtrJbeiFQkWATbzz4Hl)，對於後市盤勢觀點看法，有興趣的請參考數位訂閱。
#
# [技術分析](https://www.facebook.com/kevinyang20180801/posts/pfbid0J2MzZ3mamqTLZkjocAcxEBSAWHAT4ahN2Hiju6NqK8hzuyyRgyGrXnWAUC4nK5XXl)是散戶投資人，最誠實和值得信賴的好朋友。
#
# [在投資的世界裡](https://www.facebook.com/kevinyang20180801/posts/pfbid02BjGiw59jxpo4tzPsByqazqd9UPcA5JGLosEheLroRUZEEnE3QuHnV7Xi6Cdjz6X5l)，
# 尤其交易的時候，
# 多一些作為，少一些以為。
# 不要做超過能力圈以外的分析，因為那是徒勞無功的。
#
# [經過連日大跌](https://www.facebook.com/kevinyang20180801/posts/pfbid02XrBXdp8jS8wtZ1S6L7mGWkxJKujKvWGnVAKATdRwiNCus4ZwZEJdTgV8Z162tGdMl)，我知道同學有很多疑問，尤其持股部位很高、資金重壓的同學，壓力一定更大，但既然放假了，就專心放假吧！
# 能解決的問題就不用擔心，解決不了的問題，擔心也沒有用，周日會提早解盤，大家記得看。
# 重點是不管你周一要續抱、要停損、要加碼、要攤平、要搶反彈、要作空，記得好好想清楚，一定要把策略文字化，隔天才能按表操課。
# ![488048827_1241524087981516_5302621595946875028_n.jpg](attachment:2bf24e3d-57bb-47fc-a17c-a052d2e99db8.jpg)
#
# [最近的心情](https://www.facebook.com/kevinyang20180801/posts/pfbid0pQMjHf2KFRU6iMto7RUKYqbAegtf5CpTn6ubifRmVW5FXudaKgeDLPqGsu3gZeyzl)...
# 說了你又不聽，聽了你又不懂，懂了你又不做，做了你又做錯，錯了你又不認，認了你又不改，改了你又不服，不服你又不說！你讓我怎麼做——《江湖》
#
# [這兩天明明休市](https://www.facebook.com/kevinyang20180801/posts/pfbid02kaswVRXD5uRi7USrynwRoVNwqSJVx1QMbKDvuMpN1xXBpcUJbusepoc96YeaHBH1l)，但投資人心情卻比平常波動更大！
#
# [美國關稅政策衝擊全球市場](https://www.facebook.com/kevinyang20180801/posts/pfbid0QHVANvGDbtSpA6MnjZ9LyyPsCwsDw5DvghhuYXsZbQSDLx7JKs7nMU752JKTnE3ol)，美股持續重挫，三大指數跌幅均超過5%。道瓊工業指數終場下跌2231.07點，或5.50%，收在38314.86點。標普500下跌322.44點，或5.97%，收在5074.08點。科技股為主的那史達克下跌962.82點，或5.82%，收在15587.79點，從高點累計跌超過22%，進入熊市。
# ![488663592_1241950854605506_2359300814224696231_n.jpg](attachment:05d6f4bd-18e1-410d-a9ad-28655afd3b8e.jpg)
#
# [現在回頭看這篇10天前寫的文章](https://www.facebook.com/kevinyang20180801/posts/pfbid0A36MG6YWnpBzDTkFDWUtzDtSKnkyENcSGbjmiBpbw5do17CjdLQiDow3P7WNe4HLl)，體會一定很深。
# 📉【會不會長期翻空，其實不重要】📈
# 💡 當股市單日跌幅較大時，很多投資人會緊張地問：「股市會不會崩盤？」（或中性地說是「長期空頭」）。但其實，這是個很難回答的問題，因為「崩盤」的定義…
# https://www.facebook.com/kevinyang20180801/posts/1232877438846181
#
# [轉傳同學分享](https://www.facebook.com/kevinyang20180801/posts/pfbid02c2X4eJFXeNVybvhE9KrLQ8yfrJgnnDHHvi9PZEW2GJxPw5WJR1zwVDyum75pfMnJl):
# 老師早安～ 昨晚開心地看了安德烈波伽利演唱，散場後看到美股繼續大跌，心情五味雜陳，想到前幾年的無知聽信投顧買股大賠，心理崩潰大哭時，遇見老師的書，看到曙光，決定上一年多老師的課，收穫太多人，知識就是力量一點都不為過！
# 家中長輩曾經2、30年前慘賠3千多萬，現在看到小孩可以安穩地在股市進出，感到欣慰。謝謝老師的開課還有每天群組的分享，改變了我們散戶的認知與心態，帶來好運，感恩～
#
# [台股跌破年線](https://www.facebook.com/kevinyang20180801/posts/pfbid02y1LbHf9XNs6QZ7cG2SRJ9tpHbsW7fPRoxJPRNnYuktAdFBBSZsgqJ77ytZBBRMoxl)，清明會變盤？[楊忠憲](https://money.udn.com/money/story/12040/8649853?utm_source=facebook&utm_medium=ednmoney&utm_campaign=fanpage_post&fbclid=IwY2xjawJdl5JleHRuA2FlbQIxMAABHlZgUBFwr94aEuspQxjq5xao4sdWU3NHgT-IYnhNlrZ028F2I-mGFVTBoHDV_aem_b-lgVmgVDB2WY-I_xnqy0w)：櫃買指數早在去年已現空頭「一波比一波低」...止跌5大關鍵

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統
#   - 調整StockChartPatterns類別
#     * 取消[4月3日](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250403%E7%AD%86%E8%A8%98.ipynb)的作法，改為仍於類別內建立[OpenAI物件](https://pypi.org/project/openai/)。

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
##### 使用2024年7月22日到今日(2025年4月2日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250402.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別(GPT-4o版)
patterns = chart_pattern.RecognitionUsingGPT4o()

# %%
# 檢討後處理程序
if type(patterns) is list :
    for pattern in patterns :
        print('型態類型 ＝ {} ， 型態開始日期 ＝ {} ， 型態結束日期 ＝ {} '.format(pattern['type'],pattern['start'],pattern['end']))
        range_price = df_k_line[pattern['start']:pattern['end']]
        if pattern['type'] == 'Head and Shoulders' or pattern['type'] == 'Double Top' or pattern['type'] == 'Triple Top' :
            # 使用自動趨勢線繪製頸線
            chart_pattern        = myutils.StockChartPatterns(range_price,debug=True)
            params,lines         = chart_pattern.TrendlineAutomation(mode='open_close')
            seq_of_seq_of_points = lines[0]
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(df_k_line,**kwargs)
        else :
            # TODO : 待確認與實作
            pass
else :
    print(patterns)
# Out:
# 型態類型 ＝ Head and Shoulders ， 型態開始日期 ＝ 2024-10-07 ， 型態結束日期 ＝ 2025-02-03
# 型態類型 ＝ Double Top ， 型態開始日期 ＝ 2024-11-13 ， 型態結束日期 ＝ 2025-02-03
# 型態類型 ＝ Downtrend ， 型態開始日期 ＝ 2025-02-03 ， 型態結束日期 ＝ 2025-03-11
