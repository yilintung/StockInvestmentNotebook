# %% [markdown]
# ### 工作進度
# * 【置頂】**筆記內容架構**與**量化技術分析系統**相關資訊請參閱[260531筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/260531%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if results is not None :
        if buttom_pattern is True and '底部型態' in images :
            print('底型反轉交易策略：')
            display(images['底部型態'])
        print('解盤內容：')
        if '整體評價' in images and images['整體評價'] is not None  :
            display(images['整體評價'])
        result_md   = results.to_markdown(tablefmt="grid")
        result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
        display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdateStockDatabase()
# Out:
# 2026-07-13 21:50:47.427 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-07-13 21:50:47.478 | INFO     | FinMind.data.finmind_api:login_by_token:85 - Login success
# 2026-07-13 21:50:47.488 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 00775B：股票名稱 ＝ 台新投等債15+，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 00904：股票名稱 ＝ 台新臺灣半導體30，產業類別 ＝ ETF，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 009805：股票名稱 ＝ 台新美國電力基建，產業類別 ＝ ETF，類型 ＝ twse
# 新增股票代碼。代碼 ＝ 00990B：股票名稱 ＝ 國泰收益非投等債，產業類別 ＝ 上櫃ETF，類型 ＝ tpex
# 修改股票資訊。代碼 ＝ 1598：股票名稱 ＝ 岱宇，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1720：股票名稱 ＝ 生達，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1721：股票名稱 ＝ 三晃，產業類別 ＝ 化學工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1727：股票名稱 ＝ 中華化，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1730：股票名稱 ＝ 花仙子，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1731：股票名稱 ＝ 美吾華，產業類別 ＝ 生技醫療業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1736：股票名稱 ＝ 喬山，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 1760：股票名稱 ＝ 寶齡富錦，產業類別 ＝ 化學生技醫療，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數和櫃買指數都上漲，但都還在盤整區間。
# >    ![536191.jpg](attachment:ae1c1677-df3d-4f38-945d-4f6b95c35350.jpg)

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>鎚子線／吊人線 : 2026-07-08<br />
# 吞噬 : 2026-07-09<br />
# 孕育線／懷抱線 : 2026-07-08</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 10676.62億元 ，十日均量 ＝ 11202.49億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之雙重頂，型態範圍由2026-06-15開始到2026-07-13結束，估算目標價為40689.57點。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **盤後**：量化技術分析
# > * 「量化技術分析工具」中之「型態」項目的描述於現階段較無意義。參照以下描述與圖表：
# >    **開盤**：加權指數和櫃買指數都上漲，但都還在盤整區間。
# >    ![536192.jpg](attachment:35bab8a5-62c3-49a9-92c1-6ca46271580d.jpg)

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-07-08<br />
# 吞噬 : 2026-07-13<br />
# 孕育線／懷抱線 : 2026-07-08</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 2128.49億元 ，十日均量 ＝ 2372.76億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之矩形，型態範圍由2026-06-22開始到2026-07-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 9925 ， 股票名稱 ＝ 新保
# 股票代碼 ＝ 6603 ， 股票名稱 ＝ 富強鑫
# 股票代碼 ＝ 4106 ， 股票名稱 ＝ 雃博
# 股票代碼 ＝ 3704 ， 股票名稱 ＝ 合勤控
# 股票代碼 ＝ 3564 ， 股票名稱 ＝ 其陽
# 股票代碼 ＝ 2889 ， 股票名稱 ＝ 國票金
# 股票代碼 ＝ 2465 ， 股票名稱 ＝ 麗臺

# %% [markdown]
# * 篩選結果
#   - 漢翔(2634)：穩健續漲
#     ![260713_2.png](attachment:5e0c7497-c6b3-4191-a5a1-5080aa65c4e2.png)
#   - 上海商銀(5876)：穩健續漲
#     ![260713_3.png](attachment:a8d30cfa-39fa-4b83-ac78-989244af0c3c.png)
#   - 台塑(1301)：穩健續漲
#     ![260713_4.png](attachment:156e92b0-ce3a-4851-b564-1ba86d3315a2.png)
#   - 巨大(9921)：盤整觀察
#     ![260713_5.png](attachment:d7274788-8db5-42cf-8912-c5aa0e3ddf03.png)

# %% [markdown]
# * 觀察股列表
#   ![260713_1.png](attachment:66b9b3e3-f761-470d-a373-4eb992bbe2d2.png)

# %% [markdown]
# * 技術面+籌碼面分類整理表
#   ![535762.jpg](attachment:be4463e6-e95d-4056-a215-9b2f874d7342.jpg)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 大成(1210)
#   看法：持續反彈，但仍未過前波「假突破」壓力。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'1210')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>（未識別出Ｋ線型態）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 2824張 ，十日均量 ＝ 3679張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>底型反轉之底部型態，型態範圍由2025-08-11開始到2026-07-02結束，2026-07-06時已達估算之目標價（59.00元）。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線下彎、10日線上揚，短期盤整；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線下彎，長期盤整</p>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-08-08'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2026-06-11']['Open']

    # 設定底部日期與價格
    bottom_date  = '2026-03-04'
    bottom_price = range_prices.loc['2026-03-04']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2026-07-02'
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('1210','2025-04-28','2026-07-13',line_drawing_callback)
display(image)
# Out:
# 估算目標價為61.40元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小賣(-551)：外資小賣(-782)、投信小買(+214)、自營( )。
# 主力小買(+437)。
# 分公司買賣家數差集中(+119)。
# 融資中立(-12)、融券中立(0)。
