%% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤後快訊】短線轉弱，回測支撐
# 加權指數今天開低走低，加上台幣趨貶，終場下跌75點，成交量3209億，收在17576，守穩支撐區17516，撐盤要角明顯為鋼鐵和航運，拖累指數的類股有電機機械、汽車、水泥、玻璃陶瓷、電子零組件。櫃買指數更為弱勢，跌回盤整區間，直接回測20日線，所幸成交量萎縮，還算是價跌量增的多方結構，而且依照扣抵20日線，至少一周內還有支撐
# 加權指數在續漲過程中，要留意四個現象，首先是價量關係失衡，指續攻過程要溫和放量，但不宜出現5200億以上的高檔爆量現象，或是價跌量增的空方價量結構，例如12月18日雖然下跌，但成交量不足3500億，屬於價跌量縮的價量關係，所以仍是安全的狀態。其次是未來倘若指數回檔，要密切留意MACD是否出現高檔背離，這屬於中期高檔轉弱的領先指標。
# 第三是籌碼異常，外資和投信現貨同步出現大賣，而融資持續大增，這代表籌碼從法人手中流向散戶，籌碼分散不力於盤勢推升。最後是短線轉折是指支撐不能跌破，以目前來說，關鍵支撐是盤整高點17528，為盤整區間上緣，這個關鍵支撐不能跌破。
# 雖然目前雖然持續往多方推進，但多方有些瑕疵和隱憂，首先是類股結構，電子和金融有漲多熄火現象，支撐盤勢動能轉向傳產和資產股，這是指數波段漲勢尾聲常有的現象，加上多方接棒的個股還不夠多，幾乎都是原先已經突破或是上漲，所以如果續航力道要紮實，可能還需要有更多生力軍加入。
# 其次，外資期貨未平倉空單口數，從上周三起接連3個交易日，都攀升到接近萬口附近，今天期貨已經攀升到空單17223口，先前一直提到，5千口以下的多空單，不具備實質意義，但萬口以上就不能單純視為避險空單，而是外資有可能轉為積極作空的序曲。
# 最後是櫃買指數，如果持有中小型股比重較多，要同步留意後續櫃買指數走勢，只看加權指數會容易失真。而且台股一直以來的慣性，櫃買指數都是內資法人和主力作手的主戰場，這些業內高手對於股市的敏銳度，往往比外資法人更高，不論創高或下跌更具備領先的意義。 (歡迎分享，請載明出處K線捕手楊忠憲粉絲團)
# ![410263829_741543098011530_1617917589368062193_n.jpg](attachment:f5f29b11-bc14-4fcf-811f-d58e0d84d54a.jpg)

# %% [markdown]
# ### 本日進度
# * **暫時空手**，觀察後續盤勢發展。
# * 追蹤：燁輝(2023)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 使用2021年09月28日到今日收盤(2023年12月19日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2023_231219.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA20','SMA60','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 設定頸線
neckline_start_date = '2022-04-22'
neckline_end_date = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_price = df_k_line.loc['2023-02-24']['Open']

# 估算目標價
bottom_price_date = '2022-09-28'
breakthrough_date = '2023-12-15'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('頸線價格 ＝ {:.2f}元 ， 底部最低價格 ＝ {:.2f}元 ； 估算目標價 ＝ {:.2f}元'.format(neckline_price,bottom_price,target_price))
# Out:
# 頸線價格 ＝ 17.70元 ， 底部最低價格 ＝ 13.15元 ； 估算目標價 ＝ 22.25元

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(breakthrough_date,neckline_price),(breakthrough_date,target_price)]
                     ]

# 設定均線
added_plots={
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.4,color='xkcd:dark orange')
    
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.0,10,10), colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1000)

mpf.plot(df_k_line,**kwargs)

# %%
import myutils

# 擷取區間
df_k_line_range = df_k_line.loc['2022-06-08':]
df_sma_range = df_sma.loc['2022-06-08':]

# 尋找轉折點
#_,_,max_min = myutils.FindingTurningPoints(df_k_line_range,'open_close',order=20)
_,_,max_min = myutils.FindingTurningPoints(df_k_line_range,'open_close',order=25)

# 顯示轉折點
display(max_min)
# Out:
#                 Date  Price Type
# DateIndex
# 79        2022-09-28  13.15   LO
# 176       2023-02-24  17.70   HI
# 288       2023-08-14  14.40   LO
# 375       2023-12-18  18.85   HI

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定均線與轉折點    
turning_points_len = len(np.array(df_k_line_range['Close']))
turning_points = np.array([np.nan]*turning_points_len)
for point in max_min.iterrows() :
    turning_points[point[0]] = point[1]['Price']    
apds = [
    mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=50,color='xkcd:sky blue'),
    mpf.make_addplot(df_sma_range['SMA20'],width=1.0,color='xkcd:violet'),
    mpf.make_addplot(df_sma_range['SMA60'],width=0.4,color='xkcd:dark orange')
]

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=apds)
mpf.plot(df_k_line_range,**kwargs)
