# %% [markdown]
# ### [K線捕手](https://www.facebook.com/kevinyang20180801/)

# %% [markdown]
# [汽車、藥品、半導體３產業關稅 川普擬25%起跳](https://readers.ctee.com.tw/cm/20250220/a01aa1/1333533/share?fbclid=IwY2xjawIjZr5leHRuA2FlbQIxMQABHSlPCSFrf-1BiDA_mWXgstHnOc8jOUjKpw0cXDw2n2Nob2gY1egMLYLqZA_aem_h6HOUi9pCqkPyHDmV6YuWA)
#
# [台股利空鈍化 輝達財報等題材接力 法人估多頭氣勢可再點燃](https://www.ctee.com.tw/news/20250220700052-430201?fbclid=IwY2xjawIjZuBleHRuA2FlbQIxMQABHa4BoIMH72OgpHLIFZ-mZdYkT7Aw56J57u5cSxzJd7t4cpsCodhqhnAZ9w_aem_cIYP002fOiBz8LAMdetKtg)
#
# [資金小行情報到 台股2月戰24,000](https://www.ctee.com.tw/news/20250220700078-430201?fbclid=IwY2xjawIjZyxleHRuA2FlbQIxMQABHUyeRaDUa9zn2PTxxuDxfKAuLL5KFYRQUdkLNdQdXPw9c24NfmZNg1WdiA_aem_DuKZNgl-daVquccUuKgnrA)
#
# [美鋼價暴漲 國內鋼廠動起來 計劃提前開盤作業](https://money.udn.com/money/story/10871/8559383?fbclid=IwY2xjawIjZ0VleHRuA2FlbQIxMQABHcsyR-CEIA0wpHVZt6niHzBRNO5kgbGklPe49HdKAp5sEtCgIEdWzkM-XQ_aem_41dmovAWQ_WjlapSbqDqKg)
#
# [ETF 配息效應投信大賣超 電子氣虛 台股攻勢熄火](https://money.udn.com/money/story/5607/8559380?from=edn_subcatelist_cate&fbclid=IwY2xjawIjZ2BleHRuA2FlbQIxMQABHVyAwM040bX5YYshxGY8uQq1qaWeLeeXOmG2cAMEjnH7JgTrZPwvhGToKg_aem_CNRtJPF9O57Th2sczpFR7w)

# %% [markdown]
# 期貨開小低，短線狹幅盤整，中期持續箱型整理：
# ![messageImage_1740012370217.jpg](attachment:49c3cb80-db10-47b2-9422-301142b676b8.jpg)
#
# 加權指數開平盤附近：
# ![messageImage_1740013244207.jpg](attachment:f67e5afd-dfb2-41e0-a0e6-4869c808ce07.jpg)
#
# 櫃買指數小漲，再度挑戰關鍵的複合式壓力區：
# ![messageImage_1740013294888.jpg](attachment:a27bd7d7-197d-428a-99c3-694a47d01ed6.jpg)
# 不過量能有點不足。
#
# 加權和櫃買都面臨關鍵壓力，今天相較於前幾日，多方氣勢稍減，尤其不少原先的強勢股、漲多股，都有明顯拉回的現象。
#
# 加權指數貢獻排行：
# ![661517.jpg](attachment:cf24cfa9-f013-4039-ba87-e2abf4c25165.jpg)
#
# 早上有外出沒有全程看盤，不過今天變化也不太大，小漲小跌而已。
# ![661580.jpg](attachment:33cb59a5-0d5c-43a5-9010-d11ac33b9bd3.jpg)
# ![661581.jpg](attachment:dbc99b32-2103-46ed-8cd7-aaab35885060.jpg)

# %% [markdown]
# 晶豪科(3006)
# ![messageImage_1740013536732.jpg](attachment:7a2f61ec-2f1d-4a99-a97f-b139fc43fe23.jpg)
#
# 南電(8046)
# ![messageImage_1740013552767.jpg](attachment:9495fb2f-5b73-491f-b8fd-4c75a3c18e96.jpg)
#
# 中租-KY(5871)
# ![messageImage_1740013587343.jpg](attachment:7bc6e952-532f-4df0-b229-7321b240c613.jpg)
#
# 點序(6485)
# ![messageImage_1740013602041.jpg](attachment:2da28977-d713-4f1f-ac8e-a80a6ffb7b83.jpg)
#
# 新漢(8234)
# ![messageImage_1740013642940.jpg](attachment:a4f81404-8a4f-42e2-8338-cc7edff4e3c6.jpg)
#
# 南亞科(2408)
# ![messageImage_1740013689806.jpg](attachment:a95a3755-5f05-457a-b2b3-47c2dd880c6c.jpg)

# %% [markdown]
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 6176 瑞儀  中長期高檔盤整，籌碼不集中
# 3362 先進光  短線反彈，中期大箱型整理
# 1569 濱川  短線轉強，中期還在高檔大箱型整理
# 2615萬海  短線反彈，中期大箱型整理
# 8033雷虎  中長期都是大箱型整理
# 1301台塑  迷你底形，但籌碼不強
# 2408南亞科  迷你底形漲幅滿足
# 1309台達化  低檔狹幅整理，籌碼中性
# 6414樺漢  短中期偏多，長期大箱型整理
# 6488環球晶  迷你底形，但籌碼不強
# 2250 IKKA-KY  短線回測支撐，有高檔背離現象
# 6139亞翔  短線偏多，中長期持續打底中
# 8039台虹  中期底形，但尚未轉強
# 3037欣興  中長期偏空，短線反彈
# 4303信立  短線偏多，中長期大箱型整理
# 8069元太  中長期高檔箱型
#
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 2723美食KY  中長期底形，籌碼集中
# 2014中鴻  迷你底形漲幅完成，面臨中期壓力區
# 1762中化生  有迷你底形但尚未轉強，籌碼也不集中
# 4772台特化  中期偏空短線反彈，籌碼不集中
# 藥華藥6446  短線翻空，中長期頭部雛形
# 6269台郡  中期底部，但籌碼不集中，也尚未發動轉強
# 3548兆利  短線轉弱，中期大箱型整理
# 6788 華景電  中長期偏空，短線狹幅整理
# 2330 台積電  短中期高檔盤整，籌碼不集中
# 3035智源  迷你底形突破後回測，支撐有守
# 2317鴻海  短線反彈，籌碼不集中，中長期有頭部雛形
# 4533協易機  短線反彈後遇壓整理，中長期有頭部雛形
# 6231系微  長期偏空，短中期盤整
# 00757統一FANG  短中長期偏多，但位階高，要會設移動式支撐
# 6505台塑化  迷你底形，但籌碼不強
# 6937 天虹  短中長期偏空，有頭部雛形
#
# #### 【K線捕手楊忠憲｜技術與籌碼概況說明】
#
# 以下內容為網友隨機提問之個股技術與籌碼概況分析，並非本人持股，更不構成任何投資建議。所有資訊皆由本人逐字整理，未經電腦程式或機器人生成。由於提問數量眾多，時間與版面有限，無法逐一詳答或附圖，僅提供簡要分析。相關內容依據技術面與籌碼面進行整理，純屬個人觀點與分享，不作為任何交易依據。投資市場存在風險，請務必審慎評估自身資金狀況、投資目標與風險承受能力，並確保具備獨立交易決策能力。請妥善設置停利停損，謹慎操作。
#
# 8454富邦媒  有迷你底形，籌碼集中
# 3615安可  短線反彈，中長期偏空
# 2303聯電  短線反彈，中期有小底部雛形，籌碼集中
# 8028昇陽半導體  短中長期偏多，但位階高，要會設移動式支撐
# 6913鴻呈  短線轉弱，中期支撐暫時有守
# 3122笙泉  短線反彈，中期低檔箱型整理
# 3163 波若威  高檔箱型整理，籌碼不集中
# 2352 佳世達  短線反彈，中長期偏空
# 6576逸達  中長期底形，籌碼集中
# 1711永光  迷你底部雛形，籌碼集中
# 6136 富爾特  短線高檔轉弱，中期支撐暫時有守
# 4916事欣科  短中期偏多但位階高，接近長期壓力，要會設移動支撐
# 2413 環科  短線反彈，中期箱型整理
# 2436偉詮電  短線反彈，中期箱型整理
# 3564其陽  中期底形，籌碼集中，但尚未發動轉強
# 2637慧洋  迷你底形漲幅滿足，短線震盪整理
# 5371中光電  短線反彈，中期箱型整理

# %% [markdown]
# ![661883.jpg](attachment:90167e82-e4cf-4dc3-bed7-4cfe41536454.jpg)
# ![661884.jpg](attachment:2c6f7e9b-8544-4082-a433-1602accaf52c.jpg)

# %% [markdown]
# ### 本日進度
# * **程式開發**：型態辨識程序

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
from collections import defaultdict

# 原型版：初步開發
def chart_patterns_recognition_4point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)
    for i in range(4, (len(turning_points)+1)):
        
        # 在變數window中一次儲存4個局部最小值和局部最大值點
        window = turning_points.iloc[i-4:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存4個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        rtop_g1 = np.mean([e1,e3])
        rtop_g2 = np.mean([e2,e4])
        
        if e2 > e1 and e4 > e3 and e3 > e1 and e4 > e2 and (e2 - e1) > (e4 - e3) and abs(((e4 - e3) - (e2 - e1)) / (e2 - e1)) > 0.25 :
            # 上升楔型
            patterns['RISE_WEDGE'].append(window)
        elif e1 > e2 and e3 > e4 and e1 > e3 and e2 > e4 and (e1 - e2) > (e3 - e4) and abs(((e3 - e4) - (e1 - e2)) / (e1 - e2)) > 0.25 :
            # 下降楔型
            patterns['FALL_WEDGE'].append(window)
        elif (e1 > e2) and (abs(e1-rtop_g1)/rtop_g1 < 0.0075) and (abs(e3-rtop_g1)/rtop_g1 < 0.0075) and \
            (abs(e2-rtop_g2)/rtop_g2 < 0.0075) and (abs(e4-rtop_g2)/rtop_g2 < 0.0075) and (min(e1, e3) > max(e2, e4)):
            # 矩形
            patterns['RECT'].append(window)
        
    return patterns

from collections import defaultdict

# 原型版：初步開發
def chart_patterns_recognition_5point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)    
    for i in range(5, len(turning_points)+1):
        
        # 在變數window中一次儲存5個局部最小值和局部最大值點
        window = turning_points.iloc[i-5:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存5個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        e5      = window.iloc[4]['Price']
        rtop_g1 = np.mean([e1,e3,e5])
        rtop_g2 = np.mean([e2,e4])
                
        if (e1 > e2) and (e1 > e3) and (e3 > e5) and (e2 < e4):
            # 三角形
            patterns['TRIG'].append(window)
        else :
            # 其他型態
            pass
    
    return patterns

# 原型版：初步開發
def chart_patterns_recognition_6point_prototype(turning_points, max_bars = 100):
    # 儲存型態實例
    patterns = defaultdict(list)
    
    #循環迭代轉折點數據
    # TODO : 問題待檢討 ： len(turning_points) → (len(turning_points)+1)    
    for i in range(6, len(turning_points)+1):
        
        # 在變數window中一次儲存6個局部最小值和局部最大值點
        window = turning_points.iloc[i-6:i]
        
        # 型態必須在max_bars內發揮出來（預設為 100）
        if window.index[-1] - window.index[0] > max_bars:
            continue
        
        # 儲存6個獨特點以檢查條件
        e1      = window.iloc[0]['Price']
        e2      = window.iloc[1]['Price']
        e3      = window.iloc[2]['Price']
        e4      = window.iloc[3]['Price']
        e5      = window.iloc[4]['Price']
        e6      = window.iloc[5]['Price']

        if (e3 < e1) and (e5 < e1) and (e2 < e3) and (e4 < e2) and (e4 < e6) and \
            (abs(e2 - e6) <= 0.03*np.mean([e2,e6])) and \
            (abs(e3 - e5) <= 0.03*np.mean([e2,e6])):
                # 頭肩底
                patterns['IHS'].append(window)
        else :
            # 其他型態
            pass
    
    return patterns

# %%
##### 使用2022年2月25日到2023年3月11日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_6274_230311.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 舊資料，用舊的參數進行確認
turning_points = myutils.test_DetectTurningPoints(df_k_line,df_sma,'close',order=10,smoothing=3)
# Out:
# 轉折點總筆數 ＝ 14
#                 Date  Price Type
# DateIndex
# 2         2022-03-02  87.60   HI
# 12        2022-03-16  79.80   LO
# 17        2022-03-23  84.20   HI
# 32        2022-04-15  68.70   LO
# 43        2022-05-03  77.00   HI
# 52        2022-05-16  71.90   LO
# 63        2022-05-31  77.00   HI
# 110       2022-08-05  52.30   LO
# 120       2022-08-19  57.90   HI
# 167       2022-10-27  41.15   LO
# 193       2022-12-02  58.20   HI
# 210       2022-12-27  52.00   LO
# 227       2023-02-01  64.00   HI
# 245       2023-03-01  58.50   LO

# %%
patterns = chart_patterns_recognition_6point_prototype(turning_points,max_bars=240)
print(patterns)
pattern = patterns['IHS'][-1]

neckline_start_date = pattern.iloc[0]['Date'].strftime("%Y-%m-%d")
neckline_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_x = [date_to_index(df_k_line,pattern.iloc[2]['Date']),date_to_index(df_k_line,pattern.iloc[4]['Date'])]
neckline_y = [pattern.iloc[2]['Price'],pattern.iloc[4]['Price']]
neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
neckline_start_price = neckline_slope * date_to_index(df_k_line,neckline_start_date) + neckline_intercept
neckline_end_price   = neckline_slope * date_to_index(df_k_line,neckline_end_date) + neckline_intercept

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.5,color='xkcd:maroon'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.0,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.5,color='xkcd:dark orange')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True,addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=1.2, colors='xkcd:orange yellow', alpha=0.6), warn_too_much_data=1100)
mpf.plot(df_k_line,**kwargs)
# Out:
# defaultdict(<class 'list'>, {'IHS': [                Date  Price Type
# DateIndex
# 63        2022-05-31  77.00   HI
# 110       2022-08-05  52.30   LO
# 120       2022-08-19  57.90   HI
# 167       2022-10-27  41.15   LO
# 193       2022-12-02  58.20   HI
# 210       2022-12-27  52.00   LO]})

# %%
# 驗證通用底部型態識別函式
_ = myutils.test_bottom_pattern_detection_prototype(df_k_line,df_sma,'open_close',5)
# Out:
# ＃＃＃＃＃＃＃＃＃＃
# 轉折點總筆數 ＝ 11
#                 Date  Price Type
# DateIndex
# 19        2022-03-25   84.9   HI
# 33        2022-04-18   68.1   LO
# 43        2022-05-03   77.7   HI
# 89        2022-07-07   51.0   LO
# 99        2022-07-21   58.4   HI
# 123       2022-08-24   55.6   LO
# 131       2022-09-05   58.5   HI
# 157       2022-10-13   39.4   LO
# 160       2022-10-18   42.9   HI
# 166       2022-10-26   40.0   LO
# 251       2023-03-09   69.6   HI
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始 ＝ 0 ，結束 ＝ 11）
# ◇ＤＥＢＵＧ ： 底部型態結束後之轉折點 ＝
# Date     2023-03-09 00:00:00
# Price                   69.6
# Type                      HI
# Name: 251, dtype: object
# ＤＥＢＵＧ ： 底部型態開始索引 ＝ 89 （日期 ＝ 2022-07-07 ） ， 底部型態結束索引 ＝ 217 （日期 ＝ 2023-01-06 ）
# ＤＥＢＵＧ ： 頸線角度 ＝ -0.54°
# ＤＥＢＵＧ ： 底部最低價格 ＝ 39.40元 ； 估算目標價 ＝ 77.42元
# ＤＥＢＵＧ ： 目標價沒有過前高
# ＤＥＢＵＧ ： 轉折點資料確認範圍 （開始 ＝ 10 ，結束 ＝ 11）
# ...
