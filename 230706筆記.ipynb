# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】短線轉弱，中期盤整
# 昨天盤前提到，「短線加權指數的技術面在20日線支撐出現轉強，但是昨天提到的其他現象尚未同步跟上，要立刻挑戰前高17346壓力，條件還不夠充分，上述空方條件尚未改善之前，維持在17346壓力與月線之間做整理，反而是對多方比較有利的走勢。」
# 加權指數昨天終止短線3天的漲勢，下跌84點，成交量3422億，整體籌碼中性偏空，延續現貨表現，夜盤期指續跌104點，今天台股會有補跌的現象。美股國慶假期休息1.5日，再度開盤普遍也都是遇壓出現小回，費半指數是當中相對弱勢下跌2.2%，歐洲股市也是有類似現象，有遇壓拉回的現象。
# 目前整體來說，目前加權指數都還在高檔盤整，只是空方條件明顯比多方條件多，所以未來的3個關鍵工具，首先是周KD值是否滑落80以下、20日線扣抵再來會往上扣，要觀察20日線使否下彎，最後的關鍵是盤整區間，是否能夠守住？櫃買指數創高守住支撐，中小型股仍優於大型股。
# 最後想提醒的是昨天分享會，不少同學都問到了一些目前的熱門跟強勢個股，有的成本高有的成本低，有的賺有的套，但事實上都存在共同問題，因為當初進場就是靠感覺、聽消息(包含所謂的基本面和產業面也是聽來的)，所以現在當然不會賣。
# 要追強勢股當然可以，但要看自己有沒有能力，不只要會設定移動式支撐，還要能夠紀律執行，但多數同學是沒有學習和受過訓練，並沒有具備這個條件，然後只是一頭熱追了進去，接下來就不知道該怎麼辦？這是相當危險的事情。 (出處：K線捕手楊忠憲粉絲團)
# ![357704248_748625443938052_8051806782795805390_n.jpg](attachment:635e5471-c928-4f7f-a440-cfb90aa497e7.jpg)

# %% [markdown]
# 期貨開低，短線偏弱，維持中期盤整：
# ![messageImage_1688604319035.jpg](attachment:0befdd91-7bb0-4375-a913-f716ed16b0cf.jpg)
#
# 期貨跌幅擴大：
# ![messageImage_1688604652552.jpg](attachment:71780c6a-3bf0-4213-a502-6d4a915a3041.jpg)
#
# 加權指數也開低，測試支撐：
# ![messageImage_1688605231014.jpg](attachment:5b873d0c-6975-4ac4-ae88-3d46a16542e6.jpg)
#
# 跌點還是不小，不過前低暫時有守：
# ![messageImage_1688607552705.jpg](attachment:e4977dcb-95bf-46b5-afd2-f298c281055d.jpg)
#
# 櫃買指數續漲創高，中小型股仍是重點：
# ![messageImage_1688609383508.jpg](attachment:38d349ec-ac70-44af-9940-33ba649e7774.jpg)
#
# 加權指數小跌破早盤低點：
# ![messageImage_1688611393803.jpg](attachment:600b9b87-52d8-4374-9340-d8f768589af3.jpg)
#
# 加權指數創今日新低，成交量放大：
# ![messageImage_1688612743427.jpg](attachment:9782dabc-74bb-442d-bd7f-1ed360df6963.jpg)
#
# 櫃買指數也回到平盤之下：
# ![messageImage_1688612790973.jpg](attachment:88682db8-189c-48e0-bd68-78bbd7b4fdd4.jpg)
#
# 暫時跌破周一低點：
# [其實比較細心的同學](https://tinyurl.com/3zdbcm2f)，應該會發現昨天分享會，是這麼多年以來，唯一沒有彩蛋的一次。
# **只要大家顧好手上的持股就好，擬定好離場策略，不要再持股增加了。**
# 並不是要製造神話，跟你說我早就預知今天會大跌，只是這多方本來就存在太多瑕疵，致命的一擊是早晚的問題。
# ![358402123_748735650593698_169224068087286498_n.jpg](attachment:0fd11235-ff38-46f1-9d40-28703f75571b.jpg)
#
# 沒意外的話，外資期貨今天空單，應該一天會大增
# 進入到6月專題班說的下一個階段。
#
# **昨天分享會有同學一直很困惑，為什麼有時候法人一直賣，還是會漲？其實答案很簡單，就是法人持股部位很多，不可能一天賣完，如果一天大賣，那會搬石頭砸自己的腳，股價直接跌停了。**
# **假如總數有4.5萬張要賣，分成15天，一天只要賣3千張，市場可以吸收跟消化，法人只要賣3千張，一邊放利多，但是當日吸引買盤5千張，股價照樣漲。**
# **但是再來你會看到很多，因為法人已經出完主要部位，剩下隨便賣都是賺錢的，就可以不用再掩飾下去了，可以不用顧忌。**

# %% [markdown]
# 現貨大賣，期貨多單歸零，空單小幅增加：
# ![61850.jpg](attachment:3d1b8068-061b-45ab-92d2-8b7769bc2fae.jpg)
#
# 其實重點是這個，散戶小台多單還在增加。
# ![156070.jpg](attachment:83b9928d-dc33-4bb5-92da-3b02b8484810.jpg)
# 散戶真的很喜歡顛倒做
#
# 夜盤期指開低走低，支撐還不穩定：
# ![156224.jpg](attachment:668f96e9-6a3e-4207-a82b-aa7961a36032.jpg)

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值36,350元(收盤價：36.35元，漲0.70元)。調整後的停損價為35.00元，目標價為42.50元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,36.35,36190,-161,-0.44]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  36.35  36190  -161 -0.44

# %%
##### 使用2022年3月18日到今日收盤價(2023年7月6日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230706.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-9-13']['Open']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 估算目標價
bottom_price_date = '2022-10-21'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('目標價 ＝ {:.2f}元'.format(target_price))
target_price_date = '2023-06-02'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(2.5,15,15), colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 35.00元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-07-06
# 目標價 ＝ 42.50元

# %% [markdown]
# * 實驗：扣抵驗證(參考：[均線理論的最後一塊拼圖_230616_筆記.pptx](https://mega.nz/file/cqpn2JAC))

# %%
##### 使用2022年4月24日到2023年7月6日之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2882_230706.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA20','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 取得收盤價
close_prices   = df_k_line['Close']

# 透過pandas.DataFrame.rolling計算均線(右側，標示在最近資料發生位置)
df_ma20_right  =  close_prices.rolling(window=20).mean().round(2)

# 透過pandas.DataFrame.rolling計算均線(中間，反映根本趨勢)
# 參考：「技術分析精論：二十年來投資界最完整的技術分析全圖解(上)」 第11章 
df_ma20_center = close_prices.rolling(window=20,center=True).mean().round(2)

# %%
# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定均線
added_plots={
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=2,color='xkcd:violet'),
    "MA20R": mpf.make_addplot(df_ma20_right.values,width=0.8,color='xkcd:light violet'),
    "MA20C": mpf.make_addplot(df_ma20_center.values,width=0.8,color='xkcd:blue violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()))
mpf.plot(df_k_line,**kwargs)

# %%
# 設定資料區間
df_k_line_range      = df_k_line['2023-04-21':'2023-06-09']
df_sma_range         = df_sma['2023-04-21':'2023-06-09']

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定均線
added_plots={
    "SMA20": mpf.make_addplot(df_sma_range['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()))
mpf.plot(df_k_line_range,**kwargs)

# %%
# 設定股價走到的價位
# print(df_k_line_range.iloc[-1])
current_price = df_k_line_range.iloc[-1]['Close']

# 設定20日均線扣抵開始日期並取得其索引
deduction_date = '2023-05-15'
# TODO : 索引取得方式待檢討
number_array = df_k_line_range.index == deduction_date
idx = 0
for number_index in number_array :
    if number_index == True :
        break
    idx = idx + 1
deduction_date_idx = idx

# 取得總筆數
row, _ = df_k_line_range.shape

# 扣抵判斷
for idx in range(deduction_date_idx,row) :
    deduction_price = df_k_line_range.iloc[idx]['Close']
    if deduction_price < current_price  :
        print('扣小加大 ： {} 扣小({:.2f}) , 加大({:.2f})'.format(df_k_line_range.iloc[idx].name.strftime("%Y-%m-%d"),deduction_price,current_price))
    elif df_k_line_range.iloc[idx]['Close'] > current_price  :
        print('扣大加小 ： {} 扣大({:.2f}) , 加小({:.2f})'.format(df_k_line_range.iloc[idx].name.strftime("%Y-%m-%d"),deduction_price,current_price))
        # TODO : 碰到"扣大加小"時判斷中止
        break
    else :
        print('扣平')
# Out:
# 扣小加大 ： 2023-05-15 扣小(43.35) , 加大(44.60)
# 扣小加大 ： 2023-05-16 扣小(43.60) , 加大(44.60)
# 扣小加大 ： 2023-05-17 扣小(43.95) , 加大(44.60)
# 扣小加大 ： 2023-05-18 扣小(44.40) , 加大(44.60)
# 扣大加小 ： 2023-05-19 扣大(45.15) , 加小(44.60)
