# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】指數續漲，籌碼偏弱
# 加權指數昨天上漲56點，收盤來到17140點，成交量放大到3828億，屬於價漲量增的多方結構，就價量關係來說是正向的。有同學擔心成交量會不會太大？目前來說3828億還是是正常的，而且真的要續攻甚至過高，本來就要補量，所以目前算是大量，還不到爆量的程度。
# 不過從籌碼面觀察，6月16日開始累計觀察，三大法人和主力指標都是站在賣方，而融資卻持續攀升，顯見法人雖然沒有反手做空，但指數越漲卻漸趨保守，而散戶卻是信心十足一路加碼。櫃買指數持續創高創高突破第二天，不過漲幅收斂來到0.21%。
# 短線加權指數的技術面在20日線支撐出現轉強，但是昨天提到的其他現象尚未同步跟上，要立刻挑戰前高17346壓力，條件還不夠充分，上述空方條件尚未改善之前，維持在17346壓力與月線之間做整理，反而是對多方比較有利的走勢。
# 另外操作上，多空雙方的選股都不難，數量都慢慢增加，但是解盤一定要先看清楚趨勢是多是空？位階是高是低？是頭部還是底部？否則把空頭股票當成多頭股票作，那是非常危險的事情。
# 然後如果想跟隨市場主流追強勢股，當然會賺比較快、比較多，但是一定要會設移動支撐，否則等趨勢反轉，別人都跑了，還在想它的產業趨勢和基本面，那肯定會來不及了，經過2022年初，航海王和鋼鐵人的洗禮，應該會很清楚永遠是股價先跌一大波之後，利空才會出來的。
# 然後，晚上有分享會+中午行程，所以稍後就要出門了，盤中比較不會有訊息。最後再提醒一次，今晚的分享會也是這一季唯一的一場，有興趣的同學別錯過了。 (歡迎分享，請載明出處K線捕手楊忠憲粉絲團)
# ![357790040_747833827350547_933264204806316533_n.jpg](attachment:0b8e1b93-1f7f-45a9-b21c-008f79257681.jpg)

# %% [markdown]
# [航商的痛…過剩運力變海市蜃樓](https://readers.ctee.com.tw/cm/20230705/a04aa4/1247627/share)
#
# ![Table_Clipping_02_5__b9f41f70c6.jpg](attachment:294d8894-8d4b-4601-a61e-1c1bf0697c89.jpg)
#
# [海運業保獲利 運價逆勢喊漲](https://readers.ctee.com.tw/cm/20230705/a04aa4/1247626/share)
#
# ![Table_Clipping_06_3__96896a36fc.jpg](attachment:22649198-b7db-4360-a803-a28b1ef48f74.jpg)
#
# [美債 殖利率曲線倒掛加劇 逼近42年來最大](https://www.chinatimes.com/newspapers/20230705000169-260203?chdtv)
# 隨著市場預期聯準會（Fed）本月升息1碼、年底前還會進一步調高利率的預期，美國2年期與10年期債券殖利率3日一度逼近數十年來最大倒掛程度。前者盤中升抵4.96％，高出後者約110.8個基點，今年3月該殖利率曲線倒掛曾達110.9個基點，創下1981年以來最大紀錄。
#
# [日圓兌美元在干預警告中走高 匯市因美國假期交投清淡](https://udn.com/news/story/6811/7278709)
# 日圓兌美元周二（4日）走高，市場對日本干預的跡象保持高度警惕，但由於美國交易員因美國國慶日假期休假，市場整體保持平靜。
# 日圓兌美元周二盤中一度上漲0.3%，至144.21日圓兌1美元；周一則還下跌0.27%。但日圓兌美元目前仍然接近上周觸及的145.07日圓的近八個月低點，當時促使日本財務大臣鈴木俊一警告市場不要過度拋售日圓。

# %% [markdown]
# 期貨開小低，接近平盤：
# ![messageImage_1688517940320.jpg](attachment:9d66b06e-1935-4b1d-b94a-a86040edbf5d.jpg)

# %% [markdown]
# 外資期貨多單大減，降到剩下389口：
# ![61708.jpg](attachment:9fccfa1f-80dc-4151-888e-8c8435c613d0.jpg)

# %% [markdown]
# ### 本日進度
#
# * 力山(1515)現持有1張(**目前規劃僅試單1張**)，庫存現值35,650元(收盤價：35.65元，漲0.50元)。調整後的停損價為35.00元，目標價為42.50元。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['1515','力山',1000,36351,36.35,35.65,35494,-857,-2.36]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  1515   力山  1000  36351  36.35  35.65  35494  -857 -2.36

# %%
##### 使用2022年3月18日到今日收盤(2023年7月5日)之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_1515_230705.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 設定今天日期
today_date = df_k_line.iloc[-1]['Date'].strftime("%Y-%m-%d")

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
# 手動設定頸線
neckline_price = df_k_line.loc['2022-9-13']['Open']
neckline_start_date = '2022-06-06'
neckline_end_date = today_date
print('頸線價格 ＝ {:.2f}元 ， 開始日期 ＝ {} ， 結束日期 ＝ {}'.format(neckline_price,neckline_start_date,neckline_end_date))

# 估算目標價
bottom_price_date = '2022-10-21'
bottom_price = df_k_line.loc[bottom_price_date]['Close']
target_price = (neckline_price - bottom_price) + neckline_price
print('目標價 ＝ {:.2f}元'.format(target_price))
target_price_date = '2023-06-02'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
    [(bottom_price_date,bottom_price),(bottom_price_date,neckline_price)],
    [(target_price_date,target_price),(target_price_date,neckline_price)]
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.8,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.8,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=1.2,color='xkcd:violet')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=(2.5,15,15), colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)
# Out:
# 頸線價格 ＝ 35.00元 ， 開始日期 ＝ 2022-06-06 ， 結束日期 ＝ 2023-07-05
# 目標價 ＝ 42.50元

# %% [markdown]
# * 本月將進行整合之前寫的程式(轉折點、頭肩底型態與趨勢線…等)與[neurotrader](https://www.youtube.com/@neurotrader888/videos)之程式碼：
#   - 位階
#     + [量化位階評價法](https://vocus.cc/article/62ada936fd89780001fe6208) ： 已完成 **StockRankEvaluate()** 函式，後續整理程式碼
#   - 轉折點
#     + 峰位∕谷底的演變程序([peak-and-trough progression](https://www.amazon.com/Technical-Analysis-Explained-Fifth-Successful/dp/0071825177)) 與 滾動窗口([Rolling Window](https://www.youtube.com/watch?v=X31hyMhB-3s&t=49s)) ： 已完成 **FindingTurningPoints()** 函式
#     + *方向變化([Directional Change](https://www.youtube.com/watch?v=X31hyMhB-3s&t=179s))* ： [directional_change.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/directional_change.py)
#     + *感知重要點([Perceptually Important Points](https://www.youtube.com/watch?v=X31hyMhB-3s&t=339s))* ： [perceptually_important.py](https://tinyurl.com/yc2bykhr)
#   - 趨勢線
#     + 自行開發 ： 模擬手工方式，由兩個轉折點中畫出一條趨勢線
#     + 自動價格趨勢線([Automated Price Trend Lines](https://www.youtube.com/watch?v=wbFoefnidTU)) ： [trendline_automation.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/trendline_automation.py)
#   - 型態
#     + 頭肩底(或 頭肩頂)演算法一([Algorithmically Detecting (and Trading) Technical Chart Patterns with Python](https://medium.com/automation-generation/algorithmically-detecting-and-trading-technical-chart-patterns-with-python-c577b3a396ed)) ： [tech_screener_notebook.ipynb](https://github.com/samchaaa/alpaca_tech_screener/blob/master/tech_screener_notebook.ipynb) ： 頭肩底函式已完成，待整理
#     + 頭肩底(或 頭肩頂)演算法二([Automated Head and Shoulders Chart Pattern in Python](https://www.youtube.com/watch?v=6iFqjd5BOHw)) ： [head_shoulders.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/head_shoulders.py)
#     + 旗型與三角旗型演算法([Flag and Pennant Pattern Recognition](https://www.youtube.com/watch?v=Lb5SPCTp4uY)) ： [flags_pennants.py](https://github.com/neurotrader888/TechnicalAnalysisAutomation/blob/main/flags_pennants.py)
