# %% [markdown]
# ### 【[K線捕手](https://www.facebook.com/kevinyang20180801)盤前快訊】指數偏多，留意轉折
# 加權指數昨天再度創高來到16781，不過出現開高走低，單日收在16714，值得注意的是雖然昨天小創新高，但尾盤上攻無力，隨即拉回開高走低，而且成交量縮到3032億，遠低於近期的10日均量3231億，頗有極短線的高檔價量背離的現象。引領前兩周台股上漲的主要動能，台積電如上周一規劃，近日利多鈍化無法連續創高，已經進入震盪盤整，僅維持540-574區間盤整，不過台股因為部分中小型股出現補漲，因此還能維持多方格局，整體籌碼面也維持偏多。
# 現在當然是多頭，只是位階已經很高，要更謹慎的觀察極短線的先兆和高檔轉折的變化。多頭看支撐不看壓力，極短線轉折有兩種設定方式，一種是觀察均線支撐，切換到觀察3日均線或5日線(兩條均線貼得相當近)，另一種則是從單一K棒做觀察，是否出現爆量長黑或長上影線，也就是單日從最高點拉回200點以上，或3日累計300點以上。但這個條件是浮動，需要從最高點回推，由於加權指數6月5日創高來到16781，所以回檔200點上調為16581，回檔300點上調為16481支撐。
# 另外，前波仍有2022年5月5日以及2022年5月31日兩個前高，以及3月6日以及3月16日兩個前低，大約為16811點位的中長期轉折壓力需要克服。不過有一個很明確的事情， 那就是指數雖然續漲，但並沒有改善選股和操作難度。目前不論做多做空，操作難度越來越高，如果具體數據化，由難至易，以10到1表示，現在難度應該已經攀升到9.5。不論資金或是檔數，都應該降到最低，既可以參與多頭續漲的獲利可能，一旦盤勢有劇烈修正，隨時可以輕鬆離場。 (出處：K線捕手楊忠憲粉絲團)

# %% [markdown]
# ![352277716_951517959440827_6815988426121374170_n.jpg](attachment:6fa82cff-ff00-4fab-b0c3-cd86e0c427a1.jpg)

# %% [markdown]
# 期貨開在平盤附近：

# %% [markdown]
# ![messageImage_1686012320349.jpg](attachment:f286b646-31d6-40e1-aa00-c9a2fbd95b6b.jpg)

# %% [markdown]
# 加權指數開在平盤附近：

# %% [markdown]
# ![messageImage_1686013251591.jpg](attachment:26f9d7fe-9d2a-4c6d-a563-0f3734a141e4.jpg)

# %% [markdown]
# 櫃買指數開高，但尚未過昨天高點：

# %% [markdown]
# ![messageImage_1686013271045.jpg](attachment:937f41ec-5ca5-4391-b62c-d839170b644b.jpg)

# %% [markdown]
# 最強類股：

# %% [markdown]
# ![messageImage_1686013736884.jpg](attachment:459e9c9a-e11a-4ca7-bdd6-12145ff48e45.jpg)
# ![messageImage_1686013769936.jpg](attachment:523efbe2-0fde-45f4-8171-cb1dc74ad836.jpg)

# %% [markdown]
# 櫃買指數遇到前高壓力，拉回平盤之下：

# %% [markdown]
# ![messageImage_1686015383432.jpg](attachment:e6b2bb9b-4b39-4141-92fc-ed94b81a1786.jpg)
# ![messageImage_1686015445251.jpg](attachment:ae2a362d-aee0-4717-a30b-07a66cf81a60.jpg)

# %% [markdown]
# 盤前∕盤中觀察股：

# %% [markdown]
# ![messageImage_1686012677423.jpg](attachment:44e288aa-2edb-422c-907f-758e9221950b.jpg)
# ![messageImage_1686012700183.jpg](attachment:7bb8e7b9-cede-4daa-9256-828af1149828.jpg)
# ![messageImage_1686012898587.jpg](attachment:dc52905d-dbcb-45cf-92e3-d70502a2ca3d.jpg)
# ![messageImage_1686012918484.jpg](attachment:5a07b20a-22ce-45ae-ab8c-bda7dfff5a3c.jpg)
# ![messageImage_1686013002713.jpg](attachment:71ee2568-3ed4-4a34-9b4f-61802a9f7300.jpg)
# ![messageImage_1686013011585.jpg](attachment:007bcd3d-1eb5-41ed-8ad6-5deaacea6342.jpg)
# ![messageImage_1686014859362.jpg](attachment:eb6ed303-9807-42d2-ba6e-599eebba4c26.jpg)

# %% [markdown]
# 看看這一次上升楔形會不會成功：

# %% [markdown]
# ![messageImage_1686035261888.jpg](attachment:83060dbf-314f-41b2-8c08-c26b869df006.jpg)

# %% [markdown]
# 【[背離只是警訊，不是賣訊](https://tinyurl.com/yvfu36hf)】
# 「老師請問一下高檔背離，要在那個地方空？低檔背離，要在哪個地方買進？勝率有多少%？」
# 首先要先說明的是，我上課應該沒有這樣教，而且實務上也不存在這樣用法。先複習一下上課教的內容，為了避免混亂，統一用高檔背離做教學和說明。上課至今，提過3種背離，價量背離、KD背離、MACD背離，當然背離不只這3種，比較完整的應該有7-8種。
# 所有的高檔背離都有同樣的意義，就是股價創新高，但指標沒有同步創高，代表兩個本應同步的現象，卻背道而馳，因此叫做背離。出現高檔背離代表多頭力竭的現象，所以背離後可能出現由多頭轉為空頭，是一種領先訊號。
# 但技術分析的通則，越早出現或是越短線的訊號，準確度越低。既然背離是一種領先訊號，當然是所有現象中最快的，自然也具備準確度上缺點，甚至KD可以背離3次、MACD可以背離2次，所以絕對不可能用這樣不穩定的訊號作為交易工具，這是相當危險的。
# 而且沒有任何書籍規定背離後究竟會修正多少，自然也無法作為滿足點的估算工具。所以背離過後，必須出現技術面工具翻空的訊號，才能確認是真的多頭結束，因此背離既然不存在交易的訊號，也就沒有所謂勝率多少之說了。

# %% [markdown]
# ### 本日進度
# * 華航(2610)現持有3張(**預計購買10張**)，庫存現值68,250元(收盤價：22.75元，漲0.15元)。**停損價：21.65元，目標價：25.15元**。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np

# %%
##### 未實現損益 #####
stock_gains_losses = [['2610','華航',3000,65342,21.78,22.75,67949,2607,3.99]]
gains_losses_df = pd.DataFrame(stock_gains_losses,columns=['代碼', '股票名稱','即時庫存','付出成本','成本均價','現價','現值','損益試算','獲利率%'])
print('未實現損益：')
display(gains_losses_df)
# Out:
# 未實現損益：
#      代碼 股票名稱  即時庫存   付出成本   成本均價     現價     現值  損益試算  獲利率%
# 0  2610   華航  3000  65342  21.78  22.75  67949  2607  3.99

# %%
##### 使用2022年9月19日到2023年6月6日之日線圖資料 #####
# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_2610_230606.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# 手動設定頸線
neckline_price = df_k_line.loc['2023-05-29']['Close']
neckline_start_date = '2022-09-22'
neckline_end_date = '2023-06-06'

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
seq_of_seq_of_points=[
    [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
                     ]

# 設定均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.4,color='xkcd:royal purple'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.4,color='xkcd:cyan')
            }

# 繪出K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()),alines=dict(alines=seq_of_seq_of_points, linewidths=2.5, colors=('xkcd:yellow orange')))
mpf.plot(df_k_line,**kwargs)

print('今日收盤價 ＝ {} ， 五日均線 ＝ {}'.format(df_k_line.iloc[-1]['Close'],df_sma.iloc[-1]['SMA5']))
# Out:
# 今日收盤價 ＝ 22.75 ， 五日均線 ＝ 22.75
