# %% [markdown]
# ### 工作進度
# * 【置頂】**新的筆記內容架構**與**量化技術分析系統**相關資訊請參閱[250801筆記.ipynb](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250801%E7%AD%86%E8%A8%98.ipynb)之「工作進度」。
#   - 舊的股票投資筆記架構是混和股票老師資訊與個人看法。而現在的架構則是將股票老師的資訊獨立出來存放於[日報](https://mega.nz/folder/a85wHKwK#SA6HACStdXRvMsLd2Ct0tQ)中，筆記(Jupyter Notebbok)內容多為自己的看法以及「量化技術分析」[系統](https://github.com/yilintung/StockInvestmentNotebook/tree/main/mysys)之產出。
#   - 系統運行一陣子後可能會做一些調整，將持續觀察ＧＰＴ-４ｏ模型輸出結果。
# * 本日「K線追擊週報」LINE群組資訊：[楊忠憲K線追擊週報_250910日報.docx](https://mega.nz/file/bxxg3RaQ#wNDZPTDvLpUvKJlOOf5naZwXbmV0QdQhudyIX5nPTsA)。

# %% [markdown]
# * 引入模組與定義公用函式

# %%
import numpy as np
import mysys
import markdown
import base64
from IPython.core.display import HTML

# %%
def stock_analysis( analysis, stock_id, buttom_pattern = False) :
    results,images = analysis.analysis(stock_id)
    if buttom_pattern is True and '底部型態' in images :
        print('底型反轉交易策略：')
        display(images['底部型態'])
    print('解盤內容：')
    if '整體評價' in images :
        display(images['整體評價'])
    result_md   = results.to_markdown(tablefmt="grid")
    result_html = markdown.markdown(result_md, extensions=['markdown_grid_tables:GridTableExtension'])
    display(HTML(result_html))

# %% [markdown]
# * 更新量化技術分析資料庫

# %%
mysys.UpdatestockDatabase()
# Out:
# 2025-09-10 22:15:34.567 | INFO     | FinMind.data.finmind_api:get_data:155 - download TaiwanStockInfo, data_id:
# ##### 更新台股總覽 #####
# 修改股票資訊。代碼 ＝ 2336：股票名稱 ＝ 致伸，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2341：股票名稱 ＝ 英群，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2350：股票名稱 ＝ 環電，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2361：股票名稱 ＝ 鴻友，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2384：股票名稱 ＝ 勝華，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2391：股票名稱 ＝ 合勤，產業類別 ＝ 通信網路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2411：股票名稱 ＝ 飛瑞，產業類別 ＝ 其他電子業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2438：股票名稱 ＝ 翔耀，產業類別 ＝ 光電業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2442：股票名稱 ＝ 新美齊，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2446：股票名稱 ＝ 全懋，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 2452：股票名稱 ＝ 乾坤，產業類別 ＝ 電子零組件業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3005：股票名稱 ＝ 神基，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3008：股票名稱 ＝ 大立光，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3009：股票名稱 ＝ 奇美電，產業類別 ＝ 電子工業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3020：股票名稱 ＝ 奇普仕，產業類別 ＝ 電子通路業，類型 ＝ twse
# 修改股票資訊。代碼 ＝ 3027：股票名稱 ＝ 盛達，產業類別 ＝ 通信網路業，類型 ＝ twse
# ...

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數
#   - 台股持續多方的一天，不過加權指數今天比櫃指數買強。
#   - [創歷史新高](https://www.facebook.com/kevinyang20180801/posts/pfbid0kz71SXHRUWdYY4qDMA4WnJpf5Zpcd4FcUgn9HviET6JM6fwjWX1V3DbSLhBTRFXl)。
#   - [股票老師](https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3318)支撐改守5日線。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=829x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒</p>
# </td>
# <td colspan="1" rowspan="1"></td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 5404.7億元 ，十日均量 ＝ 4618.8億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之三重頂，型態範圍由2024-08-12開始到2025-03-03結束，估算目標價為21371.24。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為22257.56。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# ...

# %% [markdown]
# * 櫃買指數
#   - [股票老師](https://smart.businessweekly.com.tw/e-subscription/article?c=GROUP00014146&p=PROD000019311&at=13&a=3318)守10日線。

# %% [markdown]
# > **盤後**：量化技術分析
# > 補充說明：「整體評價」中ＧＰＴ－４ｏ模型所採用的支撐是設定20日線，但所描述的支撐點位有問題（ＧＰＴ－４ｏ模型描述為「約在240點左右」，實際應為250點附近）。

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-09<br />
# 十字線 : 2025-09-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 1656.51億元 ，十日均量 ＝ 1527.49億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-07-11開始到2025-03-28結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-02開始到2025-05-02結束，估算目標價為247.79。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 盟立(2464)
#   看法：持續追蹤。目前呈現反彈格局。

# %% [markdown]
# > **盤後**：量化技術分析
# > 補充說明：「整體評價」中ＧＰＴ－４ｏ模型在支撐部分是採10日均線，但判斷的支撐價格有些誤差（ＡＩ的結果是「約在70元左右」，實際應該是73元附近）。

# %%
stock_analysis(analysis,'2464')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=828x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-10<br />
# 十字線 : 2025-09-08 , 2025-09-09<br />
# 鎚子線／吊人線 : 2025-09-08<br />
# 高檔夜星 : 2025-09-04</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：未至大量門檻（成交量 ＝ 9357張 ，十日均量 ＝ 11675張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中繼型態之上升旗形，型態範圍由2025-04-09開始到2025-09-09結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-26'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-15']['Close']

    # 設定底部日期與價格
    bottom_date  = '2025-04-10'
    bottom_price = range_prices.loc['2025-04-10']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-08-15'

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('2464','2024-12-25','2025-09-10',line_drawing_callback)
display(image)
# Out:
# 估算目標價為78.10元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人小買(+228)：外資小買(+342)、投信中立(0)、自營小賣(-54)。
# 主力小買(+791)。
# 分公司買賣家數差集中(+49)。
# 融資增(+411)、融券增(+20)。

# %% [markdown]
# * 百和興業-KY(8404)
#   看法：略為拉回，但成交量有點過大以至於有價跌量增之現象；籌碼轉弱，外資大賣且買賣家數差由集中轉為分散。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'8404',buttom_pattern = True)
# Out:
# 底型反轉交易策略：
# <PIL.Image.Image image mode=RGB size=848x479>
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2025-09-08<br />
# 十字線 : 2025-09-08<br />
# 孕育線／懷抱線 : 2025-09-10</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：大型股大量（成交量 ＝ 3465張 ，十日均量 ＝ 2414張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>盤整型態之三角形，型態範圍由2024-12-05開始到2025-04-07結束。<br />
# 底型反轉之底部型態，型態範圍由2025-04-07開始到2025-09-10結束，估算目標價為26.89。</p>
# ...

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date = '2025-03-31'
    neckline_end_date   = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_price      = range_prices.loc['2025-05-14']['Open']

    # 設定底部日期與價格
    bottom_date  = '2025-04-21'
    bottom_price = range_prices.loc['2025-04-21']['Close']

    # 估算目標價
    target_price = (neckline_price - bottom_price) + neckline_price

    print('估算目標價為{:.2f}元'.format(target_price))

    # 設定突破日期
    breakout_date = '2025-09-04'

    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_price),(neckline_end_date,neckline_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_price)],
        [(breakout_date,neckline_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']

    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('8404','2024-12-31','2025-09-10',line_drawing_callback)
display(image)
# Out:
# 估算目標價為27.05元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-1519)：外資大賣(-1519)、投信中立(0)、自營中立(0)。
# 主力大賣(-645)。
# 分公司買賣家數差分散(-71)。
# 融資增(+147)、融券大增(+33)。
