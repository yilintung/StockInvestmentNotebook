| INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-15
# 2026-09-24 22:03:04.046 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-16
# 2026-09-24 22:03:10.349 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-17
# 2026-09-24 22:03:16.577 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-18
# 2026-09-24 22:03:23.224 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 2026-09-24 22:03:26.854 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 2026-09-24 22:03:31.114 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-21
# 2026-09-24 22:03:37.395 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-22
# 2026-09-24 22:03:43.456 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【略過】日Ｋ：2026-09-23
# 2026-09-24 22:03:52.534 | INFO     | FinMind.data.finmind_api:get_data:164 - download TaiwanStockPrice, data_id:
# 【新建】日Ｋ：2026-09-24

# %% [markdown]
# * 建立「解盤」物件

# %%
analysis = mysys.StockAnalysis()

# %% [markdown]
# ### 大盤解盤

# %% [markdown]
# * 加權指數

# %% [markdown]
# > **開盤**：前高支撐和5日線都暫時有守。
# > ![messageImage_1790211629975.jpg](attachment:ca6a4246-ef13-47cb-887d-ddf14c4026e8.jpg)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：加權指數解盤
stock_analysis(analysis,'TAIEX')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=832x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>十字線 : 2026-09-24<br />
# 鎚子線／吊人線 : 2026-09-24</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 7755.91億元 ，十日均量 ＝ 8363.02億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-03-31開始到2026-09-23結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-09-24死亡交叉。並且2026-09-24於超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-09-07當週死亡交叉。並且2026-09-14該週在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前走勢偏上漲，價格沿短期均線上方推進並續創波段高點，回檔幅度相對受控。均線呈現短期均線在上、中期均線在下的多頭排列，趨勢結構仍偏多。<br />
# <br />
#  價量關係<br />
# 近期上攻過程中，成交量呈現放量後轉為量能收斂，屬於推升後的量縮整理型態。若後續再攻高但量能持續萎縮，短線容易轉為高檔震盪；反之放量突破則有利延續上行。<br />
# <br />
#  支撐與壓力<br />
# - 支撐：短線先看約47,800點（近端整理區與短期均線附近），跌破則看約46,800點（中短期均線匯聚帶）。<br />
# - 壓力：上方先看約48,600點（近期高點區），若帶量突破，下一道壓力約49,000點整數關卡。<br />
# <br />
#  KD 指標解讀<br />
# KD位於高檔區，且K線已出現回落、D線仍在高位，顯示短線動能有降溫跡象，較可能進入高檔震盪而非直接加速上攻。由於仍在偏強區間，KD不宜單獨視為反轉訊號，需搭配價格是否跌破支撐與MACD動能是否轉弱確認。<br />
# <br />
#  MACD 指標解讀<br />
# DIF位於MACD線之上且持續上行，柱狀體維持正值並擴大，代表多方動能仍在增強。目前未見明顯空方背離訊號，偏向「趨勢續強、短線可能震盪整理」的結構。<br />
# <br />
#  綜合評價<br />
# 整體仍屬多頭趨勢延續，均線多頭排列與MACD動能偏強提供支撐，但KD高檔鈍化顯示短線追價風險上升、較可能以高檔整理消化漲幅。操作上可關注47,800點支撐得失作為多空分界，守穩偏多看待；若跌破並擴量，則需提防回檔加深。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# * 櫃買指數

# %% [markdown]
# > **開盤**：櫃買指數支撐也還算穩定。
# > ![messageImage_1790211687400.jpg](attachment:db4f4649-caad-4301-8c0b-70f4bd3635fa.jpg)

# %% [markdown]
# > **盤後**：量化技術分析

# %%
# 盤後：櫃買指數解盤
stock_analysis(analysis,'TPEx')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-09-21 , 2026-09-23 , 2026-09-24<br />
# 十字線 : 2026-09-21 , 2026-09-22 , 2026-09-24<br />
# 鎚子線／吊人線 : 2026-09-24</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為中位階<br />
# 長期為高位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 1948.57億元 ，十日均量 ＝ 2178.63億元）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>反轉型態之上升楔形，型態範圍由2026-07-30開始到2026-09-23結束。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線下彎，中期盤整；120日線上揚、240日線上揚，長期翻多</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-09-24死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-08-03當週黃金交叉。並且2026-09-14該週在超買區。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 目前屬於盤整偏多：價格自前波低點反彈後維持高檔震盪，近期多數時間守在中期均線之上。短期均線略有走平並出現貼近價格的狀態，顯示上攻動能仍在但進入整理。<br />
# <br />
#  價量關係<br />
# 近期上攻至高檔時成交量有放大，但隨後回到整理時量能縮減，呈現「放量推升、縮量整理」的結構。最新一段回檔量能未明顯失控，偏向健康換手而非恐慌性出貨。<br />
# <br />
#  支撐與壓力<br />
# 上方主要壓力落在前高區附近，約422點一帶，若量能無法延續，容易在此遇到賣壓。下方支撐先看短期均線與近期整理區，約413點附近；再下來關鍵支撐為近期低點區約411點，跌破則整理格局轉弱。<br />
# <br />
#  KD 指標解讀<br />
# KD先前進入超買區後回落，目前仍位於相對高檔，顯示短線追價力道降溫、以高檔震盪為主。現階段KD較偏向「整理訊號」，不宜單獨視為趨勢反轉依據，需搭配價格是否守住支撐與動能變化確認。<br />
# <br />
#  MACD 指標解讀<br />
# DIF維持在MACD線之上且兩者同步上行，柱狀體仍為正值，代表多方動能延續。惟柱狀體高檔略有收斂，顯示上攻力道有降溫跡象，短線較可能以震盪消化為主而非一路急拉。<br />
# <br />
#  綜合評價<br />
# 整體仍偏多方架構，但短線處於高檔整理，操作上以「守支撐、看量能再攻」較有利。若能帶量突破422點，多方可望延伸；反之若跌破411點且動能轉弱，則需提防整理轉為較深的回檔。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### 個股篩選

# %% [markdown]
# * 選股程序

# %%
results = analysis.screener()

# %%
for stock_info in results :
    print('股票代碼 ＝ {} ， 股票名稱 ＝ {} '.format(stock_info[0],stock_info[1]))
# Out:
# 股票代碼 ＝ 2241 ， 股票名稱 ＝ 艾姆勒
# 股票代碼 ＝ 6205 ， 股票名稱 ＝ 詮欣
# 股票代碼 ＝ 6234 ， 股票名稱 ＝ 高僑
# 股票代碼 ＝ 6456 ， 股票名稱 ＝ GIS-KY
# 股票代碼 ＝ 6122 ， 股票名稱 ＝ 擎邦
# 股票代碼 ＝ 8040 ， 股票名稱 ＝ 九暘
# 股票代碼 ＝ 2436 ， 股票名稱 ＝ 偉詮電
# 股票代碼 ＝ 2342 ， 股票名稱 ＝ 茂矽
# 股票代碼 ＝ 3552 ， 股票名稱 ＝ 同致

# %% [markdown]
# * 篩選結果
#   - 茂矽(2342)：穩健續漲
#     ![260924_2.png](attachment:1fd0aafc-5872-4378-bcf9-541aa297322a.png)
#   - 艾姆勒(2241)：已到壓力區
#     ![260924_3.png](attachment:90d6f92b-fc87-474a-984c-9a52f2b3c4f0.png)
#   - 九暘(8040)：穩健續漲
#     ![260924_4.png](attachment:33202fd4-4852-409c-8d50-4fcb31a89079.png)
#   - 詮欣(6205)：技術突破
#     ![260924_5.png](attachment:261d951b-f327-4c35-bd36-ca393deb4f1e.png)
#   - 潤泰新(9945)：盤整觀察
#     ![260924_6.png](attachment:57ff3202-e393-46df-a17f-02036126ddc0.png)

# %% [markdown]
# * 觀察股列表
#   ![260924_1.png](attachment:d7f57069-0085-4770-914e-46e6a9464a82.png)

# %% [markdown]
# ### 個股解盤

# %% [markdown]
# * 位速(3508)
#   看法：回測頸線後的反彈。

# %% [markdown]
# > **盤後**：量化技術分析

# %%
stock_analysis(analysis,'3508')
# Out:
# 解盤內容：
# <PIL.Image.Image image mode=RGB size=819x479>
# <table>
# <thead>
# <tr>
# <th colspan="1" rowspan="1">
# <p>技術分析工具</p>
# </th>
# <th colspan="1" rowspan="1">
# <p>解盤內容</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線／Ｋ棒<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>紡錘線 : 2026-09-22<br />
# 高檔夜星 : 2026-09-23</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>Ｋ線圖<br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>中期為高位階<br />
# 長期為中位階</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>成交量</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價量關係：成交量小於十日均量（成交量 ＝ 625張 ，十日均量 ＝ 646張）</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>型態</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>底型反轉之底部型態，型態範圍由2026-05-04開始到2026-08-19結束，2026-09-22時已達估算之目標價（26.84元）。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>移動平均線</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>5日線上揚、10日線上揚，短期翻多；20日線上揚、60日線上揚，中期翻多；120日線下彎、240日線上揚，長期盤整</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-09-23死亡交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>ＭＡＣＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>MACD雙線在零軸以上，中期多方</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>週Ｋ－週ＫＤ指標</p>
# </td>
# <td colspan="1" rowspan="1">
# <p>於2026-09-14當週黃金交叉。</p>
# </td>
# </tr>
# <tr>
# <td colspan="1" rowspan="1">
# <p>整體評價<br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# <br />
# </p>
# </td>
# <td colspan="1" rowspan="1">
# <p>價格趨勢<br />
# 整體仍屬上漲趨勢，近期自低檔一路墊高並推升至前波高點附近，雖有拉回但收盤仍維持在相對高檔。短線出現較大幅度震盪，屬多頭趨勢中的高檔整理與回檔交錯。<br />
# <br />
#  價量關係<br />
# 上漲段曾出現量能明顯放大配合推升，顯示追價動能曾集中；但近兩日成交量縮至相對低檔，屬價漲量縮/高檔量縮型態。此結構代表多頭仍在，但短線續攻需要量能回補，否則容易轉為區間震盪。<br />
# <br />
#  支撐與壓力<br />
# - 支撐：先看約25.5元（短期均線附近）與約24.9元（近一日回檔收盤區），跌破則支撐下移至約23.6元（次短期均線附近）。<br />
# - 壓力：上方先看約27.1～27.7元（近期高點區），若帶量突破，才有機會打開續漲空間；若無量上攻，容易在此區反覆震盪。<br />
# <br />
#  KD 指標解讀<br />
# KD位於高檔區後回落，K線已下彎且低於D線，顯示短線動能降溫、偏向整理與回檔壓力。由於仍在相對高檔區，KD不宜單獨視為反轉訊號，需搭配價格是否守住支撐與MACD動能續強與否。<br />
# <br />
#  MACD 指標解讀<br />
# DIF維持在MACD線之上且兩者仍向上，柱狀體維持正值並未明顯縮減，代表中短線多頭動能仍在。不過價格在高檔震盪、量能轉弱下，後續若柱狀體開始連續縮短，將是動能轉弱的早期警訊。<br />
# <br />
#  綜合評價<br />
# 目前屬多頭趨勢延續，但短線高檔震盪偏整理：均線呈多頭排列、MACD動能仍偏強，但KD高檔轉弱且量能降溫，使短線追價風險上升。操作上以守住25.5元～24.9元支撐作為多頭續航關鍵，若能帶量突破27.1～27.7元壓力，多頭才有機會再走一段；反之跌破支撐則回檔幅度可能擴大。</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# > **盤後**：底部反轉交易策略分析

# %%
def line_drawing_callback( range_prices) :
    # 設定頸線
    neckline_start_date  = '2026-03-31'
    neckline_end_date    = range_prices.iloc[-1].name.strftime("%Y-%m-%d")
    neckline_x           = [mysys.DateToIndex(range_prices,'2026-04-23'),mysys.DateToIndex(range_prices,'2026-08-24')]
    neckline_y           = [range_prices.loc['2026-04-23']['Open'],range_prices.loc['2026-08-24']['Open']]
    slope,intercept      = np.polyfit(neckline_x,neckline_y,1)
    neckline_start_price = slope * mysys.DateToIndex(range_prices,neckline_start_date) + intercept
    neckline_end_price   = slope * mysys.DateToIndex(range_prices,neckline_end_date) + intercept

    # 設定底部日期與價格
    bottom_date           = '2026-07-29'
    bottom_price          = range_prices.loc['2026-07-29']['Open']
    neckline_bottom_price = slope * mysys.DateToIndex(range_prices,bottom_date) + intercept

    # 設定突破日期
    breakout_date           = '2026-09-21'
    neckline_breakout_price = slope * mysys.DateToIndex(range_prices,breakout_date) + intercept

     # 估算目標價
    target_price = (neckline_breakout_price - bottom_price) + neckline_breakout_price
    print('估算目標價為{:.2f}元'.format(target_price))
    
    seq_of_seq_of_points=[
        [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
        [(bottom_date,bottom_price),(bottom_date,neckline_bottom_price)],
        [(breakout_date,neckline_breakout_price),(breakout_date,target_price)]
    ]

    linewidths=[2.0,15.0,15.0]
    
    colors=['xkcd:orange yellow','xkcd:orange yellow','xkcd:orange yellow']
    
    return seq_of_seq_of_points,linewidths,colors

# %%
image = mysys.DrawOnKlineChart('3508','2026-01-19','2026-09-24',line_drawing_callback)
display(image)
# Out:
# 估算目標價為33.43元
# <PIL.Image.Image image mode=RGB size=857x479>

# %% [markdown]
# 籌碼面：
# 法人大賣(-112)：外資大賣(-112)、投信中立(0)、自營中立(0)。
# 主力小買(+25)。
# 分公司買賣家數差分散(-10)。
# 融資中立(0)、融券中立(0)。
