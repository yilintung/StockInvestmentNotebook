# %% [markdown]
# ### 📢【[K線捕手](https://www.facebook.com/kevinyang20180801/)盤前快訊】乖離過大，醞釀反彈⚠️
# 📊 台股急跌後，反彈契機浮現？
# 台股近期震盪劇烈，自上周三轉弱後，週四小跌、週五大跌，昨日更是急挫906點，成交量放大至4372億，同時負乖離高達6.63%，伴隨融資大減。綜合來看，這些條件確實提供了短線反彈的可能性。
# 因此昨天盤中曾提醒數位訂閱群組曾提醒：「有做空的投資人可以部份回補獲利了結。如果是做多一路凹單到現在，都沒減碼，就先不要動了，等一下反彈，但也不要再加碼。」
# 🔹 夜盤期指上漲324點，止跌訊號？
# 昨日夜盤期指回升324點，台股今日有望止穩。但短短四天下跌超過1500點，出現324點的反彈，仍無法確認回升。須留意，回升是指趨勢翻多、創新高，而反彈往往只是短暫回升。
# 📉 國際股市、技術面仍未翻多
# 從國際股市、台幣走勢、十大權值股、類股結構、籌碼面、技術面來看，尚未出現明確止跌訊號。技術面多方架構破壞嚴重，短線壓力區可關注藍色區域，支撐則在紅色區域。
# 📌 短線整理，仍需留意風險
# 短期內，台股可能在該區間進行整理。但若無法改善上述因素，反彈後仍須提防持續下跌的風險。
# 📢 搶反彈適合哪些投資人？
# ✅ 適合： 持股比重低甚至空手，且具備短線交易能力的投資者
# ❌ 不適合： 已經套牢較多股票者，此時進場只是攤平，恐讓資金進一步受困。
# ⚠️ 特別提醒：本週僅交易至週三，接下來將迎來四天連假，需留意市場空窗期的風險！
# 📢 完整深度解析，請見「K線追擊周報」數位訂閱！
# 📢 歡迎分享，請註明出處：K線捕手 楊忠憲粉絲團 🔥
# ![487495897_1237734545027137_4288569673681518839_n.jpg](attachment:80e23655-d832-47cf-99a4-ff50f4007392.jpg)

# %% [markdown]
# [解放日倒數！VIX恐慌指數飆升逾12％ 全球股匯大跳水](https://www.ctee.com.tw/news/20250401700037-430201?fbclid=IwY2xjawJYIDZleHRuA2FlbQIxMAABHRn3EiqA0l8ji9iyM14jSn7FpyAgN213o0K2h8PcfuRqVz7cc-3WoxDQ6g_aem_PbI65jQtkMp1tMmzYeHzKA)
# 在美國總統川普揚言的4月2日「解放日」前夕，因對等關稅措施反覆不定及通膨預期狂飆，引爆恐慌性賣壓，擊倒全球股市。日經指數3月31日狂瀉逾1,500點或逾4％，陷入修正，亞歐股市同樣暴跌。投資人快閃湧入避風港，金價衝破每盎司3,100美元，日圓聞訊勁升，美元承壓。10年期美債殖利率31日降至4.19％，較1月高點已減少60基本點。VIX恐慌指數飆升逾12％。
# 台股匯市3月31日同步重挫，外資倒貨與內資狂殺融資兩相夾擊，台股重挫906點收20,695點，跌破21,000點關卡，3月月線大跌10.23％為全球主要股市第一；外資3月累計賣超高達4,656億元，創歷史最大單月賣超金額，導致台股3月市櫃合計市值蒸發高達8.3兆元。
#
# [融資維持率大降 台股離底部已經不遠了？法人提後市4觀點](https://www.ctee.com.tw/news/20250401700055-430201?fbclid=IwY2xjawJYIGRleHRuA2FlbQIxMAABHc4AI6kYd080OQw-NtmG1lv1KTlCj55GalnzYqJwZ19z1y7Cik3hrJ_3Yg_aem_nVm4TikRVNR_eSernwxfKg)
# 川普關稅戰一波未起一波又來，加上清明連假即將來到，市場賣盤傾巢而出，依規定，融資維持率在130％以下將遭到授信機構追繳擔保品，台股連日重挫，包括被斷及自行了斷的融資浮額大舉出籠，不過，若指數不止跌，融資斷頭賣壓未止。
# 據統計，融資維持率掉到130％以下的上市櫃股共266檔，而140％以下則更有599檔，包括力旺、緯穎、嘉澤、創意、健策、穎崴、AES-KY等昔日千金股或目前仍強守千元股均入列，以及400元俱樂部的保瑞、M31、富世達、譜瑞-KY、達發、雙鴻、藥華藥、奇鋐、華城、光聖等，融資大殺盤，是高價股全面重挫的元兇。
#
# [不只市值蒸發8.3兆！台股慘寫這些黑歷史 專家估此時利空出盡迎轉機](https://www.ctee.com.tw/news/20250401700058-430201?fbclid=IwY2xjawJYIJpleHRuA2FlbQIxMAABHWY6SFt0uCRmULxmiWekPiijhxfd6o6SBwcKOQsRngs79elOURKdivnnTg_aem_oI0Lh9v1AH5Hf5EPTqReIw)
# 台股面對川普關稅來襲、美通膨數據上升使降息預期減緩，及AI泡沫化疑慮等因素，加權指數31日大跌906點、收20,695點，導致3月台股封關收大長黑棒、月跌2,357點或跌幅10.23％，成為全球主要股市最慘市場；3月的台股也在外資高達4,656億元的賣超空襲下，寫下六大黑歷史紀錄。惟法人喊話，台股4月中可望利空出盡，迎接谷底翻身轉機。
#
# [美股收盤／標普500上演大逆轉翻紅 那指僅小跌 金融能源撐盤](https://money.udn.com/money/story/122698/8645182?from=edn_subcatelist_cate&fbclid=IwY2xjawJYIMZleHRuA2FlbQIxMAABHRESVFnjHxXjNpV7OaVYnUbYxNws5wQ7uY9tFCcsu3s6VbeAVZikuvLTug_aem_WG8qwY9ztUU5aJNu92hwdQ)
# 美股周一（3月31日）盤中劇烈震盪，盤初挫低但一路回升，上演驚人逆轉，終場收紅，投資人轉向高股息股票以及進行投資組合再平衡，暫時蓋過了川普4月2日宣布關稅引發的擔憂。
# 標普500指數31日收盤上漲30.91點，漲幅0.55%，報5,611.85點；道瓊工業指數上漲417.86點，漲幅1%，報42,001.76點。那斯達克指數下跌23.70點，跌幅0.14%，至17,299.29 點。
#
# [聯電ADR狂飆逾9% 傳格芯擬提合併 台積電ADR翻紅小漲](https://money.udn.com/money/story/123398/8645190?from=edn_newestlist_cate_side&fbclid=IwY2xjawJYIPVleHRuA2FlbQIxMAABHcuyVwfyIb1CXunFRjNMrW8WU1hmGtAel3GhY_5-9On9YUvnJI2pfyDQIA_aem_Vfu1botBids3GMlmqrKOww)
# 台股ADR周一（3月31日）多數呈現小漲小跌，主要是美股大盤在盤初重挫後上演大逆轉，終場翻紅。聯電ADR價格狂飆超過9%，至7.15美元，換算並折合台幣後為每股47.47元，較台北交易股票溢價率達6.32%，原因是日經新聞報導，全球第五大晶圓代工廠格芯 （GlobalFoundries）考慮與聯電合併，成為全球第二大晶圓代工廠。
#
# [《台北股市》盤中焦點股：福懋油、漢翔、新光金、全譜、大立光](https://tw.stock.yahoo.com/news/%E5%8F%B0%E5%8C%97%E8%82%A1%E5%B8%82-%E7%9B%A4%E4%B8%AD%E7%84%A6%E9%BB%9E%E8%82%A1-%E7%A6%8F%E6%87%8B%E6%B2%B9-%E6%BC%A2%E7%BF%94-%E6%96%B0%E5%85%89%E9%87%91-020644932.html)

# %% [markdown]
# 期貨上漲超過200點：
# ![messageImage_1743468363679.jpg](attachment:dcd8a561-81c1-4734-902e-98e0832ea161.jpg)
#
# 加權指數反彈，在支撐和壓力區間：
# ![messageImage_1743469313514.jpg](attachment:44a82c63-972d-44d7-923b-b1d62394d1d6.jpg)
#
# 目前預估量在10日均量之下，所以還是反彈量喔！
#
# 台幣短中長期持續趨貶：
# ![messageImage_1743470876983.jpg](attachment:671916da-fd24-4c35-84e0-3c9a37fcbb8b.jpg)
#
# 今天指數越漲量越縮，留意等一下可能會壓回喔！

# %% [markdown]
# 【[關鍵低點解析：紅色上升趨勢線的意義與破位影響](https://www.facebook.com/kevinyang20180801/posts/pfbid033caDqQnXuJsKAA6KEaGa8NtDpJrpj5cfp21Crg6pfAdE66fq7zkehUZqqS6rDtQKl)】
# 明天[數位訂閱](https://smart.businessweekly.com.tw/e-subscription/channel?c=GROUP00014146&fbclid=IwY2xjawJYITxleHRuA2FlbQIxMAABHWY6SFt0uCRmULxmiWekPiijhxfd6o6SBwcKOQsRngs79elOURKdivnnTg_aem_oI0Lh9v1AH5Hf5EPTqReIw)週三專題教學，來跟大家聊聊，為什麼昨天低點這麼重要？紅色上升趨勢線的意義？還有萬一跌破了，會發生甚麼事情？
# ![487462095_1237750598358865_3618721648994639097_n.jpg](attachment:bfbb2974-63d1-4b1d-b14a-6d9d01102c63.jpg)
#
# [📉 中期空頭來襲，你還能做這件事！](https://www.facebook.com/kevinyang20180801/posts/pfbid02gq7RZtjzsv84sy2jGQshzoVpqw71cNXXSHxSCNsjsJnk1sgPYBGWiRMYgfru9Zrpl)
# 當市場趨勢走空時，許多人可能會選擇觀望，甚至感到焦慮。但其實，這正是一個檢視自身交易策略的絕佳時機！
# 🔍 回顧你的交易紀錄
# 在這種時候，我習慣回顧過去曾經操作過的個股，假設當初沒有賣出，看看現在的結果會如何？這樣做的目的有兩個：
# ✅ 確認自己的判斷是否準確。
# ✅ 強化紀律，下次遇到停損訊號時，更果斷執行。
# 我近期回測了過去兩個月內操作的11檔個股，結果不意外：
# 9檔大幅修正，如果當初沒賣，現在應該虧損慘重。
# 1檔持平，影響不大。
# 1檔逆勢上漲，甚至超過當時賣出的價格。
# 結論？賣出的策略沒有錯！ 這也再次驗證了紀律操作的重要性。📊
# 🛠 你可以這樣做：
# 打開你的交易紀錄，選擇幾檔曾經操作過的個股。
# 假設當初沒有賣出，現在的獲利或虧損如何？
# 思考：當時的決策是否正確？有沒有可以優化的地方？
# 🎯 交易樣本數的重要性
# 有些投資人一年內只交易3檔股票，這樣的數據樣本過少，無法判斷究竟是運氣好，還是真正具備交易實力。
# 但如果假設你一年內有 30筆以上的交易，結果如下：
# 📈 22檔獲利
# ➖ 2檔持平
# 📉 6檔虧損
# 那麼你的交易系統應該是值得信賴的！🎯
# 📢 現在就行動！
# 利用這次市場回檔的機會，回顧並優化你的交易策略，讓自己在下一次的行情來臨時，能夠更加從容應對！🚀
#
# [上上星期說的](https://www.facebook.com/kevinyang20180801/posts/pfbid0zPH9o4KDBJR5T1U9dWGAiihQ6WcYsTEA3EXWPKXKjzHNtswdiYw9JsQhZd7Txhb2l)，前輩有交代，下墜的刀子真的不要亂接。
# 低檔、紅K、爆量，只代表有人想接，不代表接得住，解盤不能只看一天漲跌，要看趨勢、位階、型態，支撐、壓力、轉折。
# ![487406442_1237815871685671_519841984808797834_n.jpg](attachment:1659ceda-85b9-46b8-b623-3f608c3fb673.jpg)

# %% [markdown]
# ### 本日進度
# * 量化技術分析系統
#   - 調整StockChartPatterns類別程序
#     * 將「型態識別（使用ＧＰＴ－４ｏ多模態模型）方法」改用[昨日](https://github.com/yilintung/StockInvestmentNotebook/blob/main/250331%E7%AD%86%E8%A8%98.ipynb)程序。將型態識別結果輸出由*文字*改為**JSON格式**，以達成「量化」目的。
#     * 方法名稱調整：RecognitionUsingGPT → RecognitionUsingGPT4o 。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import mplfinance as mpf
import numpy as np
import myutils

# %%
def date_to_index(df_in,date_in) :
    number_array = df_in.index == date_in
    idx = 0
    for number_index in number_array :
        if number_index == True :
            break
        idx = idx + 1
    return idx

# %%
# 型態視覺化
def patterns_visualization(prices,patterns) :
    for pattern_name in patterns:
        # 顯示型態名稱
        print('＃＃＃ {} ＃＃＃'.format(pattern_name))
        for pattern in patterns[pattern_name] :
            
            # 顯示型態轉折點參數
            print('☆ 轉折點參數 ＝ {} \n★ 型態資訊 ＝ \n {} '.format(pattern['argument'],pattern['window']))
            
            # 視覺化型態
            pattern_window = pattern['window']
            
            seq_of_seq_of_points = []
            if pattern_name == '雙重頂' or pattern_name == '雙重底':
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
            
                neckline_start_date  = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date    = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_start_price = pattern_window.iloc[2]['Price']
                neckline_end_price   = pattern_window.iloc[2]['Price']
        
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '三重頂' or pattern_name == '三重底' or pattern_name == '頭肩頂' or pattern_name == '頭肩底' :
                pattern_first_date_idx  = pattern_window.iloc[0].name
                pattern_start_date_idx  = pattern_window.iloc[1].name
                neckline_start_date_idx = pattern_start_date_idx - ((pattern_start_date_idx - pattern_first_date_idx) // 2) 
                neckline_end_date_idx   = ((pattern_start_date_idx - pattern_first_date_idx) // 2) + pattern_window.iloc[-1].name
                neckline_end_date_idx   = neckline_end_date_idx if neckline_end_date_idx < prices.shape[0] else pattern_window.iloc[-1].name
        
                neckline_start_date = prices.iloc[neckline_start_date_idx].name.strftime("%Y-%m-%d")
                neckline_end_date   = prices.iloc[neckline_end_date_idx].name.strftime("%Y-%m-%d")
                neckline_x = [date_to_index(prices,pattern_window.iloc[2]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                neckline_y = [pattern_window.iloc[2]['Price'],pattern_window.iloc[4]['Price']]
                neckline_slope,neckline_intercept = np.polyfit(neckline_x,neckline_y,1)
                neckline_start_price = neckline_slope * date_to_index(prices,neckline_start_date) + neckline_intercept
                neckline_end_price   = neckline_slope * date_to_index(prices,neckline_end_date) + neckline_intercept
                
                # 設定頸線
                seq_of_seq_of_points=[[(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)]]
            elif pattern_name == '矩形' :
                # NOTE : 後處理
                rect_upper_edge =  max(pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price'])
                rect_lower_edge =  min(pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price'])

                line1_start_date  = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date    = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_start_price = rect_upper_edge
                line1_end_price   = rect_upper_edge

                line2_start_date  = line1_start_date
                line2_end_date    = line1_end_date
                line2_start_price = rect_lower_edge
                line2_end_price   = rect_lower_edge
                
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            elif pattern_name == '三角形' : 
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[4]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[4]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            else :
                line1_start_date = pattern_window.iloc[0]['Date'].strftime("%Y-%m-%d")
                line1_end_date   = pattern_window.iloc[-1]['Date'].strftime("%Y-%m-%d")
                line1_x = [date_to_index(prices,pattern_window.iloc[0]['Date']),date_to_index(prices,pattern_window.iloc[2]['Date'])]
                line1_y = [pattern_window.iloc[0]['Price'],pattern_window.iloc[2]['Price']]
                line1_slope,line1_intercept = np.polyfit(line1_x,line1_y,1)
                line1_start_price = line1_slope * date_to_index(prices,line1_start_date) + line1_intercept
                line1_end_price   = line1_slope * date_to_index(prices,line1_end_date) + line1_intercept
            
                line2_start_date = line1_start_date
                line2_end_date = line1_end_date
                line2_x = [date_to_index(prices,pattern_window.iloc[1]['Date']),date_to_index(prices,pattern_window.iloc[3]['Date'])]
                line2_y = [pattern_window.iloc[1]['Price'],pattern_window.iloc[3]['Price']]
                line2_slope,line2_intercept = np.polyfit(line2_x,line2_y,1)
                line2_start_price = line2_slope * date_to_index(prices,line2_start_date) + line2_intercept
                line2_end_price   = line2_slope * date_to_index(prices,line2_end_date) + line2_intercept
            
                # 設定趨勢線
                seq_of_seq_of_points=[
                    [(line1_start_date,line1_start_price),(line1_end_date,line1_end_price)],
                    [(line2_start_date,line2_start_price),(line2_end_date,line2_end_price)],
                ]
            
            # 設定K線格式
            mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
            s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)
            
            # 設定轉折點
            turning_points_len = len(np.array(prices['Close']))
            turning_points = np.array([np.nan]*turning_points_len)
            for point in pattern_window.iterrows() :
                turning_points[point[0]] = point[1]['Price']
            apds = [mpf.make_addplot(turning_points,type='scatter',marker='o',markersize=25,color='xkcd:sky blue')]
            
            # 繪製K線圖
            kwargs = dict(type='candle', style=s, figratio=(19,10), volume=True, addplot=apds, alines=dict(alines=seq_of_seq_of_points, linewidths=2, colors='xkcd:orange yellow', alpha=0.6), datetime_format='%Y-%m-%d', warn_too_much_data=2000)
            mpf.plot(prices,**kwargs)

# %%
##### 使用2024年7月31日到今日(2025年3月31日)收盤之日線圖資料 #####

# 載入從「好神通PLUS」輸出的Excel檔
df = pd.read_excel('./data/SINO_TSE_250331.xlsx')

# 保存K棒的基本資訊(開、高、低、收、量)
df_k_line = df.drop(columns=['SMA5','SMA10','SMA20','SMA60','SMA120','SMA240','MA5','MA10'])

# 保存價的均線
df_sma = df.drop(columns=['開盤價','最高價','最低價','收盤價','成交量','MA5','MA10']) 

# 將K棒的Columns的名稱由中文改為英文
df_k_line = df_k_line.rename(columns={'時間':'Date','開盤價':'Open','最高價':'High','最低價':'Low','收盤價':'Close','成交量':'Volume'})

# 將價的均線的Columns的名稱由中文改為英文
df_sma = df_sma.rename(columns={'時間':'Date'})

# 將K棒的Date設為Index
df_k_line.set_index(df_k_line['Date'],inplace=True)
df_k_line = df_k_line.drop(columns=['Date'])

# 將價的均線的Date設為Index
df_sma.set_index(df_sma['Date'],inplace=True)
df_sma = df_sma.drop(columns=['Date'])

# %%
### 基準：股票老師所繪製的線條 ###

# 設定K線格式
mc = mpf.make_marketcolors(up='xkcd:light red', down='xkcd:almost black', inherit=True)
s  = mpf.make_mpf_style(base_mpf_style='yahoo', marketcolors=mc)

# 設定頸線
neckline_start_date  = '2024-09-13'
neckline_end_date    = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
neckline_x           = [date_to_index(df_k_line,'2024-09-20'),date_to_index(df_k_line,'2024-11-28'),date_to_index(df_k_line,'2025-03-10')]
neckline_y           = [df_k_line.loc['2024-09-20']['Close'],df_k_line.loc['2024-11-28']['Close'],df_k_line.loc['2025-03-10']['Close']]
slope,intercept      = np.polyfit(neckline_x,neckline_y,1)
neckline_start_price = slope * date_to_index(df_k_line,neckline_start_date) + intercept
neckline_end_price   = slope * date_to_index(df_k_line,neckline_end_date) + intercept

# 設定狹幅盤整區間
line1_start_date = '2025-03-11'
line1_end_date   = df_k_line.iloc[-1].name.strftime("%Y-%m-%d")
line1_price      = df_k_line.loc['2025-03-13']['Open']
line2_start_date = line1_start_date
line2_end_date   = line1_end_date
line2_price      = df_k_line.loc['2025-03-19']['Close']

seq_of_seq_of_points=[
    [(neckline_start_date,neckline_start_price),(neckline_end_date,neckline_end_price)],
    [(line1_start_date,line1_price),(line1_end_date,line1_price)],
    [(line2_start_date,line2_price),(line2_end_date,line2_price)]
]

# 設定移動平均線
added_plots={
    "SMA5": mpf.make_addplot(df_sma['SMA5'],width=0.6,color='xkcd:maroon'),
    "SMA10": mpf.make_addplot(df_sma['SMA10'],width=0.6,color='xkcd:cyan'),
    "SMA20": mpf.make_addplot(df_sma['SMA20'],width=0.6,color='xkcd:violet'),
    "SMA60": mpf.make_addplot(df_sma['SMA60'],width=0.6,color='xkcd:salmon'),
    "SMA120": mpf.make_addplot(df_sma['SMA120'],width=0.6,color='xkcd:blue grey'),
    "SMA240": mpf.make_addplot(df_sma['SMA240'],width=0.6,color='xkcd:sky blue')
            }

# 繪製K線圖
kwargs = dict(type='candle', style=s, figratio=(19,10), addplot=list(added_plots.values()), alines=dict(alines=seq_of_seq_of_points, linewidths=(1.5,1.0,1.0), colors=('xkcd:red','xkcd:bright blue','xkcd:bright blue'), alpha=0.6), volume=True, datetime_format='%Y-%m-%d')
mpf.plot(df_k_line,**kwargs)

# %%
# 建立「股票技術型態識別」物件
chart_pattern = myutils.StockChartPatterns(df_k_line,debug=True)

# %%
# 進行型態識別
patterns = chart_pattern.Recognition(max_bars = 240,turning_point_args={'mode':'open_close', 'order':15})
patterns_visualization(df_k_line,patterns)
# Out:
# ＤＥＢＵＧ ： 轉折點引數列表 ＝ [{'mode': 'open_close', 'order': 15}]
# ＃＃＃ 上升楔型 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 3         2024-08-05  19830.88   LO
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# ＃＃＃ 矩形 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# 112       2025-01-13  22488.33   LO
# ＃＃＃ 三重頂 ＃＃＃
# ☆ 轉折點參數 ＝ {'mode': 'open_close', 'order': 15}
# ★ 型態資訊 ＝
#                  Date     Price Type
# DateIndex
# 3         2024-08-05  19830.88   LO
# 53        2024-10-18  23620.57   HI
# 82        2024-11-29  22202.28   LO
# 108       2025-01-07  23824.72   HI
# 112       2025-01-13  22488.33   LO
# 134       2025-02-21  23730.25   HI

# %%
# 進行型態識別(GPT-4o版)
result = chart_pattern.RecognitionUsingGPT4o()
print(result)
# Out:
# [{'type': 'Head and Shoulders', 'start': '2024-09-26', 'end': '2025-02-03'}, {'type': 'Double Top', 'start': '2024-10-29', 'end': '2024-12-25'}]
