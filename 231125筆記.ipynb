# %% [markdown]
# ### 【[周末影音解盤](https://www.facebook.com/watch/?v=367484785731429)】短多不變，留意轉折
# 櫃買指數本周續漲，但出現爆量上影線，未來多方是否有疑慮？
# 投信結束長達3個多月的買超，有沒有可能轉買為賣？
# 台幣強升後轉貶，未來走勢是多是空？
# 完整內容請參考影音解盤~

# %% [markdown]
# ### [【旗標科技 AIGC 系列活動 III】AI 投資分析—打造自己的股市顧問機器人](https://www.flag.com.tw/activity/edm/1121122/)
# * 資料下載 ： https://www.flag.com.tw/bk/t/f3933
#   ![S__67387404.jpg](attachment:88246989-b2af-4024-bc6a-46f0653231d9.jpg)
# * 課程大綱
#   - 投資一定要跟老師嗎？股票分析基礎
#   - 註冊OpenAI APIAPI：建構自己的聊天機器人
#   - 輕鬆取得股票資料：Python 套件、新聞爬蟲
#   - 讓AI 自動計算技術指標 資料視覺化
#   - (中場休息)
#   - AI股票趨勢分析機器人
#   - 實作應用：建構Line 機器人, 隨時隨地取用分析報告
#   - 年報解讀機器人
# * 股票分析的方法主要分成兩大派：
#   - 基本分析
#   - 技術分析
# * 應從多面向來審視投資決策
# * 串接 OpenAI API
# * **重要**：role 角色有三種 user system
# * 將文本拆解成 token ： https://platform.openai.com/tokenizer
# * 如果「reply in 繁體中文」出來還是簡體中文的話，代表GPT3的變差了
# * 會請 AI 幫我們計算『 任意』 的技術指標
#   - 用英文生成的程式碼比較穩定
#   - 讓AI依據使用者需求計算技術指標
#   - exce函式來執行AI生成的程式碼
